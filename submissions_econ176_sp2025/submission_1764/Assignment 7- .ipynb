# %% [markdown]
# # Linear Models and Neural Nets Lab (Econ 176 '25)
#
# This lab will guide you through a _modeling_ task, inspired by the I&RE module:
# + it's based on a widely-studied French third-party-liability dataset [here on Kaggle](https://www.kaggle.com/datasets/floser/french-motor-claims-datasets-fremtpl2freq)
# + this variation has seven features and is available from [OpenML](https://openml.org/). (It's also widely studied: Cited below.)
# + of the seven features, six are used as predictive features and one is the target (to be predicted from the other six)
# + the target (to be predicted) is the _number of claims filed_ &nbsp; ``claim_nb`` by an individual. We'll call these _claims_ or _incidents_.
# + the features are
#   + the ``year`` &nbsp;&nbsp; (there are only years 2018 and 2019)
#   + whether the driver lives in a ``town`` <font size="-1">``town == 1.0``</font> or in a more rural area <font size="-1">``town == 0.0``</font>
#   + the _driver's_ age (in years) &nbsp;&nbsp; ``driver_age``
#   + the car's _weight_ (in kg) &nbsp;&nbsp; ``car_weight``
#   + the car's engine _power_ (in hp) &nbsp;&nbsp; ``car_power``
#   + the _car's_ age (in years) &nbsp;&nbsp; ``car_age``
#
# <br>
#
# You'll model the
# The notebook will guide you through
# + loading the data and inspecting it, a bit
# + modeling the data with linear models (linear regression)

# %% [markdown]
# ## Loading and inspecting data
#
# &nbsp;&nbsp; <font color="Coral">there are two tasks here...</font>

# %%
# some of the libraries have warnings we want to ignore...
import warnings
warnings.filterwarnings("ignore")

# AI/ML libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml

# %matplotlib inline

# %% [markdown]
# These two cells grab and extract the data - one millon rows and seven features - from OpenML:

# %%
# Fetch the insurance-claim dataset from the OpenML repository  (an API call! :)
all = fetch_openml(data_id=45106, as_frame=True)

# %%
# Extract the pieces of the API result from the OpenML API call
df_all = all.data
df_all["claim_nb"] = all.target

print("Shape of full data:", df_all.shape)
df_all.head(15)    # print the first five rows of data
# Out:
# Shape of full data: (1000000, 7)
#       year  town  driver_age  car_weight  car_power  car_age  claim_nb
# 0   2018.0   1.0        51.0      1760.0      173.0      3.0       0.0
# 1   2019.0   1.0        41.0      1760.0      248.0      2.0       0.0
# 2   2018.0   1.0        25.0      1240.0      111.0      2.0       0.0
# 3   2019.0   0.0        40.0      1010.0       83.0      9.0       0.0
# 4   2018.0   0.0        43.0      2180.0      169.0      5.0       0.0
# 5   2018.0   1.0        45.0      1170.0      149.0      1.0       1.0
# 6   2019.0   0.0        72.0      1040.0       60.0      2.0       0.0
# 7   2018.0  -0.0        60.0      1060.0       66.0      2.0       0.0
# 8   2018.0   1.0        31.0      1400.0      118.0      0.0       0.0
# 9   2018.0   1.0        19.0      1310.0       78.0      0.0       0.0
# 10  2018.0   1.0        76.0      1140.0       89.0      4.0       0.0
# 11  2019.0   1.0        49.0      1060.0      106.0      7.0       0.0
# 12  2018.0   0.0        65.0      1670.0      173.0      1.0       0.0
# 13  2018.0   1.0        33.0      1010.0       97.0      6.0       0.0
# 14  2018.0   0.0        31.0      1490.0      146.0      1.0       0.0

# %% [markdown]
# Here are the brief descriptions of each of the features:
# + the first six are the features we will use to _make_ predictions
#   + the ``year`` &nbsp;&nbsp; (there are only years 2018 and 2019)
#   + whether the driver lives in a ``town`` <font size="-1">``town == 1.0``</font> or in a more rural area <font size="-1">``town == 0.0``</font>
#   + the _driver's_ age (in years) &nbsp;&nbsp; ``driver_age``
#   + the car's _weight_ (in kg) &nbsp;&nbsp; ``car_weight``
#   + the car's engine _power_ (in hp) &nbsp;&nbsp; ``car_power``
#   + the _car's_ age (in years) &nbsp;&nbsp; ``car_age``
# + the seventh <b><tt>claim_nb</tt></b>, the number of claims files during that year, is the target to _be predicted_

# %%
df_all.describe()
# Out:
#                  year            town      driver_age      car_weight  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean      2018.550270        0.600130       45.998782     1308.266530
# std          0.497467        0.489872       13.997827      285.505998
# min       2018.000000        0.000000       18.000000      950.000000
# 25%       2018.000000        0.000000       35.000000     1090.000000
# 50%       2019.000000        1.000000       45.000000     1240.000000
# 75%       2019.000000        1.000000       56.000000     1460.000000
# max       2019.000000        1.000000       88.000000     3120.000000
#
#             car_power         car_age        claim_nb
# count  1000000.000000  1000000.000000  1000000.000000
# mean       124.981766        4.156266        0.089334
# std         49.133293        3.545284        0.300652
# min         50.000000        0.000000        0.000000
# 25%         86.000000        1.000000        0.000000
# 50%        116.000000        3.000000        0.000000
# 75%        156.000000        6.000000        0.000000
# max        341.000000       23.000000        4.000000

# %% [markdown]
# #### <font color="Coral"><b>Task 1</b></font>
#
# With full encouragement to use the built-in Colab AI -- or another of your choice, create five specific visualizations and an additional one:
# + create a histogram of all the drivers' ages, and
# + a histogram of all the the cars' ages, and
# + a histogram of the claim numbers, `claim_nb`
# + create a scatter plot of how the car's age varies with the driver's age
# + create a scatter plot of how the `claim_nb` varies with the driver's age
# + <font color="Coral"><b>also</b></font>, create one more - different - scatter plot of your choice, using this data
#
# <br>
#
# <font color="DodgerBlue">Below for task 2, write a short reflection</font> on the results of these data-visualizations. One sentence on what you see in each is perfect.  <br> <font size="-1">(There's another cell below reminding you of this!)</font>

# %%
#
# It's easiest to make additional code cells...
#

# Collect different columns
year = df_all["year"]
town = df_all["town"]
age = df_all["driver_age"]
weight = df_all["car_weight"]
power = df_all["car_power"]
car_age = df_all["car_age"]
claim_nb = df_all["claim_nb"]

# %%
# Histogram of all drivers' ages
plt.hist(age, bins=100, edgecolor='black')
plt.title("Histogram Of Drivers' Ages")
plt.ylabel('Claim Number')
plt.xlabel('Driver Age')
plt.show()

# %%
# Histogram of all Cars ages
plt.hist(car_age, bins=100, edgecolor='black')
plt.title("Histogram Of Cars Ages")
plt.ylabel('Claim Number')
plt.xlabel('Car Age')
plt.show()

# %%
# Histogram of all claim numbers
plt.hist(claim_nb, bins=100, edgecolor='black')
plt.title("Histogram Of Crash or No Crash Claims")
plt.ylabel('Claim Number')
plt.xlabel('Crash/No Crash')
plt.show()

# %%
from scipy.stats import linregress
# Linear regression
slope, intercept, r_value, p_value, std_err = linregress(age, car_age)
line = slope * age + intercept

plt.plot(age, line, color='red', label=f'Fit: y={slope:.2f}x+{intercept:.2f}, $R^2$={r_value**2:.2f}')

#Scatter plot of cars age against drivers age
plt.scatter(age, car_age, edgecolors='black')
plt.title("Plot Of Cars Age Against Drivers Age")
plt.ylabel('Car Age')
plt.xlabel('Driver Age')
plt.show()

# %%
#Scatter plot of claim_nb against driver's age
plt.scatter(age, claim_nb, edgecolors='black')
plt.title("Plot Of Claim Number Against Drivers Age")
plt.ylabel('Claim Number')
plt.xlabel('Driver Age')
plt.show()

# %%
#Scatter plot of cars power against drivers age
plt.scatter(age, power, edgecolors='black')
plt.title("Plot Of Cars Power Against Drivers Age")
plt.ylabel('Car Power')
plt.xlabel('Driver Age')
plt.show()

# %% [markdown]
# #### <font color="Coral"><b>Task 2</b></font>
#
# <font color="DodgerBlue">Here, write a short reflection</font> -- a sentence or two for each of these is wonderful -- that describes the data-trends you see in the visualizations above.
#
# As a reminder, they were
# + histograms for the drivers' ages and the cars' ages and the claim numbers, `claim_nb`
# + a scatter plot of how the car's age varies with the driver's age
# + a scatter plot of how the `claim_nb` varies with the driver's age
# + <font color="Coral"><b>and</b></font>, one other - different - scatter plot that visualizes some of this data
#
# <br>
# <hr>
# <br>
#
# <b>Histogram of drivers' ages:</b> Based on the structure of the histogram, it appears to be a normal distribution with the average being around 38 to 42 years old. Which is something to be expected because at these ages and close to these ages, most people are working and need to commute. A funny thing is how we have more drivers on average with 80 years of age that those at 20 years old. Does this means old dirvers are better than young ones? Most likely....
#
# <b>Histogram of cars' afes:</b> The distribution is pretty sparse but the structure is similar to a normal distribution centered around 3 years old. Looks like most people are keeping up with the trend by staying within a 6 year car generation.
#
# <b>Histogram of claim_nb:</b> Spread over two values. Best thing I believe for an insurance company because most people claiming haven't been in a car crash so few expense coverage for them? It also might mean they have competent customers. Some REALLY GOOOOD drivers!!!
#
# <b>Scatterplots:</b> The data is sort of congested and that makes them a little bit less intuitive. We tried R<sup>2</sup> regression and we can only see an increasing trend showing that old peoople tend to opt for older cars which is much expected. However it is the other way around for claim_nb
#
# <b>Car power scatterplot:</b> We expected younger people to go for heavy tuned cars with lot of power but apparently everybody wants that across all driver's ages. The plot also looks like a pixelated brick wall in minecraft which we found funny. But like other scatterplots, it's still less intuitive due to clustered datapoints
#
#
#
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## Modeling
#
# You will build two models for the <b><tt>claim_nb</tt></b> target:
# + a **linear-regression** model &nbsp;&nbsp; <font size="-2">since the target is a "number of occurrences" over a span of time, we use a _Poisson_ model</font>
# + a **neural-network** model &nbsp;&nbsp;  <font size="-2">of the same sort</font>
#
# You'll experiment with
# + interpreting the models
# + then, building some "deeper" neural networks
# + seeing how the two modeling approaches differ in the relationships they can express

# %% [markdown]
# ### Part 1: &nbsp;&nbsp; Data splitting
#
# The dataset has a million rows.
# + For speed of training, we will use only 100,000 of them.
# + At the end, you'll try changing at least three model parameters. This is one of those options! 😃

# %%
# Let's make sure everything runs first... using only 100,000 rows (instead of 1,000,000)

df_all = df_all.sample(frac=1.0, random_state=42)  # This shuffles the 1,000,000-row dataset

NUMROWS = 100000
df = df_all.iloc[0:NUMROWS,:].copy()    # This uses only the first 100,000 rows (or NUMROWS rows) for speed...

# %%
# We split into 90% training data and 10% testing data

from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.1, random_state=30)
print("Shape of training data:", train.shape)
print("Shape of test data:", test.shape)
# Out:
# Shape of training data: (90000, 7)
# Shape of test data: (10000, 7)

# %%
# Define target name (y) and feature names (x)
y, x = df.columns[-1], list(df.columns[:-1])

print("The response name:", y)
print("The feature names:", x)
# Out:
# The response name: claim_nb
# The feature names: ['year', 'town', 'driver_age', 'car_weight', 'car_power', 'car_age']

# %% [markdown]
# ### Part 2: &nbsp; A (Generalized) Linear Model (GLM)
#
# Here, we build a linear-regression model of the data.
#
# We'll use [Glum](https://glum.readthedocs.io/en/latest/), a high-performance implementation in Python. <br> <font size="-2"><tt>glum</tt> stands for _generalized linear modeling" ... not sure about the <tt>u</tt></font>

# %% [markdown]
# In Colab, you are likely to need to install `glum` once:

# %%
# !pip install glum
# Out:
# Collecting glum
#   Downloading glum-3.1.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from glum) (1.4.2)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.11/dist-packages (from glum) (2.10.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from glum) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from glum) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.23 in /usr/local/lib/python3.11/dist-packages (from glum) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from glum) (1.14.1)
# Collecting formulaic>=0.6 (from glum)
#   Downloading formulaic-1.1.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting tabmat>=4.0.0 (from glum)
#   Downloading tabmat-4.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=0.6->glum)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.6->glum) (4.13.1)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.6->glum) (1.17.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->glum) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->glum) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->glum) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.23->glum) (3.6.0)
# Requirement already satisfied: narwhals in /usr/local/lib/python3.11/dist-packages (from tabmat>=4.0.0->glum) (1.33.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->glum) (1.17.0)
# Downloading glum-3.1.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 31.8 MB/s eta 0:00:00
# Downloading formulaic-1.1.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.7/115.7 kB 8.7 MB/s eta 0:00:00
# Downloading tabmat-4.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 67.1 MB/s eta 0:00:00
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Installing collected packages: interface-meta, formulaic, tabmat, glum
# Successfully installed formulaic-1.1.1 glum-3.1.2 interface-meta-1.3.0 tabmat-4.1.1

# %% [markdown]
# We can use that library to build a linear model:

# %%
#
# there's not much code to build our model!
#
from glum import GeneralizedLinearRegressor

glm_model = GeneralizedLinearRegressor(family="poisson", alpha=1e-6)
glm_model.fit(X=train[x], y=train[y])

print("Coefficients")
pd.Series(np.append(glm_model.intercept_, glm_model.coef_), index=["Intercept"] + x)
# Out:
# Coefficients
# Intercept     5.524484
# year         -0.004149
# town          0.350489
# driver_age   -0.003272
# car_weight   -0.000068
# car_power     0.004117
# car_age      -0.022168
# dtype: float64

# %% [markdown]
# We did it!  &nbsp;&nbsp; But what _is_ it?!

# %% [markdown]
# #### As an absolute model, this is <u>not</u> very useful!
#
# **Everyone** has a very high likelihood of NOT having an auto incident/filing a claim. <i>This is good!</i>
#
# This means _everyone's_ expected number of incidents is 0 &nbsp; (Well, very close to it.)

# %% [markdown]
# #### In comparing the ***relative*** impact of a feature, the model <u>is</u> useful.
#
# Here is a full description of the ***relative*** relationships expressed by those coefficients [(cite)](https://ademos.people.uic.edu/Chapter19.html#:~:text=Rather%20than%20odds%20ratios%20(which,variable%5D%20is%20%5Bcoefficient%5D.):
#
#
# > <font color="DodgerBlue">The expected log count for each unit increase/decrease (depending on the sign of the coefficient) in [outcome variable] given [predictor variable] is [coefficient].</font>
#
#
# Wow!  &nbsp;&nbsp; This needs some unpacking...
#
# <hr>
# <br>

# %% [markdown]
# <font size="+1" color="Blue">Interpreting</font> <font size="+1" > coefficients, part one: &nbsp;&nbsp; <tt><b>town</b></tt> example</font>
#
#
# In practice, it's more straightforward than this suggests:
#
# Suppose your coefficient for `town` is 0.36. &nbsp; <font size="-2">That was one of my test-run values.</font>
#
# This means that "one unit" of `town` increases the <u>log of the claim count</u> by 0.36.  <br> <i><font color="Blue">But log-counts aren't very intuitive!</font></i> &nbsp; Let's _undo_ the log:
#
#
# `exp(0.36)` is about `1.43` &nbsp;&nbsp;&nbsp; Let's see that this is true:

# %%
from math import exp
exp(0.36)
# Out:
# 1.4333294145603401

# %% [markdown]
# This means that "one unit" of `town` ***multiplies*** &nbsp; the frequency of incidents by 1.43
#
# Since `town` only has values 0 and 1, this means that
#
# **when `town` is 1, the likelihood of an incident is 1.43 times higher then when it's 0**
#
# <br>
#
# <font color="Coral"><b>Aha!</b></font>
#
# <br>
#
# This ***incident-rate ratio*** is really useful!
# + for assessing the threat of an event that is relatively rare and/or
# + the _value_ of small changes to an individual's particular situation.
#
# In theory, the multiplier can be used many times:

# %%
exp(0.360105)    # for each unit of "townness,"  we multiply the expected claims by 1.433:
# Out:
# 1.433479922050374

# %%
exp(0.360105) ** 2   # so, we multiply twice for _two_ units of "townness":
# Out:
# 2.054864686921546

# %% [markdown]
# This means, if `town == 2`, the expected claims for those individuals would be 2.05x higher:
# + because, as above, `1.433 ** 2 == 1.433*1.433 == 2.05`
#
# There _isn't_ such a value in the dataset...
# + ... but models will allow this kind of extrapolation. Be careful!

# %% [markdown]
# <font size="+1" color="Blue">Interpreting</font> <font size="+1"> coefficients, part two: &nbsp;&nbsp; <tt><b>driver_age</b></tt> example</font>
#
# Let's try an example where there are multiple values, for example, for <b><tt>driver_age</tt></b> :
# + My coefficient for <tt><b>driver_age</b></tt> was <tt>-0.003272</tt>
# + And <tt>exp(-0.003272) == 0.9967</tt> &nbsp;&nbsp; <font size="-2">Let's confirm:</font>

# %%
exp(-0.003272)    # for each year of driver_age, you multiply the expected claims by 0.9967:
# Out:
# 0.9967333471584426

# %% [markdown]
# This means that, for this model, the number of claims is multiplied by <tt>0.9967</tt> ***for each additional year of age***
#
# <br>
#
# What if an individual is fifteen years older?

# %%
0.9967 ** 15
# Out:
# 0.9516272593744175

# %% [markdown]
# the model expects the number of claims to be 95% with that "additional experience"
#
# <br>
#
# What if we compare the oldest (88) and youngest (18) in the dataset:

# %%
exp(-0.003272)**(88-18)
# Out:
# 0.7952967210000054

# %% [markdown]
# Which states that our octogenerians will make 0.79 the claims as our 18-year-olds.
#
# Taking the reciprocal, the model is saying that moving across the dataset's full age-span, from old to young, multiplies the number of claims by 1.25:

# %%
1/0.7952
# Out:
# 1.2575452716297786

# %% [markdown]
# There is definitely room for skepticism here! 😀
#
# But we've successfully interpreted the model coefficients!
#
# Next, try two of your own:

# %% [markdown]
# #### <font color="Coral"><b>Task 3</b></font> &nbsp; Two more model-interpretations:
#
# Following the approach of the two examples above, choose **two more** features from the coefficients and:
# + compute the _per-unit_ incident-rate multiplier for that feature
# + decide on a "reasonable" number of units (years, kg, hp, ...)
# + compute the incident-rate multiplier for _that many units_
# + find the "full span" of units in the dataset (it's printed above ...)
# + compute the incident-rate multiplier for _that full span_
# + and reflect on what this is saying about the incidents in this data.
#
# Specifically, share how well does these _match your intution_ about these factors for auto incidents/insurance claims? Reasonable? Skeptical? Other?
#
# <br>
# <hr>
# <br>
#
# Feel free to use this cell or new ones just below:
#
# <br>
# <br>

# %%
"""CLaims based on car age. The coefficient for this is: -0.022168"""
print('Based on car age:', exp(-0.022168))

"""Claims based on car power. The coefficient for this is: 0.004117"""
print('Based on car power:', exp(0.004117))
# Out:
# Based on car age: 0.9780759044958746
# Based on car power: 1.004125486486792

# %% [markdown]
# **This means that for this model, claims are multiplied by 0.987 for each added year of age for the car, and claims are multiplied by 1.004 for each added horsepower.**
#
# Since from the histograms we found that most people own 4 year old cars, what is the incident multiplier for this car age? What about an additional 50 horsepower?

# %%
print('Based on car age:', exp(-0.022168) ** 4)
print('Based on car power:', exp(0.004117) ** 50)
# Out:
# Based on car age: 0.9151456921393383
# Based on car power: 1.228568904837491

# %% [markdown]
# **The model expects the claims to be 91% with cars of average age of 4 years old and 123% for a car with a greater advantage of 50 hp**

# %%
"""With a minimum car age of as low as 0 years old and a higer age of 23 years old"""
print('Based on car age:', exp(-0.022168) ** (23-0))

"""With a minimum car power of  50 hp and a maximum of 341 hp"""
print('Based on car power:', exp(0.004117) ** (341-50))
# Out:
# Based on car age: 0.6005772517646187
# Based on car power: 3.3136390620763057

# %% [markdown]
# **People with really old cars as old as 23 years make 60% claims as people who have new cars which is sort of expected because people with old cars have less incentive to worry about fixing or even claiming over something that is too old. Howvever, it appears that the effect is more extreme for people with cars of more horsepower with claims as high as 331% probably because these cars are prone to accidents since they're too fast plus they are also more expensive exolaining why owners would make more claims since they don't want to bear too much cost in terms of repairs.**

# %%
"""With a minimum car age of as low as 0 years old and a higer age of 23 years old"""
print('Based on car age:', 1/(exp(-0.022168) ** (23-0)))

"""With a minimum car power of  50 hp and a maximum of 341 hp"""
print('Based on car power:', 1/(exp(0.004117) ** (341-50)))
# Out:
# Based on car age: 1.66506473074329
# Based on car power: 0.3017830189910322

# %% [markdown]
# **The model on multiplies by 1.6. We believe this means that the model assumes that claims do go up as cars get older which is to be expected. However, the multiplier for horsepower is low showing that faster cars feature lower claims than slower cars. This makes sense in some way given that these cars are usually under heavy contracts some of them requiring only owners to dirve them but no one else. This usually applies to 1000+ hp cars and might not be case for 341 hp cars but the reasoning can be linked.**

# %% [markdown]
# ### Part 3. &nbsp; **Automatic** model-interpretation
#
# A technique called SHAP, short for SHapley Additive exPlanation, is able to estimate the feature-by-feature effects of _any_ model.
#
# It _should_ be here already:

# %%
import shap

# %% [markdown]
# SHAP works by sampling the model at several points and then surveying the space around those points to see how the model is changing. It integrates all of this information in order to be able to compare the influence of all of the variables with the same units, known as SHAP values. They are again relative values, and they indicate how the target varies with changes to each feature -- in light of _all_ the features in the model.
#
# Linear models like the one above are already interpretable. However, other models - like neural nets - are much less so.
#
# To get started, let's run SHAP for our linear model:

# %%
import shap

# First, extract background data. This is the same for all models to interpret:
X_bg = train[x].sample(200, random_state=8366)    # grab 200 samples from our training data - 200 is a lot...

# Exploring the space...   This will take a while...
glm_explainer = shap.KernelExplainer(lambda x: np.log(glm_model.predict(x)), data=X_bg)     # Don't worry about the warnings!

# Then, we can choose any data to explain. We'll choose 1,000 rows randomly called X_explain
X_explain = train[x].sample(n=1000, random_state=937)
shap_glm = glm_explainer.shap_values(X_explain, nsamples=30) # there are 30 non-trivial subsets of 6 features
# Out:
# WARNING:shap:Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# Let's see one of the explained individuals:

# %%
X_explain[0:1]
# Out:
#           year  town  driver_age  car_weight  car_power  car_age
# 396019  2018.0   0.0        50.0      1290.0      119.0      1.0

# %% [markdown]
# and, let's see their SHAP values:

# %%
shap_glm[0:1]
# Out:
# array([[ 0.00213664, -0.18400681, -0.01735597,  0.00128275, -0.02764656,
#          0.06816579]])

# %% [markdown]
# Ok!
#
# These numbers are (the sign and) relative weight of each of this individual's **per-feature contributions** to their risk (their expected number of claims).
#
# For example, in this model,
# + their age makes a claim less likely
# + their car's age make a claim more likely
#
# Plus, the <tt><b>SHAPvalue</b></tt> units are commensurate:
# + the impact of the driver's age carries almost three times the weight of their car's age
#
# <br>
#
# Better to plot all of them. &nbsp; Let's do that next:

# %%
#
# A function to create all of the dependence plots among our features
#
def all_dep_plots(x, shap_values, X):
    """ Dependence plots for all features x. """
    fig, _ = plt.subplots(nrows=2, ncols=3, figsize=(10, 6), sharey=True)

    for i, ax in enumerate(fig.axes):
        xvar = x[i]
        shap.dependence_plot(
            xvar,
            shap_values,
            features=X,
            x_jitter=0.2 * (xvar in ("town", "year")),
            ymin=-0.5,
            ymax=1,
            ax=ax,
            show=False,
        )
        ax.set_title(xvar, fontdict={"size": 16})
        ax.set_ylabel("SHAP values" if i % 3 == 0 else "")
        ax.grid()
    plt.tight_layout()

print("The all_dep_plots function has been defined.")
print("Run the next cell to plot the features and their impacts")
# Out:
# The all_dep_plots function has been defined.
# Run the next cell to plot the features and their impacts

# %%
all_dep_plots(x, shap_glm, X_explain)

# %% [markdown]
# #### <font color="Coral"><b>Task 4</b></font> &nbsp; How did SHAP do?
#
# In Task 3, you chose two features and examined their effects on the target value, the number of incidents.
#
# Here, revisit those two features, and in a couple of sentences, describe whether the effects you measured match the plots above.
#
# <br>
#
# **Note/Hints**  There are lots of dimensions here! And lots of information! The x-axis of each plot shows the feature values. The y-axis is the SHAP value (the relative impact on the number of claims).
#
# The red/blue coloring of datapoints shows how the _most influential **other** feature_ overlays onto the current plot. That **other** feature is the most influential for the one labeled on the x-axis, and so it will often be different for different plots.
#
# <br>
#
# As an example of this feature-comparison, remember that one <tt><b>town</b></tt> unit multiplied the claims by 1.4, and the full span of <tt><b>driver_age</b></tt> multiplied the claims by 1.25.
#
# This matches well!  In the above plot, the span for <tt><b>town</b></tt> is a little bit larger than the span for <tt><b>driver_age</b></tt>.
#
# The SHAP units are not the same, and SHAP takes into account more than linear dependencies, but it has captured the sign and the magnitude of the model it was interpreting.
#
#
# <br>
# <hr>
# <br>
#
# For your two reflections, feel free to use this cell or new ones just below this one:
#
# <b>Car Age vs Car Power:</b> The model says that claims are multiplied by 1.6 across the span of car age ehile the multiplier is only 0.3 for car power. Both of these are sort of counterintuitive to what the SHAP prediction above shows because for example the model expects claims to increase as cars become more powerful but our multiplier expects a decrease. Same for car age. Multiplier shows increased claims but model expects a decrease. In the real world, there could be different reasons to show why the multipliers might make sense:
#
# More powerful cars being more expensive → driven more cautiously → less claims
#
# Older cars → more problems → more claims
#
# <br>
# <br>

# %% [markdown]
# ### Part 4: &nbsp;&nbsp; A Neural Network model
#
# Here, we TensorFlow to fit a "shallow" neural net.
#
# Your task is to improve the results -- by adding more layers and retraining...
#
# Plus, the resulting layered network will be able to extract nonlinear relationships among the features <br> <font size="-1">(in exchange for much more training time...)</font>

# %% [markdown]
# Neurons work best when all their data is ***roughly the same magnitude***
#
# Our brains handle this at the sensor level -- our hearing and vision systems continually try to re-establish the ambient baseline to help convert their inputs into computable magnitudes:
# + light sensitivity increases in the dark and decreases in bright light
# + for sound, loud repetitive even soft sounds are heightened when in a quiet place.
#
# <br>
#
# For neural nets, we can scale each feature to be between -1 and 1:

# %%
# Scale features to [-1, 1]
from sklearn.preprocessing import MinMaxScaler

nn_preprocessor = MinMaxScaler(feature_range=(-1, 1))
X_train = nn_preprocessor.fit_transform(train[x])

print("Output after the data has been scaled:")
pd.DataFrame(X_train[0:5], columns=x)
# Out:
# Output after the data has been scaled:
#    year  town  driver_age  car_weight  car_power   car_age
# 0   1.0  -1.0    0.246377   -0.530612  -0.501754 -1.000000
# 1  -1.0   1.0   -0.072464   -0.530612  -0.256140 -0.818182
# 2   1.0   1.0   -0.072464   -0.969388  -0.817544 -0.636364
# 3   1.0   1.0   -0.333333   -0.867347  -0.887719 -0.181818
# 4   1.0   1.0   -0.594203   -0.489796  -0.445614 -0.727273

# %%
#
# Neural nets are worthy of their own course, for sure...
#
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
cb = [EarlyStopping(patience=20), ReduceLROnPlateau(patience=5)]  # "callbacks" for training (see below)

# Architecture
inputs = keras.Input(shape=(len(x),))
# additional layers can be added here!
outputs = layers.Dense(1, activation="exponential")(inputs)
nn_model_shallow = keras.Model(inputs=inputs, outputs=outputs)

nn_model_shallow.summary()

# Calculate gradients
nn_model_shallow.compile(optimizer=Adam(learning_rate=1e-4), loss="Poisson")
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 6)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │               7 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7 (28.00 B)
#  Trainable params: 7 (28.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Above, you see the artictecture of the network.
#
# This includes the total number of neuron-connections (parameters) to train.
#
# Let's train!

# %%
#
# train the network!
#

tf.random.set_seed(4349)

history_shallow = nn_model_shallow.fit(
    x=X_train,
    y=train[y],
    epochs=200,
    batch_size=10_000,
    validation_split=0.1,
    callbacks=cb,
    verbose=1,         # consider running both values 0 (no printing) and 1 (printing)
)
# Out:
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - loss: 1.3113 - val_loss: 1.3090 - learning_rate: 1.0000e-04
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.3071 - val_loss: 1.3048 - learning_rate: 1.0000e-04
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.3029 - val_loss: 1.3006 - learning_rate: 1.0000e-04
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.2987 - val_loss: 1.2964 - learning_rate: 1.0000e-04
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 1.2946 - val_loss: 1.2923 - learning_rate: 1.0000e-04
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.2905 - val_loss: 1.2882 - learning_rate: 1.0000e-04
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.2864 - val_loss: 1.2841 - learning_rate: 1.0000e-04
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.2823 - val_loss: 1.2801 - learning_rate: 1.0000e-04
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.2783 - val_loss: 1.2760 - learning_rate: 1.0000e-04
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.2743 - val_loss: 1.2720 - learning_rate: 1.0000e-04
# Epoch 11/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.2703 - val_loss: 1.2681 - learning_rate: 1.0000e-04
# Epoch 12/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.2663 - val_loss: 1.2641 - learning_rate: 1.0000e-04
# Epoch 13/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.2624 - val_loss: 1.2602 - learning_rate: 1.0000e-04
# Epoch 14/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.2585 - val_loss: 1.2562 - learning_rate: 1.0000e-04
# Epoch 15/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.2546 - val_loss: 1.2524 - learning_rate: 1.0000e-04
# Epoch 16/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.2507 - val_loss: 1.2485 - learning_rate: 1.0000e-04
# Epoch 17/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.2468 - val_loss: 1.2447 - learning_rate: 1.0000e-04
# Epoch 18/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.2430 - val_loss: 1.2408 - learning_rate: 1.0000e-04
# Epoch 19/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.2392 - val_loss: 1.2370 - learning_rate: 1.0000e-04
# Epoch 20/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - loss: 1.2354 - val_loss: 1.2333 - learning_rate: 1.0000e-04
# Epoch 21/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2317 - val_loss: 1.2295 - learning_rate: 1.0000e-04
# Epoch 22/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2279 - val_loss: 1.2258 - learning_rate: 1.0000e-04
# Epoch 23/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.2242 - val_loss: 1.2221 - learning_rate: 1.0000e-04
# Epoch 24/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.2205 - val_loss: 1.2184 - learning_rate: 1.0000e-04
# Epoch 25/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.2168 - val_loss: 1.2147 - learning_rate: 1.0000e-04
# Epoch 26/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.2132 - val_loss: 1.2111 - learning_rate: 1.0000e-04
# Epoch 27/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.2096 - val_loss: 1.2075 - learning_rate: 1.0000e-04
# Epoch 28/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2059 - val_loss: 1.2039 - learning_rate: 1.0000e-04
# Epoch 29/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.2024 - val_loss: 1.2003 - learning_rate: 1.0000e-04
# Epoch 30/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1988 - val_loss: 1.1967 - learning_rate: 1.0000e-04
# Epoch 31/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1952 - val_loss: 1.1932 - learning_rate: 1.0000e-04
# Epoch 32/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1917 - val_loss: 1.1897 - learning_rate: 1.0000e-04
# Epoch 33/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1882 - val_loss: 1.1862 - learning_rate: 1.0000e-04
# Epoch 34/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1847 - val_loss: 1.1827 - learning_rate: 1.0000e-04
# Epoch 35/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1812 - val_loss: 1.1792 - learning_rate: 1.0000e-04
# Epoch 36/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1778 - val_loss: 1.1758 - learning_rate: 1.0000e-04
# Epoch 37/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1744 - val_loss: 1.1723 - learning_rate: 1.0000e-04
# Epoch 38/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1710 - val_loss: 1.1689 - learning_rate: 1.0000e-04
# Epoch 39/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1676 - val_loss: 1.1656 - learning_rate: 1.0000e-04
# Epoch 40/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1642 - val_loss: 1.1622 - learning_rate: 1.0000e-04
# Epoch 41/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1608 - val_loss: 1.1589 - learning_rate: 1.0000e-04
# Epoch 42/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1575 - val_loss: 1.1555 - learning_rate: 1.0000e-04
# Epoch 43/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1542 - val_loss: 1.1522 - learning_rate: 1.0000e-04
# Epoch 44/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1509 - val_loss: 1.1489 - learning_rate: 1.0000e-04
# Epoch 45/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1476 - val_loss: 1.1457 - learning_rate: 1.0000e-04
# Epoch 46/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1443 - val_loss: 1.1424 - learning_rate: 1.0000e-04
# Epoch 47/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1411 - val_loss: 1.1392 - learning_rate: 1.0000e-04
# Epoch 48/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1379 - val_loss: 1.1359 - learning_rate: 1.0000e-04
# Epoch 49/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1347 - val_loss: 1.1327 - learning_rate: 1.0000e-04
# Epoch 50/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1315 - val_loss: 1.1296 - learning_rate: 1.0000e-04
# Epoch 51/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1283 - val_loss: 1.1264 - learning_rate: 1.0000e-04
# Epoch 52/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1251 - val_loss: 1.1232 - learning_rate: 1.0000e-04
# Epoch 53/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1220 - val_loss: 1.1201 - learning_rate: 1.0000e-04
# Epoch 54/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1189 - val_loss: 1.1170 - learning_rate: 1.0000e-04
# Epoch 55/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1158 - val_loss: 1.1139 - learning_rate: 1.0000e-04
# Epoch 56/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1127 - val_loss: 1.1108 - learning_rate: 1.0000e-04
# Epoch 57/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1096 - val_loss: 1.1077 - learning_rate: 1.0000e-04
# Epoch 58/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1065 - val_loss: 1.1047 - learning_rate: 1.0000e-04
# Epoch 59/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1035 - val_loss: 1.1017 - learning_rate: 1.0000e-04
# Epoch 60/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1005 - val_loss: 1.0986 - learning_rate: 1.0000e-04
# Epoch 61/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0975 - val_loss: 1.0956 - learning_rate: 1.0000e-04
# Epoch 62/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0945 - val_loss: 1.0926 - learning_rate: 1.0000e-04
# Epoch 63/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0915 - val_loss: 1.0897 - learning_rate: 1.0000e-04
# Epoch 64/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0885 - val_loss: 1.0867 - learning_rate: 1.0000e-04
# Epoch 65/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0856 - val_loss: 1.0838 - learning_rate: 1.0000e-04
# Epoch 66/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0826 - val_loss: 1.0809 - learning_rate: 1.0000e-04
# Epoch 67/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0797 - val_loss: 1.0779 - learning_rate: 1.0000e-04
# Epoch 68/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0768 - val_loss: 1.0751 - learning_rate: 1.0000e-04
# Epoch 69/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0739 - val_loss: 1.0722 - learning_rate: 1.0000e-04
# Epoch 70/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0711 - val_loss: 1.0693 - learning_rate: 1.0000e-04
# Epoch 71/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0682 - val_loss: 1.0665 - learning_rate: 1.0000e-04
# Epoch 72/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0654 - val_loss: 1.0636 - learning_rate: 1.0000e-04
# Epoch 73/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0625 - val_loss: 1.0608 - learning_rate: 1.0000e-04
# Epoch 74/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0597 - val_loss: 1.0580 - learning_rate: 1.0000e-04
# Epoch 75/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0569 - val_loss: 1.0552 - learning_rate: 1.0000e-04
# Epoch 76/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0541 - val_loss: 1.0524 - learning_rate: 1.0000e-04
# Epoch 77/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0514 - val_loss: 1.0497 - learning_rate: 1.0000e-04
# Epoch 78/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0486 - val_loss: 1.0469 - learning_rate: 1.0000e-04
# Epoch 79/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0459 - val_loss: 1.0442 - learning_rate: 1.0000e-04
# Epoch 80/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0431 - val_loss: 1.0415 - learning_rate: 1.0000e-04
# Epoch 81/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0404 - val_loss: 1.0387 - learning_rate: 1.0000e-04
# Epoch 82/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0377 - val_loss: 1.0361 - learning_rate: 1.0000e-04
# Epoch 83/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0350 - val_loss: 1.0334 - learning_rate: 1.0000e-04
# Epoch 84/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0323 - val_loss: 1.0307 - learning_rate: 1.0000e-04
# Epoch 85/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0297 - val_loss: 1.0280 - learning_rate: 1.0000e-04
# Epoch 86/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0270 - val_loss: 1.0254 - learning_rate: 1.0000e-04
# Epoch 87/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0244 - val_loss: 1.0228 - learning_rate: 1.0000e-04
# Epoch 88/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0218 - val_loss: 1.0202 - learning_rate: 1.0000e-04
# Epoch 89/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0192 - val_loss: 1.0176 - learning_rate: 1.0000e-04
# Epoch 90/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.0166 - val_loss: 1.0150 - learning_rate: 1.0000e-04
# Epoch 91/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0140 - val_loss: 1.0124 - learning_rate: 1.0000e-04
# Epoch 92/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0114 - val_loss: 1.0098 - learning_rate: 1.0000e-04
# Epoch 93/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0088 - val_loss: 1.0073 - learning_rate: 1.0000e-04
# Epoch 94/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0063 - val_loss: 1.0047 - learning_rate: 1.0000e-04
# Epoch 95/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0038 - val_loss: 1.0022 - learning_rate: 1.0000e-04
# Epoch 96/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0012 - val_loss: 0.9997 - learning_rate: 1.0000e-04
# Epoch 97/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9987 - val_loss: 0.9972 - learning_rate: 1.0000e-04
# Epoch 98/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9962 - val_loss: 0.9947 - learning_rate: 1.0000e-04
# Epoch 99/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9937 - val_loss: 0.9922 - learning_rate: 1.0000e-04
# Epoch 100/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9913 - val_loss: 0.9897 - learning_rate: 1.0000e-04
# Epoch 101/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9888 - val_loss: 0.9873 - learning_rate: 1.0000e-04
# Epoch 102/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9864 - val_loss: 0.9849 - learning_rate: 1.0000e-04
# Epoch 103/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9839 - val_loss: 0.9824 - learning_rate: 1.0000e-04
# Epoch 104/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9815 - val_loss: 0.9800 - learning_rate: 1.0000e-04
# Epoch 105/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9791 - val_loss: 0.9776 - learning_rate: 1.0000e-04
# Epoch 106/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9767 - val_loss: 0.9752 - learning_rate: 1.0000e-04
# Epoch 107/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9743 - val_loss: 0.9728 - learning_rate: 1.0000e-04
# Epoch 108/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9719 - val_loss: 0.9704 - learning_rate: 1.0000e-04
# Epoch 109/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9695 - val_loss: 0.9681 - learning_rate: 1.0000e-04
# Epoch 110/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9672 - val_loss: 0.9657 - learning_rate: 1.0000e-04
# Epoch 111/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9648 - val_loss: 0.9634 - learning_rate: 1.0000e-04
# Epoch 112/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9625 - val_loss: 0.9610 - learning_rate: 1.0000e-04
# Epoch 113/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9601 - val_loss: 0.9587 - learning_rate: 1.0000e-04
# Epoch 114/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9578 - val_loss: 0.9564 - learning_rate: 1.0000e-04
# Epoch 115/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9555 - val_loss: 0.9541 - learning_rate: 1.0000e-04
# Epoch 116/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9532 - val_loss: 0.9518 - learning_rate: 1.0000e-04
# Epoch 117/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9509 - val_loss: 0.9495 - learning_rate: 1.0000e-04
# Epoch 118/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9487 - val_loss: 0.9473 - learning_rate: 1.0000e-04
# Epoch 119/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9464 - val_loss: 0.9450 - learning_rate: 1.0000e-04
# Epoch 120/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9441 - val_loss: 0.9428 - learning_rate: 1.0000e-04
# Epoch 121/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9419 - val_loss: 0.9405 - learning_rate: 1.0000e-04
# Epoch 122/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9397 - val_loss: 0.9383 - learning_rate: 1.0000e-04
# Epoch 123/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9374 - val_loss: 0.9361 - learning_rate: 1.0000e-04
# Epoch 124/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9352 - val_loss: 0.9339 - learning_rate: 1.0000e-04
# Epoch 125/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9330 - val_loss: 0.9317 - learning_rate: 1.0000e-04
# Epoch 126/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9308 - val_loss: 0.9295 - learning_rate: 1.0000e-04
# Epoch 127/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9287 - val_loss: 0.9273 - learning_rate: 1.0000e-04
# Epoch 128/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9265 - val_loss: 0.9252 - learning_rate: 1.0000e-04
# Epoch 129/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9243 - val_loss: 0.9230 - learning_rate: 1.0000e-04
# Epoch 130/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9222 - val_loss: 0.9209 - learning_rate: 1.0000e-04
# Epoch 131/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9200 - val_loss: 0.9187 - learning_rate: 1.0000e-04
# Epoch 132/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9179 - val_loss: 0.9166 - learning_rate: 1.0000e-04
# Epoch 133/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9158 - val_loss: 0.9145 - learning_rate: 1.0000e-04
# Epoch 134/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9136 - val_loss: 0.9124 - learning_rate: 1.0000e-04
# Epoch 135/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9115 - val_loss: 0.9103 - learning_rate: 1.0000e-04
# Epoch 136/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9094 - val_loss: 0.9082 - learning_rate: 1.0000e-04
# Epoch 137/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9074 - val_loss: 0.9061 - learning_rate: 1.0000e-04
# Epoch 138/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9053 - val_loss: 0.9040 - learning_rate: 1.0000e-04
# Epoch 139/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9032 - val_loss: 0.9020 - learning_rate: 1.0000e-04
# Epoch 140/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9011 - val_loss: 0.8999 - learning_rate: 1.0000e-04
# Epoch 141/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8991 - val_loss: 0.8979 - learning_rate: 1.0000e-04
# Epoch 142/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8971 - val_loss: 0.8959 - learning_rate: 1.0000e-04
# Epoch 143/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8950 - val_loss: 0.8938 - learning_rate: 1.0000e-04
# Epoch 144/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8930 - val_loss: 0.8918 - learning_rate: 1.0000e-04
# Epoch 145/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8910 - val_loss: 0.8898 - learning_rate: 1.0000e-04
# Epoch 146/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8890 - val_loss: 0.8878 - learning_rate: 1.0000e-04
# Epoch 147/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8870 - val_loss: 0.8858 - learning_rate: 1.0000e-04
# Epoch 148/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8850 - val_loss: 0.8838 - learning_rate: 1.0000e-04
# Epoch 149/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8830 - val_loss: 0.8819 - learning_rate: 1.0000e-04
# Epoch 150/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8810 - val_loss: 0.8799 - learning_rate: 1.0000e-04
# Epoch 151/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8791 - val_loss: 0.8779 - learning_rate: 1.0000e-04
# Epoch 152/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8771 - val_loss: 0.8760 - learning_rate: 1.0000e-04
# Epoch 153/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8752 - val_loss: 0.8741 - learning_rate: 1.0000e-04
# Epoch 154/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8732 - val_loss: 0.8721 - learning_rate: 1.0000e-04
# Epoch 155/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8713 - val_loss: 0.8702 - learning_rate: 1.0000e-04
# Epoch 156/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8694 - val_loss: 0.8683 - learning_rate: 1.0000e-04
# Epoch 157/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8675 - val_loss: 0.8664 - learning_rate: 1.0000e-04
# Epoch 158/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8656 - val_loss: 0.8645 - learning_rate: 1.0000e-04
# Epoch 159/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8637 - val_loss: 0.8626 - learning_rate: 1.0000e-04
# Epoch 160/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8618 - val_loss: 0.8607 - learning_rate: 1.0000e-04
# Epoch 161/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8599 - val_loss: 0.8588 - learning_rate: 1.0000e-04
# Epoch 162/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8580 - val_loss: 0.8570 - learning_rate: 1.0000e-04
# Epoch 163/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8561 - val_loss: 0.8551 - learning_rate: 1.0000e-04
# Epoch 164/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8543 - val_loss: 0.8533 - learning_rate: 1.0000e-04
# Epoch 165/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8524 - val_loss: 0.8514 - learning_rate: 1.0000e-04
# Epoch 166/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8506 - val_loss: 0.8496 - learning_rate: 1.0000e-04
# Epoch 167/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8487 - val_loss: 0.8477 - learning_rate: 1.0000e-04
# Epoch 168/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8469 - val_loss: 0.8459 - learning_rate: 1.0000e-04
# Epoch 169/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8451 - val_loss: 0.8441 - learning_rate: 1.0000e-04
# Epoch 170/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8433 - val_loss: 0.8423 - learning_rate: 1.0000e-04
# Epoch 171/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8415 - val_loss: 0.8405 - learning_rate: 1.0000e-04
# Epoch 172/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8397 - val_loss: 0.8387 - learning_rate: 1.0000e-04
# Epoch 173/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8379 - val_loss: 0.8369 - learning_rate: 1.0000e-04
# Epoch 174/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8361 - val_loss: 0.8352 - learning_rate: 1.0000e-04
# Epoch 175/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8343 - val_loss: 0.8334 - learning_rate: 1.0000e-04
# Epoch 176/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8326 - val_loss: 0.8316 - learning_rate: 1.0000e-04
# Epoch 177/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8308 - val_loss: 0.8299 - learning_rate: 1.0000e-04
# Epoch 178/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8291 - val_loss: 0.8281 - learning_rate: 1.0000e-04
# Epoch 179/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8273 - val_loss: 0.8264 - learning_rate: 1.0000e-04
# Epoch 180/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8256 - val_loss: 0.8247 - learning_rate: 1.0000e-04
# Epoch 181/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8238 - val_loss: 0.8229 - learning_rate: 1.0000e-04
# Epoch 182/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8221 - val_loss: 0.8212 - learning_rate: 1.0000e-04
# Epoch 183/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8204 - val_loss: 0.8195 - learning_rate: 1.0000e-04
# Epoch 184/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8187 - val_loss: 0.8178 - learning_rate: 1.0000e-04
# Epoch 185/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8170 - val_loss: 0.8161 - learning_rate: 1.0000e-04
# Epoch 186/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.8153 - val_loss: 0.8144 - learning_rate: 1.0000e-04
# Epoch 187/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8136 - val_loss: 0.8127 - learning_rate: 1.0000e-04
# Epoch 188/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8119 - val_loss: 0.8111 - learning_rate: 1.0000e-04
# Epoch 189/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8102 - val_loss: 0.8094 - learning_rate: 1.0000e-04
# Epoch 190/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8085 - val_loss: 0.8077 - learning_rate: 1.0000e-04
# Epoch 191/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8069 - val_loss: 0.8061 - learning_rate: 1.0000e-04
# Epoch 192/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.8052 - val_loss: 0.8044 - learning_rate: 1.0000e-04
# Epoch 193/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8036 - val_loss: 0.8028 - learning_rate: 1.0000e-04
# Epoch 194/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8019 - val_loss: 0.8011 - learning_rate: 1.0000e-04
# Epoch 195/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8003 - val_loss: 0.7995 - learning_rate: 1.0000e-04
# Epoch 196/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7987 - val_loss: 0.7979 - learning_rate: 1.0000e-04
# Epoch 197/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7970 - val_loss: 0.7963 - learning_rate: 1.0000e-04
# Epoch 198/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7954 - val_loss: 0.7946 - learning_rate: 1.0000e-04
# Epoch 199/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7938 - val_loss: 0.7930 - learning_rate: 1.0000e-04
# Epoch 200/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.7922 - val_loss: 0.7914 - learning_rate: 1.0000e-04

# %%
# prompt: Could you show a heatmap of the values of the neuron's weights in the above model, named nn_model?

import seaborn as sns
import matplotlib.pyplot as plt

# Here, nn_model_shallow is the Keras (NNet) model
weights = nn_model_shallow.layers[1].get_weights()[0]  # Get weights from this layer (omitting the intercepts, which are in [1])
weights = np.transpose(weights)

# Create a heatmap of the weights
plt.figure(figsize=(10, 8))
sns.heatmap(weights, annot=False, cmap='viridis')
plt.title("Neuron Weights Heatmap of the Input Layer")
plt.xlabel("Input Features (6)")
plt.ylabel("Neurons from Inputs to Output")
plt.show()

# %% [markdown]
# And, let's see how the model does... using `shap`

# %%
def nn_predict_shallow(X):
    """Prediction function of the neural network (log scale)."""
    df = pd.DataFrame(X, columns=x)
    df_scaled = nn_preprocessor.transform(df)
    pred = nn_model_shallow.predict(df_scaled, verbose=0, batch_size=10_000).flatten()
    return np.log(pred)


nn_explainer = shap.KernelExplainer(nn_predict_shallow, data=X_bg)
shap_nn = nn_explainer.shap_values(X_explain, nsamples=30)

all_dep_plots(x, shap_nn, X_explain)
# Out:
# WARNING:shap:Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# #### Next, let's add a "hidden" layer to our network...
#
# Here, we add a middle, "hidden," layer to our network in line 14, below. Notice that
# + the value 7 is the number of neurons
# + the inputs from the initial layer are, in fact, the inputs to this middle layer
# + the variable z holds the outputs of this layer.
# + the output layer uses z as its input (and then estimates the goal, the number of claims from there)
#
# Additional layers are able to continue this pattern (one example is commented out on line 17):

# %%
#
# Let's add a second layer to our network:

import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
cb = [EarlyStopping(patience=20), ReduceLROnPlateau(patience=5)]  # "callbacks" for training (see below)

# Architecture: Adding Layers
inputs = keras.Input(shape=(len(x),))            # Here is the input layer

z = layers.Dense(6, activation="tanh")(inputs)   # Here is the new layer: 7 neurons, inputs are the input, and z is the output. Use "tanh"

# For more layers, you can continue using z.     # Here is a commented-out example:
# z = layers.Dense(6, activation="tanh")(z)     # This is another layer: 3 neurons, z is the input, and z is the output

outputs = layers.Dense(1, activation="exponential")(z)   # Here, we convert the previous layer's results (z) into the overall output
nn_model_2layer = keras.Model(inputs=inputs, outputs=outputs)   # The final layer often uses a different activation function

nn_model_2layer.summary()

nn_model_2layer.compile(optimizer=Adam(learning_rate=1e-4), loss="Poisson")
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 6)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 6)                   │              42 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               7 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 49 (196.00 B)
#  Trainable params: 49 (196.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.random.set_seed(4349)

history_2layer = nn_model_2layer.fit(
    x=X_train,
    y=train[y],
    epochs=200,
    batch_size=10_000,
    validation_split=0.1,
    callbacks=cb,
    verbose=1,         # consider running both values 0 (no printing) and 1 (printing)
)
# Out:
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.3442 - val_loss: 1.3377 - learning_rate: 1.0000e-04
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3352 - val_loss: 1.3287 - learning_rate: 1.0000e-04
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3262 - val_loss: 1.3199 - learning_rate: 1.0000e-04
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3174 - val_loss: 1.3111 - learning_rate: 1.0000e-04
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3086 - val_loss: 1.3024 - learning_rate: 1.0000e-04
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3000 - val_loss: 1.2938 - learning_rate: 1.0000e-04
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.2914 - val_loss: 1.2853 - learning_rate: 1.0000e-04
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2830 - val_loss: 1.2769 - learning_rate: 1.0000e-04
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2746 - val_loss: 1.2687 - learning_rate: 1.0000e-04
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2663 - val_loss: 1.2605 - learning_rate: 1.0000e-04
# Epoch 11/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2582 - val_loss: 1.2524 - learning_rate: 1.0000e-04
# Epoch 12/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2501 - val_loss: 1.2444 - learning_rate: 1.0000e-04
# Epoch 13/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2421 - val_loss: 1.2365 - learning_rate: 1.0000e-04
# Epoch 14/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2342 - val_loss: 1.2286 - learning_rate: 1.0000e-04
# Epoch 15/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2264 - val_loss: 1.2209 - learning_rate: 1.0000e-04
# Epoch 16/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2187 - val_loss: 1.2132 - learning_rate: 1.0000e-04
# Epoch 17/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2111 - val_loss: 1.2057 - learning_rate: 1.0000e-04
# Epoch 18/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2035 - val_loss: 1.1982 - learning_rate: 1.0000e-04
# Epoch 19/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1961 - val_loss: 1.1908 - learning_rate: 1.0000e-04
# Epoch 20/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1887 - val_loss: 1.1835 - learning_rate: 1.0000e-04
# Epoch 21/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1814 - val_loss: 1.1763 - learning_rate: 1.0000e-04
# Epoch 22/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1742 - val_loss: 1.1691 - learning_rate: 1.0000e-04
# Epoch 23/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1671 - val_loss: 1.1621 - learning_rate: 1.0000e-04
# Epoch 24/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1600 - val_loss: 1.1551 - learning_rate: 1.0000e-04
# Epoch 25/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1530 - val_loss: 1.1482 - learning_rate: 1.0000e-04
# Epoch 26/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1461 - val_loss: 1.1413 - learning_rate: 1.0000e-04
# Epoch 27/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1393 - val_loss: 1.1346 - learning_rate: 1.0000e-04
# Epoch 28/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1326 - val_loss: 1.1279 - learning_rate: 1.0000e-04
# Epoch 29/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1259 - val_loss: 1.1212 - learning_rate: 1.0000e-04
# Epoch 30/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1193 - val_loss: 1.1147 - learning_rate: 1.0000e-04
# Epoch 31/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1127 - val_loss: 1.1082 - learning_rate: 1.0000e-04
# Epoch 32/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1063 - val_loss: 1.1018 - learning_rate: 1.0000e-04
# Epoch 33/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0999 - val_loss: 1.0955 - learning_rate: 1.0000e-04
# Epoch 34/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0936 - val_loss: 1.0892 - learning_rate: 1.0000e-04
# Epoch 35/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0873 - val_loss: 1.0830 - learning_rate: 1.0000e-04
# Epoch 36/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0811 - val_loss: 1.0769 - learning_rate: 1.0000e-04
# Epoch 37/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0750 - val_loss: 1.0708 - learning_rate: 1.0000e-04
# Epoch 38/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0689 - val_loss: 1.0648 - learning_rate: 1.0000e-04
# Epoch 39/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0629 - val_loss: 1.0588 - learning_rate: 1.0000e-04
# Epoch 40/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0570 - val_loss: 1.0529 - learning_rate: 1.0000e-04
# Epoch 41/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0511 - val_loss: 1.0471 - learning_rate: 1.0000e-04
# Epoch 42/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0453 - val_loss: 1.0414 - learning_rate: 1.0000e-04
# Epoch 43/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0395 - val_loss: 1.0357 - learning_rate: 1.0000e-04
# Epoch 44/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0339 - val_loss: 1.0300 - learning_rate: 1.0000e-04
# Epoch 45/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0282 - val_loss: 1.0244 - learning_rate: 1.0000e-04
# Epoch 46/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0226 - val_loss: 1.0189 - learning_rate: 1.0000e-04
# Epoch 47/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0171 - val_loss: 1.0134 - learning_rate: 1.0000e-04
# Epoch 48/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0117 - val_loss: 1.0080 - learning_rate: 1.0000e-04
# Epoch 49/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0063 - val_loss: 1.0027 - learning_rate: 1.0000e-04
# Epoch 50/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0009 - val_loss: 0.9974 - learning_rate: 1.0000e-04
# Epoch 51/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9956 - val_loss: 0.9921 - learning_rate: 1.0000e-04
# Epoch 52/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9904 - val_loss: 0.9869 - learning_rate: 1.0000e-04
# Epoch 53/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9852 - val_loss: 0.9818 - learning_rate: 1.0000e-04
# Epoch 54/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9800 - val_loss: 0.9767 - learning_rate: 1.0000e-04
# Epoch 55/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9750 - val_loss: 0.9716 - learning_rate: 1.0000e-04
# Epoch 56/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9699 - val_loss: 0.9666 - learning_rate: 1.0000e-04
# Epoch 57/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9649 - val_loss: 0.9617 - learning_rate: 1.0000e-04
# Epoch 58/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9600 - val_loss: 0.9568 - learning_rate: 1.0000e-04
# Epoch 59/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9551 - val_loss: 0.9520 - learning_rate: 1.0000e-04
# Epoch 60/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9503 - val_loss: 0.9472 - learning_rate: 1.0000e-04
# Epoch 61/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9455 - val_loss: 0.9424 - learning_rate: 1.0000e-04
# Epoch 62/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9407 - val_loss: 0.9377 - learning_rate: 1.0000e-04
# Epoch 63/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9360 - val_loss: 0.9330 - learning_rate: 1.0000e-04
# Epoch 64/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9314 - val_loss: 0.9284 - learning_rate: 1.0000e-04
# Epoch 65/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9268 - val_loss: 0.9239 - learning_rate: 1.0000e-04
# Epoch 66/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.9222 - val_loss: 0.9193 - learning_rate: 1.0000e-04
# Epoch 67/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.9177 - val_loss: 0.9149 - learning_rate: 1.0000e-04
# Epoch 68/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.9132 - val_loss: 0.9104 - learning_rate: 1.0000e-04
# Epoch 69/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9088 - val_loss: 0.9060 - learning_rate: 1.0000e-04
# Epoch 70/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9044 - val_loss: 0.9017 - learning_rate: 1.0000e-04
# Epoch 71/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9001 - val_loss: 0.8974 - learning_rate: 1.0000e-04
# Epoch 72/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8957 - val_loss: 0.8931 - learning_rate: 1.0000e-04
# Epoch 73/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8915 - val_loss: 0.8889 - learning_rate: 1.0000e-04
# Epoch 74/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8873 - val_loss: 0.8847 - learning_rate: 1.0000e-04
# Epoch 75/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8831 - val_loss: 0.8805 - learning_rate: 1.0000e-04
# Epoch 76/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8789 - val_loss: 0.8764 - learning_rate: 1.0000e-04
# Epoch 77/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8748 - val_loss: 0.8724 - learning_rate: 1.0000e-04
# Epoch 78/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8707 - val_loss: 0.8683 - learning_rate: 1.0000e-04
# Epoch 79/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8667 - val_loss: 0.8643 - learning_rate: 1.0000e-04
# Epoch 80/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8627 - val_loss: 0.8604 - learning_rate: 1.0000e-04
# Epoch 81/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8588 - val_loss: 0.8564 - learning_rate: 1.0000e-04
# Epoch 82/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8548 - val_loss: 0.8526 - learning_rate: 1.0000e-04
# Epoch 83/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8510 - val_loss: 0.8487 - learning_rate: 1.0000e-04
# Epoch 84/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8471 - val_loss: 0.8449 - learning_rate: 1.0000e-04
# Epoch 85/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8433 - val_loss: 0.8411 - learning_rate: 1.0000e-04
# Epoch 86/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8395 - val_loss: 0.8374 - learning_rate: 1.0000e-04
# Epoch 87/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8358 - val_loss: 0.8337 - learning_rate: 1.0000e-04
# Epoch 88/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8321 - val_loss: 0.8300 - learning_rate: 1.0000e-04
# Epoch 89/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8284 - val_loss: 0.8263 - learning_rate: 1.0000e-04
# Epoch 90/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8247 - val_loss: 0.8227 - learning_rate: 1.0000e-04
# Epoch 91/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8211 - val_loss: 0.8191 - learning_rate: 1.0000e-04
# Epoch 92/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8175 - val_loss: 0.8156 - learning_rate: 1.0000e-04
# Epoch 93/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8140 - val_loss: 0.8121 - learning_rate: 1.0000e-04
# Epoch 94/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8105 - val_loss: 0.8086 - learning_rate: 1.0000e-04
# Epoch 95/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8070 - val_loss: 0.8051 - learning_rate: 1.0000e-04
# Epoch 96/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8035 - val_loss: 0.8017 - learning_rate: 1.0000e-04
# Epoch 97/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8001 - val_loss: 0.7983 - learning_rate: 1.0000e-04
# Epoch 98/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7967 - val_loss: 0.7949 - learning_rate: 1.0000e-04
# Epoch 99/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7934 - val_loss: 0.7916 - learning_rate: 1.0000e-04
# Epoch 100/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7900 - val_loss: 0.7883 - learning_rate: 1.0000e-04
# Epoch 101/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7867 - val_loss: 0.7850 - learning_rate: 1.0000e-04
# Epoch 102/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7834 - val_loss: 0.7818 - learning_rate: 1.0000e-04
# Epoch 103/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7802 - val_loss: 0.7785 - learning_rate: 1.0000e-04
# Epoch 104/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7770 - val_loss: 0.7753 - learning_rate: 1.0000e-04
# Epoch 105/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7738 - val_loss: 0.7722 - learning_rate: 1.0000e-04
# Epoch 106/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7706 - val_loss: 0.7690 - learning_rate: 1.0000e-04
# Epoch 107/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7674 - val_loss: 0.7659 - learning_rate: 1.0000e-04
# Epoch 108/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7643 - val_loss: 0.7628 - learning_rate: 1.0000e-04
# Epoch 109/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.7612 - val_loss: 0.7598 - learning_rate: 1.0000e-04
# Epoch 110/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7582 - val_loss: 0.7567 - learning_rate: 1.0000e-04
# Epoch 111/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7551 - val_loss: 0.7537 - learning_rate: 1.0000e-04
# Epoch 112/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7521 - val_loss: 0.7507 - learning_rate: 1.0000e-04
# Epoch 113/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7491 - val_loss: 0.7478 - learning_rate: 1.0000e-04
# Epoch 114/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7462 - val_loss: 0.7448 - learning_rate: 1.0000e-04
# Epoch 115/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7432 - val_loss: 0.7419 - learning_rate: 1.0000e-04
# Epoch 116/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7403 - val_loss: 0.7390 - learning_rate: 1.0000e-04
# Epoch 117/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7374 - val_loss: 0.7362 - learning_rate: 1.0000e-04
# Epoch 118/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.7346 - val_loss: 0.7333 - learning_rate: 1.0000e-04
# Epoch 119/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7317 - val_loss: 0.7305 - learning_rate: 1.0000e-04
# Epoch 120/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7289 - val_loss: 0.7277 - learning_rate: 1.0000e-04
# Epoch 121/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7261 - val_loss: 0.7250 - learning_rate: 1.0000e-04
# Epoch 122/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7233 - val_loss: 0.7222 - learning_rate: 1.0000e-04
# Epoch 123/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.7206 - val_loss: 0.7195 - learning_rate: 1.0000e-04
# Epoch 124/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7178 - val_loss: 0.7168 - learning_rate: 1.0000e-04
# Epoch 125/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.7151 - val_loss: 0.7141 - learning_rate: 1.0000e-04
# Epoch 126/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7124 - val_loss: 0.7114 - learning_rate: 1.0000e-04
# Epoch 127/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7098 - val_loss: 0.7088 - learning_rate: 1.0000e-04
# Epoch 128/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7071 - val_loss: 0.7061 - learning_rate: 1.0000e-04
# Epoch 129/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7045 - val_loss: 0.7035 - learning_rate: 1.0000e-04
# Epoch 130/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.7019 - val_loss: 0.7010 - learning_rate: 1.0000e-04
# Epoch 131/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6993 - val_loss: 0.6984 - learning_rate: 1.0000e-04
# Epoch 132/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6967 - val_loss: 0.6959 - learning_rate: 1.0000e-04
# Epoch 133/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6942 - val_loss: 0.6933 - learning_rate: 1.0000e-04
# Epoch 134/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6916 - val_loss: 0.6908 - learning_rate: 1.0000e-04
# Epoch 135/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6891 - val_loss: 0.6883 - learning_rate: 1.0000e-04
# Epoch 136/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6867 - val_loss: 0.6859 - learning_rate: 1.0000e-04
# Epoch 137/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6842 - val_loss: 0.6834 - learning_rate: 1.0000e-04
# Epoch 138/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6817 - val_loss: 0.6810 - learning_rate: 1.0000e-04
# Epoch 139/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6793 - val_loss: 0.6786 - learning_rate: 1.0000e-04
# Epoch 140/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6769 - val_loss: 0.6762 - learning_rate: 1.0000e-04
# Epoch 141/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6745 - val_loss: 0.6738 - learning_rate: 1.0000e-04
# Epoch 142/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6721 - val_loss: 0.6715 - learning_rate: 1.0000e-04
# Epoch 143/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6697 - val_loss: 0.6691 - learning_rate: 1.0000e-04
# Epoch 144/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6674 - val_loss: 0.6668 - learning_rate: 1.0000e-04
# Epoch 145/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6651 - val_loss: 0.6645 - learning_rate: 1.0000e-04
# Epoch 146/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6628 - val_loss: 0.6622 - learning_rate: 1.0000e-04
# Epoch 147/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.6605 - val_loss: 0.6599 - learning_rate: 1.0000e-04
# Epoch 148/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6582 - val_loss: 0.6577 - learning_rate: 1.0000e-04
# Epoch 149/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6559 - val_loss: 0.6555 - learning_rate: 1.0000e-04
# Epoch 150/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6537 - val_loss: 0.6532 - learning_rate: 1.0000e-04
# Epoch 151/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6515 - val_loss: 0.6510 - learning_rate: 1.0000e-04
# Epoch 152/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6492 - val_loss: 0.6488 - learning_rate: 1.0000e-04
# Epoch 153/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6470 - val_loss: 0.6467 - learning_rate: 1.0000e-04
# Epoch 154/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6449 - val_loss: 0.6445 - learning_rate: 1.0000e-04
# Epoch 155/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6427 - val_loss: 0.6424 - learning_rate: 1.0000e-04
# Epoch 156/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6406 - val_loss: 0.6402 - learning_rate: 1.0000e-04
# Epoch 157/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6384 - val_loss: 0.6381 - learning_rate: 1.0000e-04
# Epoch 158/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6363 - val_loss: 0.6360 - learning_rate: 1.0000e-04
# Epoch 159/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6342 - val_loss: 0.6339 - learning_rate: 1.0000e-04
# Epoch 160/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6321 - val_loss: 0.6319 - learning_rate: 1.0000e-04
# Epoch 161/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6300 - val_loss: 0.6298 - learning_rate: 1.0000e-04
# Epoch 162/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6280 - val_loss: 0.6278 - learning_rate: 1.0000e-04
# Epoch 163/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6259 - val_loss: 0.6257 - learning_rate: 1.0000e-04
# Epoch 164/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6239 - val_loss: 0.6237 - learning_rate: 1.0000e-04
# Epoch 165/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6219 - val_loss: 0.6217 - learning_rate: 1.0000e-04
# Epoch 166/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6198 - val_loss: 0.6197 - learning_rate: 1.0000e-04
# Epoch 167/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6179 - val_loss: 0.6178 - learning_rate: 1.0000e-04
# Epoch 168/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6159 - val_loss: 0.6158 - learning_rate: 1.0000e-04
# Epoch 169/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6139 - val_loss: 0.6139 - learning_rate: 1.0000e-04
# Epoch 170/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6120 - val_loss: 0.6119 - learning_rate: 1.0000e-04
# Epoch 171/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6100 - val_loss: 0.6100 - learning_rate: 1.0000e-04
# Epoch 172/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6081 - val_loss: 0.6081 - learning_rate: 1.0000e-04
# Epoch 173/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6062 - val_loss: 0.6062 - learning_rate: 1.0000e-04
# Epoch 174/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6043 - val_loss: 0.6043 - learning_rate: 1.0000e-04
# Epoch 175/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6024 - val_loss: 0.6024 - learning_rate: 1.0000e-04
# Epoch 176/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6005 - val_loss: 0.6006 - learning_rate: 1.0000e-04
# Epoch 177/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5986 - val_loss: 0.5987 - learning_rate: 1.0000e-04
# Epoch 178/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5968 - val_loss: 0.5969 - learning_rate: 1.0000e-04
# Epoch 179/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5949 - val_loss: 0.5951 - learning_rate: 1.0000e-04
# Epoch 180/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5931 - val_loss: 0.5933 - learning_rate: 1.0000e-04
# Epoch 181/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5913 - val_loss: 0.5915 - learning_rate: 1.0000e-04
# Epoch 182/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5895 - val_loss: 0.5897 - learning_rate: 1.0000e-04
# Epoch 183/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5877 - val_loss: 0.5879 - learning_rate: 1.0000e-04
# Epoch 184/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5859 - val_loss: 0.5862 - learning_rate: 1.0000e-04
# Epoch 185/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5841 - val_loss: 0.5844 - learning_rate: 1.0000e-04
# Epoch 186/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5824 - val_loss: 0.5827 - learning_rate: 1.0000e-04
# Epoch 187/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5806 - val_loss: 0.5809 - learning_rate: 1.0000e-04
# Epoch 188/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5789 - val_loss: 0.5792 - learning_rate: 1.0000e-04
# Epoch 189/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5772 - val_loss: 0.5775 - learning_rate: 1.0000e-04
# Epoch 190/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5754 - val_loss: 0.5758 - learning_rate: 1.0000e-04
# Epoch 191/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5737 - val_loss: 0.5741 - learning_rate: 1.0000e-04
# Epoch 192/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5720 - val_loss: 0.5724 - learning_rate: 1.0000e-04
# Epoch 193/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5704 - val_loss: 0.5708 - learning_rate: 1.0000e-04
# Epoch 194/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5687 - val_loss: 0.5691 - learning_rate: 1.0000e-04
# Epoch 195/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5670 - val_loss: 0.5675 - learning_rate: 1.0000e-04
# Epoch 196/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5654 - val_loss: 0.5658 - learning_rate: 1.0000e-04
# Epoch 197/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5637 - val_loss: 0.5642 - learning_rate: 1.0000e-04
# Epoch 198/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5621 - val_loss: 0.5626 - learning_rate: 1.0000e-04
# Epoch 199/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5605 - val_loss: 0.5610 - learning_rate: 1.0000e-04
# Epoch 200/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5589 - val_loss: 0.5594 - learning_rate: 1.0000e-04

# %% [markdown]
# Let's see the neurons!
#
# At least as a heatmap of the weights:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

weights = nn_model_2layer.layers[1].get_weights()[0]  # Get weights from this layer (omit the intercept, which is [1])
weights = np.transpose(weights)

# Create a heatmap of the weights
plt.figure(figsize=(10, 8))
sns.heatmap(weights, annot=False, cmap='viridis')
plt.title("Neuron Weights Heatmap of the Input Layer")
plt.xlabel(f"Input Features (6)")
plt.ylabel("Neurons from Inputs to Layer1 (7)")
plt.show()

# %% [markdown]
# Next layer!

# %%
# Next layer
weights = nn_model_2layer.layers[2].get_weights()[0]  # Get weights from this layer (omit the intercept, which is [1])
weights = np.transpose(weights)

# Create a heatmap of the weights
plt.figure(figsize=(10, 8))
sns.heatmap(weights, annot=False, cmap='viridis')
plt.title("Neuron Weights Heatmap of Next Layer")
plt.xlabel("Neurons from Layer 1 (of 7)")
plt.ylabel("Neurons from Layer 1 to Layer 2 (of 1)")
plt.show()

# %% [markdown]
# Let's run `shap` to see if it does better...

# %%
def nn_predict_2layer(X):
    """Prediction function of the neural network (log scale)."""
    df = pd.DataFrame(X, columns=x)
    df_scaled = nn_preprocessor.transform(df)
    pred = nn_model_2layer.predict(df_scaled, verbose=0, batch_size=10_000).flatten()
    return np.log(pred)

nn_explainer = shap.KernelExplainer(nn_predict_2layer, data=X_bg)
shap_nn = nn_explainer.shap_values(X_explain, nsamples=30)

all_dep_plots(x, shap_nn, X_explain)   # create all feature-dependency plots
# Out:
# WARNING:shap:Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# Notice that these features do not _yet_ match the ones computed by the linear regression model we interpreted above.
#
# Thus far, the NNet is too primitive to be able to learn the real relationships among those dataset features.
#
# <font color="Coral">Your task</font> is to experiment below, in order to create a larger, more faithful NNet model.

# %% [markdown]
# ### The "Real" data model
#
# Usually datasets do not have a "real" model. At least not one that's known!
#
# This dataset, however, does have a _real_ underlying model! (It was inspired by the real data and then used to generate this dataset.)
#
# Here is the real model:

# %%
#
# The age is a much more complicated - non-linear - feature
def age_effect(age):
    x = (age - 66) / 60
    return 0.05 + x**8 + 0.4 * x**3 + 0.3 * x**2 + 0.06 * x

#
# here is the true model for this dataset:
def true_model(X):
    """Returns pd.Series of true expected frequencies."""
    df = pd.DataFrame(X, columns=x)  # Needed because SHAP turns df to np.array
    log_lambda = (
        0.15 * df.town
        + np.log(age_effect(df.driver_age))
        + (0.3 + 0.15 * df.town) * df.car_power / 100
        - 0.02 * df.car_age
    )
    return np.exp(log_lambda)

# %% [markdown]
# `shap` is not specific to NNets or linear regression models. It supports the interpretation of _any_ model, including the real one.
#
# Here is `shap`'s interpretation of this real model:

# %%
import shap

true_model_explainer = shap.KernelExplainer(lambda x: np.log(true_model(x)), data=X_bg)
shap_true = true_model_explainer.shap_values(X_explain, nsamples=30)

all_dep_plots(x, shap_true, X_explain)
# Out:
# WARNING:shap:Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# Things to notice:
# + the relationship between driver_age and the number of claims is "highly non-linear!"
# + there are also _two slopes_ for the linear car_power feature (so, officially, it's "not linear")
# + note, too, that car_weight has no impact on the output...
#   + Challenge question (not really a hw task): <br>  _**Why** do the modeling techniques above observe an impact of the car_weight feature?_

# %% [markdown]
# ## Final challenge: <font color="DodgerBlue">_Improve the NNet_</font>
#
# #### <font color="Coral"><b>Task Finale</b></font>
#
# From here, your task is to
# + create a more-capable neural network... with the goal of representing the actual data interactions ***better*** than the linear-regression model
# + consider using more layers (but not too many)
# + consider the "step-down" architecture, where
#   + the first post-input layer has the most neurons ("feature building")
#   + then, subsequent layers have fewer...
#   + tapering into the output layer
#
# You'll find that the NNet won't represent the "real" model perfectly, but it will
# + find its own features
# + represent the non-linear relationship (for driver_age)
# + and, for me, it could _start_ to represent the dependence of car_power on town
#
# <br>

# %% [markdown]
# ### Use the cells below to experiment with NNet building...
#
# Use the above `2layer` example as a template, and then - below -
# + experiment and create a new model -- and
# + show its `shap` interpretation... -- and
# + be sure to include a <font color="DodgerBlue">3-5 sentence <b>reflection</b> on</font> your experimentation (how long it took!) and how well the resulting NNet does at capturing the feature relationships of the actual, underlying "reality" ...
#
# <br>
#
# Worth remembering:  _We're **all** neural nets!_
# + It would seem we're always "keeping this in mind" 😀

# %%
#
# Let's add a second layer to our network:

import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
cb = [EarlyStopping(patience=20), ReduceLROnPlateau(patience=5)]  # "callbacks" for training (see below)

# Architecture: Adding Layers
inputs = keras.Input(shape=(len(x),))            # Here is the input layer

z = layers.Dense(12, activation="relu")(inputs)   # Here is the new layer: 12 neurons

# For more layers, you can continue using z.     # Here is a commented-out example:
z = layers.Dense(10, activation="relu")(z)     # This is another layer: 6 neurons
z = layers.Dense(8, activation="relu")(z)     # This is another layer: 6 neurons
z = layers.Dense(6, activation="relu")(z)     # This is another layer: 6 neurons
z = layers.Dense(4, activation="relu")(z)     # This is another layer: 6 neurons

outputs = layers.Dense(1, activation="exponential")(z)   # Here, we convert the previous layer's results (z) into the overall output
nn_model_2layer = keras.Model(inputs=inputs, outputs=outputs)   # The final layer often uses a different activation function

nn_model_2layer.summary()

nn_model_2layer.compile(optimizer=Adam(learning_rate=1e-4), loss="Poisson")
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 6)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 12)                  │              84 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 10)                  │             130 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 8)                   │              88 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 6)                   │              54 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 4)                   │              28 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 389 (1.52 KB)
#  Trainable params: 389 (1.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.random.set_seed(4349)

history_2layer = nn_model_2layer.fit(
    x=X_train,
    y=train[y],
    epochs=2000,
    batch_size=1024,
    validation_split=0.1,
    callbacks=cb,
    verbose=1,         # consider running both values 0 (no printing) and 1 (printing)
)
# Out:
# Epoch 1/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.3077 - val_loss: 0.3170 - learning_rate: 1.0000e-04
# Epoch 2/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3073 - val_loss: 0.3167 - learning_rate: 1.0000e-04
# Epoch 3/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3070 - val_loss: 0.3165 - learning_rate: 1.0000e-04
# Epoch 4/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3068 - val_loss: 0.3163 - learning_rate: 1.0000e-04
# Epoch 5/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3065 - val_loss: 0.3161 - learning_rate: 1.0000e-04
# Epoch 6/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3064 - val_loss: 0.3159 - learning_rate: 1.0000e-04
# Epoch 7/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3062 - val_loss: 0.3157 - learning_rate: 1.0000e-04
# Epoch 8/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3060 - val_loss: 0.3156 - learning_rate: 1.0000e-04
# Epoch 9/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3058 - val_loss: 0.3154 - learning_rate: 1.0000e-04
# Epoch 10/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3057 - val_loss: 0.3153 - learning_rate: 1.0000e-04
# Epoch 11/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3055 - val_loss: 0.3151 - learning_rate: 1.0000e-04
# Epoch 12/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3054 - val_loss: 0.3150 - learning_rate: 1.0000e-04
# Epoch 13/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3052 - val_loss: 0.3149 - learning_rate: 1.0000e-04
# Epoch 14/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3051 - val_loss: 0.3147 - learning_rate: 1.0000e-04
# Epoch 15/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3050 - val_loss: 0.3146 - learning_rate: 1.0000e-04
# Epoch 16/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3049 - val_loss: 0.3145 - learning_rate: 1.0000e-04
# Epoch 17/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3047 - val_loss: 0.3144 - learning_rate: 1.0000e-04
# Epoch 18/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3046 - val_loss: 0.3143 - learning_rate: 1.0000e-04
# Epoch 19/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3045 - val_loss: 0.3142 - learning_rate: 1.0000e-04
# Epoch 20/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3044 - val_loss: 0.3141 - learning_rate: 1.0000e-04
# Epoch 21/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3043 - val_loss: 0.3140 - learning_rate: 1.0000e-04
# Epoch 22/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3042 - val_loss: 0.3139 - learning_rate: 1.0000e-04
# Epoch 23/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3041 - val_loss: 0.3139 - learning_rate: 1.0000e-04
# Epoch 24/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3040 - val_loss: 0.3138 - learning_rate: 1.0000e-04
# Epoch 25/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3039 - val_loss: 0.3137 - learning_rate: 1.0000e-04
# Epoch 26/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3038 - val_loss: 0.3136 - learning_rate: 1.0000e-04
# Epoch 27/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3038 - val_loss: 0.3135 - learning_rate: 1.0000e-04
# Epoch 28/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3037 - val_loss: 0.3135 - learning_rate: 1.0000e-04
# Epoch 29/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3036 - val_loss: 0.3134 - learning_rate: 1.0000e-04
# Epoch 30/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3035 - val_loss: 0.3133 - learning_rate: 1.0000e-04
# Epoch 31/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3034 - val_loss: 0.3132 - learning_rate: 1.0000e-04
# Epoch 32/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3034 - val_loss: 0.3132 - learning_rate: 1.0000e-04
# Epoch 33/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3033 - val_loss: 0.3131 - learning_rate: 1.0000e-04
# Epoch 34/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3032 - val_loss: 0.3130 - learning_rate: 1.0000e-04
# Epoch 35/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3032 - val_loss: 0.3129 - learning_rate: 1.0000e-04
# Epoch 36/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3031 - val_loss: 0.3129 - learning_rate: 1.0000e-04
# Epoch 37/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3030 - val_loss: 0.3128 - learning_rate: 1.0000e-04
# Epoch 38/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3030 - val_loss: 0.3128 - learning_rate: 1.0000e-04
# Epoch 39/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3029 - val_loss: 0.3127 - learning_rate: 1.0000e-04
# Epoch 40/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3028 - val_loss: 0.3126 - learning_rate: 1.0000e-04
# Epoch 41/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3028 - val_loss: 0.3126 - learning_rate: 1.0000e-04
# Epoch 42/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3027 - val_loss: 0.3125 - learning_rate: 1.0000e-04
# Epoch 43/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3027 - val_loss: 0.3125 - learning_rate: 1.0000e-04
# Epoch 44/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3026 - val_loss: 0.3124 - learning_rate: 1.0000e-04
# Epoch 45/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3026 - val_loss: 0.3124 - learning_rate: 1.0000e-04
# Epoch 46/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3025 - val_loss: 0.3123 - learning_rate: 1.0000e-04
# Epoch 47/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3024 - val_loss: 0.3123 - learning_rate: 1.0000e-04
# Epoch 48/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3024 - val_loss: 0.3122 - learning_rate: 1.0000e-04
# Epoch 49/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3023 - val_loss: 0.3122 - learning_rate: 1.0000e-04
# Epoch 50/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3023 - val_loss: 0.3122 - learning_rate: 1.0000e-04
# Epoch 51/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3022 - val_loss: 0.3121 - learning_rate: 1.0000e-04
# Epoch 52/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3022 - val_loss: 0.3121 - learning_rate: 1.0000e-04
# Epoch 53/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3022 - val_loss: 0.3120 - learning_rate: 1.0000e-04
# Epoch 54/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3021 - val_loss: 0.3120 - learning_rate: 1.0000e-04
# Epoch 55/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3021 - val_loss: 0.3120 - learning_rate: 1.0000e-04
# Epoch 56/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3020 - val_loss: 0.3119 - learning_rate: 1.0000e-04
# Epoch 57/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3020 - val_loss: 0.3119 - learning_rate: 1.0000e-04
# Epoch 58/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3019 - val_loss: 0.3119 - learning_rate: 1.0000e-04
# Epoch 59/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3019 - val_loss: 0.3118 - learning_rate: 1.0000e-04
# Epoch 60/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3019 - val_loss: 0.3118 - learning_rate: 1.0000e-04
# Epoch 61/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3018 - val_loss: 0.3118 - learning_rate: 1.0000e-04
# Epoch 62/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3018 - val_loss: 0.3118 - learning_rate: 1.0000e-04
# Epoch 63/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3018 - val_loss: 0.3117 - learning_rate: 1.0000e-04
# Epoch 64/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3017 - val_loss: 0.3117 - learning_rate: 1.0000e-04
# Epoch 65/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3017 - val_loss: 0.3117 - learning_rate: 1.0000e-04
# Epoch 66/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3017 - val_loss: 0.3116 - learning_rate: 1.0000e-04
# Epoch 67/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3016 - val_loss: 0.3116 - learning_rate: 1.0000e-04
# Epoch 68/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3016 - val_loss: 0.3116 - learning_rate: 1.0000e-04
# Epoch 69/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3016 - val_loss: 0.3116 - learning_rate: 1.0000e-04
# Epoch 70/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3016 - val_loss: 0.3116 - learning_rate: 1.0000e-04
# Epoch 71/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.3015 - val_loss: 0.3115 - learning_rate: 1.0000e-04
# Epoch 72/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3015 - val_loss: 0.3115 - learning_rate: 1.0000e-04
# Epoch 73/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3015 - val_loss: 0.3115 - learning_rate: 1.0000e-04
# Epoch 74/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3015 - val_loss: 0.3115 - learning_rate: 1.0000e-04
# Epoch 75/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3014 - val_loss: 0.3114 - learning_rate: 1.0000e-04
# Epoch 76/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3014 - val_loss: 0.3114 - learning_rate: 1.0000e-04
# Epoch 77/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3014 - val_loss: 0.3114 - learning_rate: 1.0000e-04
# Epoch 78/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3014 - val_loss: 0.3114 - learning_rate: 1.0000e-04
# Epoch 79/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3013 - val_loss: 0.3114 - learning_rate: 1.0000e-04
# Epoch 80/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3013 - val_loss: 0.3114 - learning_rate: 1.0000e-04
# Epoch 81/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-05
# Epoch 82/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-05
# Epoch 83/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-05
# Epoch 84/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-05
# Epoch 85/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-05
# Epoch 86/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-05
# Epoch 87/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-05
# Epoch 88/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-06
# Epoch 89/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-06
# Epoch 90/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-06
# Epoch 91/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-06
# Epoch 92/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-06
# Epoch 93/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-07
# Epoch 94/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-07
# Epoch 95/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-07
# Epoch 96/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-07
# Epoch 97/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-07
# Epoch 98/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-08
# Epoch 99/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-08
# Epoch 100/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-08
# Epoch 101/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-08
# Epoch 102/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-08
# Epoch 103/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-09
# Epoch 104/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-09
# Epoch 105/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-09
# Epoch 106/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-09
# Epoch 107/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-09
# Epoch 108/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-10
# Epoch 109/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-10
# Epoch 110/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-10
# Epoch 111/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-10
# Epoch 112/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-10
# Epoch 113/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-11
# Epoch 114/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-11
# Epoch 115/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-11
# Epoch 116/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-11
# Epoch 117/2000
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3013 - val_loss: 0.3113 - learning_rate: 1.0000e-11

# %%
def nn_predict_2layer(X):
    """Prediction function of the neural network (log scale)."""
    df = pd.DataFrame(X, columns=x)
    df_scaled = nn_preprocessor.transform(df)
    pred = nn_model_2layer.predict(df_scaled, verbose=0, batch_size=10_000).flatten()
    return np.log(pred)

nn_explainer = shap.KernelExplainer(nn_predict_2layer, data=X_bg)
shap_nn = nn_explainer.shap_values(X_explain, nsamples=30)

all_dep_plots(x, shap_nn, X_explain)   # create all feature-dependency plots
# Out:
# WARNING:shap:Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# We first of all changed the activation function to relu which more advantageous in situatuions where we have hidden layers and data that has potential non-linear characteristics. This reduces strain on the training model and allows us to even move and predict faster.
#
# We added new hidden layers and increased number of neurons to allow the model to crunch numbers properly and prevent it from overweighing some parameters.
#
# We also increased number of epochs and lowered the batch size to allow more frequent test per epoch.
#
# Training, resting, splitting and vizualizing the model took 6 minutes and the result looks really close but not as perfect as we would want. We mainly wanted the NN to recogninze that driver_age data is non linear and forma parabola which is what it did. Our model started forming a slight curve to follow the data.
