# %% [markdown]
# # Square API-and-SDK Lab: &nbsp;&nbsp; _Payments and Processing_
#
# This lab challenge introduces you to a widely-used payments-processing API and SDK, from ***Square***
# + We will use the sandbox (for imagined transactions) and, at times, no API calls at all.
# + You'll create a business and business location...
# + You'll create transactions at your business...
# + You'll analyze the tradeoffs/savings from two different payment approaches for your business...
# + With reflection on the process as a whole. <br> <font size="-1">(and EC for creative data-visualization across multiple runs)</font>
#
# <br>
#
# [ Due by Sun. March 2 ] &nbsp;&nbsp; Setting up your Square developer account -- and taking a screenshot of a successful API call (using your authentication token) -- submit to Gradescope by 3/2.
#
#
# <br>
#
# [ Due by Sun. March 9 ] &nbsp;&nbsp;  Your copy of this notebook, its business, and analysis/reflection -- submit to Gradescope by 3/9. <br> <font size="-1">(Be sure to submit the <tt>.ipynb</tt> notebook file.)</font>
#
# <br>

# %% [markdown]
# ## Payment-project description and starter notebook
#
# This is the notebook from our computing-themed Payments day... &nbsp;&nbsp; <font size="-2">(Feb. 25, 2025)</font>

# %%
print("Our Business: Coffee Time!     (Our Consultancy: Pay Up...)")

# %% [markdown]
# ### <font color="DodgerBlue">Payments: &nbsp; _Project Description_</font>
#
# This is at the bottom of this notebook, as well.
#
# Examples from here to the end will walk you through getting started. Your task is to, **first**, get those payment-simulations to work, for your Square business (and your Square access token)...
#
# **Then**, add a comparative analysis between two types - and costs - of payment-making, either from one of these four possible sets of alternatives, or from a contrast (pair of alternatives) of your own design.
#
# <br>
# <hr>
# <br>
#
#
# #### <font color="Coral"><b>HW Tasks</b></font>: &nbsp;&nbsp;  <font size="-1">details for this payments hw...</font>
#
# 1. Make sure the analysis cells (below) are working for you... _Then_,
# 1. Choose an analysis to undertake. It can be one of our four suggested ones or one of your own:
#    + <font color="DodgerBlue"><b>the "CFF" program</b></font>: _How much would the Merchant gain if it created a CFF program where one person (the CFF) paid for all of their friends each time, resulting in fewer charges?_ (and how much could be passed along to the CFF customer?)
#       + You'll have to include in the payment - perhaps in the _Notes_ field - ***how many*** people each CFF paid for, each time, and use that value to compute the savings...
#    + <font color="DodgerBlue"><b>the "CoffeeCash" program</b></font>: _How much would the Merchant gain if it could consolidate all of the orders from a single customer over the course of, say, a week?_ This also would result in fewer charges. (Part of this could be passed along, in theory...)
#       + Here, Square will compute how much it would have charged the Merchant... and you'll compute the lower amount _after_ consolidation.
#    + <font color="DodgerBlue"><b>the pitch for the _Merchant_ to join "Cube"</b></font>: &nbsp; Cube is an _imagined_ variant of Square that uses FedNow instead of Credit Cards. How much would the Merchant save with Cube?
#       + Here, just use the nominal amounts of FedNow vs Square's charges. [Here is the FedNow Fee Schedule](https://www.frbservices.org/resources/fees/fednow-2025). (The top line is the one to use. The $25/month is waived this year.)
#    + <font color="DodgerBlue"><b>the pitch for Square to _become_ "Cube"</b></font>: &nbsp; As a consultant, you are considering pitching that Square itself roll out a new premium brand, named _Cube_ &nbsp; (perhaps as a new "dimension" in payment-processing.) It uses FedNow instead of Credit Cards. How much would **Square** benefit in this case?
#       + Just use the nominal amounts for FedNow vs CCards, for this hw...
#       + This is <u>not</u> the same as the previous one! This one compares FedNow vs CCards, instead of FedNow vs Square! (As a result, this one's a bit more "real" ... if only a bit!)
#    + <font color="DodgerBlue"><b>Other payment ideas?</b></font> &nbsp; ***Great!*** &nbsp; Feel free to use your own idea here, as long as it compares two real, or real-ish, payment approaches. Os, save them as part of your business-creation project at course's end.
# 1. Change the simulation to match your business's details 😀  You can stick with coffee - or choose another realm.
# 1. Change the simulation so that you're comparing two different approaches to handling payments.
# 1. Be sure to run small-as-possible tests to make sure things work well
#    + Debug as needed -- Remember, debug locally and only use the real requests when it seems entirely debugged...
# 1. Live-test your shop's "bustle," perhaps looping over five payments.
# 1. Then, grab those last five payments from Square's API.
# 1. **Analyze** these five, prototyping and debugging your analysis
# 1. Through that analysis, compare the costs of the two payment approaches you're using.
# 1. Then, try the whole workflow for a larger set of new payments, perhaps a few dozen? 42? 100?
#    + No need for more than this, unless you'd like to...
# 1. Finally, create a short write up with
#    + your choice of payment-approaches to analyze (and your choice of business, if you changed it from coffee 😀)
#    + note any API customizations you needed to investigate the business-intervention
#      + For example, the CFF requires an additional piece of information: how many people the purchaser was covering
#      + There is plenty of freedom here, and not every approach needs extra info
#    + include the results of your analysis
#    + are there other variations (of the comparison you made) worth noting -- what are the tradeoffs? It doesn't need to be a market-winning idea or even a reasonable idea, just an idea...
#      + This might seem unneeded, but it's often helpful, even if silly, obvious, or outlandish. <br> <font size="-1">(We all -- rightly -- like making decisions within a "trade-off space.")</font>
#
# <font color="DodgerBlue"><b>EC #1</b></font> &nbsp; (up to +10%) <font size="-1"> for computing each strategy's different resulting profits (or costs) over time -- and then plotting these values on the same axes. For example, the horizontal (x) axis could be the number of customers seen. The vertical (y) axis would be the value (whether profit or costs). </font>
#
# <font color="Coral"><b>EC #2</b></font> &nbsp; (up to _another_ +10%) <font size="-1">for running the entire above simulation "lots" of times (up to you: more than 500) and then, across all those runs, plotting the _averages_, the _90th percentile_, and the _10th percentile_ at each step. Extra fun if the percentiles are shown as a "translucent error band." AI - and Seaborn's <tt>lineplot</tt> - might help. See its [examples](https://seaborn.pydata.org/examples/index.html) below the documentation.  </font>

# %% [markdown]
# ### Reminder: _Web requests_

# %%
#
# Reminder of how a "web-scraping" call works with requests
#

import requests

url = "https://www.cs.hmc.edu/~dodds/demo.html"   # this is sometimes called an "endpoint" ...
result = requests.get(url)
result

# if it succeeds, you should see <Response [200]>

# %%
#
# Notice that, as we explore, it's GOOD TO SEPARATE the request from its analysis...
#        We'll keep doing this...

print(result.text)   # the "demo page"

# %% [markdown]
# #### Other HTTP approaches worth knowing:
# + <tt>curl</tt>: &nbsp; client url, a command-line utility for web calls
# + in-browser resources, always
# + a provided <tt>SDK</tt> or _Software Development Kit_
#   + we'll use one below

# %%
#
# curl is "easier" than requests and other programmatic methods
#
# The initial ! tells the notebook to run at the command-line, not Python:

# !curl https://www.cs.hmc.edu/~dodds/demo.html

# "getting" the output is trickier, however!

# %% [markdown]
# ### Reminder: _API calls_
#
# universally considered the "more ethical" side of automatic HTTP

# %%
#
# We could use curl for API calls:

# !curl http://api.open-notify.org/iss-now.json

# Notice that the result is printed, not returned...

# %%
#
# curl is useful for its many parameters, e.g., -I gets the HTTP "headers"
#      which are unseen meta-data sent along with the visible part of a request:

# !curl -I  http://api.open-notify.org/iss-now.json

# !curl -I  https://www.cs.hmc.edu/~dodds/demo.html

# %% [markdown]
# #### Let's use requests to make an API call to obtain the ISS's position in JSON
# + Acronyms!
# + API == Application Programming Interface
# + ISS == International Space Station (not really Fintech-relevant, but...)
# + JSON == Javascript Object Notation, which are Python dictionaries
#
# Also:
# + SDK == Software Development Kit (a _whole set_ of APIs)

# %%
#
# Reminder of how API calls work using requests...

import requests

url = "http://api.open-notify.org/iss-now.json"   # this is sometimes called an "endpoint" ...
result = requests.get(url)
result

# if it succeeds, you should see <Response [200]>

# %%
#
# In this case, we know the result is a JSON file, and we can obtain it that way:

contents = result.json()      # needs to convert the text to a json dictionary...
print(f"The json data is {contents}")     # Aha!  Let's re/introduce f-strings...

# Take a look... what is a JSON object in Python terms?

# %%
#
# Let's re-remind ourselves how dictionaries work:

lat = contents['iss_position']['longitude']
lat = float(lat)
print(lat)

# %% [markdown]
# ### Getting started with the Square API
#
# This is the API, not yet the SDK...
# + Application programming interface ("the web calls")  vs.
# + Software Development Kit ("the library")

# %% [markdown]
# #### Let's run the &nbsp; _Locations_ &nbsp; API via <tt>curl</tt>

# %%
# !curl https://connect.squareupsandbox.com/v2/locations \
  -H 'Square-Version: 2025-02-20' \
  -H 'Authorization: Bearer <token_goes_here_get_rid_of_angle_brackets_too>' \
  -H 'Content-Type: application/json'
# Out:
# {
#   "errors": [
#     {
#       "category": "AUTHENTICATION_ERROR",
#       "code": "UNAUTHORIZED",
#       "detail": "This request could not be authorized."
#     }
#   ]
# }

# %% [markdown]
# #### It won't work!
#
# You <font color="Coral"><b>need an account</b></font>, which will provide that "Bearer Token"
# + You should create an account from this [Square Developer Account page](https://developer.squareup.com/docs/get-started/create-account-and-application)
# + Helpfully, it shares all of the information it needs. As the "software development business," feel free to use your Fintech project's name or "Econ176" or a variation of your own choosing...
# + Then, you can click on ["Make your first API call"](https://developer.squareup.com/docs/get-started/make-api-request)
# + Perhaps keep a copy of your access token somewhere non-public. (You can always get it again from Square.)
# + As long as you don't share your team's copy of this notebook out, it's ok simply to keep it in here.
# + And, you're on your way... !

# %%
#
# Set an environment variable to YOUR access token

import os
os.environ['SQUARE_ACCESS_TOKEN'] = "EAAAl6T5fHr7G-QYZsy12yQy_MjVQg1WisTJtpyHyN_72g1F6tIdhoUg2GB4HzAG"

# %%
# We can also use Colab's secrets. (This is not required. Just to show they're there.)

# from google.colab import userdata
# userdata.get('number')

# %% [markdown]
# ## Onward, to the Square libraries
#
# These are usually called "the SDK" or the _Software Development Kit_
#
# For Square, the Python library (SDK) is called `squareup`
#
# Colab includes <tt>requests</tt> by default, but it doesn't include the <tt>squareup</tt> library by default, so we install it here:

# %%
# install the squareup library, if it's not already installed

# !pip install squareup
# Out:
# Collecting squareup
#   Downloading squareup-40.1.0.220250220-py3-none-any.whl.metadata (6.0 kB)
# Collecting apimatic-core>=0.2.17,~=0.2.0 (from squareup)
#   Downloading apimatic_core-0.2.19-py3-none-any.whl.metadata (13 kB)
# Collecting apimatic-core-interfaces>=0.1.5,~=0.1.0 (from squareup)
#   Downloading apimatic_core_interfaces-0.1.6-py3-none-any.whl.metadata (3.3 kB)
# Collecting apimatic-requests-client-adapter>=0.1.6,~=0.1.0 (from squareup)
#   Downloading apimatic_requests_client_adapter-0.1.7-py3-none-any.whl.metadata (3.4 kB)
# Collecting deprecation~=2.1 (from squareup)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting jsonpickle~=3.3.0 (from apimatic-core>=0.2.17,~=0.2.0->squareup)
#   Downloading jsonpickle-3.3.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: python-dateutil~=2.8 in /usr/local/lib/python3.11/dist-packages (from apimatic-core>=0.2.17,~=0.2.0->squareup) (2.8.2)
# Requirement already satisfied: requests~=2.31 in /usr/local/lib/python3.11/dist-packages (from apimatic-core>=0.2.17,~=0.2.0->squareup) (2.32.3)
# Requirement already satisfied: setuptools>=68.0.0 in /usr/local/lib/python3.11/dist-packages (from apimatic-core>=0.2.17,~=0.2.0->squareup) (75.1.0)
# Collecting jsonpointer~=2.3 (from apimatic-core>=0.2.17,~=0.2.0->squareup)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting cachecontrol~=0.12.6 (from apimatic-requests-client-adapter>=0.1.6,~=0.1.0->squareup)
#   Downloading CacheControl-0.12.14-py2.py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from deprecation~=2.1->squareup) (24.2)
# Requirement already satisfied: msgpack>=0.5.2 in /usr/local/lib/python3.11/dist-packages (from cachecontrol~=0.12.6->apimatic-requests-client-adapter>=0.1.6,~=0.1.0->squareup) (1.1.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil~=2.8->apimatic-core>=0.2.17,~=0.2.0->squareup) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests~=2.31->apimatic-core>=0.2.17,~=0.2.0->squareup) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests~=2.31->apimatic-core>=0.2.17,~=0.2.0->squareup) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests~=2.31->apimatic-core>=0.2.17,~=0.2.0->squareup) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests~=2.31->apimatic-core>=0.2.17,~=0.2.0->squareup) (2025.1.31)
# Downloading squareup-40.1.0.220250220-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.9/117.9 kB 4.4 MB/s eta 0:00:00
# Downloading apimatic_core-0.2.19-py3-none-any.whl (123 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.7/123.7 kB 8.8 MB/s eta 0:00:00
# Downloading apimatic_core_interfaces-0.1.6-py3-none-any.whl (7.6 kB)
# Downloading apimatic_requests_client_adapter-0.1.7-py3-none-any.whl (11 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading CacheControl-0.12.14-py2.py3-none-any.whl (21 kB)
# Downloading jsonpickle-3.3.0-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 kB 2.8 MB/s eta 0:00:00
# Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Installing collected packages: apimatic-core-interfaces, jsonpointer, jsonpickle, deprecation, cachecontrol, apimatic-core, apimatic-requests-client-adapter, squareup
#   Attempting uninstall: jsonpointer
#     Found existing installation: jsonpointer 3.0.0
#     Uninstalling jsonpointer-3.0.0:
#       Successfully uninstalled jsonpointer-3.0.0
#   Attempting uninstall: jsonpickle
#     Found existing installation: jsonpickle 4.0.2
#     Uninstalling jsonpickle-4.0.2:
#       Successfully uninstalled jsonpickle-4.0.2
#   Attempting uninstall: cachecontrol
#     Found existing installation: CacheControl 0.14.2
#     Uninstalling CacheControl-0.14.2:
#       Successfully uninstalled CacheControl-0.14.2
# Successfully installed apimatic-core-0.2.19 apimatic-core-interfaces-0.1.6 apimatic-requests-client-adapter-0.1.7 cachecontrol-0.12.14 deprecation-2.1.0 jsonpickle-3.3.0 jsonpointer-2.4 squareup-40.1.0.220250220

# %%
#
# here is the SDK ...    (officially, Square's _Python_ SDK)

import square

# %%
from square.http.auth.o_auth_2 import BearerAuthCredentials
from square.client import Client
import os

client = Client(
    bearer_auth_credentials=BearerAuthCredentials(
        access_token=os.environ['SQUARE_ACCESS_TOKEN']    # You've likely included this above. Note: don't github it/release it!
    ),
    environment='sandbox')

# Old version uses only the access_token line.

# Let's see our client object:
client

# %%
# if we want to see all of the capabilities of our SDK:

for attribute in dir(client):
    if "__" not in attribute:   # skip the Python-specific ones ...
        print(attribute)        # let's see the Square-specific ones
# Out:
# apple_pay
# auth_managers
# bank_accounts
# booking_custom_attributes
# bookings
# cards
# cash_drawers
# catalog
# checkout
# config
# customer_custom_attributes
# customer_groups
# customer_segments
# customers
# devices
# disputes
# employees
# events
# gift_card_activities
# gift_cards
# global_configuration
# inventory
# invoices
# labor
# location_custom_attributes
# locations
# loyalty
# merchant_custom_attributes
# merchants
# mobile_authorization
# o_auth
# order_custom_attributes
# orders
# payments
# payouts
# refunds
# sdk_version
# sites
# snippets
# square_version
# subscriptions
# team
# terminal
# transactions
# user_agent_detail
# v1_transactions
# vendors
# webhook_subscriptions

# %%
#
# here is the API call to list the locations!

result = client.locations.list_locations()
result
# Out:
# <ApiResponse {"locations": [{"id": "L59TJX72SCJSQ","name": "Coffee Time, Downtown Pittsburgh Branch","address": {"address_line_1": "326 Third Avenue","locality": "Pittsburgh","administrative_district_level_1": "PA","postal_code": "15222","country": "US"},"timezone": "UTC","capabilities": ["CREDIT_CARD_PROCESSING","AUTOMATIC_TRANSFERS"],"status": "ACTIVE","created_at": "2025-03-13T18:32:54.128Z","merchant_id": "ML6P7FBVYE51F","country": "US","language_code": "en-US","currency": "USD","business_name": "Coffee Time","type": "PHYSICAL","business_hours": {},"description": "Stillers Swillers","mcc": "7299"},{"id": "L6DJMTAEEWBDV","name": "Default Test Account","address": {"address_line_1": "1600 Pennsylvania Ave NW","locality": "Washington","administrative_district_level_1": "DC","postal_code": "20500","country": "US"},"timezone": "UTC","capabilities": ["CREDIT_CARD_PROCESSING","AUTOMATIC_TRANSFERS"],"status": "ACTIVE","created_at": "2025-02-25T18:48:19.647Z","merchant_id": "ML6P7FBVYE51F","country": "US","language_code": "en-US","currency": "USD","business_name": "Default Test Account","type": "PHYSICAL","business_hours": {},"mcc": "7299"}]}
# >

# %%
# get attributes of the result object
print("Attributes (data and functions) of result:")
for item in dir(result):
    if "__" not in item:
        print(item)
# Out:
# Attributes (data and functions) of result:
# body
# create
# cursor
# errors
# headers
# is_error
# is_success
# reason_phrase
# request
# status_code
# text

# %%
# here's one that's data:
result.status_code
# Out:
# 200

# %%
# here's one that's a function:
result.is_success()
# Out:
# True

# %% [markdown]
# <b>Yay!</b> we've made our first successful SDK-based programs.
#
# Programs which, in turn, made successful API calls...
#
# It's best (when hand-testing) to separate the network calls (API calls) from the analysis of their results, since there will definitely be lots of debugging as you develop that analysis ...
#
# ... and also develop an _internal_ conceptual model of the data!

# %%
# separating the network (API) call from the analysis of its results
#     means using result without re-retrieving it from Square. For example,

if result.is_success():
  print(f"result.body is", result.body)
elif result.is_error():
  print(f"result.errors are", result.errors)
# Out:
# result.body is {'locations': [{'id': 'L59TJX72SCJSQ', 'name': 'Coffee Time, Downtown Pittsburgh Branch', 'address': {'address_line_1': '326 Third Avenue', 'locality': 'Pittsburgh', 'administrative_district_level_1': 'PA', 'postal_code': '15222', 'country': 'US'}, 'timezone': 'UTC', 'capabilities': ['CREDIT_CARD_PROCESSING', 'AUTOMATIC_TRANSFERS'], 'status': 'ACTIVE', 'created_at': '2025-03-13T18:32:54.128Z', 'merchant_id': 'ML6P7FBVYE51F', 'country': 'US', 'language_code': 'en-US', 'currency': 'USD', 'business_name': 'Coffee Time', 'type': 'PHYSICAL', 'business_hours': {}, 'description': 'Stillers Swillers', 'mcc': '7299'}, {'id': 'L6DJMTAEEWBDV', 'name': 'Default Test Account', 'address': {'address_line_1': '1600 Pennsylvania Ave NW', 'locality': 'Washington', 'administrative_district_level_1': 'DC', 'postal_code': '20500', 'country': 'US'}, 'timezone': 'UTC', 'capabilities': ['CREDIT_CARD_PROCESSING', 'AUTOMATIC_TRANSFERS'], 'status': 'ACTIVE', 'created_at': '2025-02-25T18:48:19.647Z', 'merchant_id': 'ML6P7FBVYE51F', 'country': 'US', 'language_code': 'en-US', 'currency': 'USD', 'business_name': 'Default Test Account', 'type': 'PHYSICAL', 'business_hours': {}, 'mcc': '7299'}]}

# %% [markdown]
# It's <tt>json</tt>, so we can use the <tt>json</tt> library...

# %%
# Let's print more readably.  To do so, let's use Python's JSON library:

import json

if result.is_success():
    print("result.body is")
    print(json.dumps(result.body, indent=2))
elif result.is_error():
    print("result.errors are")
    print(result.errors)
# Out:
# result.body is
# {
#   "locations": [
#     {
#       "id": "L59TJX72SCJSQ",
#       "name": "Coffee Time, Downtown Pittsburgh Branch",
#       "address": {
#         "address_line_1": "326 Third Avenue",
#         "locality": "Pittsburgh",
#         "administrative_district_level_1": "PA",
#         "postal_code": "15222",
#         "country": "US"
#       },
#       "timezone": "UTC",
#       "capabilities": [
#         "CREDIT_CARD_PROCESSING",
#         "AUTOMATIC_TRANSFERS"
#       ],
#       "status": "ACTIVE",
#       "created_at": "2025-03-13T18:32:54.128Z",
#       "merchant_id": "ML6P7FBVYE51F",
#       "country": "US",
#       "language_code": "en-US",
#       "currency": "USD",
#       "business_name": "Coffee Time",
#       "type": "PHYSICAL",
#       "business_hours": {},
#       "description": "Stillers Swillers",
#       "mcc": "7299"
#     },
#     {
#       "id": "L6DJMTAEEWBDV",
#       "name": "Default Test Account",
#       "address": {
#         "address_line_1": "1600 Pennsylvania Ave NW",
#         "locality": "Washington",
#         "administrative_district_level_1": "DC",
#         "postal_code": "20500",
#         "country": "US"
#       },
#       "timezone": "UTC",
#       "capabilities": [
#         "CREDIT_CARD_PROCESSING",
#         "AUTOMATIC_TRANSFERS"
#       ],
#       "status": "ACTIVE",
#       "created_at": "2025-02-25T18:48:19.647Z",
#       "merchant_id": "ML6P7FBVYE51F",
#       "country": "US",
#       "language_code": "en-US",
#       "currency": "USD",
#       "business_name": "Default Test Account",
#       "type": "PHYSICAL",
#       "business_hours": {},
#       "mcc": "7299"
#     }
#   ]
# }

# %%
#
# further analysis of the "component pieces" of result:

if result.is_success():
    for location in result.body['locations']:
        print(f"{location['id']}: ", end="")
        print(f"{location['name']}, ", end="")
        print(f"{location['address']['address_line_1']}, ", end="")
        print(f"{location['address']['locality']}")
        if 'description' in location: print(f"{location['description']}")
        else: print("<no description>")

elif result.is_error():
    for error in result.errors:
        print(error['category'])
        print(error['code'])
        print(error['detail'])
# Out:
# L59TJX72SCJSQ: Coffee Time, Downtown Pittsburgh Branch, 326 Third Avenue, Pittsburgh
# Stillers Swillers
# L6DJMTAEEWBDV: Default Test Account, 1600 Pennsylvania Ave NW, Washington
# <no description>

# %% [markdown]
# #### Let's _create_ a location...

# %%
#
# call!  (POST)  Please change this address for your own branch location!
#    Note: a _POST_ call requires a body of information that is sent in the API call:
#
# You should be wondering... how would I know what fields to include and how to include them?!
#    Answer:
# Square has an online API interface that helps with this!
#    It's here:   https://developer.squareup.com/explorer/square/locations-api/create-location

result = client.locations.create_location(
  body = {
    "location": {
      "name": "Coffee Time, Downtown Pittsburgh Branch ",
      "business_name": "Coffee Time",
      "description": "Stillers Swillers",
      "address": {
        "address_line_1": "326 Third Avenue",
        "locality": "Pittsburgh",
        "administrative_district_level_1": "PA",
        "postal_code": "15222"
      }
    }
  }
)
result.status_code
# Out:
# 400

# %%
# separating the network (API) call from the analysis of its results:

import json

if result.is_success():
  print(json.dumps(result.body, indent=2))
elif result.is_error():
  print(result.errors)
# Out:
# [{'code': 'BAD_REQUEST', 'detail': 'Location names must be unique within a merchant account', 'field': 'name', 'category': 'INVALID_REQUEST_ERROR'}]

# %% [markdown]
# #### Next, let's try the <u><i>Payments</i></u> API!

# %%
#
# here is the API call to list the payments so far (with default parameters):

result = client.payments.list_payments()
result.status_code
# Out:
# 200

# %%
# again, separating the network (API) call from the analysis of its results:

import json

if result.is_success():
  print(json.dumps(result.body, indent=2))
elif result.is_error():
  print(result.errors)
# Out:
# {
#   "payments": [
#     {
#       "id": "bRspCCoxCxfu0OFWWXVwmZz6t6dZY",
#       "created_at": "2025-03-15T03:32:16.648Z",
#       "updated_at": "2025-03-15T03:32:18.311Z",
#       "amount_money": {
#         "amount": 1891,
#         "currency": "USD"
#       },
#       "status": "COMPLETED",
#       "delay_duration": "PT168H",
#       "source_type": "CARD",
#       "card_details": {
#         "status": "CAPTURED",
#         "card": {
#           "card_brand": "VISA",
#           "last_4": "5858",
#           "exp_month": 3,
#           "exp_year": 2027,
#           "fingerprint": "sq-1-6bO_U7mtbWRtd9NmqzXISdpW8uWBe5JSikyW40PxS351Nw8c_MOmm6Owvl1o95isyA",
#           "card_type": "CREDIT",
#           "prepaid_type": "NOT_PREPAID",
#           "bin": "453275"
#         },
#         "entry_method": "KEYED",
#         "cvv_status": "CVV_ACCEPTED",
#         "avs_status": "AVS_ACCEPTED",
#         "statement_description": "SQ *DEFAULT TEST ACCOUNT",
#         "card_payment_timeline": {
#           "authorized_at": "2025-03-15T03:32:16.779Z",
#           "captured_at": "2025-03-15T03:32:16.885Z"
#         }
#       },
#       "location_id": "L6DJMTAEEWBDV",
#       "order_id": "pjLOXwXzQ8lbFsx5c9CL031sA4OZY",
#       "risk_evaluation": {
#         "created_at": "2025-03-15T03:32:16.779Z",
#         "risk_level": "NORMAL"
#       },
#       "processing_fee": [
#         {
#           "effective_at": "2025-03-15T05:32:18.000Z",
#           "type": "INITIAL",
#           "amount_money": {
#             "amount": 85,
#             "currency": "USD"
#           }
#         }
#       ],
#       "buyer_email_address": "cff@

#             "currency": "USD"
#           }
#         }
#       ],
#       "buyer_email_address": "cff@pitzer.edu",
#       "note": "Venti PhilzPour",
#       "total_money": {
#         "amount": 1468,
#         "currency": "USD"
#       },
#       "approved_money": {
#         "amount": 1468,
#         "currency": "USD"
#       },
#       "receipt_number": "pMQY",
#       "receipt_url": "https://squareupsandbox.com/receipt/preview/pMQYTOqXro33HCXAtXBSmJYOryDZY",
#       "delay_action": "CANCEL",
#       "delayed_until": "2025-03-22T03:25:28.273Z",
#       "application_details": {
#         "square_product": "ECOMMERCE_API",
#         "application_id": "sandbox-sq0idb-YP5gnUWm9NRiLUmEeQRhGA"
#       },
#       "version_token": "fIBgnvYYge7GU2xS3EwVVBzSKhg31o0j96oOeQJSmVT6o"
#     },
#     {
#       "id": "NsVpOxCo9UknI19sAR1D7QCwBPTZY",
#       "created_at": "2025-03-15T03:25:24.631Z",
#       "updated_at": "2025-03-15T03:25:25.966Z",
#       "amount_money": {
#         "amount": 1495,
#         "currency": "USD"
#       },
#       "status": "COMPLETED",
#       "delay_duration": "PT168H",
#       "source_type": "CARD",
#       "card_details": {
#         "status": "CAPTURED",
#         "card": {
#           "card_brand": "VISA",
#           "last_4": "5858",
#           "exp_month": 3,
#           "exp_year": 2027,
#           "fingerprint": "sq-1-6bO_U7mtbWRtd9NmqzXISdpW8uWBe5JSikyW40PxS351Nw8c_MOmm6Owvl1o95isyA",
#           "card_type": "CREDIT",
#           "prepaid_type": "NOT_PREPAID",
#           "bin": "453275"
#         },
#         "entry_method": "KEYED",
#         "cvv_status": "CVV_ACCEPTED",
#         "avs_status": "AVS_ACCEPTED",
#         "statement_description": "SQ *DEFAULT TEST ACCOUNT",
#         "card_payment_timeline": {
#           "authorized_at": "2025-03-15T03:25:24.760Z",
#           "captured_at": "2025-03-15T03:25:24.876Z"
#         }
#       },
#       "location_id": "L6DJMTAEEWBDV",
#       "order_id": "prHEksV7lzsVVcy6DB3dB29FwZYZY",
#       "risk_evaluation": {
#         "created_at": "2025-03-15T03:25:24.761Z",
#         "risk_level": "NORMAL"
#       },
#       "processing_fee": [
#         {
#           "effective_at": "2025-03-15T05:25:25.000Z",
#           "type": "INITIAL",
#           "amount_money": {
#             "amount": 73,
#             "currency": "USD"
#           }
#         }
#       ],
#       "buyer_email_address": "cff@pomona.edu",
#       "note": "Venti Cometeer",
#       "total_money": {
#         "amount": 1495,
#         "currency": "USD"
#       },
#       "approved_money": {
#         "amount": 1495,
#         "currency": "USD"
#       },
#       "receipt_number": "NsVp",
#       "receipt_url": "https://squareupsandbox.com/receipt/preview/NsVpOxCo9UknI19sAR1D7QCwBPTZY",
#       "delay_action": "CANCEL",
#       "delayed_until": "2025-03-22T03:25:24.631Z",
#       "application_details": {
#         "square_product": "ECOMMERCE_API",
#         "application_id": "sandbox-sq0idb-YP5gnUWm9NRiLUmEeQRhGA"
#       },
#       "version_token": "QfyqAjIU1mi7SNk5ZYjnjDE8sPCtmI2w4u9ZmmepGjj6o"
#     },
#     {
#       "id": "L3P5XCiPkDUKSIq3gx4tugnautXZY",
#       "created_at": "2025-03-15T03:25:20.949Z",
#       "updated_at": "2025-03-15T03:25:22.325Z",
#       "amount_money": {
#         "amount": 904,
#         "currency": "USD"
#       },
#       "status": "COMPLETED",
#       "delay_duration": "PT168H",
#       "source_type": "CARD",
#       "card_details": {
#         "status": "CAPTURED",
#         "card": {
#           "card_brand": "VISA",
#           "last_4": "5858",
#           "exp_month": 3,
#           "exp_year": 2027,
#           "fingerprint": "sq-1-6bO_U7mtbWRtd9NmqzXISdpW8uWBe5JSikyW40PxS351Nw8c_MOmm6Owvl1o95isyA",
#           "card_type": "CREDIT",
#           "prepaid_type": "NOT_PREPAID",
#           "bin": "453275"
#         },
#         "entry_method": "KEYED",
#         "cvv_status": "CVV_ACCEPTED",
#         "avs_status": "AVS_ACCEPTED",
#         "statement_description": "SQ *DEFAULT TEST ACCOUNT",
#         "card_payment_timeline": {
#           "authorized_at": "2025-03-15T03:25:21.085Z",
#           "captured_at": "2025-03-15T03:25:21.194Z"
#         }
#       },
#       "location_id": "L6DJMTAEEWBDV",
#       "order_id": "lvuo5Gj1pIFnWj2JzFJq5tbwxNAZY",
#       "risk_evaluation": {
#         "created_at": "2025-03-15T03:25:21.085Z",
#         "risk_level": "NORMAL"
#       },
#       "processing_fee": [
#         {
#           "effective_at": "2025-03-15T05:25:22.000Z",
#           "type": "INITIAL",
#           "amount_money": {
#             "amount": 56,
#             "currency": "USD"
#           }
#         }
#       ],
#       "buyer_email_address": "cff@pitzer.edu",
#       "note": "Quarantadue Cometeer",
#       "total_money": {
#         "amount": 904,
#         "currency": "USD"
#       },
#       "approved_money": {
#         "amount": 904,
#         "currency": "USD"
#       },
#       "receipt_number": "L3P5",
#       "receipt_url": "https://squareupsandbox.com/receipt/preview/L3P5XCiPkDUKSIq3gx4tugnautXZY",
#       "delay_action": "CANCEL",
#       "delayed_until": "2025-03-22T03:25:20.949Z",
#       "application_details": {
#         "square_product": "ECOMMERCE_API",
#         "application_id": "sandbox-sq0idb-YP5gnUWm9NRiLUmEeQRhGA"
#       },
#       "version_token": "2bP1ILclJc3hLYsrwrAXBVLUjeIHvqrpy07Zf85RaVP6o"
#     },
#     {
#       "id": "XtDrlmdLXDy1mmiAavKtdbwASWbZY",
#       "created_at": "2025-03-15T03:25:15.304Z",
#       "updated_at": "2025-03-15T03:25:17.154Z",
#       "amount_money": {
#         "amount": 1163,
#         "currency": "USD"
#       },
#       "status": "COMPLETED",
#       "delay_duration": "PT168H",
#       "source_type": "CARD",
#       "card_details": {
#         "status": "CAPTURED",
#         "card": {
#           "card_brand": "VISA",
#           "last_4": "5858",
#           "exp_month": 3,
#           "exp_year": 2027,
#           "fingerprint": "sq-1-6bO_U7mtbWRtd9NmqzXISdpW8uWBe5JSikyW40PxS351Nw8c_MOmm6Owvl1o95isyA",
#           "card_type": "CREDIT",
#           "prepaid_type": "NOT_PREPAID",
#           "bin": "453275"
#         },
#         "entry_method": "KEYED",
#         "cvv_status": "CVV_ACCEPTED",
#         "avs_status": "AVS_ACCEPTED",
#         "statement_description": "SQ *DEFAULT TEST ACCOUNT",
#         "card_payment_timeline": {
#           "authorized_at": "2025-03-15T03:25:15.433Z",
#           "captured_at": "2025-03-15T03:25:15.545Z"
#         }
#       },
#       "location_id": "L6DJMTAEEWBDV",
#       "order_id": "xB69qcApgq81wbZRoL2R0cMaiHFZY",
#       "risk_evaluation": {
#         "created_at": "2025-03-15T03:25:15.433Z",
#         "risk_level": "NORMAL"
#       },
#       "processing_fee": [
#         {
#           "effective_at": "2025-03-15T05:25:17.000Z",
#           "type": "INITIAL",
#           "amount_money": {
#             "amount": 64,
#             "currency": "USD"
#           }
#         }
#       ],
#       "buyer_email_address": "cff@pitzer.edu",
#       "note": "Venti Cometeer",
#       "total_money": {
#         "amount": 1163,
#         "currency": "USD"
#       },
#       "approved_money": {
#         "amount": 1163,
#         "currency": "USD"
#       },
#       "receipt_number": "XtDr",
#       "receipt_url": "https://squareupsandbox.com/receipt/preview/XtDrlmdLXDy1mmiAavKtdbwASWbZY",
#       "delay_action": "CANCEL",
#       "delayed_until": "2025-03-22T03:25:15.304Z",
#       "application_details": {
#         "square_product": "ECOMMERCE_API",
#         "application_id": "sandbox-sq0idb-YP5gnUWm9NRiLUmEeQRhGA"
#       },
#       "version_token": "Gh6IoigcbZ5eb7sEWFk5QzlM1m6M7RfQXtLsYDTLTXI6o"
#     }
#   ],
#   "cursor": "eyJjcmVhdGVkQXQiOjE3NDIwMDkxMTUzMDQsImlkIjoiWHREcmxtZExYRHkxbW1pQWF2S3RkYndBU1diWlkifQ"
# }

# %% [markdown]
# #### Creating a payment from the SDK
#
# Like locations, new payments are POSTed...
#
# ... meaning that a "body" of data is sent along with the request to create that entry in Square's remote database (which is really all that's happening, from a developer point of view...)
#
# <br>
#
# <b>However</b>, it's important to avoid accidentally POSTing a payment twice (duplicate charge)
#
# <br>
#
# So one <tt>idemopotency_key</tt> is constructed and attached to each payment. Running twice only POSTs once:

# %%
#
# create an idempotency key...
#
# in general, we'd keep this separate from the call below
# however, for a simulation of many payments, we _need_ a separate idempotency key for each!
#

# Python's library for unique identifiers is uuid:

import uuid
idempotency_key = str(uuid.uuid4())   # this generates a random value
print(f"idempotency_key: {idempotency_key}")
# Out:
# idempotency_key: 2032e06d-d570-4485-9f59-926f8fbcdab4

# %%
#
# With that in place, here's a bare-bones SDK call to create a payment:

result = client.payments.create_payment(
  body = {
    "source_id": "cnon:card-nonce-ok",
    "idempotency_key": idempotency_key,
    "amount_money": {
      "amount": 42,
      "currency": "USD"
    },
    "autocomplete": True,
    "accept_partial_authorization": False    # this and autocomplete can't both be True
  }
)
result.status_code
# Out:
# 200

# %%
#
# Again, separating the network call (API) from the analysis of its result
#

import json

if result.is_success():
  print(json.dumps(result.body, indent=2))
elif result.is_error():
  print(result.errors)
# Out:
# {
#   "payment": {
#     "id": "ZirYypVPBxBmBeD9IrOOSo3o1BDZY",
#     "created_at": "2025-03-15T02:54:56.642Z",
#     "updated_at": "2025-03-15T02:54:56.876Z",
#     "amount_money": {
#       "amount": 42,
#       "currency": "USD"
#     },
#     "status": "COMPLETED",
#     "delay_duration": "PT168H",
#     "source_type": "CARD",
#     "card_details": {
#       "status": "CAPTURED",
#       "card": {
#         "card_brand": "VISA",
#         "last_4": "5858",
#         "exp_month": 3,
#         "exp_year": 2027,
#         "fingerprint": "sq-1-6bO_U7mtbWRtd9NmqzXISdpW8uWBe5JSikyW40PxS351Nw8c_MOmm6Owvl1o95isyA",
#         "card_type": "CREDIT",
#         "prepaid_type": "NOT_PREPAID",
#         "bin": "453275"
#       },
#       "entry_method": "KEYED",
#       "cvv_status": "CVV_ACCEPTED",
#       "avs_status": "AVS_ACCEPTED",
#       "statement_description": "SQ *DEFAULT TEST ACCOUNT",
#       "card_payment_timeline": {
#         "authorized_at": "2025-03-15T02:54:56.769Z",
#         "captured_at": "2025-03-15T02:54:56.876Z"
#       }
#     },
#     "location_id": "L6DJMTAEEWBDV",
#     "order_id": "hfrO5TEw89XRcCPW60Z71Vo4cWSZY",
#     "risk_evaluation": {
#       "created_at": "2025-03-15T02:54:56.769Z",
#       "risk_level": "NORMAL"
#     },
#     "total_money": {
#       "amount": 42,
#       "currency": "USD"
#     },
#     "approved_money": {
#       "amount": 42,
#       "currency": "USD"
#     },
#     "receipt_number": "ZirY",
#     "receipt_url": "https://squareupsandbox.com/receipt/preview/ZirYypVPBxBmBeD9IrOOSo3o1BDZY",
#     "delay_action": "CANCEL",
#     "delayed_until": "2025-03-22T02:54:56.642Z",
#     "application_details": {
#       "square_product": "ECOMMERCE_API",
#       "application_id": "sandbox-sq0idb-YP5gnUWm9NRiLUmEeQRhGA"
#     },
#     "version_token": "m34DscNpq2Qu3nNVPG0Xj2vBTBMBP67Tit8Ume82Fjc6o"
#   }
# }

# %% [markdown]
# #### Errors happen...
#
# + you'll need to read them,
# + digest them,
# + ask us!,
# + go to the API documentation and other docs,
# + ask GPT, or Perplexity, or older cousin Google ...

# %%
#
# example of an error (copied over to this cell)
#

""" Here was the code from a create_payment call that had both "autocomplete" and "accept partial authorization"
        This combination of features is not permitted (as I found out!)


import json

if result.is_success():
  print(json.dumps(result.body, indent=2))
elif result.is_error():
  print(result.errors)
"""

# Here was the error message, printed from line 14 above:

# [{'code': 'BAD_REQUEST', 'detail': 'Accept partial authorization not valid for autocomplete payments.', 'category': 'INVALID_REQUEST_ERROR'}]
# Out:
# ' Here was the code from a create_payment call that had both "autocomplete" and "accept partial authorization"\n        This combination of features is not permitted (as I found out!)\n\n\nimport json\n\nif result.is_success():\n  print(json.dumps(result.body, indent=2))\nelif result.is_error():\n  print(result.errors)\n'

# %% [markdown]
# # Payment Processes: &nbsp; _Execution and Analysis_

# %% [markdown]
# #### Making 5 payments...
#
# Let's create some business "bustle" in which a loop makes random payments
# + For "CoffeeTime" I'll imagine it's busy -- plus, to keep things moving, we'll use intervals of seconds to represent minutes
# + Since there's always a line, let's imagine an order between 500 cents and 900 cents, every 2 to 5 minutes (here, 2 to 5 seconds)
# + we'll print a short summary of the details and return the result of the request
# + for fun, we'll choose a random buyer email address and a random item ordered
# + we will be able to use these for example analyses later...

# %%
#
# first, a function that encapsulates _one_ random payment
#

import time, uuid, random
# we will assume there are global variables:
#    client
#    os.environ[']

EMAILS = [ "cff@cmc.edu", "cff@pitzer.edu", "cff@scripps.edu", "cff@pomona.edu", "cff@hmc.edu" ]
COFFEES = [ "Coffee", "PhilzPour", "Cometeer" ]
SIZES = [ "Venti", "Trenta", "Quarantadue" ]

def random_payment(LOW=500, HIGH=2000, real_request=False): # Coffee Prices are $3 to $20
    """ one random payment to our business, CoffeeTime! """
    # create the details for a new payment:
    idempotency_key = str(uuid.uuid4())      # create an idempotency key

    amount = random.randint(LOW,HIGH)        # create the amount
    email = random.choice( EMAILS )          # choose a customer
    order = random.choice( SIZES ) + " " + random.choice( COFFEES )

    # put the details into the dictionary we need:
    payment_details = {
        "source_id": "cnon:card-nonce-ok",
        "idempotency_key": idempotency_key,
        "amount_money": {
            "amount": amount,
            "currency": "USD"
        },
        "autocomplete": True,
        "note": order,
        "buyer_email_address": email,
    }

    # make the order, if requested
    result = "Not actually requested..."

    if real_request == True:
        # the client object needs to exist (from above!)
        result = client.payments.create_payment(body = payment_details) # here!
        time.sleep(random.randint(2,5))  # wait a few seconds

    print(f"  {email=} {order=} {amount=}")
    return result

# %%
#
# single-run testing of the above function, printing the result (if actually requested!)

result = random_payment(real_request=False)
print()
print(f"{result = }")
if result != "Not actually requested...":
    print(json.dumps(result.body, indent=2))
# Out:
#   email='cff@pomona.edu' order='Venti PhilzPour' amount=1708
#
# result = 'Not actually requested...'

# %% [markdown]
# #### Let's add "bustle" by looping:

# %%
#
# a loop to make several payments  (by default, 5)

NUM_PAYMENTS = 510

for payment_number in range(NUM_PAYMENTS):
    print(f"Payment {payment_number}:")

    # make a random payment:
    result = random_payment(real_request=True)

    # check result
    if type(result) == str:   # it's our string, "Not actually requested..."
       pass
    elif result.status_code != 200 or result.is_error():  # a real API error! Let's see it...
        print(f"{result.status_code=}")
        print(result.errors)
# Out:
# Payment 0:
#   email='cff@scripps.edu' order='Trenta Cometeer' amount=1907
# Payment 1:
#   email='cff@pomona.edu' order='Venti Cometeer' amount=689
# Payment 2:
#   email='cff@pitzer.edu' order='Trenta Coffee' amount=1983
# Payment 3:
#   email='cff@pitzer.edu' order='Trenta PhilzPour' amount=568
# Payment 4:
#   email='cff@scripps.edu' order='Venti Coffee' amount=1095
# Payment 5:
#   email='cff@scripps.edu' order='Venti PhilzPour' amount=1346
# Payment 6:
#   email='cff@hmc.edu' order='Trenta Cometeer' amount=809
# Payment 7:
#   email='cff@pitzer.edu' order='Trenta Cometeer' amount=1978
# Payment 8:
#   email='cff@pomona.edu' order='Trenta Coffee' amount=585
# Payment 9:
#   email='cff@cmc.edu' order='Venti Coffee' amount=1047
# Payment 10:
#   email='cff@pomona.edu' order='Venti PhilzPour' amount=1679
# Payment 11:
#   email='cff@pomona.edu' order='Quarantadue PhilzPour' amount=551
# Payment 12:
#   email='cff@scripps.edu' order='Venti Cometeer' amount=1757
# Payment 13:
#   email='cff@pitzer.edu' order='Quarantadue Cometeer' amount=1240
# Payment 14:
#   email='cff@cmc.edu' order='Quarantadue Cometeer' amount=1715
# Payment 15:
#   email='cff@hmc.edu' order='Venti Cometeer' amount=1114
# Payment 16:
#   email='cff@cmc.edu' order='Quarantadue PhilzPour' amount=1303
# Payment 17:
#   email='cff@cmc.edu' order='Venti Cometeer' amount=1762
# Payment 18:
#   email='cff@scripps.edu' order='Quarantadue PhilzPour' amount=1897
# Payment 19:
#   email='cff@pomona.edu' order='Trenta Coffee' amount=1986
# Payment 20:
#   email='cff@scripps.edu' order='Venti Coffee' amount=1843
# Payment 21:
#   email='cff@pomona.edu' order='Trenta Coffee' amount=758
# Payment 22:
#   email='cff@hmc.edu' order='Quarantadue PhilzPour' amount=957
# Payment 23:
#   email='cff@pomona.edu' order='Trenta PhilzPour' amount=1470
# Payment 24:
#   email='cff@scripps.edu' order='Venti Cometeer' amount=674
# Payment 25:
#   email='cff@scripps.edu' order='Quarantadue Coffee' amount=564
# Payment 26:
#   email='cff@hmc.edu' order='Venti Coffee' amount=1122
# Payment 27:
#   email='cff@pitzer.edu' order='Quarantadue Coffee' amount=1687
# Payment 28:
#   email='cff@cmc.edu' order='Quarantadue PhilzPour' amount=820
# Payment 29:
#   email='cff@pitzer.edu' order='Trenta PhilzPour' amount=817
# Payment 30:
#   email='cff@cmc.edu' order='Quarantadue Cometeer' amount=1384
# Payment 31:
#   email='cff@scripps.edu' order='Quarantadue PhilzPour' amount=1319
# Payment 32:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=1912
# Payment 33:
#   email='cff@pomona.edu' order='Quarantadue Cometeer' amount=1948
# Payment 34:
#   email='cff@pomona.edu' order='Venti PhilzPour' amount=747
# Payment 35:
#   email='cff@scripps.edu' order='Quarantadue Coffee' amount=679
# Payment 36:
#   email='cff@hmc.edu' order='Venti PhilzPour' amount=1918
# Payment 37:
#   email='cff@scripps.edu' order='Quarantadue PhilzPour' amount=1246
# Payment 38:
#   email='cff@hmc.edu' order='Trenta PhilzPour' amount=528
# Payment 39:
#   email='cff@scripps.edu' order='Trenta Cometeer' amount=1990
# Payment 40:
#   email='cff@pomona.edu' order='Venti PhilzPour' amount=937
# Payment 41:
#   email='cff@cmc.edu' order='Quarantadue PhilzPour' amount=1225
# Payment 42:
#   email='cff@hmc.edu' order='Venti Cometeer' amount=1444
# Payment 43:
#   email='cff@hmc.edu' order='Quarantadue PhilzPour' amount=1274
# Payment 44:
#   email='cff@pomona.edu' order='Venti Coffee' amount=1706
# Payment 45:
#   email='cff@scripps.edu' order='Venti Cometeer' amount=845
# Payment 46:
#   email='cff@cmc.edu' order='Trenta PhilzPour' amount=1501
# Payment 47:
#   email='cff@cmc.edu' order='Venti Cometeer' amount=1602
# Payment 48:
#   email='cff@pomona.edu' order='Venti Cometeer' amount=1808
# Payment 49:
#   email='cff@cmc.edu' order='Quarantadue PhilzPour' amount=1896
# Payment 50:
#   email='cff@pomona.edu' order='Quarantadue Cometeer' amount=775
# Payment 51:
#   email='cff@pomona.edu' order='Trenta PhilzPour' amount=1637
# Payment 52:
#   email='cff@scripps.edu' order='Quarantadue PhilzPour' amount=631
# Payment 53:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=872
# Payment 54:
#   email='cff@hmc.edu' order='Quarantadue Coffee' amount=1854
# Payment 55:
#   email='cff@hmc.edu' order='Venti Cometeer' amount=1243
# Payment 56:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=1694
# Payment 57:
#   email='cff@cmc.edu' order='Quarantadue Cometeer' amount=1711
# Payment 58:
#   email='cff@cmc.edu' order='Venti Coffee' amount=1522
# Payment 59:
#   email='cff@cmc.edu' order='Quarantadue PhilzPour' amount=1939
# Payment 60:
#   email='cff@cmc.edu' order='Venti Coffee' amount=613
# Payment 61:
#   email='cff@pomona.edu' order='Trenta Coffee' amount=645
# Payment 62:
#   email='cff@scripps.edu' order='Quarantadue Cometeer' amount=568
# Payment 63:
#   email='cff@cmc.edu' order='Quarantadue PhilzPour' amount=1647
# Payment 64:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=1587
# Payment 65:
#   email='cff@scripps.edu' order='Venti Coffee' amount=1158
# Payment 66:
#   email='cff@scripps.edu' order='Trenta PhilzPour' amount=676
# Payment 67:
#   email='cff@scripps.edu' order='Venti PhilzPour' amount=1819
# Payment 68:
#   email='cff@cmc.edu' order='Venti Coffee' amount=835
# Payment 69:
#   email='cff@pomona.edu' order='Quarantadue Cometeer' amount=1193
# Payment 70:
#   email='cff@scripps.edu' order='Venti Coffee' amount=815
# Payment 71:
#   email='cff@pomona.edu' order='Trenta PhilzPour' amount=1416
# Payment 72:
#   email='cff@pomona.edu' order='Quarantadue PhilzPour' amount=753
# Payment 73:
#   email='cff@pitzer.edu' order='Quarantadue Coffee' amount=1766
# Payment 74:
#   email='cff@hmc.edu' order='Venti Coffee' amount=1258
# Payment 75:
#   email='cff@pomona.edu' order='Venti Coffee' amount=1733
# Payment 76:
#   email='cff@cmc.edu' order='Venti PhilzPour' amount=1894
# Payment 77:
#   email='cff@scripps.edu' order='Venti Coffee' amount=1323
# Payment 78:
#   email='cff@scripps.edu' order='Venti Cometeer' amount=666
# Payment 79:
#   email='cff@pomona.edu' order='Quarantadue Coffee' amount=719
# Payment 80:
#   email='cff@pomona.edu' order='Trenta Coffee' amount=1303
# Payment 81:
#   email='cff@scripps.edu' order='Trenta Cometeer' amount=1774
# Payment 82:
#   email='cff@pitzer.edu' order='Trenta Coffee' amount=1877
# Payment 83:
#   email='cff@pitzer.edu' order='Quarantadue Cometeer' amount=1025
# Payment 84:
#   email='cff@hmc.edu' order='Venti PhilzPour' amount=1671
# Payment 85:
#   email='cff@hmc.edu' order='Trenta Coffee' amount=1152
# Payment 86:
#   email='cff@pitzer.edu' order='Trenta Coffee' amount=1354
# Payment 87:
#   email='cff@pitzer.edu' order='Venti PhilzPour' amount=1092
# Payment 88:
#   email='cff@pomona.edu' order='Quarantadue Coffee' amount=1596
# Payment 89:
#   email='cff@pitzer.edu' order='Quarantadue PhilzPour' amount=1807
# Payment 90:
#   email='cff@cmc.edu' order='Venti Coffee' amount=549
# Payment 91:
#   email='cff@hmc.edu' order='Trenta Cometeer' amount=1582
# Payment 92:
#   email='cff@pomona.edu' order='Quarantadue Cometeer' amount=1620
# Payment 93:
#   email='cff@scripps.edu' order='Venti PhilzPour' amount=668
# Payment 94:
#   email='cff@cmc.edu' order='Trenta Cometeer' amount=1307
# Payment 95:
#   email='cff@pitzer.edu' order='Trenta PhilzPour' amount=714
# Payment 96:
#   email='cff@pomona.edu' order='Trenta Coffee' amount=1237
# Payment 97:
#   email='cff@cmc.edu' order='Trenta Cometeer' amount=1126
# Payment 98:
#   email='cff@cmc.edu' order='Trenta PhilzPour' amount=891
# Payment 99:
#   email='cff@pomona.edu' order='Venti PhilzPour' amount=854
# Payment 100:
#   email='cff@pomona.edu' order='Trenta Cometeer' amount=957
# Payment 101:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=1609
# Payment 102:
#   email='cff@pitzer.edu' order='Quarantadue Cometeer' amount=1863
# Payment 103:
#   email='cff@pitzer.edu' order='Quarantadue Cometeer' amount=897
# Payment 104:
#   email='cff@hmc.edu' order='Quarantadue PhilzPour' amount=588
# Payment 105:
#   email='cff@scripps.edu' order='Quarantadue PhilzPour' amount=1833
# Payment 106:
#   email='cff@pomona.edu' order='Trenta PhilzPour' amount=866
# Payment 107:
#   email='cff@cmc.edu' order='Trenta Cometeer' amount=1141
# Payment 108:
#   email='cff@hmc.edu' order='Trenta Cometeer' amount=1224
# Payment 109:
#   email='cff@cmc.edu' order='Trenta Coffee' amount=996
# Payment 110:
#   email='cff@pitzer.edu' order='Quarantadue PhilzPour' amount=1287
# Payment 111:
#   email='cff@pitzer.edu' order='Quarantadue Coffee' amount=1332
# Payment 112:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=1292
# Payment 113:
#   email='cff@pitzer.edu' order='Quarantadue Coffee' amount=1105
# Payment 114:
#   email='cff@hmc.edu' order='Venti PhilzPour' amount=987
# Payment 115:
#   email='cff@cmc.edu' order='Trenta PhilzPour' amount=806
# Payment 116:
#   email='cff@pitzer.edu' order='Venti Coffee' amount=1155
# Payment 117:
#   email='cff@scripps.edu' order='Trenta Cometeer' amount=1140
# Payment 118:
#   email='cff@hmc.edu' order='Quarantadue Coffee' amount=1459
# Payment 119:
#   email='cff@pomona.edu' order='Venti PhilzPour' amount=1237
# Payment 120:
#   email='cff@hmc.edu' order='Venti PhilzPour' amount=1904
# Payment 121:
#   email='cff@pitzer.edu' order='Quarantadue Cometeer' amount=1979
# Payment 122:
#   email='cff@hmc.edu' order='Quarantadue Coffee' amount=1236
# Payment 123:
#   email='cff@pomona.edu' order='Trenta PhilzPour' amount=1826
# Payment 124:
#   email='cff@hmc.edu' order='Venti Cometeer' amount=1572
# Payment 125:
#   email='cff@hmc.edu' order='Quarantadue Cometeer' amount=1552
# Payment 126:
#   email='cff@cmc.edu' order='Venti Cometeer' amount=1366
# Payment 127:
#   email='cff@pomona.edu' order='Venti Cometeer' amount=1425
# Payment 128:
#   email='cff@scripps.edu' order='Venti Coffee' amount=1858
# Payment 129:
#   email='cff@hmc.edu' order='Quarantadue Cometeer' amount=1592
# Payment 130:
#   email='cff@pomona.edu' order='Venti Coffee' amount=1523
# Payment 131:
#   email='cff@cmc.edu' order='Trenta Coffee' amount=1545
# Payment 132:
#   email='cff@cmc.edu' order='Venti Coffee' amount=1740
# Payment 133:
#   email='cff@hmc.edu' order='Venti Coffee' amount=1127
# Payment 134:
#   email='cff@pomona.edu' order='Venti PhilzPour' amount=1308
# Payment 135:
#   email='cff@hmc.edu' order='Quarantadue PhilzPour' amount=952
# Payment 136:
#   email='cff@cmc.edu' order='Venti Cometeer' amount=1506
# Payment 137:
#   email='cff@pitzer.edu' order='Trenta Coffee' amount=1736
# Payment 138:
#   email='cff@scripps.edu' order='Trenta PhilzPour' amount=1939
# Payment 139:
#   email='cff@cmc.edu' order='Quarantadue Cometeer' amount=1703
# Payment 140:
#   email='cff@cmc.edu' order='Quarantadue PhilzPour' amount=1710
# Payment 141:
#   email='cff@cmc.edu' order='Venti PhilzPour' amount=1620
# Payment 142:
#   email='cff@scripps.edu' order='Trenta Coffee' amount=971
# Payment 143:
#   email='cff@cmc.edu' order='Venti PhilzPour' amount=1171
# Payment 144:
#   email='cff@scripps.edu' order='Quarantadue PhilzPour' amount=502
# Payment 145:
#   email='cff@pomona.edu' order='Trenta Coffee' amount=635
# Payment 146:
#   email='cff@pomona.edu' order='Trenta Coffee' amount=976
# Payment 147:
#   email='cff@pitzer.edu' order='Trenta Cometeer' amount=1684
# Payment 148:
#   email='cff@pomona.edu' order='Venti PhilzPour' amount=1685
# Payment 149:
#   email='cff@scripps.edu' order='Trenta Coffee' amount=649
# Payment 150:
#   email='cff@pitzer.edu' order='Venti PhilzPour' amount=1151
# Payment 151:
#   email='cff@cmc.edu' order='Quarantadue Coffee' amount=1925
# Payment 152:
#   email='cff@pomona.edu' order='Trenta Coffee' amount=1106
# Payment 153:
#   email='cff@hmc.edu' order='Venti Coffee' amount=1375
# Payment 154:
#   email='cff@hmc.edu' order='Trenta PhilzPour' amount=1597
# Payment 155:
#   email='cff@scripps.edu' order='Quarantadue PhilzPour' amount=1640
# Payment 156:
#   email='cff@pomona.edu' order='Venti PhilzPour' amount=812
# Payment 157:
#   email='cff@hmc.edu' order='Venti PhilzPour' amount=1650
# Payment 158:
#   email='cff@hmc.edu' order='Venti Coffee' amount=1351
# Payment 159:
#   email='cff@scripps.edu' order='Venti Coffee' amount=810
# Payment 160:
#   email='cff@pitzer.edu' order='Venti PhilzPour' amount=946
# Payment 161:
#   email='cff@pitzer.edu' order='Trenta Cometeer' amount=1161
# Payment 162:
#   email='cff@pitzer.edu' order='Trenta Coffee' amount=1305
# Payment 163:
#   email='cff@pomona.edu' order='Quarantadue PhilzPour' amount=969
# Payment 164:
#   email='cff@pomona.edu' order='Venti Cometeer' amount=1382
# Payment 165:
#   email='cff@pitzer.edu' order='Venti PhilzPour' amount=680
# Payment 166:
#   email='cff@scripps.edu' order='Venti Coffee' amount=1463
# Payment 167:
#   email='cff@scripps.edu' order='Trenta Coffee' amount=873
# Payment 168:
#   email='cff@hmc.edu' order='Quarantadue Coffee' amount=1271
# Payment 169:
#   email='cff@scripps.edu' order='Quarantadue PhilzPour' amount=1492
# Payment 170:
#   email='cff@pitzer.edu' order='Trenta Coffee' amount=1641
# Payment 171:
#   email='cff@pomona.edu' order='Trenta PhilzPour' amount=1923
# Payment 172:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=1730
# Payment 173:
#   email='cff@pitzer.edu' order='Trenta PhilzPour' amount=730
# Payment 174:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=770
# Payment 175:
#   email='cff@cmc.edu' order='Quarantadue Coffee' amount=1298
# Payment 176:
#   email='cff@pitzer.edu' order='Trenta PhilzPour' amount=1315
# Payment 177:
#   email='cff@hmc.edu' order='Quarantadue Coffee' amount=1330
# Payment 178:
#   email='cff@pitzer.edu' order='Venti Coffee' amount=688
# Payment 179:
#   email='cff@scripps.edu' order='Venti Coffee' amount=558
# Payment 180:
#   email='cff@hmc.edu' order='Venti Cometeer' amount=590
# Payment 181:
#   email='cff@hmc.edu' order='Quarantadue Cometeer' amount=1099
# Payment 182:
#   email='cff@hmc.edu' order='Trenta Cometeer' amount=1570
# Payment 183:
#   email='cff@pitzer.edu' order='Quarantadue Cometeer' amount=522
# Payment 184:
#   email='cff@scripps.edu' order='Quarantadue Cometeer' amount=1966
# Payment 185:
#   email='cff@cmc.edu' order='Trenta PhilzPour' amount=1140
# Payment 186:
#   email='cff@scripps.edu' order='Trenta PhilzPour' amount=1411
# Payment 187:
#   email='cff@pitzer.edu' order='Venti Coffee' amount=520
# Payment 188:
#   email='cff@pitzer.edu' order='Quarantadue PhilzPour' amount=656
# Payment 189:
#   email='cff@cmc.edu' order='Trenta Coffee' amount=1784
# Payment 190:
#   email='cff@pitzer.edu' order='Quarantadue PhilzPour' amount=560
# Payment 191:
#   email='cff@pitzer.edu' order='Quarantadue Cometeer' amount=1266
# Payment 192:
#   email='cff@scripps.edu' order='Venti PhilzPour' amount=1066
# Payment 193:
#   email='cff@scripps.edu' order='Trenta Cometeer' amount=788
# Payment 194:
#   email='cff@scripps.edu' order='Venti PhilzPour' amount=1899
# Payment 195:
#   email='cff@hmc.edu' order='Trenta Cometeer' amount=679
# Payment 196:
#   email='cff@pomona.edu' order='Trenta Cometeer' amount=1658
# Payment 197:
#   email='cff@scripps.edu' order='Trenta PhilzPour' amount=1937
# Payment 198:
#   email='cff@pomona.edu' order='Trenta Cometeer' amount=759
# Payment 199:
#   email='cff@hmc.edu' order='Quarantadue Coffee' amount=1166
# Payment 200:
#   email='cff@scripps.edu' order='Trenta Coffee' amount=773
# Payment 201:
#   email='cff@pomona.edu' order='Trenta Coffee' amount=1393
# Payment 202:
#   email='cff@pomona.edu' order='Venti Cometeer' amount=1781
# Payment 203:
#   email='cff@pomona.edu' order='Quarantadue Cometeer' amount=1420
# Payment 204:
#   email='cff@hmc.edu' order='Quarantadue PhilzPour' amount=1570
# Payment 205:
#   email='cff@scripps.edu' order='Trenta Coffee' amount=1392
# Payment 206:
#   email='cff@pomona.edu' order='Quarantadue PhilzPour' amount=1239
# Payment 207:
#   email='cff@scripps.edu' order='Trenta Coffee' amount=1505
# Payment 208:
#   email='cff@scripps.edu' order='Quarantadue PhilzPour' amount=572
# Payment 209:
#   email='cff@pitzer.edu' order='Trenta Cometeer' amount=764
# Payment 210:
#   email='cff@pomona.edu' order='Quarantadue PhilzPour' amount=757
# Payment 211:
#   email='cff@hmc.edu' order='Trenta Cometeer' amount=634
# Payment 212:
#   email='cff@pitzer.edu' order='Quarantadue PhilzPour' amount=928
# Payment 213:
#   email='cff@scripps.edu' order='Quarantadue Cometeer' amount=1022
# Payment 214:
#   email='cff@hmc.edu' order='Trenta PhilzPour' amount=1659
# Payment 215:
#   email='cff@pomona.edu' order='Quarantadue Cometeer' amount=1374
# Payment 216:
#   email='cff@cmc.edu' order='Venti Cometeer' amount=909
# Payment 217:
#   email='cff@hmc.edu' order='Venti Cometeer' amount=1499
# Payment 218:
#   email='cff@cmc.edu' order='Quarantadue Coffee' amount=1602
# Payment 219:
#   email='cff@pitzer.edu' order='Quarantadue Coffee' amount=818
# Payment 220:
#   email='cff@pomona.edu' order='Venti Coffee' amount=1013
# Payment 221:
#   email='cff@scripps.edu' order='Trenta PhilzPour' amount=1045
# Payment 222:
#   email='cff@pitzer.edu' order='Venti PhilzPour' amount=767
# Payment 223:
#   email='cff@hmc.edu' order='Quarantadue Coffee' amount=1672
# Payment 224:
#   email='cff@hmc.edu' order='Trenta Coffee' amount=1770
# Payment 225:
#   email='cff@cmc.edu' order='Venti Coffee' amount=886
# Payment 226:
#   email='cff@pitzer.edu' order='Trenta Coffee' amount=707
# Payment 227:
#   email='cff@pomona.edu' order='Trenta PhilzPour' amount=807
# Payment 228:
#   email='cff@cmc.edu' order='Venti PhilzPour' amount=1219
# Payment 229:
#   email='cff@pitzer.edu' order='Quarantadue PhilzPour' amount=570
# Payment 230:
#   email='cff@hmc.edu' order='Venti Cometeer' amount=875
# Payment 231:
#   email='cff@pitzer.edu' order='Venti PhilzPour' amount=910
# Payment 232:
#   email='cff@hmc.edu' order='Trenta Coffee' amount=541
# Payment 233:
#   email='cff@pomona.edu' order='Trenta PhilzPour' amount=709
# Payment 234:
#   email='cff@hmc.edu' order='Venti PhilzPour' amount=1067
# Payment 235:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=1667
# Payment 236:
#   email='cff@cmc.edu' order='Quarantadue Cometeer' amount=837
# Payment 237:
#   email='cff@hmc.edu' order='Venti Cometeer' amount=1916
# Payment 238:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=1551
# Payment 239:
#   email='cff@hmc.edu' order='Trenta PhilzPour' amount=1297
# Payment 240:
#   email='cff@hmc.edu' order='Venti PhilzPour' amount=1280
# Payment 241:
#   email='cff@hmc.edu' order='Trenta Coffee' amount=848
# Payment 242:
#   email='cff@cmc.edu' order='Trenta PhilzPour' amount=592
# Payment 243:
#   email='cff@pomona.edu' order='Trenta PhilzPour' amount=1049
# Payment 244:
#   email='cff@scripps.edu' order='Quarantadue Cometeer' amount=580
# Payment 245:
#   email='cff@cmc.edu' order='Venti Coffee' amount=1829
# Payment 246:
#   email='cff@pitzer.edu' order='Venti Coffee' amount=1098
# Payment 247:
#   email='cff@scripps.edu' order='Quarantadue PhilzPour' amount=1039
# Payment 248:
#   email='cff@cmc.edu' order='Venti Cometeer' amount=1646
# Payment 249:
#   email='cff@cmc.edu' order='Trenta PhilzPour' amount=1363
# Payment 250:
#   email='cff@pitzer.edu' order='Quarantadue Cometeer' amount=1052
# Payment 251:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=1655
# Payment 252:
#   email='cff@pomona.edu' order='Venti Cometeer' amount=1858
# Payment 253:
#   email='cff@hmc.edu' order='Venti Coffee' amount=1614
# Payment 254:
#   email='cff@scripps.edu' order='Trenta Coffee' amount=537
# Payment 255:
#   email='cff@pitzer.edu' order='Quarantadue Coffee' amount=811
# Payment 256:
#   email='cff@hmc.edu' order='Venti Coffee' amount=1694
# Payment 257:
#   email='cff@pitzer.edu' order='Trenta Cometeer' amount=1594
# Payment 258:
#   email='cff@hmc.edu' order='Trenta Coffee' amount=1282
# Payment 259:
#   email='cff@hmc.edu' order='Venti Coffee' amount=697
# Payment 260:
#   email='cff@hmc.edu' order='Venti Coffee' amount=1056
# Payment 261:
#   email='cff@scripps.edu' order='Trenta PhilzPour' amount=970
# Payment 262:
#   email='cff@cmc.edu' order='Quarantadue Coffee' amount=536
# Payment 263:
#   email='cff@scripps.edu' order='Venti PhilzPour' amount=1767
# Payment 264:
#   email='cff@cmc.edu' order='Venti PhilzPour' amount=924
# Payment 265:
#   email='cff@cmc.edu' order='Venti PhilzPour' amount=635
# Payment 266:
#   email='cff@scripps.edu' order='Trenta Coffee' amount=1411
# Payment 267:
#   email='cff@pomona.edu' order='Venti Coffee' amount=1120
# Payment 268:
#   email='cff@cmc.edu' order='Quarantadue Coffee' amount=1682
# Payment 269:
#   email='cff@scripps.edu' order='Quarantadue PhilzPour' amount=1012
# Payment 270:
#   email='cff@hmc.edu' order='Venti PhilzPour' amount=1356
# Payment 271:
#   email='cff@cmc.edu' order='Trenta Coffee' amount=657
# Payment 272:
#   email='cff@scripps.edu' order='Quarantadue Cometeer' amount=1946
# Payment 273:
#   email='cff@pomona.edu' order='Venti Coffee' amount=946
# Payment 274:
#   email='cff@pitzer.edu' order='Trenta PhilzPour' amount=1764
# Payment 275:
#   email='cff@pitzer.edu' order='Venti PhilzPour' amount=1258
# Payment 276:
#   email='cff@scripps.edu' order='Quarantadue PhilzPour' amount=707
# Payment 277:
#   email='cff@pitzer.edu' order='Quarantadue Cometeer' amount=1292
# Payment 278:
#   email='cff@pitzer.edu' order='Venti PhilzPour' amount=1750
# Payment 279:
#   email='cff@cmc.edu' order='Trenta Coffee' amount=1022
# Payment 280:
#   email='cff@pitzer.edu' order='Venti Coffee' amount=1453
# Payment 281:
#   email='cff@scripps.edu' order='Quarantadue Coffee' amount=1921
# Payment 282:
#   email='cff@pomona.edu' order='Quarantadue Cometeer' amount=1259
# Payment 283:
#   email='cff@cmc.edu' order='Venti PhilzPour' amount=579
# Payment 284:
#   email='cff@scripps.edu' order='Trenta Cometeer' amount=868
# Payment 285:
#   email='cff@pitzer.edu' order='Trenta PhilzPour' amount=1843
# Payment 286:
#   email='cff@hmc.edu' order='Quarantadue PhilzPour' amount=1517
# Payment 287:
#   email='cff@pomona.edu' order='Trenta Cometeer' amount=1628
# Payment 288:
#   email='cff@scripps.edu' order='Quarantadue Cometeer' amount=1662
# Payment 289:
#   email='cff@scripps.edu' order='Quarantadue Coffee' amount=1850
# Payment 290:
#   email='cff@cmc.edu' order='Quarantadue Cometeer' amount=532
# Payment 291:
#   email='cff@pomona.edu' order='Quarantadue Cometeer' amount=1701
# Payment 292:
#   email='cff@scripps.edu' order='Venti Cometeer' amount=1112
# Payment 293:
#   email='cff@cmc.edu' order='Venti Coffee' amount=646
# Payment 294:
#   email='cff@hmc.edu' order='Venti PhilzPour' amount=1039
# Payment 295:
#   email='cff@scripps.edu' order='Trenta Cometeer' amount=1377
# Payment 296:
#   email='cff@pomona.edu' order='Quarantadue Coffee' amount=1864
# Payment 297:
#   email='cff@hmc.edu' order='Trenta Coffee' amount=1930
# Payment 298:
#   email='cff@cmc.edu' order='Venti Coffee' amount=1235
# Payment 299:
#   email='cff@hmc.edu' order='Trenta Coffee' amount=1417
# Payment 300:
#   email='cff@pitzer.edu' order='Quarantadue Coffee' amount=1279
# Payment 301:
#   email='cff@pitzer.edu' order='Trenta Coffee' amount=981
# Payment 302:
#   email='cff@pitzer.edu' order='Quarantadue Coffee' amount=620
# Payment 303:
#   email='cff@cmc.edu' order='Trenta PhilzPour' amount=1012
# Payment 304:
#   email='cff@hmc.edu' order='Quarantadue Coffee' amount=1150
# Payment 305:
#   email='cff@hmc.edu' order='Trenta Cometeer' amount=925
# Payment 306:
#   email='cff@cmc.edu' order='Venti Cometeer' amount=561
# Payment 307:
#   email='cff@pitzer.edu' order='Trenta PhilzPour' amount=1630
# Payment 308:
#   email='cff@scripps.edu' order='Quarantadue Cometeer' amount=546
# Payment 309:
#   email='cff@scripps.edu' order='Venti Coffee' amount=1359
# Payment 310:
#   email='cff@pitzer.edu' order='Trenta PhilzPour' amount=1525
# Payment 311:
#   email='cff@pitzer.edu' order='Quarantadue PhilzPour' amount=960
# Payment 312:
#   email='cff@hmc.edu' order='Venti Cometeer' amount=973
# Payment 313:
#   email='cff@hmc.edu' order='Quarantadue PhilzPour' amount=1355
# Payment 314:
#   email='cff@pitzer.edu' order='Trenta PhilzPour' amount=1616
# Payment 315:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=2000
# Payment 316:
#   email='cff@pomona.edu' order='Quarantadue PhilzPour' amount=1164
# Payment 317:
#   email='cff@cmc.edu' order='Quarantadue PhilzPour' amount=1000
# Payment 318:
#   email='cff@hmc.edu' order='Quarantadue PhilzPour' amount=1281
# Payment 319:
#   email='cff@hmc.edu' order='Venti PhilzPour' amount=1308
# Payment 320:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=1155
# Payment 321:
#   email='cff@cmc.edu' order='Venti Coffee' amount=1017
# Payment 322:
#   email='cff@cmc.edu' order='Quarantadue PhilzPour' amount=1597
# Payment 323:
#   email='cff@scripps.edu' order='Trenta Cometeer' amount=1341
# Payment 324:
#   email='cff@scripps.edu' order='Venti Coffee' amount=794
# Payment 325:
#   email='cff@pitzer.edu' order='Venti PhilzPour' amount=1657
# Payment 326:
#   email='cff@scripps.edu' order='Trenta Coffee' amount=725
# Payment 327:
#   email='cff@pitzer.edu' order='Quarantadue Coffee' amount=1225
# Payment 328:
#   email='cff@hmc.edu' order='Venti PhilzPour' amount=853
# Payment 329:
#   email='cff@pomona.edu' order='Quarantadue Coffee' amount=1844
# Payment 330:
#   email='cff@scripps.edu' order='Venti Coffee' amount=658
# Payment 331:
#   email='cff@cmc.edu' order='Venti PhilzPour' amount=1375
# Payment 332:
#   email='cff@cmc.edu' order='Trenta Coffee' amount=654
# Payment 333:
#   email='cff@hmc.edu' order='Quarantadue Coffee' amount=1131
# Payment 334:
#   email='cff@hmc.edu' order='Trenta Cometeer' amount=1571
# Payment 335:
#   email='cff@pitzer.edu' order='Venti PhilzPour' amount=983
# Payment 336:
#   email='cff@hmc.edu' order='Venti PhilzPour' amount=1332
# Payment 337:
#   email='cff@scripps.edu' order='Trenta Coffee' amount=1022
# Payment 338:
#   email='cff@scripps.edu' order='Quarantadue PhilzPour' amount=1671
# Payment 339:
#   email='cff@hmc.edu' order='Venti Coffee' amount=1536
# Payment 340:
#   email='cff@pomona.edu' order='Quarantadue Coffee' amount=1071
# Payment 341:
#   email='cff@pomona.edu' order='Quarantadue Cometeer' amount=1310
# Payment 342:
#   email='cff@pomona.edu' order='Quarantadue PhilzPour' amount=1365
# Payment 343:
#   email='cff@pitzer.edu' order='Venti Coffee' amount=1227
# Payment 344:
#   email='cff@scripps.edu' order='Trenta Coffee' amount=1312
# Payment 345:
#   email='cff@pitzer.edu' order='Trenta PhilzPour' amount=873
# Payment 346:
#   email='cff@hmc.edu' order='Quarantadue Cometeer' amount=560
# Payment 347:
#   email='cff@scripps.edu' order='Quarantadue Coffee' amount=1225
# Payment 348:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=643
# Payment 349:
#   email='cff@cmc.edu' order='Trenta PhilzPour' amount=1867
# Payment 350:
#   email='cff@cmc.edu' order='Trenta Coffee' amount=627
# Payment 351:
#   email='cff@cmc.edu' order='Quarantadue PhilzPour' amount=1091
# Payment 352:
#   email='cff@scripps.edu' order='Quarantadue PhilzPour' amount=926
# Payment 353:
#   email='cff@pomona.edu' order='Quarantadue PhilzPour' amount=1633
# Payment 354:
#   email='cff@pitzer.edu' order='Venti Coffee' amount=750
# Payment 355:
#   email='cff@pitzer.edu' order='Quarantadue Coffee' amount=975
# Payment 356:
#   email='cff@cmc.edu' order='Quarantadue Coffee' amount=1216
# Payment 357:
#   email='cff@pomona.edu' order='Trenta Cometeer' amount=1387
# Payment 358:
#   email='cff@pomona.edu' order='Venti PhilzPour' amount=1694
# Payment 359:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=620
# Payment 360:
#   email='cff@cmc.edu' order='Venti PhilzPour' amount=1583
# Payment 361:
#   email='cff@cmc.edu' order='Trenta Cometeer' amount=711
# Payment 362:
#   email='cff@scripps.edu' order='Venti Cometeer' amount=1080
# Payment 363:
#   email='cff@hmc.edu' order='Quarantadue Coffee' amount=857
# Payment 364:
#   email='cff@hmc.edu' order='Quarantadue PhilzPour' amount=885
# Payment 365:
#   email='cff@pomona.edu' order='Trenta Cometeer' amount=1518
# Payment 366:
#   email='cff@hmc.edu' order='Trenta Coffee' amount=1511
# Payment 367:
#   email='cff@pomona.edu' order='Quarantadue Coffee' amount=1212
# Payment 368:
#   email='cff@scripps.edu' order='Venti Coffee' amount=1255
# Payment 369:
#   email='cff@scripps.edu' order='Venti PhilzPour' amount=698
# Payment 370:
#   email='cff@scripps.edu' order='Quarantadue Cometeer' amount=695
# Payment 371:
#   email='cff@pitzer.edu' order='Trenta Cometeer' amount=1551
# Payment 372:
#   email='cff@scripps.edu' order='Trenta Coffee' amount=873
# Payment 373:
#   email='cff@cmc.edu' order='Quarantadue Cometeer' amount=514
# Payment 374:
#   email='cff@hmc.edu' order='Venti PhilzPour' amount=542
# Payment 375:
#   email='cff@pomona.edu' order='Venti PhilzPour' amount=1254
# Payment 376:
#   email='cff@pitzer.edu' order='Trenta Coffee' amount=1584
# Payment 377:
#   email='cff@pomona.edu' order='Trenta Coffee' amount=1656
# Payment 378:
#   email='cff@hmc.edu' order='Quarantadue Coffee' amount=904
# Payment 379:
#   email='cff@scripps.edu' order='Trenta Coffee' amount=988
# Payment 380:
#   email='cff@scripps.edu' order='Trenta PhilzPour' amount=835
# Payment 381:
#   email='cff@cmc.edu' order='Venti Coffee' amount=925
# Payment 382:
#   email='cff@cmc.edu' order='Quarantadue PhilzPour' amount=625
# Payment 383:
#   email='cff@cmc.edu' order='Quarantadue PhilzPour' amount=1747
# Payment 384:
#   email='cff@hmc.edu' order='Trenta PhilzPour' amount=660
# Payment 385:
#   email='cff@cmc.edu' order='Venti Cometeer' amount=1227
# Payment 386:
#   email='cff@hmc.edu' order='Quarantadue PhilzPour' amount=1769
# Payment 387:
#   email='cff@scripps.edu' order='Trenta PhilzPour' amount=1690
# Payment 388:
#   email='cff@hmc.edu' order='Trenta Coffee' amount=1664
# Payment 389:
#   email='cff@scripps.edu' order='Trenta PhilzPour' amount=661
# Payment 390:
#   email='cff@hmc.edu' order='Venti Cometeer' amount=857
# Payment 391:
#   email='cff@pomona.edu' order='Venti Cometeer' amount=889
# Payment 392:
#   email='cff@scripps.edu' order='Quarantadue PhilzPour' amount=872
# Payment 393:
#   email='cff@scripps.edu' order='Trenta PhilzPour' amount=1122
# Payment 394:
#   email='cff@hmc.edu' order='Trenta Cometeer' amount=1606
# Payment 395:
#   email='cff@pitzer.edu' order='Trenta PhilzPour' amount=1504
# Payment 396:
#   email='cff@cmc.edu' order='Trenta PhilzPour' amount=1965
# Payment 397:
#   email='cff@hmc.edu' order='Quarantadue PhilzPour' amount=997
# Payment 398:
#   email='cff@cmc.edu' order='Venti PhilzPour' amount=1611
# Payment 399:
#   email='cff@pitzer.edu' order='Quarantadue Coffee' amount=1167
# Payment 400:
#   email='cff@cmc.edu' order='Trenta Cometeer' amount=1612
# Payment 401:
#   email='cff@cmc.edu' order='Quarantadue PhilzPour' amount=689
# Payment 402:
#   email='cff@pomona.edu' order='Trenta Cometeer' amount=1835
# Payment 403:
#   email='cff@scripps.edu' order='Venti Coffee' amount=1890
# Payment 404:
#   email='cff@hmc.edu' order='Venti Coffee' amount=1956
# Payment 405:
#   email='cff@pitzer.edu' order='Quarantadue PhilzPour' amount=907
# Payment 406:
#   email='cff@cmc.edu' order='Quarantadue Cometeer' amount=944
# Payment 407:
#   email='cff@cmc.edu' order='Trenta PhilzPour' amount=1422
# Payment 408:
#   email='cff@scripps.edu' order='Venti PhilzPour' amount=675
# Payment 409:
#   email='cff@hmc.edu' order='Venti Cometeer' amount=1842
# Payment 410:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=1163
# Payment 411:
#   email='cff@pitzer.edu' order='Quarantadue Cometeer' amount=904
# Payment 412:
#   email='cff@pomona.edu' order='Venti Cometeer' amount=1495
# Payment 413:
#   email='cff@pitzer.edu' order='Venti PhilzPour' amount=1468
# Payment 414:
#   email='cff@scripps.edu' order='Trenta Cometeer' amount=1582
# Payment 415:
#   email='cff@cmc.edu' order='Venti Coffee' amount=1169
# Payment 416:
#   email='cff@hmc.edu' order='Quarantadue PhilzPour' amount=1252
# Payment 417:
#   email='cff@pomona.edu' order='Venti Cometeer' amount=1736
# Payment 418:
#   email='cff@pomona.edu' order='Trenta PhilzPour' amount=1335
# Payment 419:
#   email='cff@pomona.edu' order='Venti PhilzPour' amount=1873
# Payment 420:
#   email='cff@pomona.edu' order='Trenta PhilzPour' amount=1221
# Payment 421:
#   email='cff@cmc.edu' order='Trenta PhilzPour' amount=980
# Payment 422:
#   email='cff@pitzer.edu' order='Quarantadue Coffee' amount=1443
# Payment 423:
#   email='cff@scripps.edu' order='Trenta PhilzPour' amount=898
# Payment 424:
#   email='cff@pomona.edu' order='Quarantadue PhilzPour' amount=760
# Payment 425:
#   email='cff@scripps.edu' order='Trenta Coffee' amount=923
# Payment 426:
#   email='cff@hmc.edu' order='Trenta Cometeer' amount=1353
# Payment 427:
#   email='cff@hmc.edu' order='Quarantadue Cometeer' amount=1468
# Payment 428:
#   email='cff@cmc.edu' order='Trenta Coffee' amount=917
# Payment 429:
#   email='cff@hmc.edu' order='Quarantadue PhilzPour' amount=764
# Payment 430:
#   email='cff@pomona.edu' order='Trenta Coffee' amount=1099
# Payment 431:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=1967
# Payment 432:
#   email='cff@pitzer.edu' order='Trenta PhilzPour' amount=815
# Payment 433:
#   email='cff@hmc.edu' order='Trenta Coffee' amount=1295
# Payment 434:
#   email='cff@scripps.edu' order='Trenta PhilzPour' amount=747
# Payment 435:
#   email='cff@cmc.edu' order='Venti Cometeer' amount=1652
# Payment 436:
#   email='cff@hmc.edu' order='Quarantadue Cometeer' amount=692
# Payment 437:
#   email='cff@cmc.edu' order='Venti Cometeer' amount=1485
# Payment 438:
#   email='cff@scripps.edu' order='Quarantadue Coffee' amount=1241
# Payment 439:
#   email='cff@cmc.edu' order='Trenta Cometeer' amount=842
# Payment 440:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=581
# Payment 441:
#   email='cff@hmc.edu' order='Trenta Coffee' amount=1048
# Payment 442:
#   email='cff@cmc.edu' order='Quarantadue PhilzPour' amount=1767
# Payment 443:
#   email='cff@scripps.edu' order='Quarantadue PhilzPour' amount=763
# Payment 444:
#   email='cff@cmc.edu' order='Venti Cometeer' amount=1635
# Payment 445:
#   email='cff@hmc.edu' order='Venti PhilzPour' amount=1051
# Payment 446:
#   email='cff@hmc.edu' order='Quarantadue Cometeer' amount=926
# Payment 447:
#   email='cff@cmc.edu' order='Quarantadue Coffee' amount=1795
# Payment 448:
#   email='cff@pomona.edu' order='Venti PhilzPour' amount=1980
# Payment 449:
#   email='cff@pitzer.edu' order='Venti PhilzPour' amount=1690
# Payment 450:
#   email='cff@pomona.edu' order='Venti PhilzPour' amount=1433
# Payment 451:
#   email='cff@pitzer.edu' order='Venti Coffee' amount=1286
# Payment 452:
#   email='cff@hmc.edu' order='Quarantadue Coffee' amount=1526
# Payment 453:
#   email='cff@scripps.edu' order='Venti Coffee' amount=563
# Payment 454:
#   email='cff@hmc.edu' order='Trenta PhilzPour' amount=1370
# Payment 455:
#   email='cff@scripps.edu' order='Trenta Coffee' amount=534
# Payment 456:
#   email='cff@pomona.edu' order='Quarantadue PhilzPour' amount=1986
# Payment 457:
#   email='cff@pitzer.edu' order='Quarantadue PhilzPour' amount=1485
# Payment 458:
#   email='cff@pomona.edu' order='Quarantadue Coffee' amount=988
# Payment 459:
#   email='cff@pomona.edu' order='Quarantadue Cometeer' amount=1508
# Payment 460:
#   email='cff@scripps.edu' order='Trenta PhilzPour' amount=1073
# Payment 461:
#   email='cff@cmc.edu' order='Quarantadue Coffee' amount=1132
# Payment 462:
#   email='cff@pitzer.edu' order='Quarantadue PhilzPour' amount=772
# Payment 463:
#   email='cff@pitzer.edu' order='Quarantadue Cometeer' amount=876
# Payment 464:
#   email='cff@scripps.edu' order='Trenta Cometeer' amount=1898
# Payment 465:
#   email='cff@cmc.edu' order='Trenta Cometeer' amount=841
# Payment 466:
#   email='cff@scripps.edu' order='Venti PhilzPour' amount=610
# Payment 467:
#   email='cff@cmc.edu' order='Venti Cometeer' amount=854
# Payment 468:
#   email='cff@hmc.edu' order='Trenta Coffee' amount=667
# Payment 469:
#   email='cff@pitzer.edu' order='Venti Coffee' amount=1195
# Payment 470:
#   email='cff@pomona.edu' order='Quarantadue PhilzPour' amount=1243
# Payment 471:
#   email='cff@pitzer.edu' order='Quarantadue Coffee' amount=1050
# Payment 472:
#   email='cff@pitzer.edu' order='Venti PhilzPour' amount=1681
# Payment 473:
#   email='cff@hmc.edu' order='Trenta Coffee' amount=1464
# Payment 474:
#   email='cff@cmc.edu' order='Trenta Coffee' amount=509
# Payment 475:
#   email='cff@scripps.edu' order='Venti Coffee' amount=1563
# Payment 476:
#   email='cff@scripps.edu' order='Venti PhilzPour' amount=537
# Payment 477:
#   email='cff@pomona.edu' order='Quarantadue Coffee' amount=1862
# Payment 478:
#   email='cff@pomona.edu' order='Venti Coffee' amount=837
# Payment 479:
#   email='cff@pomona.edu' order='Quarantadue Coffee' amount=749
# Payment 480:
#   email='cff@scripps.edu' order='Quarantadue Cometeer' amount=1648
# Payment 481:
#   email='cff@hmc.edu' order='Trenta PhilzPour' amount=588
# Payment 482:
#   email='cff@hmc.edu' order='Quarantadue Coffee' amount=1544
# Payment 483:
#   email='cff@cmc.edu' order='Venti Coffee' amount=1972
# Payment 484:
#   email='cff@scripps.edu' order='Venti PhilzPour' amount=1391
# Payment 485:
#   email='cff@pitzer.edu' order='Trenta Cometeer' amount=592
# Payment 486:
#   email='cff@pitzer.edu' order='Venti Cometeer' amount=1220
# Payment 487:
#   email='cff@pomona.edu' order='Venti Cometeer' amount=1510
# Payment 488:
#   email='cff@scripps.edu' order='Trenta Coffee' amount=1781
# Payment 489:
#   email='cff@pitzer.edu' order='Trenta Cometeer' amount=1426
# Payment 490:
#   email='cff@cmc.edu' order='Trenta Cometeer' amount=574
# Payment 491:
#   email='cff@pomona.edu' order='Venti Cometeer' amount=1805
# Payment 492:
#   email='cff@pomona.edu' order='Venti Cometeer' amount=573
# Payment 493:
#   email='cff@hmc.edu' order='Venti PhilzPour' amount=574
# Payment 494:
#   email='cff@hmc.edu' order='Venti PhilzPour' amount=625
# Payment 495:
#   email='cff@pitzer.edu' order='Trenta PhilzPour' amount=1446
# Payment 496:
#   email='cff@pitzer.edu' order='Venti PhilzPour' amount=1191
# Payment 497:
#   email='cff@scripps.edu' order='Quarantadue PhilzPour' amount=760
# Payment 498:
#   email='cff@scripps.edu' order='Trenta Cometeer' amount=1115
# Payment 499:
#   email='cff@hmc.edu' order='Venti PhilzPour' amount=1120
# Payment 500:
#   email='cff@hmc.edu' order='Venti Coffee' amount=1185
# Payment 501:
#   email='cff@scripps.edu' order='Quarantadue Cometeer' amount=1893
# Payment 502:
#   email='cff@pomona.edu' order='Trenta PhilzPour' amount=731
# Payment 503:
#   email='cff@hmc.edu' order='Quarantadue Cometeer' amount=1901
# Payment 504:
#   email='cff@pitzer.edu' order='Quarantadue Coffee' amount=1518
# Payment 505:
#   email='cff@hmc.edu' order='Quarantadue Cometeer' amount=1965
# Payment 506:
#   email='cff@cmc.edu' order='Quarantadue Cometeer' amount=1486
# Payment 507:
#   email='cff@pomona.edu' order='Quarantadue Cometeer' amount=1851
# Payment 508:
#   email='cff@pitzer.edu' order='Quarantadue Cometeer' amount=1778
# Payment 509:
#   email='cff@pitzer.edu' order='Trenta Coffee' amount=1891

# %% [markdown]
# #### Tasks to try out...
# 1. Try the above cells as they are, using the <tt>real_request=False</tt> input, so that no network API calls are made
# 1. Be sure that you feel good about how these cells are working...
# 1. Change <tt>real_request=False</tt> to <tt>real_request=True</tt> in the _single-run testing_ cell and try it out!
# 1. Check that it worked - and check your Square transaction logs, to be sure it worked.
# 1. Change back to <tt>real_request=False</tt> in the _single-run testing_ cell, just in case it accidentally gets run in the future...
# 1. Change the looping cell the same way and live-test the "bustling business" example! Adapt and debug, as necessary
#   + If you need to debug, set <tt>real_request=False</tt> until its working.
#   + Take this approach in general: debug locally, ... only when everything is working locally, live-test on the network
# 1. Yay! You have your "payment-bustle" simulation!
# 1. Change back to <tt>real_request=False</tt> in the looping cell, just in case it gets run in the future...   <br> &nbsp;&nbsp; <font size="-1">For example, by choosing the "Run all" option in the Colab notebook.</font>
# 1. Next, we'll analyze our payments...

# %%
#
# here, we _get_ all the payments:
 #      (another API call, naturally)
 #      (via SDK, equally naturally!)

result = client.payments.list_payments(
  limit = NUM_PAYMENTS
)
result.status_code
# Out:
# 200

# %%
#
# Let's see the result...

if result.is_success():
  print(json.dumps(result.body, indent=2))
elif result.is_error():
  print(result.errors)
# Out:
# {
#   "payments": [
#     {
#       "id": "bRspCCoxCxfu0OFWWXVwmZz6t6dZY",
#       "created_at": "2025-03-15T03:32:16.648Z",
#       "updated_at": "2025-03-15T03:32:18.311Z",
#       "amount_money": {
#         "amount": 1891,
#         "currency": "USD"
#       },
#       "status": "COMPLETED",
#       "delay_duration": "PT168H",
#       "source_type": "CARD",
#       "card_details": {
#         "status": "CAPTURED",
#         "card": {
#           "card_brand": "VISA",
#           "last_4": "5858",
#           "exp_month": 3,
#           "exp_year": 2027,
#           "fingerprint": "sq-1-6bO_U7mtbWRtd9NmqzXISdpW8uWBe5JSikyW40PxS351Nw8c_MOmm6Owvl1o95isyA",
#           "card_type": "CREDIT",
#           "prepaid_type": "NOT_PREPAID",
#           "bin": "453275"
#         },
#         "entry_method": "KEYED",
#         "cvv_status": "CVV_ACCEPTED",
#         "avs_status": "AVS_ACCEPTED",
#         "statement_description": "SQ *DEFAULT TEST ACCOUNT",
#         "card_payment_timeline": {
#           "authorized_at": "2025-03-15T03:32:16.779Z",
#           "captured_at": "2025-03-15T03:32:16.885Z"
#         }
#       },
#       "location_id": "L6DJMTAEEWBDV",
#       "order_id": "pjLOXwXzQ8lbFsx5c9CL031sA4OZY",
#       "risk_evaluation": {
#         "created_at": "2025-03-15T03:32:16.779Z",
#         "risk_level": "NORMAL"
#       },
#       "processing_fee": [
#         {
#           "effective_at": "2025-03-15T05:32:18.000Z",
#           "type": "INITIAL",
#           "amount_money": {
#             "amount": 85,
#             "currency": "USD"
#           }
#         }
#       ],
#       "buyer_email_address": "cff@
000Z",
#           "type": "INITIAL",
#           "amount_money": {
#             "amount": 73,
#             "currency": "USD"
#           }
#         }
#       ],
#       "buyer_email_address": "cff@pitzer.edu",
#       "note": "Venti PhilzPour",
#       "total_money": {
#         "amount": 1468,
#         "currency": "USD"
#       },
#       "approved_money": {
#         "amount": 1468,
#         "currency": "USD"
#       },
#       "receipt_number": "pMQY",
#       "receipt_url": "https://squareupsandbox.com/receipt/preview/pMQYTOqXro33HCXAtXBSmJYOryDZY",
#       "delay_action": "CANCEL",
#       "delayed_until": "2025-03-22T03:25:28.273Z",
#       "application_details": {
#         "square_product": "ECOMMERCE_API",
#         "application_id": "sandbox-sq0idb-YP5gnUWm9NRiLUmEeQRhGA"
#       },
#       "version_token": "fIBgnvYYge7GU2xS3EwVVBzSKhg31o0j96oOeQJSmVT6o"
#     },
#     {
#       "id": "NsVpOxCo9UknI19sAR1D7QCwBPTZY",
#       "created_at": "2025-03-15T03:25:24.631Z",
#       "updated_at": "2025-03-15T03:25:25.966Z",
#       "amount_money": {
#         "amount": 1495,
#         "currency": "USD"
#       },
#       "status": "COMPLETED",
#       "delay_duration": "PT168H",
#       "source_type": "CARD",
#       "card_details": {
#         "status": "CAPTURED",
#         "card": {
#           "card_brand": "VISA",
#           "last_4": "5858",
#           "exp_month": 3,
#           "exp_year": 2027,
#           "fingerprint": "sq-1-6bO_U7mtbWRtd9NmqzXISdpW8uWBe5JSikyW40PxS351Nw8c_MOmm6Owvl1o95isyA",
#           "card_type": "CREDIT",
#           "prepaid_type": "NOT_PREPAID",
#           "bin": "453275"
#         },
#         "entry_method": "KEYED",
#         "cvv_status": "CVV_ACCEPTED",
#         "avs_status": "AVS_ACCEPTED",
#         "statement_description": "SQ *DEFAULT TEST ACCOUNT",
#         "card_payment_timeline": {
#           "authorized_at": "2025-03-15T03:25:24.760Z",
#           "captured_at": "2025-03-15T03:25:24.876Z"
#         }
#       },
#       "location_id": "L6DJMTAEEWBDV",
#       "order_id": "prHEksV7lzsVVcy6DB3dB29FwZYZY",
#       "risk_evaluation": {
#         "created_at": "2025-03-15T03:25:24.761Z",
#         "risk_level": "NORMAL"
#       },
#       "processing_fee": [
#         {
#           "effective_at": "2025-03-15T05:25:25.000Z",
#           "type": "INITIAL",
#           "amount_money": {
#             "amount": 73,
#             "currency": "USD"
#           }
#         }
#       ],
#       "buyer_email_address": "cff@pomona.edu",
#       "note": "Venti Cometeer",
#       "total_money": {
#         "amount": 1495,
#         "currency": "USD"
#       },
#       "approved_money": {
#         "amount": 1495,
#         "currency": "USD"
#       },
#       "receipt_number": "NsVp",
#       "receipt_url": "https://squareupsandbox.com/receipt/preview/NsVpOxCo9UknI19sAR1D7QCwBPTZY",
#       "delay_action": "CANCEL",
#       "delayed_until": "2025-03-22T03:25:24.631Z",
#       "application_details": {
#         "square_product": "ECOMMERCE_API",
#         "application_id": "sandbox-sq0idb-YP5gnUWm9NRiLUmEeQRhGA"
#       },
#       "version_token": "QfyqAjIU1mi7SNk5ZYjnjDE8sPCtmI2w4u9ZmmepGjj6o"
#     },
#     {
#       "id": "L3P5XCiPkDUKSIq3gx4tugnautXZY",
#       "created_at": "2025-03-15T03:25:20.949Z",
#       "updated_at": "2025-03-15T03:25:22.325Z",
#       "amount_money": {
#         "amount": 904,
#         "currency": "USD"
#       },
#       "status": "COMPLETED",
#       "delay_duration": "PT168H",
#       "source_type": "CARD",
#       "card_details": {
#         "status": "CAPTURED",
#         "card": {
#           "card_brand": "VISA",
#           "last_4": "5858",
#           "exp_month": 3,
#           "exp_year": 2027,
#           "fingerprint": "sq-1-6bO_U7mtbWRtd9NmqzXISdpW8uWBe5JSikyW40PxS351Nw8c_MOmm6Owvl1o95isyA",
#           "card_type": "CREDIT",
#           "prepaid_type": "NOT_PREPAID",
#           "bin": "453275"
#         },
#         "entry_method": "KEYED",
#         "cvv_status": "CVV_ACCEPTED",
#         "avs_status": "AVS_ACCEPTED",
#         "statement_description": "SQ *DEFAULT TEST ACCOUNT",
#         "card_payment_timeline": {
#           "authorized_at": "2025-03-15T03:25:21.085Z",
#           "captured_at": "2025-03-15T03:25:21.194Z"
#         }
#       },
#       "location_id": "L6DJMTAEEWBDV",
#       "order_id": "lvuo5Gj1pIFnWj2JzFJq5tbwxNAZY",
#       "risk_evaluation": {
#         "created_at": "2025-03-15T03:25:21.085Z",
#         "risk_level": "NORMAL"
#       },
#       "processing_fee": [
#         {
#           "effective_at": "2025-03-15T05:25:22.000Z",
#           "type": "INITIAL",
#           "amount_money": {
#             "amount": 56,
#             "currency": "USD"
#           }
#         }
#       ],
#       "buyer_email_address": "cff@pitzer.edu",
#       "note": "Quarantadue Cometeer",
#       "total_money": {
#         "amount": 904,
#         "currency": "USD"
#       },
#       "approved_money": {
#         "amount": 904,
#         "currency": "USD"
#       },
#       "receipt_number": "L3P5",
#       "receipt_url": "https://squareupsandbox.com/receipt/preview/L3P5XCiPkDUKSIq3gx4tugnautXZY",
#       "delay_action": "CANCEL",
#       "delayed_until": "2025-03-22T03:25:20.949Z",
#       "application_details": {
#         "square_product": "ECOMMERCE_API",
#         "application_id": "sandbox-sq0idb-YP5gnUWm9NRiLUmEeQRhGA"
#       },
#       "version_token": "2bP1ILclJc3hLYsrwrAXBVLUjeIHvqrpy07Zf85RaVP6o"
#     },
#     {
#       "id": "XtDrlmdLXDy1mmiAavKtdbwASWbZY",
#       "created_at": "2025-03-15T03:25:15.304Z",
#       "updated_at": "2025-03-15T03:25:17.154Z",
#       "amount_money": {
#         "amount": 1163,
#         "currency": "USD"
#       },
#       "status": "COMPLETED",
#       "delay_duration": "PT168H",
#       "source_type": "CARD",
#       "card_details": {
#         "status": "CAPTURED",
#         "card": {
#           "card_brand": "VISA",
#           "last_4": "5858",
#           "exp_month": 3,
#           "exp_year": 2027,
#           "fingerprint": "sq-1-6bO_U7mtbWRtd9NmqzXISdpW8uWBe5JSikyW40PxS351Nw8c_MOmm6Owvl1o95isyA",
#           "card_type": "CREDIT",
#           "prepaid_type": "NOT_PREPAID",
#           "bin": "453275"
#         },
#         "entry_method": "KEYED",
#         "cvv_status": "CVV_ACCEPTED",
#         "avs_status": "AVS_ACCEPTED",
#         "statement_description": "SQ *DEFAULT TEST ACCOUNT",
#         "card_payment_timeline": {
#           "authorized_at": "2025-03-15T03:25:15.433Z",
#           "captured_at": "2025-03-15T03:25:15.545Z"
#         }
#       },
#       "location_id": "L6DJMTAEEWBDV",
#       "order_id": "xB69qcApgq81wbZRoL2R0cMaiHFZY",
#       "risk_evaluation": {
#         "created_at": "2025-03-15T03:25:15.433Z",
#         "risk_level": "NORMAL"
#       },
#       "processing_fee": [
#         {
#           "effective_at": "2025-03-15T05:25:17.000Z",
#           "type": "INITIAL",
#           "amount_money": {
#             "amount": 64,
#             "currency": "USD"
#           }
#         }
#       ],
#       "buyer_email_address": "cff@pitzer.edu",
#       "note": "Venti Cometeer",
#       "total_money": {
#         "amount": 1163,
#         "currency": "USD"
#       },
#       "approved_money": {
#         "amount": 1163,
#         "currency": "USD"
#       },
#       "receipt_number": "XtDr",
#       "receipt_url": "https://squareupsandbox.com/receipt/preview/XtDrlmdLXDy1mmiAavKtdbwASWbZY",
#       "delay_action": "CANCEL",
#       "delayed_until": "2025-03-22T03:25:15.304Z",
#       "application_details": {
#         "square_product": "ECOMMERCE_API",
#         "application_id": "sandbox-sq0idb-YP5gnUWm9NRiLUmEeQRhGA"
#       },
#       "version_token": "Gh6IoigcbZ5eb7sEWFk5QzlM1m6M7RfQXtLsYDTLTXI6o"
#     }
#   ],
#   "cursor": "eyJjcmVhdGVkQXQiOjE3NDIwMDkxMTUzMDQsImlkIjoiWHREcmxtZExYRHkxbW1pQWF2S3RkYndBU1diWlkifQ"
# }

# %% [markdown]
# Phew!  &nbsp;&nbsp; We're going to need to access this data programmatically in order to analyze - and answer questions - about it!
#
# Here, let's see if we can access the amount and email fields of each:

# %%
#
# Yikes! There _seem_ to be a lot of keys...
print(list(result.body.keys()))

# Aha, actually not so many...
# Out:
# ['payments', 'cursor']

# %%
# opportunity to check for all of the keys/fields in each payment:

for payment in result.body['payments']:
    for key in payment.keys():
        print(key)
    break
# Out:
# id
# created_at
# updated_at
# amount_money
# status
# delay_duration
# source_type
# card_details
# location_id
# order_id
# risk_evaluation
# processing_fee
# buyer_email_address
# note
# total_money
# approved_money
# receipt_number
# receipt_url
# delay_action
# delayed_until
# application_details
# version_token

# %%
#
# loop over them and get the amount and email for each

for payment in result.body['payments']:

    amount = payment['total_money']['amount']   # to hold the amount of this transaction

    # an email variable to hold the email -- or a default string, if there is no email...
    if 'buyer_email_address' in payment:  email = payment['buyer_email_address']
    else:                                 email = "<not provided>"

    print("Amount:", amount)
    print(" Email:   ", email)
# Out:
# Amount: 1891
#  Email:    cff@pitzer.edu
# Amount: 1778
#  Email:    cff@pitzer.edu
# Amount: 1851
#  Email:    cff@pomona.edu
# Amount: 1486
#  Email:    cff@cmc.edu
# Amount: 1965
#  Email:    cff@hmc.edu
# Amount: 1518
#  Email:    cff@pitzer.edu
# Amount: 1901
#  Email:    cff@hmc.edu
# Amount: 731
#  Email:    cff@pomona.edu
# Amount: 1893
#  Email:    cff@scripps.edu
# Amount: 1185
#  Email:    cff@hmc.edu
# Amount: 1120
#  Email:    cff@hmc.edu
# Amount: 1115
#  Email:    cff@scripps.edu
# Amount: 760
#  Email:    cff@scripps.edu
# Amount: 1191
#  Email:    cff@pitzer.edu
# Amount: 1446
#  Email:    cff@pitzer.edu
# Amount: 625
#  Email:    cff@hmc.edu
# Amount: 574
#  Email:    cff@pitzer.edu
# Amount: 1967
#  Email:    cff@pitzer.edu
# Amount: 1099
#  Email:    cff@pomona.edu
# Amount: 764
#  Email:    cff@hmc.edu
# Amount: 917
#  Email:    cff@cmc.edu
# Amount: 1468
#  Email:    cff@hmc.edu
# Amount: 1353
#  Email:    cff@hmc.edu
# Amount: 923
#  Email:    cff@scripps.edu
# Amount: 760
#  Email:    cff@pomona.edu
# Amount: 898
#  Email:    cff@scripps.edu
# Amount: 1443
#  Email:    cff@pitzer.edu
# Amount: 980
#  Email:    cff@cmc.edu
# Amount: 1221
#  Email:    cff@pomona.edu
# Amount: 1873
#  Email:    cff@pomona.edu
# Amount: 1335
#  Email:    cff@pomona.edu
# Amount: 1736
#  Email:    cff@pomona.edu
# Amount: 1252
#  Email:    cff@hmc.edu
# Amount: 1169
#  Email:    cff@cmc.edu
# Amount: 1582
#  Email:    cff@scripps.edu
# Amount: 1468
#  Email:    cff@pitzer.edu
# Amount: 1495
#  Email:    cff@pomona.edu
# Amount: 904
#  Email:    cff@pitzer.edu
# Amount: 1163
#  Email:    cff@pitzer.edu

# %%
#
# My analysis is to count the per-customer average of CMC coffee costs:

total_buyers = 0
num_cmcers = 0
total_cmc_payments = 0
total_payments = 0

for payment in result.body['payments']:
    total_buyers += 1

    amount = payment['total_money']['amount']
    print("Amount:", amount)

    if 'buyer_email_address' in payment:  email = payment['buyer_email_address']
    else:                                 email = "<not provided>"
    print(" Email:   ", email)

    if "cmc" in email:   # is the email from cmc?
        num_cmcers += 1
        total_cmc_payments += amount  # the amount
    total_payments += amount  # the amount

print()
print(f"Total # of CMCers:  {num_cmcers = }")
print(f"Total CMC coffees:  {total_cmc_payments = }")
print(f"Total coffees:      {total_payments = }")

print()

if num_cmcers > 0:  # were there any CMCers?
    cmc_av = total_cmc_payments/num_cmcers
    print(f"Average for CMC:    {cmc_av}")
    full_av = total_payments/total_buyers
    print(f"Average overall:    {full_av}")
    print(total_buyers)
else:
    print("Failure: There were no CMC'ers!  Sell more coffee!!")
# Out:
# Amount: 1891
#  Email:    cff@pitzer.edu
# Amount: 1778
#  Email:    cff@pitzer.edu
# Amount: 1851
#  Email:    cff@pomona.edu
# Amount: 1486
#  Email:    cff@cmc.edu
# Amount: 1965
#  Email:    cff@hmc.edu
# Amount: 1518
#  Email:    cff@pitzer.edu
# Amount: 1901
#  Email:    cff@hmc.edu
# Amount: 731
#  Email:    cff@pomona.edu
# Amount: 1893
#  Email:    cff@scripps.edu
# Amount: 1185
#  Email:    cff@hmc.edu
# Amount: 1120
#  Email:    cff@hmc.edu
# Amount: 1115
#  Email:    cff@scripps.edu
# Amount: 760
#  Email:    cff@scripps.edu
# Amount: 1191
#  Email:    cff@pitzer.edu
# Amount: 1446
#  Email:    cff@pitzer.edu
# Amount: 625
#  Email:    cff@hmc.edu
# Amount: 574
#  Email:    cff@hmc.edu
# Amount: 573
#  Email:    cff@pomona.edu
# Amount: 1805
#  Email:    cff@pomona.edu
# Amount: 574
#  Email:    cff@cmc.edu
# Amount: 917
#  Email:    cff@cmc.edu
# Amount: 1468
#  Email:    cff@hmc.edu
# Amount: 1353
#  Email:    cff@hmc.edu
# Amount: 923
#  Email:    cff@scripps.edu
# Amount: 760
#  Email:    cff@pomona.edu
# Amount: 898
#  Email:    cff@scripps.edu
# Amount: 1443
#  Email:    cff@pitzer.edu
# Amount: 980
#  Email:    cff@cmc.edu
# Amount: 1221
#  Email:    cff@pomona.edu
# Amount: 1873
#  Email:    cff@pomona.edu
# Amount: 1335
#  Email:    cff@pomona.edu
# Amount: 1736
#  Email:    cff@pomona.edu
# Amount: 1252
#  Email:    cff@hmc.edu
# Amount: 1169
#  Email:    cff@cmc.edu
# Amount: 1582
#  Email:    cff@scripps.edu
# Amount: 1468
#  Email:    cff@pitzer.edu
# Amount: 1495
#  Email:    cff@pomona.edu
# Amount: 904
#  Email:    cff@pitzer.edu
# Amount: 1163
#  Email:    cff@pitzer.edu
#
# Total # of CMCers:  num_cmcers = 16
# Total CMC coffees:  total_cmc_payments = 19610
# Total coffees:      total_payments = 123521
#
# Average for CMC:    1225.625
# Average overall:    1235.21
# 100

# %% [markdown]
# #### How do we obtain the processing fees?
#
# First, [here are Square's rates](https://squareup.com/help/us/en/article/5068-what-are-square-s-fees) &nbsp;&nbsp;  Notice how many different payment types there are!
#
# <br>
#
# Now, let's see the data... checking the fields, there is a `'processing fee'` field:

# %%
# Let's see square's processing fees...

for payment in result.body['payments']:
    print(payment['processing_fee'])
# Out:
# [{'effective_at': '2025-03-15T05:32:18.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 85, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:32:13.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 82, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:32:09.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 84, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:32:06.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 73, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:32:00.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 87, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:31:55.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 74, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:31:49.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 85, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:31:44.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 51, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:31:42.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 85, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:31:37.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 64, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:31:33.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 62, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:31:29.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 62, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:31:25.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 52, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:31:22.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 65, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:31:19.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 72, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:31:14.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 48, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:31:10.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 47, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:31:03.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 47, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:31:00.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 82, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:30:55.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 47, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:30:52.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 71, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:30:49.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 82, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:30:45.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 74, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:30:41.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 65, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:30:37.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 47, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:30:34.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 70, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:30:31.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 87, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:30:29.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 75, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:30:25.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 47, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:30:23.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 78, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:30:19.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 52, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:30:14.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 54, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:30:09.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 84, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:30:03.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 46, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:30:01.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 75, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:29:56.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 45, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:29:52.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 72, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:29:47.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 79, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:29:42.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 60, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:29:39.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 66, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:29:33.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 65, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:29:28.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 49, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:29:23.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 55, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:29:20.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 48, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:29:17.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 54, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:29:13.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 85, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:29:07.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 55, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:29:01.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 52, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:28:56.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 63, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:28:52.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 61, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:28:46.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 74, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:28:42.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 59, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:28:38.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 73, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:28:35.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 88, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:28:30.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 45, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:28:25.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 70, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:28:22.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 46, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:28:16.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 74, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:28:12.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 67, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:28:06.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 72, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:28:02.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 79, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:27:58.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 87, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:27:56.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 82, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:27:52.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 57, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:27:46.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 60, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:27:43.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 77, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:27:39.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 52, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:27:37.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 81, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:27:30.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 60, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:27:27.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 47, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:27:21.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 54, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:27:18.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 66, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:27:13.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 73, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:27:10.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 50, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:27:05.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 78, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:26:59.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 52, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:26:54.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 68, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:26:49.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 54, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:26:44.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 87, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:26:41.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 62, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:26:36.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 52, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:26:33.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 57, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:26:31.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 73, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:26:27.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 69, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:26:22.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 57, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:26:19.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 52, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:26:12.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 56, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:26:09.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 72, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:26:03.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 58, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:26:00.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 65, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:25:57.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 84, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:25:54.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 69, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:25:48.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 80, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:25:44.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 66, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:25:40.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 64, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:25:34.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 76, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:25:30.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 73, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:25:25.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 73, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:25:22.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 56, 'currency': 'USD'}}]
# [{'effective_at': '2025-03-15T05:25:17.000Z', 'type': 'INITIAL', 'amount_money': {'amount': 64, 'currency': 'USD'}}]

# %%
# Let's total up square's processing fees: the API is at 2.9 + 30¢

CF = [] # List of Calculated Fees
AF = [] # List of Alternative Fees

total = 0.0
for payment in result.body['payments']:
    amount = payment['total_money']['amount']
    fee_amt = payment['processing_fee'][0]['amount_money']['amount']   # we'll assume USD (actually it's cents!)
    fee_amt = float(fee_amt)
    computed_fee = amount*0.029 + 30
    CF.append(computed_fee)

    Alternnative_fee  = amount*0.035 + 15 # Using Card On File Transaction
    AF.append(Alternnative_fee)

    # print(f"{    fee_amt = } ({amount = :4d}) ({computed_fee = :5.2f}) ({Alternnative_fee = :5.2f})")
    '''Too many transactions to print'''

CF_total = sum(CF) # Total Square Fees
AF_total = sum(AF) # Total Alternative Fees

print(f"\nTotal Computed Fees: ${CF_total/100 :.2f} ({CF_total :.3f})\nTotal Alternative Fees: ${AF_total/100 :.2f} ({AF_total :.3f})")
# Out:
# Total Computed Fees: $65.82 (6582.109)
# Total Alternative Fees: $58.23 (5823.235)

# %% [markdown]
# #### Reflection on fees
#
# It seems that we _can_ add these up ... and they do add up!
#
# For sure, we could also vary our analysis in any way we might imagine... .
#
# <br>
#
# That imagining - and analysis - is the challenge for all of these different "business-experiments" below.
#
# You'll choose one to implement:

# %% [markdown]
# <br>
# <hr>
# <br>
#
#
# #### <font color="Coral"><b>HW Tasks</b></font>: &nbsp;&nbsp;  <font size="-1">details for this payments hw...</font>
#
# 1. Make sure the analysis cells (below) are working for you... _Then_,
# 1. Choose an analysis to undertake. It can be one of our four suggested ones or one of your own:
#    + <font color="DodgerBlue"><b>the "CFF" program</b></font>: _How much would the Merchant gain if it created a CFF program where one person (the CFF) paid for all of their friends each time, resulting in fewer charges?_ (and how much could be passed along to the CFF customer?)
#       + You'll have to include in the payment - perhaps in the _Notes_ field - ***how many*** people each CFF paid for, each time, and use that value to compute the savings...
#    + <font color="DodgerBlue"><b>the "CoffeeCash" program</b></font>: _How much would the Merchant gain if it could consolidate all of the orders from a single customer over the course of, say, a week?_ This also would result in fewer charges. (Part of this could be passed along, in theory...)
#       + Here, Square will compute how much it would have charged the Merchant... and you'll compute the lower amount _after_ consolidation.
#    + <font color="DodgerBlue"><b>the pitch for the _Merchant_ to join "Cube"</b></font>: &nbsp; Cube is an _imagined_ variant of Square that uses FedNow instead of Credit Cards. How much would the Merchant save with Cube?
#       + Here, just use the nominal amounts of FedNow vs Square's charges. [Here is the FedNow Fee Schedule](https://www.frbservices.org/resources/fees/fednow-2025). (The top line is the one to use. The $25/month is waived this year.)
#    + <font color="DodgerBlue"><b>the pitch for Square to _become_ "Cube"</b></font>: &nbsp; As a consultant, you are considering pitching that Square itself roll out a new premium brand, named _Cube_ &nbsp; (perhaps as a new "dimension" in payment-processing.) It uses FedNow instead of Credit Cards. How much would **Square** benefit in this case?
#       + Just use the nominal amounts for FedNow vs CCards, for this hw...
#       + This is <u>not</u> the same as the previous one! This one compares FedNow vs CCards, instead of FedNow vs Square! (As a result, this one's a bit more "real" ... if only a bit!)
#    + <font color="DodgerBlue"><b>Other payment ideas?</b></font> &nbsp; ***Great!*** &nbsp; Feel free to use your own idea here, as long as it compares two real, or real-ish, payment approaches. Os, save them as part of your business-creation project at course's end.
# 1. Change the simulation to match your business's details 😀  You can stick with coffee - or choose another realm.
# 1. Change the simulation so that you're comparing two different approaches to handling payments.
# 1. Be sure to run small-as-possible tests to make sure things work well
#    + Debug as needed -- Remember, debug locally and only use the real requests when it seems entirely debugged...
# 1. Live-test your shop's "bustle," perhaps looping over five payments.
# 1. Then, grab those last five payments from Square's API.
# 1. **Analyze** these five, prototyping and debugging your analysis
# 1. Through that analysis, compare the costs of the two payment approaches you're using.
# 1. Then, try the whole workflow for a larger set of new payments, perhaps a few dozen? 42? 100?
#    + No need for more than this, unless you'd like to...
# 1. Finally, create a short write up with
#    + your choice of payment-approaches to analyze (and your choice of business, if you changed it from coffee 😀)
#    + note any API customizations you needed to investigate the business-intervention
#      + For example, the CFF requires an additional piece of information: how many people the purchaser was covering
#      + There is plenty of freedom here, and not every approach needs extra info
#    + include the results of your analysis
#    + are there other variations (of the comparison you made) worth noting -- what are the tradeoffs? It doesn't need to be a market-winning idea or even a reasonable idea, just an idea...
#      + This might seem unneeded, but it's often helpful, even if silly, obvious, or outlandish. <br> <font size="-1">(We all -- rightly -- like making decisions within a "trade-off space.")</font>
#
# <font color="DodgerBlue"><b>EC #1</b></font> &nbsp; (up to +10%) <font size="-1"> for computing each strategy's different resulting profits (or costs) over time -- and then plotting these values on the same axes. For example, the horizontal (x) axis could be the number of customers seen. The vertical (y) axis would be the value (whether profit or costs). </font>
#
# <font color="Coral"><b>EC #2</b></font> &nbsp; (up to _another_ +10%) <font size="-1">for running the entire above simulation "lots" of times (up to you: more than 500) and then, across all those runs, plotting the _averages_, the _90th percentile_, and the _10th percentile_ at each step. Extra fun if the percentiles are shown as a "translucent error band." AI - and Seaborn's <tt>lineplot</tt> - might help. See its [examples](https://seaborn.pydata.org/examples/index.html) below the documentation.  </font>

# %% [markdown]
# ---
#
#
# **Analysis: Square Payment Link API vs. Card on File Transactions**
#
# This analysis was based on the fact that these two modes of transactions feature a transaction fee equation that can besomewhat considered close or equal
#
#   + **Square API:** 2.9% + 30¢
#
#   + **Card on File:** 3.5% + 15¢
#
# Looking at the two fee rates above we see that *Card of File* has a higer percentage taxed than *Square API* but has a lower added flat fee. It would be interesting to see what has more effect. **A percent ratio**, or the **flat fee**.
#
# <font color="Red"><b>Issue:</b></font> &nbsp; we managed to do 510 payments but for the purpose of my analysis, we could not pull all the 510. The payment API is only giving us 100 payments. Not sure if there is a particular line or step we forgot to run before but it would've helped to have a total of 510 run payments in order to get a more accurate analysis.

# %%
print(len(CF))
print(len(AF))
NUM_PAYMENTS = 100 # Reset the number of payments to 100 since we can't get to the desired 510

# Plot showing CF and Af against Number of payments
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(1, NUM_PAYMENTS + 1)  # X-axis values from 1 to 510

'''--------------------------------------------------------------------------'''
# Calculating statistics across all runs
CF_mean = np.mean(CF)
AF_mean = np.mean(AF)

CF_90th = np.percentile(CF, 90)
CF_10th = np.percentile(CF, 10)

AF_90th = np.percentile(AF, 90)
AF_10th = np.percentile(AF, 10)

# Creating arrays for visualization
CF_mean_array = np.full(NUM_PAYMENTS, CF_mean)
AF_mean_array = np.full(NUM_PAYMENTS, AF_mean)

CF_90th_array = np.full(NUM_PAYMENTS, CF_90th)
CF_10th_array = np.full(NUM_PAYMENTS, CF_10th)

AF_90th_array = np.full(NUM_PAYMENTS, AF_90th)
AF_10th_array = np.full(NUM_PAYMENTS, AF_10th)
'''--------------------------------------------------------------------------'''

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(x, CF, label="Square API", linestyle='-', marker='', alpha=0.7)
plt.plot(x, AF, label="Card on File", linestyle='-', marker='', alpha=0.7)
plt.xlabel("Payment Number")
plt.ylabel("Payment Fee")
plt.title("Square API and Card on File Transaction Fees Vs. Number of Payments")
plt.legend()
plt.grid(True)
plt.show()

# Plotting the mean lines
plt.figure(figsize=(10, 5))
plt.plot(x, CF_mean_array, label="CF Mean", linestyle='-', color='blue')
plt.plot(x, AF_mean_array, label="AF Mean", linestyle='-', color='red')

# Plotting the shaded error bands for percentiles
plt.fill_between(x, CF_10th_array, CF_90th_array, color='blue', alpha=0.2, label="CF 10th-90th Percentile")
plt.fill_between(x, AF_10th_array, AF_90th_array, color='red', alpha=0.2, label="AF 10th-90th Percentile")

plt.xlabel("Payment Number")
plt.ylabel("Payment Fee")
plt.title("Analysis With Confidence Intervals")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 100
# 100

# %% [markdown]
# ---
#
# From the above figures we can see that overall Card on file costs less per transaction than Square API. Due to this, we concluded that the flatt fee offset added after the rate has a much larger effect on transaction fees than the percentage rate.
#
# **There is a nice quote about Card on File we foun on Square Website:**
#
# "*The higher fee for manually entered and card on file transactions is due to a greater risk involved with these payments, as neither the payment card nor the cardholder needs to be present for the payment to occur."*
#
# => Funny enough that given the risk involved it looks like the mercant is better off overall using Card on file than Square API. But overall this might not be worth the lawsuit losses they might face if any of these manually entered payment info was to go wrong....
#
#
# ---

# %% [markdown]
# ## Congrats!
#
# You're ready to start <i><u>Pay Up!</u></i> , your new fintech consultancy which specializes in creative payment processing and alternatives...
#
# <br>
#
# Payments are an important facet of fintech, but they're only one. Feel free to expand on this for a final project -- or take another path.

# %% [markdown]
# # &nbsp;
