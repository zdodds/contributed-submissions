# %% [markdown]
# # Linear Models and Neural Nets Lab (Econ 176 '25)
#
# This lab will guide you through a _modeling_ task, inspired by the I&RE module:
# + it's based on a widely-studied French third-party-liability dataset [here on Kaggle](https://www.kaggle.com/datasets/floser/french-motor-claims-datasets-fremtpl2freq)
# + this variation has seven features and is available from [OpenML](https://openml.org/). (It's also widely studied: Cited below.)
# + of the seven features, six are used as predictive features and one is the target (to be predicted from the other six)
# + the target (to be predicted) is the _number of claims filed_ &nbsp; ``claim_nb`` by an individual. We'll call these _claims_ or _incidents_.
# + the features are
#   + the ``year`` &nbsp;&nbsp; (there are only years 2018 and 2019)
#   + whether the driver lives in a ``town`` <font size="-1">``town == 1.0``</font> or in a more rural area <font size="-1">``town == 0.0``</font>
#   + the _driver's_ age (in years) &nbsp;&nbsp; ``driver_age``
#   + the car's _weight_ (in kg) &nbsp;&nbsp; ``car_weight``
#   + the car's engine _power_ (in hp) &nbsp;&nbsp; ``car_power``
#   + the _car's_ age (in years) &nbsp;&nbsp; ``car_age``
#
# <br>
#
# You'll model the
# The notebook will guide you through
# + loading the data and inspecting it, a bit
# + modeling the data with linear models (linear regression)

# %% [markdown]
# ## Loading and inspecting data
#
# &nbsp;&nbsp; <font color="Coral">there are two tasks here...</font>

# %%
# some of the libraries have warnings we want to ignore...
import warnings
warnings.filterwarnings("ignore")

# AI/ML libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml

# %matplotlib inline

# %% [markdown]
# These two cells grab and extract the data - one millon rows and seven features - from OpenML:

# %%
# Fetch the insurance-claim dataset from the OpenML repository  (an API call! :)
all = fetch_openml(data_id=45106, as_frame=True)

# %%
# Extract the pieces of the API result from the OpenML API call
df_all = all.data
df_all["claim_nb"] = all.target

print("Shape of full data:", df_all.shape)
df_all.head(15)    # print the first five rows of data
# Out:
# Shape of full data: (1000000, 7)
#       year  town  driver_age  car_weight  car_power  car_age  claim_nb
# 0   2018.0   1.0        51.0      1760.0      173.0      3.0       0.0
# 1   2019.0   1.0        41.0      1760.0      248.0      2.0       0.0
# 2   2018.0   1.0        25.0      1240.0      111.0      2.0       0.0
# 3   2019.0   0.0        40.0      1010.0       83.0      9.0       0.0
# 4   2018.0   0.0        43.0      2180.0      169.0      5.0       0.0
# 5   2018.0   1.0        45.0      1170.0      149.0      1.0       1.0
# 6   2019.0   0.0        72.0      1040.0       60.0      2.0       0.0
# 7   2018.0  -0.0        60.0      1060.0       66.0      2.0       0.0
# 8   2018.0   1.0        31.0      1400.0      118.0      0.0       0.0
# 9   2018.0   1.0        19.0      1310.0       78.0      0.0       0.0
# 10  2018.0   1.0        76.0      1140.0       89.0      4.0       0.0
# 11  2019.0   1.0        49.0      1060.0      106.0      7.0       0.0
# 12  2018.0   0.0        65.0      1670.0      173.0      1.0       0.0
# 13  2018.0   1.0        33.0      1010.0       97.0      6.0       0.0
# 14  2018.0   0.0        31.0      1490.0      146.0      1.0       0.0

# %% [markdown]
# Here are the brief descriptions of each of the features:
# + the first six are the features we will use to _make_ predictions
#   + the ``year`` &nbsp;&nbsp; (there are only years 2018 and 2019)
#   + whether the driver lives in a ``town`` <font size="-1">``town == 1.0``</font> or in a more rural area <font size="-1">``town == 0.0``</font>
#   + the _driver's_ age (in years) &nbsp;&nbsp; ``driver_age``
#   + the car's _weight_ (in kg) &nbsp;&nbsp; ``car_weight``
#   + the car's engine _power_ (in hp) &nbsp;&nbsp; ``car_power``
#   + the _car's_ age (in years) &nbsp;&nbsp; ``car_age``
# + the seventh <b><tt>claim_nb</tt></b>, the number of claims files during that year, is the target to _be predicted_

# %%
df_all.describe()
# Out:
#                  year            town      driver_age      car_weight  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean      2018.550270        0.600130       45.998782     1308.266530
# std          0.497467        0.489872       13.997827      285.505998
# min       2018.000000       -0.000000       18.000000      950.000000
# 25%       2018.000000        0.000000       35.000000     1090.000000
# 50%       2019.000000        1.000000       45.000000     1240.000000
# 75%       2019.000000        1.000000       56.000000     1460.000000
# max       2019.000000        1.000000       88.000000     3120.000000
#
#             car_power         car_age        claim_nb
# count  1000000.000000  1000000.000000  1000000.000000
# mean       124.981766        4.156266        0.089334
# std         49.133293        3.545284        0.300652
# min         50.000000        0.000000        0.000000
# 25%         86.000000        1.000000        0.000000
# 50%        116.000000        3.000000        0.000000
# 75%        156.000000        6.000000        0.000000
# max        341.000000       23.000000        4.000000

# %% [markdown]
# #### <font color="Coral"><b>Task 1</b></font>
#
# With full encouragement to use the built-in Colab AI -- or another of your choice, create five specific visualizations and an additional one:
# + create a histogram of all the drivers' ages, and
# + a histogram of all the the cars' ages, and
# + a histogram of the claim numbers, `claim_nb`
# + create a scatter plot of how the car's age varies with the driver's age
# + create a scatter plot of how the `claim_nb` varies with the driver's age
# + <font color="Coral"><b>also</b></font>, create one more - different - scatter plot of your choice, using this data
#
# <br>
#
# <font color="DodgerBlue">Below for task 2, write a short reflection</font> on the results of these data-visualizations. One sentence on what you see in each is perfect.  <br> <font size="-1">(There's another cell below reminding you of this!)</font>

# %%
#
# It's easiest to make additional code cells...
#

# %%
# Histogram of drivers' ages
plt.figure(figsize=(10, 6))
plt.hist(df_all['driver_age'], bins=30, alpha=0.7, color='blue', edgecolor='black')
plt.title('Distribution of Driver Ages', fontsize=14)
plt.xlabel('Driver Age (years)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(alpha=0.3)
plt.show()

# Histogram of cars' ages
plt.figure(figsize=(10, 6))
plt.hist(df_all['car_age'], bins=25, alpha=0.7, color='green', edgecolor='black')
plt.title('Distribution of Car Ages', fontsize=14)
plt.xlabel('Car Age (years)', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.grid(alpha=0.3)
plt.show()

# %%
# Histogram of claim numbers
plt.figure(figsize=(10, 6))
plt.hist(df_all['claim_nb'], bins=np.arange(-0.5, 5.5, 1), alpha=0.7, color='red', edgecolor='black')
plt.title('Distribution of Insurance Claims', fontsize=14)
plt.xlabel('Number of Claims', fontsize=12)
plt.ylabel('Frequency', fontsize=12)
plt.xticks(range(0, 5))
plt.grid(alpha=0.3)
plt.show()

# Scatter plot of car age vs driver age
plt.figure(figsize=(10, 6))
# Take a random sample to avoid overplotting
sample_size = 50000
sample_df = df_all.sample(sample_size, random_state=42)
plt.scatter(sample_df['driver_age'], sample_df['car_age'], alpha=0.3, s=10)
plt.title('Car Age vs Driver Age', fontsize=14)
plt.xlabel('Driver Age (years)', fontsize=12)
plt.ylabel('Car Age (years)', fontsize=12)
plt.grid(alpha=0.3)
plt.show()

# %%
# Scatter plot of claim_nb vs driver age
plt.figure(figsize=(10, 6))
# Use jittering to better visualize discrete claim values
claims_df = df_all.sample(sample_size, random_state=24)
plt.scatter(claims_df['driver_age'], claims_df['claim_nb'] + np.random.normal(0, 0.05, len(claims_df)), 
            alpha=0.3, s=10, color='purple')
plt.title('Number of Claims vs Driver Age', fontsize=14)
plt.xlabel('Driver Age (years)', fontsize=12)
plt.ylabel('Number of Claims', fontsize=12)
plt.grid(alpha=0.3)
plt.show()

# Additional scatter plot: car_power vs claim_nb with town as color
plt.figure(figsize=(10, 6))
power_claims_df = df_all.sample(sample_size, random_state=35)
scatter = plt.scatter(power_claims_df['car_power'], 
                     power_claims_df['claim_nb'] + np.random.normal(0, 0.05, len(power_claims_df)),
                     c=power_claims_df['town'], cmap='viridis', 
                     alpha=0.5, s=15)
plt.colorbar(scatter, label='Town (1=urban, 0=rural)')
plt.title('Number of Claims vs Car Power (colored by Town)', fontsize=14)
plt.xlabel('Car Power (hp)', fontsize=12)
plt.ylabel('Number of Claims', fontsize=12)
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# #### <font color="Coral"><b>Task 2</b></font>
#
# <font color="DodgerBlue">Here, write a short reflection</font> -- a sentence or two for each of these is wonderful -- that describes the data-trends you see in the visualizations above.
#
# As a reminder, they were
# + histograms for the drivers' ages and the cars' ages and the claim numbers, `claim_nb`
# + a scatter plot of how the car's age varies with the driver's age
# + a scatter plot of how the `claim_nb` varies with the driver's age
# + <font color="Coral"><b>and</b></font>, one other - different - scatter plot that visualizes some of this data
#
# <br>
# <hr>
# <br>
#
# Feel free to use a new cell or the space below:
#
#
#
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# #### Task 2 Reflection:
#
# The driver age histogram shows a relatively normal distribution with peaks in the 40-50 age range, suggesting most drivers in the dataset are middle-aged. The car age histogram is right-skewed with most vehicles being newer (1-3 years old), which aligns with expected car ownership patterns where newer cars are more common than older ones. The claims distribution is extremely skewed, with the vast majority of policyholders (about 90%) filing zero claims, showing the rareness of insurance incidents. The car age vs driver age scatter plot shows no strong correlation, indicating that drivers of all ages own cars of varying ages. The claims vs driver age scatter plot suggests that claim frequency is relatively consistent across age groups, though the jittering makes it difficult to see subtle patterns. The claims vs car power plot with town coloring reveals a slight trend where higher-powered cars and urban areas (yellow points) may have slightly higher claim frequencies, though the effect appears modest.

# %% [markdown]
# ## Modeling
#
# You will build two models for the <b><tt>claim_nb</tt></b> target:
# + a **linear-regression** model &nbsp;&nbsp; <font size="-2">since the target is a "number of occurrences" over a span of time, we use a _Poisson_ model</font>
# + a **neural-network** model &nbsp;&nbsp;  <font size="-2">of the same sort</font>
#
# You'll experiment with
# + interpreting the models
# + then, building some "deeper" neural networks
# + seeing how the two modeling approaches differ in the relationships they can express

# %% [markdown]
# ### Part 1: &nbsp;&nbsp; Data splitting
#
# The dataset has a million rows.
# + For speed of training, we will use only 100,000 of them.
# + At the end, you'll try changing at least three model parameters. This is one of those options! 😃

# %%
# Let's make sure everything runs first... using only 100,000 rows (instead of 1,000,000)

df_all = df_all.sample(frac=1.0, random_state=42)  # This shuffles the 1,000,000-row dataset

NUMROWS = 100000
df = df_all.iloc[0:NUMROWS,:].copy()    # This uses only the first 100,000 rows (or NUMROWS rows) for speed...

# %%
# We split into 90% training data and 10% testing data

from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.1, random_state=30)
print("Shape of training data:", train.shape)
print("Shape of test data:", test.shape)
# Out:
# Shape of training data: (90000, 7)
# Shape of test data: (10000, 7)

# %%
# Define target name (y) and feature names (x)
y, x = df.columns[-1], list(df.columns[:-1])

print("The response name:", y)
print("The feature names:", x)
# Out:
# The response name: claim_nb
# The feature names: ['year', 'town', 'driver_age', 'car_weight', 'car_power', 'car_age']

# %% [markdown]
# ### Part 2: &nbsp; A (Generalized) Linear Model (GLM)
#
# Here, we build a linear-regression model of the data.
#
# We'll use [Glum](https://glum.readthedocs.io/en/latest/), a high-performance implementation in Python. <br> <font size="-2"><tt>glum</tt> stands for _generalized linear modeling" ... not sure about the <tt>u</tt></font>

# %% [markdown]
# In Colab, you are likely to need to install `glum` once:

# %%
# !pip install glum
# Out:
# Requirement already satisfied: glum in ./venv/lib/python3.12/site-packages (3.1.2)
# Requirement already satisfied: joblib in ./venv/lib/python3.12/site-packages (from glum) (1.4.2)
# Requirement already satisfied: numexpr in ./venv/lib/python3.12/site-packages (from glum) (2.10.2)
# Requirement already satisfied: numpy in ./venv/lib/python3.12/site-packages (from glum) (2.1.3)
# Requirement already satisfied: pandas in ./venv/lib/python3.12/site-packages (from glum) (2.2.3)
# Requirement already satisfied: scikit-learn>=0.23 in ./venv/lib/python3.12/site-packages (from glum) (1.6.1)
# Requirement already satisfied: scipy in ./venv/lib/python3.12/site-packages (from glum) (1.15.2)
# Requirement already satisfied: formulaic>=0.6 in ./venv/lib/python3.12/site-packages (from glum) (1.1.1)
# Requirement already satisfied: tabmat>=4.0.0 in ./venv/lib/python3.12/site-packages (from glum) (4.1.1)
# Requirement already satisfied: interface-meta>=1.2.0 in ./venv/lib/python3.12/site-packages (from formulaic>=0.6->glum) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./venv/lib/python3.12/site-packages (from formulaic>=0.6->glum) (4.13.1)
# Requirement already satisfied: wrapt>=1.0 in ./venv/lib/python3.12/site-packages (from formulaic>=0.6->glum) (1.17.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./venv/lib/python3.12/site-packages (from pandas->glum) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.12/site-packages (from pandas->glum) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./venv/lib/python3.12/site-packages (from pandas->glum) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./venv/lib/python3.12/site-packages (from scikit-learn>=0.23->glum) (3.6.0)
# Requirement already satisfied: narwhals in ./venv/lib/python3.12/site-packages (from tabmat>=4.0.0->glum) (1.34.0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->glum) (1.17.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# We can use that library to build a linear model:

# %%
#
# there's not much code to build our model!
#
from glum import GeneralizedLinearRegressor

glm_model = GeneralizedLinearRegressor(family="poisson", alpha=1e-6)
glm_model.fit(X=train[x], y=train[y])

print("Coefficients")
pd.Series(np.append(glm_model.intercept_, glm_model.coef_), index=["Intercept"] + x)
# Out:
# Coefficients
# Intercept     5.524484
# year         -0.004149
# town          0.350489
# driver_age   -0.003272
# car_weight   -0.000068
# car_power     0.004117
# car_age      -0.022168
# dtype: float64

# %% [markdown]
# We did it!  &nbsp;&nbsp; But what _is_ it?!

# %% [markdown]
# #### As an absolute model, this is <u>not</u> very useful!
#
# **Everyone** has a very high likelihood of NOT having an auto incident/filing a claim. <i>This is good!</i>
#
# This means _everyone's_ expected number of incidents is 0 &nbsp; (Well, very close to it.)

# %% [markdown]
# #### In comparing the ***relative*** impact of a feature, the model <u>is</u> useful.
#
# Here is a full description of the ***relative*** relationships expressed by those coefficients [(cite)](https://ademos.people.uic.edu/Chapter19.html#:~:text=Rather%20than%20odds%20ratios%20(which,variable%5D%20is%20%5Bcoefficient%5D.):
#
#
# > <font color="DodgerBlue">The expected log count for each unit increase/decrease (depending on the sign of the coefficient) in [outcome variable] given [predictor variable] is [coefficient].</font>
#
#
# Wow!  &nbsp;&nbsp; This needs some unpacking...
#
# <hr>
# <br>

# %% [markdown]
# <font size="+1" color="Blue">Interpreting</font> <font size="+1" > coefficients, part one: &nbsp;&nbsp; <tt><b>town</b></tt> example</font>
#
#
# In practice, it's more straightforward than this suggests:
#
# Suppose your coefficient for `town` is 0.36. &nbsp; <font size="-2">That was one of my test-run values.</font>
#
# This means that "one unit" of `town` increases the <u>log of the claim count</u> by 0.36.  <br> <i><font color="Blue">But log-counts aren't very intuitive!</font></i> &nbsp; Let's _undo_ the log:
#
#
# `exp(0.36)` is about `1.43` &nbsp;&nbsp;&nbsp; Let's see that this is true:

# %%
from math import exp
exp(0.36)
# Out:
# 1.4333294145603401

# %% [markdown]
# This means that "one unit" of `town` ***multiplies*** &nbsp; the frequency of incidents by 1.43
#
# Since `town` only has values 0 and 1, this means that
#
# **when `town` is 1, the likelihood of an incident is 1.43 times higher then when it's 0**
#
# <br>
#
# <font color="Coral"><b>Aha!</b></font>
#
# <br>
#
# This ***incident-rate ratio*** is really useful!
# + for assessing the threat of an event that is relatively rare and/or
# + the _value_ of small changes to an individual's particular situation.
#
# In theory, the multiplier can be used many times:

# %%
exp(0.360105)    # for each unit of "townness,"  we multiply the expected claims by 1.433:
# Out:
# 1.433479922050374

# %%
exp(0.360105) ** 2   # so, we multiply twice for _two_ units of "townness":
# Out:
# 2.054864686921546

# %% [markdown]
# This means, if `town == 2`, the expected claims for those individuals would be 2.05x higher:
# + because, as above, `1.433 ** 2 == 1.433*1.433 == 2.05`
#
# There _isn't_ such a value in the dataset...
# + ... but models will allow this kind of extrapolation. Be careful!

# %% [markdown]
# <font size="+1" color="Blue">Interpreting</font> <font size="+1"> coefficients, part two: &nbsp;&nbsp; <tt><b>driver_age</b></tt> example</font>
#
# Let's try an example where there are multiple values, for example, for <b><tt>driver_age</tt></b> :
# + My coefficient for <tt><b>driver_age</b></tt> was <tt>-0.003272</tt>
# + And <tt>exp(-0.003272) == 0.9967</tt> &nbsp;&nbsp; <font size="-2">Let's confirm:</font>

# %%
exp(-0.003272)    # for each year of driver_age, you multiply the expected claims by 0.9967:
# Out:
# 0.9967333471584426

# %% [markdown]
# This means that, for this model, the number of claims is multiplied by <tt>0.9967</tt> ***for each additional year of age***
#
# <br>
#
# What if an individual is fifteen years older?

# %%
0.9967 ** 15
# Out:
# 0.9516272593744175

# %% [markdown]
# the model expects the number of claims to be 95% with that "additional experience"
#
# <br>
#
# What if we compare the oldest (88) and youngest (18) in the dataset:

# %%
exp(-0.003272)**(88-18)
# Out:
# 0.7952967210000054

# %% [markdown]
# Which states that our octogenerians will make 0.79 the claims as our 18-year-olds.
#
# Taking the reciprocal, the model is saying that moving across the dataset's full age-span, from old to young, multiplies the number of claims by 1.25:

# %%
1/0.7952
# Out:
# 1.2575452716297786

# %% [markdown]
# There is definitely room for skepticism here! 😀
#
# But we've successfully interpreted the model coefficients!
#
# Next, try two of your own:

# %% [markdown]
# #### <font color="Coral"><b>Task 3</b></font> &nbsp; Two more model-interpretations:
#
# Following the approach of the two examples above, choose **two more** features from the coefficients and:
# + compute the _per-unit_ incident-rate multiplier for that feature
# + decide on a "reasonable" number of units (years, kg, hp, ...)
# + compute the incident-rate multiplier for _that many units_
# + find the "full span" of units in the dataset (it's printed above ...)
# + compute the incident-rate multiplier for _that full span_
# + and reflect on what this is saying about the incidents in this data.
#
# Specifically, share how well does these _match your intution_ about these factors for auto incidents/insurance claims? Reasonable? Skeptical? Other?
#
# <br>
# <hr>
# <br>
#
# Feel free to use this cell or new ones just below:
#
# <br>
# <br>

# %%
from math import exp

print("Car Power Analysis:")
print(f"Per unit multiplier: {exp(0.004117)}")
print(f"50hp increase: {exp(0.004117 * 50)}")
print(f"Full range (50hp to 341hp): {exp(0.004117 * (341-50))}")

print("Car Weight Analysis:")
print(f"Per unit (kg) multiplier: {exp(-0.000068)}")
print(f"500kg increase: {exp(-0.000068 * 500)}")
print(f"Full range (950kg to 3120kg): {exp(-0.000068 * (3120-950))}")
# Out:
# Car Power Analysis:
# Per unit multiplier: 1.004125486486792
# 50hp increase: 1.228568904837495
# Full range (50hp to 341hp): 3.3136390620763705
# Car Weight Analysis:
# Per unit (kg) multiplier: 0.9999320023119476
# 500kg increase: 0.9665715046375066
# Full range (950kg to 3120kg): 0.8628106681281974

# %% [markdown]
# ### Car Power Analysis:
#
# Each 1 unit increase in car power multiplies the expected number of claims by 1.0041 or 0.41% increase. A 50hp increase would result in a 22.9% increase in claims. The full range of car power (50hp to 341hp) would result in a 3.31 times increase in claims. This makes sense to me because high power cars enable more risky driving, which leads to more incidents.
#
# ### Car Weight Analysis:
#
# Each 1 unit increase in car weight multiplies the expected number of claims by 0.999932 or 0.0068% decrease. A 500kg increase would result in a 3.3% decrease in claims. The full range of car weight (950kg to 3120kg) would have about 13.7% decrease in claims. This might be because heavier cars are safer in collisions, so they have less incidents.

# %% [markdown]
# <br>
# <hr>
# <br>

# %% [markdown]
# ### Part 3. &nbsp; **Automatic** model-interpretation
#
# A technique called SHAP, short for SHapley Additive exPlanation, is able to estimate the feature-by-feature effects of _any_ model.
#
# It _should_ be here already:

# %%
import shap

# %% [markdown]
# SHAP works by sampling the model at several points and then surveying the space around those points to see how the model is changing. It integrates all of this information in order to be able to compare the influence of all of the variables with the same units, known as SHAP values. They are again relative values, and they indicate how the target varies with changes to each feature -- in light of _all_ the features in the model.
#
# Linear models like the one above are already interpretable. However, other models - like neural nets - are much less so.
#
# To get started, let's run SHAP for our linear model:

# %%
import shap

# First, extract background data. This is the same for all models to interpret:
X_bg = train[x].sample(200, random_state=8366)    # grab 200 samples from our training data - 200 is a lot...

# Exploring the space...   This will take a while...
glm_explainer = shap.KernelExplainer(lambda x: np.log(glm_model.predict(x)), data=X_bg)     # Don't worry about the warnings!

# Then, we can choose any data to explain. We'll choose 1,000 rows randomly called X_explain
X_explain = train[x].sample(n=1000, random_state=937)
shap_glm = glm_explainer.shap_values(X_explain, nsamples=30) # there are 30 non-trivial subsets of 6 features
# Out:
# Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# Let's see one of the explained individuals:

# %%
X_explain[0:1]
# Out:
#           year  town  driver_age  car_weight  car_power  car_age
# 396019  2018.0   0.0        50.0      1290.0      119.0      1.0

# %% [markdown]
# and, let's see their SHAP values:

# %%
shap_glm[0:1]
# Out:
# array([[ 0.00213664, -0.18400681, -0.01735597,  0.00128275, -0.02764656,
#          0.06816579]])

# %% [markdown]
# Ok!
#
# These numbers are (the sign and) relative weight of each of this individual's **per-feature contributions** to their risk (their expected number of claims).
#
# For example, in this model,
# + their age makes a claim less likely
# + their car's age make a claim more likely
#
# Plus, the <tt><b>SHAPvalue</b></tt> units are commensurate:
# + the impact of the driver's age carries almost three times the weight of their car's age
#
# <br>
#
# Better to plot all of them. &nbsp; Let's do that next:

# %%
#
# A function to create all of the dependence plots among our features
#
def all_dep_plots(x, shap_values, X):
    """ Dependence plots for all features x. """
    fig, _ = plt.subplots(nrows=2, ncols=3, figsize=(10, 6), sharey=True)

    for i, ax in enumerate(fig.axes):
        xvar = x[i]
        shap.dependence_plot(
            xvar,
            shap_values,
            features=X,
            x_jitter=0.2 * (xvar in ("town", "year")),
            ymin=-0.5,
            ymax=1,
            ax=ax,
            show=False,
        )
        ax.set_title(xvar, fontdict={"size": 16})
        ax.set_ylabel("SHAP values" if i % 3 == 0 else "")
        ax.grid()
    plt.tight_layout()

print("The all_dep_plots function has been defined.")
print("Run the next cell to plot the features and their impacts")
# Out:
# The all_dep_plots function has been defined.
# Run the next cell to plot the features and their impacts

# %%
all_dep_plots(x, shap_glm, X_explain)

# %% [markdown]
# #### <font color="Coral"><b>Task 4</b></font> &nbsp; How did SHAP do?
#
# In Task 3, you chose two features and examined their effects on the target value, the number of incidents.
#
# Here, revisit those two features, and in a couple of sentences, describe whether the effects you measured match the plots above.
#
# <br>
#
# **Note/Hints**  There are lots of dimensions here! And lots of information! The x-axis of each plot shows the feature values. The y-axis is the SHAP value (the relative impact on the number of claims).
#
# The red/blue coloring of datapoints shows how the _most influential **other** feature_ overlays onto the current plot. That **other** feature is the most influential for the one labeled on the x-axis, and so it will often be different for different plots.
#
# <br>
#
# As an example of this feature-comparison, remember that one <tt><b>town</b></tt> unit multiplied the claims by 1.4, and the full span of <tt><b>driver_age</b></tt> multiplied the claims by 1.25.
#
# This matches well!  In the above plot, the span for <tt><b>town</b></tt> is a little bit larger than the span for <tt><b>driver_age</b></tt>.
#
# The SHAP units are not the same, and SHAP takes into account more than linear dependencies, but it has captured the sign and the magnitude of the model it was interpreting.
#
#
# <br>
# <hr>
# <br>
#
# For your two reflections, feel free to use this cell or new ones just below this one:
#
# <br>
# <br>

# %% [markdown]
# Reflection
#
# For car power, the SHAP plot confirms the coefficient analysis. It shows a clear positive relationship between car power and claims, matching the calculated 331% increase across the full range. The relationship is consistently linear, giving us more confidence in our interpretation that higher-powered cars lead to more claims.
#
# For car weight, the plot also validates the coefficient interpretation, showing the slight negative relationship. The small magnitude of effect in the plot aligns with the 13.7% decrease across the full weight range.
#
# I thought it was interesting how the plit shows the interaction between car power and weight since we can see the gradient. Suggusts these features work together to influence the number of claims.

# %% [markdown]
# ### Part 4: &nbsp;&nbsp; A Neural Network model
#
# Here, we TensorFlow to fit a "shallow" neural net.
#
# Your task is to improve the results -- by adding more layers and retraining...
#
# Plus, the resulting layered network will be able to extract nonlinear relationships among the features <br> <font size="-1">(in exchange for much more training time...)</font>

# %% [markdown]
# Neurons work best when all their data is ***roughly the same magnitude***
#
# Our brains handle this at the sensor level -- our hearing and vision systems continually try to re-establish the ambient baseline to help convert their inputs into computable magnitudes:
# + light sensitivity increases in the dark and decreases in bright light
# + for sound, loud repetitive even soft sounds are heightened when in a quiet place.
#
# <br>
#
# For neural nets, we can scale each feature to be between -1 and 1:

# %%
# Scale features to [-1, 1]
from sklearn.preprocessing import MinMaxScaler

nn_preprocessor = MinMaxScaler(feature_range=(-1, 1))
X_train = nn_preprocessor.fit_transform(train[x])

print("Output after the data has been scaled:")
pd.DataFrame(X_train[0:5], columns=x)
# Out:
# Output after the data has been scaled:
#    year  town  driver_age  car_weight  car_power   car_age
# 0   1.0  -1.0    0.246377   -0.530612  -0.501754 -1.000000
# 1  -1.0   1.0   -0.072464   -0.530612  -0.256140 -0.818182
# 2   1.0   1.0   -0.072464   -0.969388  -0.817544 -0.636364
# 3   1.0   1.0   -0.333333   -0.867347  -0.887719 -0.181818
# 4   1.0   1.0   -0.594203   -0.489796  -0.445614 -0.727273

# %%
#
# Neural nets are worthy of their own course, for sure...
#
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
cb = [EarlyStopping(patience=20), ReduceLROnPlateau(patience=5)]  # "callbacks" for training (see below)

# Architecture
inputs = keras.Input(shape=(len(x),))
# additional layers can be added here!
outputs = layers.Dense(1, activation="exponential")(inputs)
nn_model_shallow = keras.Model(inputs=inputs, outputs=outputs)

nn_model_shallow.summary()

# Calculate gradients
nn_model_shallow.compile(optimizer=Adam(learning_rate=1e-4), loss="Poisson")
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │             7 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 7 (28.00 B)
#  Trainable params: 7 (28.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Above, you see the artictecture of the network.
#
# This includes the total number of neuron-connections (parameters) to train.
#
# Let's train!

# %%
#
# train the network!
#

tf.random.set_seed(4349)

history_shallow = nn_model_shallow.fit(
    x=X_train,
    y=train[y],
    epochs=200,
    batch_size=10_000,
    validation_split=0.1,
    callbacks=cb,
    verbose=1,         # consider running both values 0 (no printing) and 1 (printing)
)
# Out:
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7900 - val_loss: 0.7856 - learning_rate: 1.0000e-04
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7882 - val_loss: 0.7838 - learning_rate: 1.0000e-04
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7864 - val_loss: 0.7821 - learning_rate: 1.0000e-04
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7846 - val_loss: 0.7803 - learning_rate: 1.0000e-04
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7828 - val_loss: 0.7785 - learning_rate: 1.0000e-04
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7810 - val_loss: 0.7768 - learning_rate: 1.0000e-04
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7792 - val_loss: 0.7750 - learning_rate: 1.0000e-04
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7775 - val_loss: 0.7733 - learning_rate: 1.0000e-04
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7758 - val_loss: 0.7716 - learning_rate: 1.0000e-04
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7740 - val_loss: 0.7699 - learning_rate: 1.0000e-04
# Epoch 11/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7723 - val_loss: 0.7682 - learning_rate: 1.0000e-04
# Epoch 12/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7706 - val_loss: 0.7665 - learning_rate: 1.0000e-04
# Epoch 13/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7689 - val_loss: 0.7648 - learning_rate: 1.0000e-04
# Epoch 14/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7672 - val_loss: 0.7632 - learning_rate: 1.0000e-04
# Epoch 15/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7655 - val_loss: 0.7615 - learning_rate: 1.0000e-04
# Epoch 16/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7639 - val_loss: 0.7598 - learning_rate: 1.0000e-04
# Epoch 17/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7622 - val_loss: 0.7582 - learning_rate: 1.0000e-04
# Epoch 18/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7605 - val_loss: 0.7566 - learning_rate: 1.0000e-04
# Epoch 19/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7589 - val_loss: 0.7550 - learning_rate: 1.0000e-04
# Epoch 20/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7573 - val_loss: 0.7534 - learning_rate: 1.0000e-04
# Epoch 21/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7557 - val_loss: 0.7518 - learning_rate: 1.0000e-04
# Epoch 22/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7540 - val_loss: 0.7502 - learning_rate: 1.0000e-04
# Epoch 23/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7524 - val_loss: 0.7486 - learning_rate: 1.0000e-04
# Epoch 24/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7508 - val_loss: 0.7470 - learning_rate: 1.0000e-04
# Epoch 25/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7493 - val_loss: 0.7454 - learning_rate: 1.0000e-04
# Epoch 26/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7477 - val_loss: 0.7439 - learning_rate: 1.0000e-04
# Epoch 27/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7461 - val_loss: 0.7423 - learning_rate: 1.0000e-04
# Epoch 28/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7446 - val_loss: 0.7408 - learning_rate: 1.0000e-04
# Epoch 29/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7430 - val_loss: 0.7393 - learning_rate: 1.0000e-04
# Epoch 30/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7415 - val_loss: 0.7378 - learning_rate: 1.0000e-04
# Epoch 31/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7399 - val_loss: 0.7362 - learning_rate: 1.0000e-04
# Epoch 32/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7384 - val_loss: 0.7347 - learning_rate: 1.0000e-04
# Epoch 33/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7369 - val_loss: 0.7332 - learning_rate: 1.0000e-04
# Epoch 34/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7354 - val_loss: 0.7318 - learning_rate: 1.0000e-04
# Epoch 35/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7339 - val_loss: 0.7303 - learning_rate: 1.0000e-04
# Epoch 36/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7324 - val_loss: 0.7288 - learning_rate: 1.0000e-04
# Epoch 37/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7309 - val_loss: 0.7274 - learning_rate: 1.0000e-04
# Epoch 38/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7295 - val_loss: 0.7259 - learning_rate: 1.0000e-04
# Epoch 39/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7280 - val_loss: 0.7245 - learning_rate: 1.0000e-04
# Epoch 40/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7265 - val_loss: 0.7230 - learning_rate: 1.0000e-04
# Epoch 41/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7251 - val_loss: 0.7216 - learning_rate: 1.0000e-04
# Epoch 42/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7237 - val_loss: 0.7202 - learning_rate: 1.0000e-04
# Epoch 43/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7222 - val_loss: 0.7187 - learning_rate: 1.0000e-04
# Epoch 44/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7208 - val_loss: 0.7173 - learning_rate: 1.0000e-04
# Epoch 45/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7194 - val_loss: 0.7159 - learning_rate: 1.0000e-04
# Epoch 46/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7180 - val_loss: 0.7145 - learning_rate: 1.0000e-04
# Epoch 47/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7166 - val_loss: 0.7132 - learning_rate: 1.0000e-04
# Epoch 48/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7152 - val_loss: 0.7118 - learning_rate: 1.0000e-04
# Epoch 49/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.7138 - val_loss: 0.7104 - learning_rate: 1.0000e-04
# Epoch 50/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7124 - val_loss: 0.7091 - learning_rate: 1.0000e-04
# Epoch 51/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7110 - val_loss: 0.7077 - learning_rate: 1.0000e-04
# Epoch 52/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7097 - val_loss: 0.7064 - learning_rate: 1.0000e-04
# Epoch 53/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7083 - val_loss: 0.7050 - learning_rate: 1.0000e-04
# Epoch 54/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7070 - val_loss: 0.7037 - learning_rate: 1.0000e-04
# Epoch 55/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7056 - val_loss: 0.7024 - learning_rate: 1.0000e-04
# Epoch 56/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7043 - val_loss: 0.7010 - learning_rate: 1.0000e-04
# Epoch 57/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7029 - val_loss: 0.6997 - learning_rate: 1.0000e-04
# Epoch 58/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7016 - val_loss: 0.6984 - learning_rate: 1.0000e-04
# Epoch 59/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7003 - val_loss: 0.6971 - learning_rate: 1.0000e-04
# Epoch 60/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6990 - val_loss: 0.6958 - learning_rate: 1.0000e-04
# Epoch 61/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6977 - val_loss: 0.6945 - learning_rate: 1.0000e-04
# Epoch 62/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6964 - val_loss: 0.6933 - learning_rate: 1.0000e-04
# Epoch 63/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6951 - val_loss: 0.6920 - learning_rate: 1.0000e-04
# Epoch 64/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6938 - val_loss: 0.6907 - learning_rate: 1.0000e-04
# Epoch 65/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6925 - val_loss: 0.6895 - learning_rate: 1.0000e-04
# Epoch 66/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6913 - val_loss: 0.6882 - learning_rate: 1.0000e-04
# Epoch 67/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6900 - val_loss: 0.6869 - learning_rate: 1.0000e-04
# Epoch 68/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6888 - val_loss: 0.6857 - learning_rate: 1.0000e-04
# Epoch 69/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6875 - val_loss: 0.6845 - learning_rate: 1.0000e-04
# Epoch 70/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6863 - val_loss: 0.6832 - learning_rate: 1.0000e-04
# Epoch 71/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6850 - val_loss: 0.6820 - learning_rate: 1.0000e-04
# Epoch 72/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6838 - val_loss: 0.6808 - learning_rate: 1.0000e-04
# Epoch 73/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6826 - val_loss: 0.6796 - learning_rate: 1.0000e-04
# Epoch 74/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6813 - val_loss: 0.6784 - learning_rate: 1.0000e-04
# Epoch 75/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6801 - val_loss: 0.6772 - learning_rate: 1.0000e-04
# Epoch 76/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6789 - val_loss: 0.6760 - learning_rate: 1.0000e-04
# Epoch 77/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6777 - val_loss: 0.6748 - learning_rate: 1.0000e-04
# Epoch 78/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6765 - val_loss: 0.6736 - learning_rate: 1.0000e-04
# Epoch 79/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6753 - val_loss: 0.6725 - learning_rate: 1.0000e-04
# Epoch 80/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6741 - val_loss: 0.6713 - learning_rate: 1.0000e-04
# Epoch 81/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6730 - val_loss: 0.6701 - learning_rate: 1.0000e-04
# Epoch 82/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6718 - val_loss: 0.6690 - learning_rate: 1.0000e-04
# Epoch 83/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6706 - val_loss: 0.6678 - learning_rate: 1.0000e-04
# Epoch 84/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6695 - val_loss: 0.6667 - learning_rate: 1.0000e-04
# Epoch 85/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6683 - val_loss: 0.6655 - learning_rate: 1.0000e-04
# Epoch 86/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6672 - val_loss: 0.6644 - learning_rate: 1.0000e-04
# Epoch 87/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6660 - val_loss: 0.6632 - learning_rate: 1.0000e-04
# Epoch 88/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6649 - val_loss: 0.6621 - learning_rate: 1.0000e-04
# Epoch 89/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6637 - val_loss: 0.6610 - learning_rate: 1.0000e-04
# Epoch 90/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6626 - val_loss: 0.6599 - learning_rate: 1.0000e-04
# Epoch 91/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6615 - val_loss: 0.6588 - learning_rate: 1.0000e-04
# Epoch 92/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6604 - val_loss: 0.6577 - learning_rate: 1.0000e-04
# Epoch 93/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6592 - val_loss: 0.6566 - learning_rate: 1.0000e-04
# Epoch 94/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6581 - val_loss: 0.6555 - learning_rate: 1.0000e-04
# Epoch 95/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6570 - val_loss: 0.6544 - learning_rate: 1.0000e-04
# Epoch 96/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6559 - val_loss: 0.6533 - learning_rate: 1.0000e-04
# Epoch 97/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6548 - val_loss: 0.6522 - learning_rate: 1.0000e-04
# Epoch 98/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6537 - val_loss: 0.6511 - learning_rate: 1.0000e-04
# Epoch 99/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6527 - val_loss: 0.6501 - learning_rate: 1.0000e-04
# Epoch 100/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6516 - val_loss: 0.6490 - learning_rate: 1.0000e-04
# Epoch 101/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6505 - val_loss: 0.6480 - learning_rate: 1.0000e-04
# Epoch 102/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6494 - val_loss: 0.6469 - learning_rate: 1.0000e-04
# Epoch 103/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6484 - val_loss: 0.6458 - learning_rate: 1.0000e-04
# Epoch 104/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6473 - val_loss: 0.6448 - learning_rate: 1.0000e-04
# Epoch 105/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6463 - val_loss: 0.6438 - learning_rate: 1.0000e-04
# Epoch 106/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6452 - val_loss: 0.6427 - learning_rate: 1.0000e-04
# Epoch 107/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6442 - val_loss: 0.6417 - learning_rate: 1.0000e-04
# Epoch 108/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6431 - val_loss: 0.6407 - learning_rate: 1.0000e-04
# Epoch 109/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6421 - val_loss: 0.6396 - learning_rate: 1.0000e-04
# Epoch 110/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6411 - val_loss: 0.6386 - learning_rate: 1.0000e-04
# Epoch 111/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6400 - val_loss: 0.6376 - learning_rate: 1.0000e-04
# Epoch 112/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6390 - val_loss: 0.6366 - learning_rate: 1.0000e-04
# Epoch 113/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6380 - val_loss: 0.6356 - learning_rate: 1.0000e-04
# Epoch 114/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6370 - val_loss: 0.6346 - learning_rate: 1.0000e-04
# Epoch 115/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6360 - val_loss: 0.6336 - learning_rate: 1.0000e-04
# Epoch 116/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6350 - val_loss: 0.6326 - learning_rate: 1.0000e-04
# Epoch 117/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6340 - val_loss: 0.6316 - learning_rate: 1.0000e-04
# Epoch 118/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6330 - val_loss: 0.6307 - learning_rate: 1.0000e-04
# Epoch 119/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6320 - val_loss: 0.6297 - learning_rate: 1.0000e-04
# Epoch 120/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6310 - val_loss: 0.6287 - learning_rate: 1.0000e-04
# Epoch 121/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6300 - val_loss: 0.6277 - learning_rate: 1.0000e-04
# Epoch 122/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6290 - val_loss: 0.6268 - learning_rate: 1.0000e-04
# Epoch 123/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6281 - val_loss: 0.6258 - learning_rate: 1.0000e-04
# Epoch 124/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6271 - val_loss: 0.6248 - learning_rate: 1.0000e-04
# Epoch 125/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6261 - val_loss: 0.6239 - learning_rate: 1.0000e-04
# Epoch 126/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6252 - val_loss: 0.6229 - learning_rate: 1.0000e-04
# Epoch 127/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6242 - val_loss: 0.6220 - learning_rate: 1.0000e-04
# Epoch 128/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6233 - val_loss: 0.6211 - learning_rate: 1.0000e-04
# Epoch 129/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6223 - val_loss: 0.6201 - learning_rate: 1.0000e-04
# Epoch 130/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6214 - val_loss: 0.6192 - learning_rate: 1.0000e-04
# Epoch 131/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6204 - val_loss: 0.6183 - learning_rate: 1.0000e-04
# Epoch 132/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6195 - val_loss: 0.6173 - learning_rate: 1.0000e-04
# Epoch 133/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6186 - val_loss: 0.6164 - learning_rate: 1.0000e-04
# Epoch 134/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6176 - val_loss: 0.6155 - learning_rate: 1.0000e-04
# Epoch 135/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6167 - val_loss: 0.6146 - learning_rate: 1.0000e-04
# Epoch 136/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6158 - val_loss: 0.6137 - learning_rate: 1.0000e-04
# Epoch 137/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6149 - val_loss: 0.6128 - learning_rate: 1.0000e-04
# Epoch 138/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6140 - val_loss: 0.6119 - learning_rate: 1.0000e-04
# Epoch 139/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6130 - val_loss: 0.6110 - learning_rate: 1.0000e-04
# Epoch 140/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6121 - val_loss: 0.6101 - learning_rate: 1.0000e-04
# Epoch 141/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6112 - val_loss: 0.6092 - learning_rate: 1.0000e-04
# Epoch 142/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6103 - val_loss: 0.6083 - learning_rate: 1.0000e-04
# Epoch 143/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6094 - val_loss: 0.6074 - learning_rate: 1.0000e-04
# Epoch 144/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6085 - val_loss: 0.6065 - learning_rate: 1.0000e-04
# Epoch 145/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6077 - val_loss: 0.6057 - learning_rate: 1.0000e-04
# Epoch 146/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6068 - val_loss: 0.6048 - learning_rate: 1.0000e-04
# Epoch 147/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6059 - val_loss: 0.6039 - learning_rate: 1.0000e-04
# Epoch 148/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6050 - val_loss: 0.6031 - learning_rate: 1.0000e-04
# Epoch 149/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6041 - val_loss: 0.6022 - learning_rate: 1.0000e-04
# Epoch 150/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6033 - val_loss: 0.6013 - learning_rate: 1.0000e-04
# Epoch 151/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6024 - val_loss: 0.6005 - learning_rate: 1.0000e-04
# Epoch 152/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6015 - val_loss: 0.5996 - learning_rate: 1.0000e-04
# Epoch 153/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6007 - val_loss: 0.5988 - learning_rate: 1.0000e-04
# Epoch 154/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5998 - val_loss: 0.5979 - learning_rate: 1.0000e-04
# Epoch 155/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5990 - val_loss: 0.5971 - learning_rate: 1.0000e-04
# Epoch 156/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5981 - val_loss: 0.5962 - learning_rate: 1.0000e-04
# Epoch 157/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5973 - val_loss: 0.5954 - learning_rate: 1.0000e-04
# Epoch 158/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5964 - val_loss: 0.5946 - learning_rate: 1.0000e-04
# Epoch 159/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5956 - val_loss: 0.5938 - learning_rate: 1.0000e-04
# Epoch 160/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5948 - val_loss: 0.5929 - learning_rate: 1.0000e-04
# Epoch 161/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5939 - val_loss: 0.5921 - learning_rate: 1.0000e-04
# Epoch 162/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5931 - val_loss: 0.5913 - learning_rate: 1.0000e-04
# Epoch 163/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5923 - val_loss: 0.5905 - learning_rate: 1.0000e-04
# Epoch 164/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5914 - val_loss: 0.5897 - learning_rate: 1.0000e-04
# Epoch 165/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5906 - val_loss: 0.5888 - learning_rate: 1.0000e-04
# Epoch 166/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5898 - val_loss: 0.5880 - learning_rate: 1.0000e-04
# Epoch 167/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5890 - val_loss: 0.5872 - learning_rate: 1.0000e-04
# Epoch 168/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5882 - val_loss: 0.5864 - learning_rate: 1.0000e-04
# Epoch 169/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5874 - val_loss: 0.5856 - learning_rate: 1.0000e-04
# Epoch 170/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5866 - val_loss: 0.5848 - learning_rate: 1.0000e-04
# Epoch 171/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5858 - val_loss: 0.5841 - learning_rate: 1.0000e-04
# Epoch 172/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5850 - val_loss: 0.5833 - learning_rate: 1.0000e-04
# Epoch 173/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5842 - val_loss: 0.5825 - learning_rate: 1.0000e-04
# Epoch 174/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5834 - val_loss: 0.5817 - learning_rate: 1.0000e-04
# Epoch 175/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5826 - val_loss: 0.5809 - learning_rate: 1.0000e-04
# Epoch 176/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5818 - val_loss: 0.5801 - learning_rate: 1.0000e-04
# Epoch 177/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5810 - val_loss: 0.5794 - learning_rate: 1.0000e-04
# Epoch 178/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5802 - val_loss: 0.5786 - learning_rate: 1.0000e-04
# Epoch 179/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5794 - val_loss: 0.5778 - learning_rate: 1.0000e-04
# Epoch 180/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5787 - val_loss: 0.5771 - learning_rate: 1.0000e-04
# Epoch 181/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5779 - val_loss: 0.5763 - learning_rate: 1.0000e-04
# Epoch 182/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5771 - val_loss: 0.5755 - learning_rate: 1.0000e-04
# Epoch 183/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5764 - val_loss: 0.5748 - learning_rate: 1.0000e-04
# Epoch 184/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5756 - val_loss: 0.5740 - learning_rate: 1.0000e-04
# Epoch 185/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5748 - val_loss: 0.5733 - learning_rate: 1.0000e-04
# Epoch 186/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5741 - val_loss: 0.5725 - learning_rate: 1.0000e-04
# Epoch 187/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5733 - val_loss: 0.5718 - learning_rate: 1.0000e-04
# Epoch 188/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5726 - val_loss: 0.5711 - learning_rate: 1.0000e-04
# Epoch 189/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5718 - val_loss: 0.5703 - learning_rate: 1.0000e-04
# Epoch 190/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5711 - val_loss: 0.5696 - learning_rate: 1.0000e-04
# Epoch 191/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5703 - val_loss: 0.5688 - learning_rate: 1.0000e-04
# Epoch 192/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5696 - val_loss: 0.5681 - learning_rate: 1.0000e-04
# Epoch 193/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5688 - val_loss: 0.5674 - learning_rate: 1.0000e-04
# Epoch 194/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5681 - val_loss: 0.5667 - learning_rate: 1.0000e-04
# Epoch 195/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5674 - val_loss: 0.5659 - learning_rate: 1.0000e-04
# Epoch 196/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5666 - val_loss: 0.5652 - learning_rate: 1.0000e-04
# Epoch 197/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5659 - val_loss: 0.5645 - learning_rate: 1.0000e-04
# Epoch 198/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5652 - val_loss: 0.5638 - learning_rate: 1.0000e-04
# Epoch 199/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5645 - val_loss: 0.5631 - learning_rate: 1.0000e-04
# Epoch 200/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5637 - val_loss: 0.5624 - learning_rate: 1.0000e-04

# %%
# prompt: Could you show a heatmap of the values of the neuron's weights in the above model, named nn_model?

import seaborn as sns
import matplotlib.pyplot as plt

# Here, nn_model_shallow is the Keras (NNet) model
weights = nn_model_shallow.layers[1].get_weights()[0]  # Get weights from this layer (omitting the intercepts, which are in [1])
weights = np.transpose(weights)

# Create a heatmap of the weights
plt.figure(figsize=(10, 8))
sns.heatmap(weights, annot=False, cmap='viridis')
plt.title("Neuron Weights Heatmap of the Input Layer")
plt.xlabel("Input Features (6)")
plt.ylabel("Neurons from Inputs to Output")
plt.show()

# %% [markdown]
# And, let's see how the model does... using `shap`

# %%
def nn_predict_shallow(X):
    """Prediction function of the neural network (log scale)."""
    df = pd.DataFrame(X, columns=x)
    df_scaled = nn_preprocessor.transform(df)
    pred = nn_model_shallow.predict(df_scaled, verbose=0, batch_size=10_000).flatten()
    return np.log(pred)


nn_explainer = shap.KernelExplainer(nn_predict_shallow, data=X_bg)
shap_nn = nn_explainer.shap_values(X_explain, nsamples=30)

all_dep_plots(x, shap_nn, X_explain)
# Out:
# Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# #### Next, let's add a "hidden" layer to our network...
#
# Here, we add a middle, "hidden," layer to our network in line 14, below. Notice that
# + the value 7 is the number of neurons
# + the inputs from the initial layer are, in fact, the inputs to this middle layer
# + the variable z holds the outputs of this layer.
# + the output layer uses z as its input (and then estimates the goal, the number of claims from there)
#
# Additional layers are able to continue this pattern (one example is commented out on line 17):

# %%
#
# Let's add a second layer to our network:

import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
cb = [EarlyStopping(patience=20), ReduceLROnPlateau(patience=5)]  # "callbacks" for training (see below)

# Architecture: Adding Layers
inputs = keras.Input(shape=(len(x),))            # Here is the input layer

z = layers.Dense(7, activation="tanh")(inputs)   # Here is the new layer: 7 neurons, inputs are the input, and z is the output. Use "tanh"

# For more layers, you can continue using z.     # Here is a commented-out example:
# z = layers.Dense(3, activation="tanh"))(z)     # This is another layer: 3 neurons, z is the input, and z is the output

outputs = layers.Dense(1, activation="exponential")(z)   # Here, we convert the previous layer's results (z) into the overall output
nn_model_2layer = keras.Model(inputs=inputs, outputs=outputs)   # The final layer often uses a different activation function

nn_model_2layer.summary()

nn_model_2layer.compile(optimizer=Adam(learning_rate=1e-4), loss="Poisson")
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 7)              │            49 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             8 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 57 (228.00 B)
#  Trainable params: 57 (228.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.random.set_seed(4349)

history_2layer = nn_model_2layer.fit(
    x=X_train,
    y=train[y],
    epochs=200,
    batch_size=10_000,
    validation_split=0.1,
    callbacks=cb,
    verbose=1,         # consider running both values 0 (no printing) and 1 (printing)
)
# Out:
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8972 - val_loss: 0.8890 - learning_rate: 1.0000e-04
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8901 - val_loss: 0.8819 - learning_rate: 1.0000e-04
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8830 - val_loss: 0.8750 - learning_rate: 1.0000e-04
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8761 - val_loss: 0.8682 - learning_rate: 1.0000e-04
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8693 - val_loss: 0.8615 - learning_rate: 1.0000e-04
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8626 - val_loss: 0.8550 - learning_rate: 1.0000e-04
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8561 - val_loss: 0.8486 - learning_rate: 1.0000e-04
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8496 - val_loss: 0.8422 - learning_rate: 1.0000e-04
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8433 - val_loss: 0.8360 - learning_rate: 1.0000e-04
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8371 - val_loss: 0.8299 - learning_rate: 1.0000e-04
# Epoch 11/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8310 - val_loss: 0.8240 - learning_rate: 1.0000e-04
# Epoch 12/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8251 - val_loss: 0.8181 - learning_rate: 1.0000e-04
# Epoch 13/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8192 - val_loss: 0.8123 - learning_rate: 1.0000e-04
# Epoch 14/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8134 - val_loss: 0.8067 - learning_rate: 1.0000e-04
# Epoch 15/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8077 - val_loss: 0.8011 - learning_rate: 1.0000e-04
# Epoch 16/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8022 - val_loss: 0.7956 - learning_rate: 1.0000e-04
# Epoch 17/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7967 - val_loss: 0.7902 - learning_rate: 1.0000e-04
# Epoch 18/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7913 - val_loss: 0.7849 - learning_rate: 1.0000e-04
# Epoch 19/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7860 - val_loss: 0.7797 - learning_rate: 1.0000e-04
# Epoch 20/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7808 - val_loss: 0.7746 - learning_rate: 1.0000e-04
# Epoch 21/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7757 - val_loss: 0.7696 - learning_rate: 1.0000e-04
# Epoch 22/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7706 - val_loss: 0.7646 - learning_rate: 1.0000e-04
# Epoch 23/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7657 - val_loss: 0.7598 - learning_rate: 1.0000e-04
# Epoch 24/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7608 - val_loss: 0.7550 - learning_rate: 1.0000e-04
# Epoch 25/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7560 - val_loss: 0.7502 - learning_rate: 1.0000e-04
# Epoch 26/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7512 - val_loss: 0.7456 - learning_rate: 1.0000e-04
# Epoch 27/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7466 - val_loss: 0.7410 - learning_rate: 1.0000e-04
# Epoch 28/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7420 - val_loss: 0.7365 - learning_rate: 1.0000e-04
# Epoch 29/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7375 - val_loss: 0.7321 - learning_rate: 1.0000e-04
# Epoch 30/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7331 - val_loss: 0.7277 - learning_rate: 1.0000e-04
# Epoch 31/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7287 - val_loss: 0.7234 - learning_rate: 1.0000e-04
# Epoch 32/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.7244 - val_loss: 0.7192 - learning_rate: 1.0000e-04
# Epoch 33/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7201 - val_loss: 0.7150 - learning_rate: 1.0000e-04
# Epoch 34/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7159 - val_loss: 0.7109 - learning_rate: 1.0000e-04
# Epoch 35/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7118 - val_loss: 0.7069 - learning_rate: 1.0000e-04
# Epoch 36/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7078 - val_loss: 0.7029 - learning_rate: 1.0000e-04
# Epoch 37/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7037 - val_loss: 0.6990 - learning_rate: 1.0000e-04
# Epoch 38/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6998 - val_loss: 0.6951 - learning_rate: 1.0000e-04
# Epoch 39/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6959 - val_loss: 0.6913 - learning_rate: 1.0000e-04
# Epoch 40/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6921 - val_loss: 0.6875 - learning_rate: 1.0000e-04
# Epoch 41/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6883 - val_loss: 0.6838 - learning_rate: 1.0000e-04
# Epoch 42/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6846 - val_loss: 0.6801 - learning_rate: 1.0000e-04
# Epoch 43/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6809 - val_loss: 0.6765 - learning_rate: 1.0000e-04
# Epoch 44/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6772 - val_loss: 0.6729 - learning_rate: 1.0000e-04
# Epoch 45/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6737 - val_loss: 0.6694 - learning_rate: 1.0000e-04
# Epoch 46/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6701 - val_loss: 0.6659 - learning_rate: 1.0000e-04
# Epoch 47/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6666 - val_loss: 0.6625 - learning_rate: 1.0000e-04
# Epoch 48/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6632 - val_loss: 0.6591 - learning_rate: 1.0000e-04
# Epoch 49/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6598 - val_loss: 0.6558 - learning_rate: 1.0000e-04
# Epoch 50/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6564 - val_loss: 0.6525 - learning_rate: 1.0000e-04
# Epoch 51/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6531 - val_loss: 0.6492 - learning_rate: 1.0000e-04
# Epoch 52/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6498 - val_loss: 0.6460 - learning_rate: 1.0000e-04
# Epoch 53/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6466 - val_loss: 0.6429 - learning_rate: 1.0000e-04
# Epoch 54/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6434 - val_loss: 0.6397 - learning_rate: 1.0000e-04
# Epoch 55/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6403 - val_loss: 0.6366 - learning_rate: 1.0000e-04
# Epoch 56/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6372 - val_loss: 0.6336 - learning_rate: 1.0000e-04
# Epoch 57/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.6341 - val_loss: 0.6305 - learning_rate: 1.0000e-04
# Epoch 58/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6310 - val_loss: 0.6276 - learning_rate: 1.0000e-04
# Epoch 59/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6280 - val_loss: 0.6246 - learning_rate: 1.0000e-04
# Epoch 60/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6251 - val_loss: 0.6217 - learning_rate: 1.0000e-04
# Epoch 61/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6221 - val_loss: 0.6188 - learning_rate: 1.0000e-04
# Epoch 62/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6192 - val_loss: 0.6160 - learning_rate: 1.0000e-04
# Epoch 63/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6164 - val_loss: 0.6132 - learning_rate: 1.0000e-04
# Epoch 64/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6135 - val_loss: 0.6104 - learning_rate: 1.0000e-04
# Epoch 65/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6107 - val_loss: 0.6076 - learning_rate: 1.0000e-04
# Epoch 66/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6080 - val_loss: 0.6049 - learning_rate: 1.0000e-04
# Epoch 67/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6052 - val_loss: 0.6022 - learning_rate: 1.0000e-04
# Epoch 68/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6025 - val_loss: 0.5995 - learning_rate: 1.0000e-04
# Epoch 69/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5998 - val_loss: 0.5969 - learning_rate: 1.0000e-04
# Epoch 70/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5972 - val_loss: 0.5943 - learning_rate: 1.0000e-04
# Epoch 71/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5946 - val_loss: 0.5917 - learning_rate: 1.0000e-04
# Epoch 72/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5920 - val_loss: 0.5892 - learning_rate: 1.0000e-04
# Epoch 73/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5894 - val_loss: 0.5867 - learning_rate: 1.0000e-04
# Epoch 74/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5868 - val_loss: 0.5842 - learning_rate: 1.0000e-04
# Epoch 75/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5843 - val_loss: 0.5817 - learning_rate: 1.0000e-04
# Epoch 76/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5818 - val_loss: 0.5793 - learning_rate: 1.0000e-04
# Epoch 77/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5794 - val_loss: 0.5768 - learning_rate: 1.0000e-04
# Epoch 78/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5769 - val_loss: 0.5744 - learning_rate: 1.0000e-04
# Epoch 79/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5745 - val_loss: 0.5721 - learning_rate: 1.0000e-04
# Epoch 80/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5721 - val_loss: 0.5697 - learning_rate: 1.0000e-04
# Epoch 81/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5698 - val_loss: 0.5674 - learning_rate: 1.0000e-04
# Epoch 82/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5674 - val_loss: 0.5651 - learning_rate: 1.0000e-04
# Epoch 83/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5651 - val_loss: 0.5628 - learning_rate: 1.0000e-04
# Epoch 84/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5628 - val_loss: 0.5606 - learning_rate: 1.0000e-04
# Epoch 85/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5605 - val_loss: 0.5583 - learning_rate: 1.0000e-04
# Epoch 86/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5583 - val_loss: 0.5561 - learning_rate: 1.0000e-04
# Epoch 87/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5560 - val_loss: 0.5539 - learning_rate: 1.0000e-04
# Epoch 88/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5538 - val_loss: 0.5517 - learning_rate: 1.0000e-04
# Epoch 89/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5516 - val_loss: 0.5496 - learning_rate: 1.0000e-04
# Epoch 90/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5494 - val_loss: 0.5475 - learning_rate: 1.0000e-04
# Epoch 91/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5473 - val_loss: 0.5454 - learning_rate: 1.0000e-04
# Epoch 92/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5452 - val_loss: 0.5433 - learning_rate: 1.0000e-04
# Epoch 93/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5430 - val_loss: 0.5412 - learning_rate: 1.0000e-04
# Epoch 94/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5410 - val_loss: 0.5391 - learning_rate: 1.0000e-04
# Epoch 95/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5389 - val_loss: 0.5371 - learning_rate: 1.0000e-04
# Epoch 96/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5368 - val_loss: 0.5351 - learning_rate: 1.0000e-04
# Epoch 97/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5348 - val_loss: 0.5331 - learning_rate: 1.0000e-04
# Epoch 98/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5328 - val_loss: 0.5311 - learning_rate: 1.0000e-04
# Epoch 99/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5308 - val_loss: 0.5291 - learning_rate: 1.0000e-04
# Epoch 100/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5288 - val_loss: 0.5272 - learning_rate: 1.0000e-04
# Epoch 101/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5268 - val_loss: 0.5252 - learning_rate: 1.0000e-04
# Epoch 102/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5248 - val_loss: 0.5233 - learning_rate: 1.0000e-04
# Epoch 103/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5229 - val_loss: 0.5214 - learning_rate: 1.0000e-04
# Epoch 104/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5210 - val_loss: 0.5196 - learning_rate: 1.0000e-04
# Epoch 105/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5191 - val_loss: 0.5177 - learning_rate: 1.0000e-04
# Epoch 106/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5172 - val_loss: 0.5158 - learning_rate: 1.0000e-04
# Epoch 107/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5153 - val_loss: 0.5140 - learning_rate: 1.0000e-04
# Epoch 108/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5135 - val_loss: 0.5122 - learning_rate: 1.0000e-04
# Epoch 109/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5116 - val_loss: 0.5104 - learning_rate: 1.0000e-04
# Epoch 110/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5098 - val_loss: 0.5086 - learning_rate: 1.0000e-04
# Epoch 111/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5080 - val_loss: 0.5068 - learning_rate: 1.0000e-04
# Epoch 112/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5062 - val_loss: 0.5051 - learning_rate: 1.0000e-04
# Epoch 113/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5044 - val_loss: 0.5033 - learning_rate: 1.0000e-04
# Epoch 114/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5027 - val_loss: 0.5016 - learning_rate: 1.0000e-04
# Epoch 115/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5009 - val_loss: 0.4999 - learning_rate: 1.0000e-04
# Epoch 116/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4992 - val_loss: 0.4982 - learning_rate: 1.0000e-04
# Epoch 117/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4975 - val_loss: 0.4965 - learning_rate: 1.0000e-04
# Epoch 118/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4958 - val_loss: 0.4948 - learning_rate: 1.0000e-04
# Epoch 119/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4941 - val_loss: 0.4932 - learning_rate: 1.0000e-04
# Epoch 120/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4924 - val_loss: 0.4915 - learning_rate: 1.0000e-04
# Epoch 121/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4907 - val_loss: 0.4899 - learning_rate: 1.0000e-04
# Epoch 122/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4891 - val_loss: 0.4883 - learning_rate: 1.0000e-04
# Epoch 123/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4874 - val_loss: 0.4867 - learning_rate: 1.0000e-04
# Epoch 124/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4858 - val_loss: 0.4851 - learning_rate: 1.0000e-04
# Epoch 125/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4842 - val_loss: 0.4835 - learning_rate: 1.0000e-04
# Epoch 126/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4826 - val_loss: 0.4819 - learning_rate: 1.0000e-04
# Epoch 127/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4810 - val_loss: 0.4804 - learning_rate: 1.0000e-04
# Epoch 128/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4794 - val_loss: 0.4788 - learning_rate: 1.0000e-04
# Epoch 129/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4779 - val_loss: 0.4773 - learning_rate: 1.0000e-04
# Epoch 130/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4763 - val_loss: 0.4758 - learning_rate: 1.0000e-04
# Epoch 131/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4748 - val_loss: 0.4743 - learning_rate: 1.0000e-04
# Epoch 132/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4732 - val_loss: 0.4728 - learning_rate: 1.0000e-04
# Epoch 133/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4717 - val_loss: 0.4713 - learning_rate: 1.0000e-04
# Epoch 134/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4702 - val_loss: 0.4699 - learning_rate: 1.0000e-04
# Epoch 135/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4687 - val_loss: 0.4684 - learning_rate: 1.0000e-04
# Epoch 136/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4673 - val_loss: 0.4669 - learning_rate: 1.0000e-04
# Epoch 137/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4658 - val_loss: 0.4655 - learning_rate: 1.0000e-04
# Epoch 138/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4643 - val_loss: 0.4641 - learning_rate: 1.0000e-04
# Epoch 139/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4629 - val_loss: 0.4627 - learning_rate: 1.0000e-04
# Epoch 140/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4615 - val_loss: 0.4613 - learning_rate: 1.0000e-04
# Epoch 141/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4600 - val_loss: 0.4599 - learning_rate: 1.0000e-04
# Epoch 142/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4586 - val_loss: 0.4585 - learning_rate: 1.0000e-04
# Epoch 143/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4572 - val_loss: 0.4572 - learning_rate: 1.0000e-04
# Epoch 144/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4559 - val_loss: 0.4558 - learning_rate: 1.0000e-04
# Epoch 145/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4545 - val_loss: 0.4545 - learning_rate: 1.0000e-04
# Epoch 146/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4531 - val_loss: 0.4531 - learning_rate: 1.0000e-04
# Epoch 147/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4518 - val_loss: 0.4518 - learning_rate: 1.0000e-04
# Epoch 148/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4504 - val_loss: 0.4505 - learning_rate: 1.0000e-04
# Epoch 149/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4491 - val_loss: 0.4492 - learning_rate: 1.0000e-04
# Epoch 150/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4478 - val_loss: 0.4479 - learning_rate: 1.0000e-04
# Epoch 151/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4464 - val_loss: 0.4466 - learning_rate: 1.0000e-04
# Epoch 152/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4451 - val_loss: 0.4454 - learning_rate: 1.0000e-04
# Epoch 153/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4439 - val_loss: 0.4441 - learning_rate: 1.0000e-04
# Epoch 154/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4426 - val_loss: 0.4429 - learning_rate: 1.0000e-04
# Epoch 155/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4413 - val_loss: 0.4416 - learning_rate: 1.0000e-04
# Epoch 156/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4400 - val_loss: 0.4404 - learning_rate: 1.0000e-04
# Epoch 157/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4388 - val_loss: 0.4392 - learning_rate: 1.0000e-04
# Epoch 158/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4375 - val_loss: 0.4380 - learning_rate: 1.0000e-04
# Epoch 159/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4363 - val_loss: 0.4368 - learning_rate: 1.0000e-04
# Epoch 160/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4351 - val_loss: 0.4356 - learning_rate: 1.0000e-04
# Epoch 161/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4339 - val_loss: 0.4344 - learning_rate: 1.0000e-04
# Epoch 162/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4327 - val_loss: 0.4332 - learning_rate: 1.0000e-04
# Epoch 163/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4315 - val_loss: 0.4321 - learning_rate: 1.0000e-04
# Epoch 164/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4303 - val_loss: 0.4309 - learning_rate: 1.0000e-04
# Epoch 165/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4291 - val_loss: 0.4298 - learning_rate: 1.0000e-04
# Epoch 166/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4280 - val_loss: 0.4286 - learning_rate: 1.0000e-04
# Epoch 167/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4268 - val_loss: 0.4275 - learning_rate: 1.0000e-04
# Epoch 168/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4257 - val_loss: 0.4264 - learning_rate: 1.0000e-04
# Epoch 169/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4245 - val_loss: 0.4253 - learning_rate: 1.0000e-04
# Epoch 170/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4234 - val_loss: 0.4242 - learning_rate: 1.0000e-04
# Epoch 171/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4223 - val_loss: 0.4231 - learning_rate: 1.0000e-04
# Epoch 172/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4212 - val_loss: 0.4220 - learning_rate: 1.0000e-04
# Epoch 173/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4201 - val_loss: 0.4210 - learning_rate: 1.0000e-04
# Epoch 174/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4190 - val_loss: 0.4199 - learning_rate: 1.0000e-04
# Epoch 175/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4179 - val_loss: 0.4189 - learning_rate: 1.0000e-04
# Epoch 176/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4168 - val_loss: 0.4178 - learning_rate: 1.0000e-04
# Epoch 177/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4158 - val_loss: 0.4168 - learning_rate: 1.0000e-04
# Epoch 178/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4147 - val_loss: 0.4158 - learning_rate: 1.0000e-04
# Epoch 179/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4137 - val_loss: 0.4148 - learning_rate: 1.0000e-04
# Epoch 180/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4126 - val_loss: 0.4138 - learning_rate: 1.0000e-04
# Epoch 181/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4116 - val_loss: 0.4128 - learning_rate: 1.0000e-04
# Epoch 182/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4106 - val_loss: 0.4118 - learning_rate: 1.0000e-04
# Epoch 183/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4096 - val_loss: 0.4108 - learning_rate: 1.0000e-04
# Epoch 184/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4086 - val_loss: 0.4098 - learning_rate: 1.0000e-04
# Epoch 185/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4076 - val_loss: 0.4089 - learning_rate: 1.0000e-04
# Epoch 186/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.4066 - val_loss: 0.4079 - learning_rate: 1.0000e-04
# Epoch 187/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4056 - val_loss: 0.4070 - learning_rate: 1.0000e-04
# Epoch 188/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4046 - val_loss: 0.4060 - learning_rate: 1.0000e-04
# Epoch 189/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4037 - val_loss: 0.4051 - learning_rate: 1.0000e-04
# Epoch 190/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4027 - val_loss: 0.4042 - learning_rate: 1.0000e-04
# Epoch 191/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4018 - val_loss: 0.4032 - learning_rate: 1.0000e-04
# Epoch 192/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4008 - val_loss: 0.4023 - learning_rate: 1.0000e-04
# Epoch 193/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3999 - val_loss: 0.4014 - learning_rate: 1.0000e-04
# Epoch 194/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3990 - val_loss: 0.4005 - learning_rate: 1.0000e-04
# Epoch 195/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3981 - val_loss: 0.3997 - learning_rate: 1.0000e-04
# Epoch 196/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3972 - val_loss: 0.3988 - learning_rate: 1.0000e-04
# Epoch 197/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3963 - val_loss: 0.3979 - learning_rate: 1.0000e-04
# Epoch 198/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3954 - val_loss: 0.3971 - learning_rate: 1.0000e-04
# Epoch 199/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3945 - val_loss: 0.3962 - learning_rate: 1.0000e-04
# Epoch 200/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3936 - val_loss: 0.3954 - learning_rate: 1.0000e-04

# %% [markdown]
# Let's see the neurons!
#
# At least as a heatmap of the weights:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

weights = nn_model_2layer.layers[1].get_weights()[0]  # Get weights from this layer (omit the intercept, which is [1])
weights = np.transpose(weights)

# Create a heatmap of the weights
plt.figure(figsize=(10, 8))
sns.heatmap(weights, annot=False, cmap='viridis')
plt.title("Neuron Weights Heatmap of the Input Layer")
plt.xlabel(f"Input Features (6)")
plt.ylabel("Neurons from Inputs to Layer1 (7)")
plt.show()

# %% [markdown]
# Next layer!

# %%
# Next layer
weights = nn_model_2layer.layers[2].get_weights()[0]  # Get weights from this layer (omit the intercept, which is [1])
weights = np.transpose(weights)

# Create a heatmap of the weights
plt.figure(figsize=(10, 8))
sns.heatmap(weights, annot=False, cmap='viridis')
plt.title("Neuron Weights Heatmap of Next Layer")
plt.xlabel("Neurons from Layer 1 (of 7)")
plt.ylabel("Neurons from Layer 1 to Layer 2 (of 1)")
plt.show()

# %% [markdown]
# Let's run `shap` to see if it does better...

# %%
def nn_predict_2layer(X):
    """Prediction function of the neural network (log scale)."""
    df = pd.DataFrame(X, columns=x)
    df_scaled = nn_preprocessor.transform(df)
    pred = nn_model_2layer.predict(df_scaled, verbose=0, batch_size=10_000).flatten()
    return np.log(pred)

nn_explainer = shap.KernelExplainer(nn_predict_2layer, data=X_bg)
shap_nn = nn_explainer.shap_values(X_explain, nsamples=30)

all_dep_plots(x, shap_nn, X_explain)   # create all feature-dependency plots
# Out:
# Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# Notice that these features do not _yet_ match the ones computed by the linear regression model we interpreted above.
#
# Thus far, the NNet is too primitive to be able to learn the real relationships among those dataset features.
#
# <font color="Coral">Your task</font> is to experiment below, in order to create a larger, more faithful NNet model.

# %% [markdown]
# ### The "Real" data model
#
# Usually datasets do not have a "real" model. At least not one that's known!
#
# This dataset, however, does have a _real_ underlying model! (It was inspired by the real data and then used to generate this dataset.)
#
# Here is the real model:

# %%
#
# The age is a much more complicated - non-linear - feature
def age_effect(age):
    x = (age - 66) / 60
    return 0.05 + x**8 + 0.4 * x**3 + 0.3 * x**2 + 0.06 * x

#
# here is the true model for this dataset:
def true_model(X):
    """Returns pd.Series of true expected frequencies."""
    df = pd.DataFrame(X, columns=x)  # Needed because SHAP turns df to np.array
    log_lambda = (
        0.15 * df.town
        + np.log(age_effect(df.driver_age))
        + (0.3 + 0.15 * df.town) * df.car_power / 100
        - 0.02 * df.car_age
    )
    return np.exp(log_lambda)

# %% [markdown]
# `shap` is not specific to NNets or linear regression models. It supports the interpretation of _any_ model, including the real one.
#
# Here is `shap`'s interpretation of this real model:

# %%
import shap

true_model_explainer = shap.KernelExplainer(lambda x: np.log(true_model(x)), data=X_bg)
shap_true = true_model_explainer.shap_values(X_explain, nsamples=30)

all_dep_plots(x, shap_true, X_explain)
# Out:
# Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# Things to notice:
# + the relationship between driver_age and the number of claims is "highly non-linear!"
# + there are also _two slopes_ for the linear car_power feature (so, officially, it's "not linear")
# + note, too, that car_weight has no impact on the output...
#   + Challenge question (not really a hw task): <br>  _**Why** do the modeling techniques above observe an impact of the car_weight feature?_

# %% [markdown]
# Challenge Answer:
#
# It might be due to multicollinearity! I had made the observation before that car power and car weight were highly correlated. The model split the effect between the two features.

# %% [markdown]
# ## Final challenge: <font color="DodgerBlue">_Improve the NNet_</font>
#
# #### <font color="Coral"><b>Task Finale</b></font>
#
# From here, your task is to
# + create a more-capable neural network... with the goal of representing the actual data interactions ***better*** than the linear-regression model
# + consider using more layers (but not too many)
# + consider the "step-down" architecture, where
#   + the first post-input layer has the most neurons ("feature building")
#   + then, subsequent layers have fewer...
#   + tapering into the output layer
#
# You'll find that the NNet won't represent the "real" model perfectly, but it will
# + find its own features
# + represent the non-linear relationship (for driver_age)
# + and, for me, it could _start_ to represent the dependence of car_power on town
#
# <br>

# %% [markdown]
# ### Use the cells below to experiment with NNet building...
#
# Use the above `2layer` example as a template, and then - below -
# + experiment and create a new model -- and
# + show its `shap` interpretation... -- and
# + be sure to include a <font color="DodgerBlue">3-5 sentence <b>reflection</b> on</font> your experimentation (how long it took!) and how well the resulting NNet does at capturing the feature relationships of the actual, underlying "reality" ...
#
# <br>
#
# Worth remembering:  _We're **all** neural nets!_
# + It would seem we're always "keeping this in mind" 😀

# %%
#

import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
cb = [EarlyStopping(patience=20), ReduceLROnPlateau(patience=5)]  # "callbacks" for training (see below)

inputs = keras.Input(shape=(len(x),))

#  more neurons! 
z = layers.Dense(24, activation="relu")(inputs) 

z = layers.Dense(12, activation="relu")(z)

z = layers.Dense(6, activation="relu")(z)  

# Output layer - keep exponential activation for Poisson distribution
outputs = layers.Dense(1, activation="exponential")(z)
nn_model_stepdown = keras.Model(inputs=inputs, outputs=outputs)

nn_model_stepdown.summary()

nn_model_stepdown.compile(optimizer=Adam(learning_rate=2e-4), loss="Poisson")
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 24)             │           168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 12)             │           300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 6)              │            78 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 1)              │             7 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 553 (2.16 KB)
#  Trainable params: 553 (2.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_stepdown = nn_model_stepdown.fit(
    x=X_train,
    y=train[y],
    epochs=200,
    batch_size=10_000,
    validation_split=0.1,
    callbacks=cb,
    verbose=1
)
# Out:
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.8364 - val_loss: 0.8217 - learning_rate: 2.0000e-04
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8184 - val_loss: 0.8046 - learning_rate: 2.0000e-04
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8015 - val_loss: 0.7884 - learning_rate: 2.0000e-04
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7854 - val_loss: 0.7726 - learning_rate: 2.0000e-04
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7697 - val_loss: 0.7569 - learning_rate: 2.0000e-04
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7540 - val_loss: 0.7412 - learning_rate: 2.0000e-04
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7382 - val_loss: 0.7252 - learning_rate: 2.0000e-04
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.7222 - val_loss: 0.7089 - learning_rate: 2.0000e-04
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.7058 - val_loss: 0.6921 - learning_rate: 2.0000e-04
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6889 - val_loss: 0.6752 - learning_rate: 2.0000e-04
# Epoch 11/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.6720 - val_loss: 0.6585 - learning_rate: 2.0000e-04
# Epoch 12/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6553 - val_loss: 0.6421 - learning_rate: 2.0000e-04
# Epoch 13/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6390 - val_loss: 0.6260 - learning_rate: 2.0000e-04
# Epoch 14/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6229 - val_loss: 0.6100 - learning_rate: 2.0000e-04
# Epoch 15/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6069 - val_loss: 0.5943 - learning_rate: 2.0000e-04
# Epoch 16/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5913 - val_loss: 0.5791 - learning_rate: 2.0000e-04
# Epoch 17/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5761 - val_loss: 0.5644 - learning_rate: 2.0000e-04
# Epoch 18/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5615 - val_loss: 0.5501 - learning_rate: 2.0000e-04
# Epoch 19/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5473 - val_loss: 0.5363 - learning_rate: 2.0000e-04
# Epoch 20/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.5335 - val_loss: 0.5228 - learning_rate: 2.0000e-04
# Epoch 21/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5201 - val_loss: 0.5097 - learning_rate: 2.0000e-04
# Epoch 22/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5070 - val_loss: 0.4968 - learning_rate: 2.0000e-04
# Epoch 23/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4941 - val_loss: 0.4842 - learning_rate: 2.0000e-04
# Epoch 24/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.4814 - val_loss: 0.4716 - learning_rate: 2.0000e-04
# Epoch 25/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4688 - val_loss: 0.4594 - learning_rate: 2.0000e-04
# Epoch 26/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4567 - val_loss: 0.4478 - learning_rate: 2.0000e-04
# Epoch 27/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4451 - val_loss: 0.4369 - learning_rate: 2.0000e-04
# Epoch 28/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4342 - val_loss: 0.4265 - learning_rate: 2.0000e-04
# Epoch 29/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4239 - val_loss: 0.4167 - learning_rate: 2.0000e-04
# Epoch 30/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4141 - val_loss: 0.4075 - learning_rate: 2.0000e-04
# Epoch 31/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4049 - val_loss: 0.3989 - learning_rate: 2.0000e-04
# Epoch 32/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3963 - val_loss: 0.3909 - learning_rate: 2.0000e-04
# Epoch 33/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3883 - val_loss: 0.3835 - learning_rate: 2.0000e-04
# Epoch 34/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3808 - val_loss: 0.3768 - learning_rate: 2.0000e-04
# Epoch 35/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3740 - val_loss: 0.3706 - learning_rate: 2.0000e-04
# Epoch 36/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3678 - val_loss: 0.3649 - learning_rate: 2.0000e-04
# Epoch 37/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3621 - val_loss: 0.3598 - learning_rate: 2.0000e-04
# Epoch 38/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3569 - val_loss: 0.3552 - learning_rate: 2.0000e-04
# Epoch 39/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3523 - val_loss: 0.3510 - learning_rate: 2.0000e-04
# Epoch 40/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3480 - val_loss: 0.3473 - learning_rate: 2.0000e-04
# Epoch 41/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3442 - val_loss: 0.3440 - learning_rate: 2.0000e-04
# Epoch 42/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3408 - val_loss: 0.3410 - learning_rate: 2.0000e-04
# Epoch 43/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3377 - val_loss: 0.3383 - learning_rate: 2.0000e-04
# Epoch 44/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3349 - val_loss: 0.3359 - learning_rate: 2.0000e-04
# Epoch 45/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3324 - val_loss: 0.3337 - learning_rate: 2.0000e-04
# Epoch 46/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3301 - val_loss: 0.3318 - learning_rate: 2.0000e-04
# Epoch 47/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3281 - val_loss: 0.3300 - learning_rate: 2.0000e-04
# Epoch 48/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3262 - val_loss: 0.3285 - learning_rate: 2.0000e-04
# Epoch 49/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3246 - val_loss: 0.3271 - learning_rate: 2.0000e-04
# Epoch 50/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3230 - val_loss: 0.3259 - learning_rate: 2.0000e-04
# Epoch 51/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3217 - val_loss: 0.3247 - learning_rate: 2.0000e-04
# Epoch 52/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3204 - val_loss: 0.3237 - learning_rate: 2.0000e-04
# Epoch 53/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3193 - val_loss: 0.3228 - learning_rate: 2.0000e-04
# Epoch 54/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3182 - val_loss: 0.3220 - learning_rate: 2.0000e-04
# Epoch 55/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3173 - val_loss: 0.3213 - learning_rate: 2.0000e-04
# Epoch 56/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3164 - val_loss: 0.3206 - learning_rate: 2.0000e-04
# Epoch 57/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3156 - val_loss: 0.3200 - learning_rate: 2.0000e-04
# Epoch 58/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3149 - val_loss: 0.3195 - learning_rate: 2.0000e-04
# Epoch 59/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3142 - val_loss: 0.3190 - learning_rate: 2.0000e-04
# Epoch 60/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3136 - val_loss: 0.3185 - learning_rate: 2.0000e-04
# Epoch 61/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3130 - val_loss: 0.3181 - learning_rate: 2.0000e-04
# Epoch 62/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3125 - val_loss: 0.3178 - learning_rate: 2.0000e-04
# Epoch 63/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3120 - val_loss: 0.3174 - learning_rate: 2.0000e-04
# Epoch 64/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3115 - val_loss: 0.3171 - learning_rate: 2.0000e-04
# Epoch 65/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3111 - val_loss: 0.3168 - learning_rate: 2.0000e-04
# Epoch 66/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3107 - val_loss: 0.3166 - learning_rate: 2.0000e-04
# Epoch 67/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3103 - val_loss: 0.3163 - learning_rate: 2.0000e-04
# Epoch 68/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3100 - val_loss: 0.3161 - learning_rate: 2.0000e-04
# Epoch 69/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3096 - val_loss: 0.3159 - learning_rate: 2.0000e-04
# Epoch 70/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3093 - val_loss: 0.3157 - learning_rate: 2.0000e-04
# Epoch 71/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3090 - val_loss: 0.3155 - learning_rate: 2.0000e-04
# Epoch 72/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3087 - val_loss: 0.3154 - learning_rate: 2.0000e-04
# Epoch 73/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3085 - val_loss: 0.3152 - learning_rate: 2.0000e-04
# Epoch 74/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3082 - val_loss: 0.3151 - learning_rate: 2.0000e-04
# Epoch 75/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3080 - val_loss: 0.3150 - learning_rate: 2.0000e-04
# Epoch 76/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3078 - val_loss: 0.3148 - learning_rate: 2.0000e-04
# Epoch 77/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3076 - val_loss: 0.3147 - learning_rate: 2.0000e-04
# Epoch 78/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3074 - val_loss: 0.3146 - learning_rate: 2.0000e-04
# Epoch 79/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3072 - val_loss: 0.3145 - learning_rate: 2.0000e-04
# Epoch 80/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3070 - val_loss: 0.3144 - learning_rate: 2.0000e-04
# Epoch 81/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3068 - val_loss: 0.3143 - learning_rate: 2.0000e-04
# Epoch 82/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3067 - val_loss: 0.3143 - learning_rate: 2.0000e-04
# Epoch 83/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3065 - val_loss: 0.3142 - learning_rate: 2.0000e-04
# Epoch 84/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3064 - val_loss: 0.3141 - learning_rate: 2.0000e-04
# Epoch 85/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3062 - val_loss: 0.3141 - learning_rate: 2.0000e-04
# Epoch 86/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3061 - val_loss: 0.3140 - learning_rate: 2.0000e-04
# Epoch 87/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3060 - val_loss: 0.3139 - learning_rate: 2.0000e-04
# Epoch 88/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3059 - val_loss: 0.3139 - learning_rate: 2.0000e-04
# Epoch 89/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3058 - val_loss: 0.3138 - learning_rate: 2.0000e-04
# Epoch 90/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3056 - val_loss: 0.3138 - learning_rate: 2.0000e-04
# Epoch 91/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3055 - val_loss: 0.3138 - learning_rate: 2.0000e-04
# Epoch 92/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3054 - val_loss: 0.3137 - learning_rate: 2.0000e-04
# Epoch 93/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3053 - val_loss: 0.3137 - learning_rate: 2.0000e-04
# Epoch 94/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3052 - val_loss: 0.3136 - learning_rate: 2.0000e-04
# Epoch 95/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3052 - val_loss: 0.3136 - learning_rate: 2.0000e-04
# Epoch 96/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3051 - val_loss: 0.3136 - learning_rate: 2.0000e-04
# Epoch 97/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3050 - val_loss: 0.3136 - learning_rate: 2.0000e-04
# Epoch 98/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3049 - val_loss: 0.3135 - learning_rate: 2.0000e-04
# Epoch 99/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3048 - val_loss: 0.3135 - learning_rate: 2.0000e-04
# Epoch 100/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3048 - val_loss: 0.3135 - learning_rate: 2.0000e-04
# Epoch 101/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3047 - val_loss: 0.3135 - learning_rate: 2.0000e-04
# Epoch 102/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3046 - val_loss: 0.3134 - learning_rate: 2.0000e-04
# Epoch 103/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3046 - val_loss: 0.3134 - learning_rate: 2.0000e-04
# Epoch 104/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3045 - val_loss: 0.3134 - learning_rate: 2.0000e-04
# Epoch 105/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3044 - val_loss: 0.3134 - learning_rate: 2.0000e-04
# Epoch 106/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3044 - val_loss: 0.3134 - learning_rate: 2.0000e-04
# Epoch 107/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3043 - val_loss: 0.3133 - learning_rate: 2.0000e-04
# Epoch 108/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3043 - val_loss: 0.3133 - learning_rate: 2.0000e-04
# Epoch 109/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-05
# Epoch 110/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-05
# Epoch 111/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-05
# Epoch 112/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-05
# Epoch 113/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-05
# Epoch 114/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-06
# Epoch 115/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-06
# Epoch 116/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-06
# Epoch 117/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-06
# Epoch 118/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-06
# Epoch 119/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-07
# Epoch 120/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-07
# Epoch 121/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-07
# Epoch 122/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-07
# Epoch 123/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-07
# Epoch 124/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-08
# Epoch 125/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-08
# Epoch 126/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-08
# Epoch 127/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-08
# Epoch 128/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-08
# Epoch 129/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-09
# Epoch 130/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-09
# Epoch 131/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-09
# Epoch 132/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-09
# Epoch 133/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-09
# Epoch 134/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-10
# Epoch 135/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-10
# Epoch 136/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-10
# Epoch 137/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-10
# Epoch 138/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-10
# Epoch 139/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-11
# Epoch 140/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-11
# Epoch 141/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-11
# Epoch 142/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-11
# Epoch 143/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-11
# Epoch 144/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-12
# Epoch 145/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-12
# Epoch 146/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-12
# Epoch 147/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-12
# Epoch 148/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3042 - val_loss: 0.3133 - learning_rate: 2.0000e-12

# %%
def nn_predict_stepdown(X):
    """Prediction function of the step-down neural network (log scale)."""
    df = pd.DataFrame(X, columns=x)
    df_scaled = nn_preprocessor.transform(df)
    pred = nn_model_stepdown.predict(df_scaled, verbose=0, batch_size=10_000).flatten()
    return np.log(pred)

# Create the explainer
nn_stepdown_explainer = shap.KernelExplainer(nn_predict_stepdown, data=X_bg)

# Calculate SHAP values (this may take a while for deeper networks)
shap_nn_stepdown = nn_stepdown_explainer.shap_values(X_explain, nsamples=30)

# Plot dependency plots using the existing function
all_dep_plots(x, shap_nn_stepdown, X_explain)
# Out:
# Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
# Training history plot

# After training the model
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history_stepdown.history['loss'], label='Training Loss')
plt.plot(history_stepdown.history['val_loss'], label='Validation Loss')
plt.title('Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

if 'lr' in history_stepdown.history:
    plt.subplot(1, 2, 2)
    plt.plot(history_stepdown.history['lr'])
    plt.title('Learning Rate')
    plt.xlabel('Epoch')
    plt.ylabel('Learning Rate')
    
plt.tight_layout()
plt.show()

# %%
# Prediction vs actual

# Test set predictions
X_test = nn_preprocessor.transform(test[x])
y_pred = nn_model_stepdown.predict(X_test, verbose=0).flatten()
y_true = test[y].values

# Simple metrics
mean_abs_error = np.mean(np.abs(y_pred - y_true))
mean_squared_error = np.mean((y_pred - y_true)**2)
print(f"Mean Absolute Error: {mean_abs_error:.4f}")
print(f"Mean Squared Error: {mean_squared_error:.4f}")

# Plot prediction distribution
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(y_true, bins=10, alpha=0.5, label='Actual')
plt.hist(y_pred, bins=10, alpha=0.5, label='Predicted')
plt.legend()
plt.title('Distribution Comparison')

plt.subplot(1, 2, 2)
plt.scatter(y_true, y_pred, alpha=0.3)
plt.plot([0, max(y_true)], [0, max(y_true)], 'r--')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.tight_layout()
plt.show()
# Out:
# Mean Absolute Error: 0.1633
# Mean Squared Error: 0.0919

# %% [markdown]
# I want more!

# %%
# attempt after many iterations

#

import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
cb = [EarlyStopping(patience=20), ReduceLROnPlateau(patience=5)]

inputs = keras.Input(shape=(len(x),))


z = layers.Dense(24)(inputs)  
z = layers.LeakyReLU(alpha=0.1)(z)  
z = layers.Dropout(0.25)(z) 

# Second layer
z = layers.Dense(12)(z)
z = layers.LeakyReLU(alpha=0.1)(z)

# Third layer
z = layers.Dense(6)(z)        
z = layers.LeakyReLU(alpha=0.1)(z)

# Output layer
outputs = layers.Dense(1, activation="exponential")(z)
nn_model_improved = keras.Model(inputs=inputs, outputs=outputs)

nn_model_improved.summary()

# Keep same learning rate
nn_model_improved.compile(optimizer=Adam(learning_rate=2e-4), loss="Poisson")
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_15 (Dense)                │ (None, 24)             │           168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu (LeakyReLU)         │ (None, 24)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 24)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 12)             │           300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_1 (LeakyReLU)       │ (None, 12)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 6)              │            78 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_2 (LeakyReLU)       │ (None, 6)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 1)              │             7 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 553 (2.16 KB)
#  Trainable params: 553 (2.16 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_improved = nn_model_improved.fit(
    x=X_train,
    y=train[y],
    epochs=200,
    batch_size=5000,
    validation_split=0.1,
    callbacks=cb,
    verbose=1
)

# Plot training history
plt.figure(figsize=(12, 4))
plt.plot(history_improved.history['loss'], label='Training Loss')
plt.plot(history_improved.history['val_loss'], label='Validation Loss')
plt.title('Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Evaluation on test set
X_test = nn_preprocessor.transform(test[x])
y_pred = nn_model_improved.predict(X_test, verbose=0).flatten()
y_true = test[y].values

# Metrics
mean_abs_error = np.mean(np.abs(y_pred - y_true))
mean_squared_error = np.mean((y_pred - y_true)**2)
print(f"Mean Absolute Error: {mean_abs_error:.4f}")
print(f"Mean Squared Error: {mean_squared_error:.4f}")

# Visualization
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(y_true, bins=10, alpha=0.5, label='Actual')
plt.hist(y_pred, bins=10, alpha=0.5, label='Predicted')
plt.legend()
plt.title('Distribution Comparison')

plt.subplot(1, 2, 2)
plt.scatter(y_true, y_pred, alpha=0.3)
plt.plot([0, max(y_true)], [0, max(y_true)], 'r--')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted')
plt.tight_layout()
plt.show()

# SHAP Analysis
def nn_predict_improved(X):
    """Prediction function of the improved neural network (log scale)."""
    df = pd.DataFrame(X, columns=x)
    df_scaled = nn_preprocessor.transform(df)
    pred = nn_model_improved.predict(df_scaled, verbose=0, batch_size=10_000).flatten()
    return np.log(pred)

# Create explainer
nn_improved_explainer = shap.KernelExplainer(nn_predict_improved, data=X_bg)
shap_nn_improved = nn_improved_explainer.shap_values(X_explain, nsamples=30)

# Plot dependency plots
all_dep_plots(x, shap_nn_improved, X_explain)

# Feature importance summary
feature_importance = np.abs(shap_nn_improved).mean(0)
features_df = pd.DataFrame(list(zip(x, feature_importance)), columns=['Feature', 'Importance'])
features_df = features_df.sort_values('Importance', ascending=False)
print("Feature Importance:")
print(features_df)
# Out:
# Epoch 1/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.7890 - val_loss: 0.7647 - learning_rate: 2.0000e-04
# Epoch 2/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.7222 - val_loss: 0.6853 - learning_rate: 2.0000e-04
# Epoch 3/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.6547 - val_loss: 0.6105 - learning_rate: 2.0000e-04
# Epoch 4/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5940 - val_loss: 0.5462 - learning_rate: 2.0000e-04
# Epoch 5/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5387 - val_loss: 0.4937 - learning_rate: 2.0000e-04
# Epoch 6/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4928 - val_loss: 0.4525 - learning_rate: 2.0000e-04
# Epoch 7/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4577 - val_loss: 0.4202 - learning_rate: 2.0000e-04
# Epoch 8/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4283 - val_loss: 0.3954 - learning_rate: 2.0000e-04
# Epoch 9/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4045 - val_loss: 0.3762 - learning_rate: 2.0000e-04
# Epoch 10/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3872 - val_loss: 0.3616 - learning_rate: 2.0000e-04
# Epoch 11/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3739 - val_loss: 0.3505 - learning_rate: 2.0000e-04
# Epoch 12/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3620 - val_loss: 0.3422 - learning_rate: 2.0000e-04
# Epoch 13/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3523 - val_loss: 0.3359 - learning_rate: 2.0000e-04
# Epoch 14/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3486 - val_loss: 0.3312 - learning_rate: 2.0000e-04
# Epoch 15/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3431 - val_loss: 0.3278 - learning_rate: 2.0000e-04
# Epoch 16/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3387 - val_loss: 0.3253 - learning_rate: 2.0000e-04
# Epoch 17/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3352 - val_loss: 0.3234 - learning_rate: 2.0000e-04
# Epoch 18/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3339 - val_loss: 0.3221 - learning_rate: 2.0000e-04
# Epoch 19/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3313 - val_loss: 0.3211 - learning_rate: 2.0000e-04
# Epoch 20/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3308 - val_loss: 0.3203 - learning_rate: 2.0000e-04
# Epoch 21/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3278 - val_loss: 0.3197 - learning_rate: 2.0000e-04
# Epoch 22/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3277 - val_loss: 0.3192 - learning_rate: 2.0000e-04
# Epoch 23/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3278 - val_loss: 0.3188 - learning_rate: 2.0000e-04
# Epoch 24/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3250 - val_loss: 0.3185 - learning_rate: 2.0000e-04
# Epoch 25/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3256 - val_loss: 0.3183 - learning_rate: 2.0000e-04
# Epoch 26/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3244 - val_loss: 0.3180 - learning_rate: 2.0000e-04
# Epoch 27/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3239 - val_loss: 0.3178 - learning_rate: 2.0000e-04
# Epoch 28/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3235 - val_loss: 0.3177 - learning_rate: 2.0000e-04
# Epoch 29/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3233 - val_loss: 0.3175 - learning_rate: 2.0000e-04
# Epoch 30/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3225 - val_loss: 0.3174 - learning_rate: 2.0000e-04
# Epoch 31/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3214 - val_loss: 0.3172 - learning_rate: 2.0000e-04
# Epoch 32/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3198 - val_loss: 0.3171 - learning_rate: 2.0000e-04
# Epoch 33/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3225 - val_loss: 0.3170 - learning_rate: 2.0000e-04
# Epoch 34/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3213 - val_loss: 0.3169 - learning_rate: 2.0000e-04
# Epoch 35/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3217 - val_loss: 0.3168 - learning_rate: 2.0000e-04
# Epoch 36/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3202 - val_loss: 0.3167 - learning_rate: 2.0000e-04
# Epoch 37/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3206 - val_loss: 0.3166 - learning_rate: 2.0000e-04
# Epoch 38/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3196 - val_loss: 0.3165 - learning_rate: 2.0000e-04
# Epoch 39/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3204 - val_loss: 0.3164 - learning_rate: 2.0000e-04
# Epoch 40/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3188 - val_loss: 0.3163 - learning_rate: 2.0000e-04
# Epoch 41/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3204 - val_loss: 0.3162 - learning_rate: 2.0000e-04
# Epoch 42/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3187 - val_loss: 0.3162 - learning_rate: 2.0000e-04
# Epoch 43/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3179 - val_loss: 0.3161 - learning_rate: 2.0000e-04
# Epoch 44/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3193 - val_loss: 0.3160 - learning_rate: 2.0000e-04
# Epoch 45/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3175 - val_loss: 0.3159 - learning_rate: 2.0000e-04
# Epoch 46/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3167 - val_loss: 0.3158 - learning_rate: 2.0000e-04
# Epoch 47/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3172 - val_loss: 0.3158 - learning_rate: 2.0000e-04
# Epoch 48/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3171 - val_loss: 0.3157 - learning_rate: 2.0000e-04
# Epoch 49/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3179 - val_loss: 0.3157 - learning_rate: 2.0000e-04
# Epoch 50/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3176 - val_loss: 0.3156 - learning_rate: 2.0000e-04
# Epoch 51/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3166 - val_loss: 0.3155 - learning_rate: 2.0000e-04
# Epoch 52/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3182 - val_loss: 0.3155 - learning_rate: 2.0000e-04
# Epoch 53/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3179 - val_loss: 0.3154 - learning_rate: 2.0000e-04
# Epoch 54/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3159 - val_loss: 0.3154 - learning_rate: 2.0000e-04
# Epoch 55/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3162 - val_loss: 0.3153 - learning_rate: 2.0000e-04
# Epoch 56/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3157 - val_loss: 0.3153 - learning_rate: 2.0000e-04
# Epoch 57/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3154 - val_loss: 0.3152 - learning_rate: 2.0000e-04
# Epoch 58/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3160 - val_loss: 0.3152 - learning_rate: 2.0000e-04
# Epoch 59/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3157 - val_loss: 0.3151 - learning_rate: 2.0000e-04
# Epoch 60/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3150 - val_loss: 0.3151 - learning_rate: 2.0000e-04
# Epoch 61/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3134 - val_loss: 0.3151 - learning_rate: 2.0000e-04
# Epoch 62/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3147 - val_loss: 0.3150 - learning_rate: 2.0000e-04
# Epoch 63/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3137 - val_loss: 0.3150 - learning_rate: 2.0000e-04
# Epoch 64/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3123 - val_loss: 0.3149 - learning_rate: 2.0000e-04
# Epoch 65/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3140 - val_loss: 0.3149 - learning_rate: 2.0000e-04
# Epoch 66/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3141 - val_loss: 0.3148 - learning_rate: 2.0000e-04
# Epoch 67/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3144 - val_loss: 0.3147 - learning_rate: 2.0000e-04
# Epoch 68/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3138 - val_loss: 0.3147 - learning_rate: 2.0000e-04
# Epoch 69/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3138 - val_loss: 0.3147 - learning_rate: 2.0000e-04
# Epoch 70/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3139 - val_loss: 0.3146 - learning_rate: 2.0000e-04
# Epoch 71/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3139 - val_loss: 0.3146 - learning_rate: 2.0000e-04
# Epoch 72/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3136 - val_loss: 0.3145 - learning_rate: 2.0000e-04
# Epoch 73/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3126 - val_loss: 0.3145 - learning_rate: 2.0000e-04
# Epoch 74/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3127 - val_loss: 0.3145 - learning_rate: 2.0000e-04
# Epoch 75/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3131 - val_loss: 0.3144 - learning_rate: 2.0000e-04
# Epoch 76/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3115 - val_loss: 0.3144 - learning_rate: 2.0000e-04
# Epoch 77/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3128 - val_loss: 0.3143 - learning_rate: 2.0000e-04
# Epoch 78/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3135 - val_loss: 0.3142 - learning_rate: 2.0000e-04
# Epoch 79/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3125 - val_loss: 0.3142 - learning_rate: 2.0000e-04
# Epoch 80/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3120 - val_loss: 0.3142 - learning_rate: 2.0000e-04
# Epoch 81/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3122 - val_loss: 0.3141 - learning_rate: 2.0000e-04
# Epoch 82/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3115 - val_loss: 0.3141 - learning_rate: 2.0000e-04
# Epoch 83/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3118 - val_loss: 0.3140 - learning_rate: 2.0000e-04
# Epoch 84/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3113 - val_loss: 0.3140 - learning_rate: 2.0000e-04
# Epoch 85/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3107 - val_loss: 0.3140 - learning_rate: 2.0000e-04
# Epoch 86/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3111 - val_loss: 0.3139 - learning_rate: 2.0000e-04
# Epoch 87/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3117 - val_loss: 0.3139 - learning_rate: 2.0000e-04
# Epoch 88/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3111 - val_loss: 0.3139 - learning_rate: 2.0000e-04
# Epoch 89/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3110 - val_loss: 0.3138 - learning_rate: 2.0000e-04
# Epoch 90/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3117 - val_loss: 0.3138 - learning_rate: 2.0000e-04
# Epoch 91/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3106 - val_loss: 0.3138 - learning_rate: 2.0000e-04
# Epoch 92/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3104 - val_loss: 0.3137 - learning_rate: 2.0000e-04
# Epoch 93/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3111 - val_loss: 0.3137 - learning_rate: 2.0000e-04
# Epoch 94/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3119 - val_loss: 0.3136 - learning_rate: 2.0000e-04
# Epoch 95/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3113 - val_loss: 0.3136 - learning_rate: 2.0000e-04
# Epoch 96/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3111 - val_loss: 0.3136 - learning_rate: 2.0000e-04
# Epoch 97/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3109 - val_loss: 0.3136 - learning_rate: 2.0000e-04
# Epoch 98/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3106 - val_loss: 0.3135 - learning_rate: 2.0000e-04
# Epoch 99/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3095 - val_loss: 0.3135 - learning_rate: 2.0000e-04
# Epoch 100/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3095 - val_loss: 0.3135 - learning_rate: 2.0000e-04
# Epoch 101/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3097 - val_loss: 0.3134 - learning_rate: 2.0000e-04
# Epoch 102/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3109 - val_loss: 0.3134 - learning_rate: 2.0000e-04
# Epoch 103/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3106 - val_loss: 0.3134 - learning_rate: 2.0000e-04
# Epoch 104/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3089 - val_loss: 0.3133 - learning_rate: 2.0000e-04
# Epoch 105/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3095 - val_loss: 0.3133 - learning_rate: 2.0000e-04
# Epoch 106/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3097 - val_loss: 0.3133 - learning_rate: 2.0000e-04
# Epoch 107/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3097 - val_loss: 0.3133 - learning_rate: 2.0000e-04
# Epoch 108/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3103 - val_loss: 0.3132 - learning_rate: 2.0000e-04
# Epoch 109/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3098 - val_loss: 0.3132 - learning_rate: 2.0000e-04
# Epoch 110/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3095 - val_loss: 0.3132 - learning_rate: 2.0000e-04
# Epoch 111/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3096 - val_loss: 0.3132 - learning_rate: 2.0000e-04
# Epoch 112/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3088 - val_loss: 0.3131 - learning_rate: 2.0000e-04
# Epoch 113/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3098 - val_loss: 0.3131 - learning_rate: 2.0000e-04
# Epoch 114/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3095 - val_loss: 0.3131 - learning_rate: 2.0000e-04
# Epoch 115/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3092 - val_loss: 0.3130 - learning_rate: 2.0000e-04
# Epoch 116/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3092 - val_loss: 0.3130 - learning_rate: 2.0000e-04
# Epoch 117/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3089 - val_loss: 0.3130 - learning_rate: 2.0000e-04
# Epoch 118/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3096 - val_loss: 0.3130 - learning_rate: 2.0000e-04
# Epoch 119/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3077 - val_loss: 0.3129 - learning_rate: 2.0000e-04
# Epoch 120/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3085 - val_loss: 0.3129 - learning_rate: 2.0000e-04
# Epoch 121/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3088 - val_loss: 0.3129 - learning_rate: 2.0000e-04
# Epoch 122/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3085 - val_loss: 0.3129 - learning_rate: 2.0000e-04
# Epoch 123/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3093 - val_loss: 0.3129 - learning_rate: 2.0000e-04
# Epoch 124/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3078 - val_loss: 0.3129 - learning_rate: 2.0000e-05
# Epoch 125/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3087 - val_loss: 0.3129 - learning_rate: 2.0000e-05
# Epoch 126/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3092 - val_loss: 0.3129 - learning_rate: 2.0000e-05
# Epoch 127/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3085 - val_loss: 0.3129 - learning_rate: 2.0000e-05
# Epoch 128/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3085 - val_loss: 0.3129 - learning_rate: 2.0000e-05
# Epoch 129/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3091 - val_loss: 0.3129 - learning_rate: 2.0000e-06
# Epoch 130/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3087 - val_loss: 0.3129 - learning_rate: 2.0000e-06
# Epoch 131/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3084 - val_loss: 0.3129 - learning_rate: 2.0000e-06
# Epoch 132/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3087 - val_loss: 0.3129 - learning_rate: 2.0000e-06
# Epoch 133/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3079 - val_loss: 0.3129 - learning_rate: 2.0000e-06
# Epoch 134/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3092 - val_loss: 0.3129 - learning_rate: 2.0000e-07
# Epoch 135/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3086 - val_loss: 0.3129 - learning_rate: 2.0000e-07
# Epoch 136/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3079 - val_loss: 0.3129 - learning_rate: 2.0000e-07
# Epoch 137/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3089 - val_loss: 0.3129 - learning_rate: 2.0000e-07
# Epoch 138/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3083 - val_loss: 0.3129 - learning_rate: 2.0000e-07
# Epoch 139/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3079 - val_loss: 0.3129 - learning_rate: 2.0000e-08
# Epoch 140/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3088 - val_loss: 0.3129 - learning_rate: 2.0000e-08
# Epoch 141/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3085 - val_loss: 0.3129 - learning_rate: 2.0000e-08
# Epoch 142/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3086 - val_loss: 0.3129 - learning_rate: 2.0000e-08
# Epoch 143/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3079 - val_loss: 0.3129 - learning_rate: 2.0000e-08
# Epoch 144/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3083 - val_loss: 0.3129 - learning_rate: 2.0000e-09
# Epoch 145/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3089 - val_loss: 0.3129 - learning_rate: 2.0000e-09
# Epoch 146/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3084 - val_loss: 0.3129 - learning_rate: 2.0000e-09
# Epoch 147/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3085 - val_loss: 0.3129 - learning_rate: 2.0000e-09
# Epoch 148/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3080 - val_loss: 0.3129 - learning_rate: 2.0000e-09
# Epoch 149/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3090 - val_loss: 0.3129 - learning_rate: 2.0000e-10
# Epoch 150/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3083 - val_loss: 0.3129 - learning_rate: 2.0000e-10
# Epoch 151/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3085 - val_loss: 0.3129 - learning_rate: 2.0000e-10
# Epoch 152/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3086 - val_loss: 0.3129 - learning_rate: 2.0000e-10
# Epoch 153/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3076 - val_loss: 0.3129 - learning_rate: 2.0000e-10
# Epoch 154/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3085 - val_loss: 0.3129 - learning_rate: 2.0000e-11
# Epoch 155/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3088 - val_loss: 0.3129 - learning_rate: 2.0000e-11
# Epoch 156/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3083 - val_loss: 0.3129 - learning_rate: 2.0000e-11
# Epoch 157/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3088 - val_loss: 0.3129 - learning_rate: 2.0000e-11
# Epoch 158/200
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3085 - val_loss: 0.3129 - learning_rate: 2.0000e-11
# Mean Absolute Error: 0.1667
# Mean Squared Error: 0.0915
# Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Feature Importance:
#       Feature  Importance
# 1        town    0.151879
# 4   car_power    0.095608
# 3  car_weight    0.074265
# 2  driver_age    0.065124
# 0        year    0.029092
# 5     car_age    0.021478

# %% [markdown]
# eh thats good enough for now. looks like the two lines are being picked up in car weight instead of car power but its by year instead of town! Interesting. Wish I had more time to play around with this.
