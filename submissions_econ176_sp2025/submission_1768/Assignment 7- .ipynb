# %% [markdown]
# # Linear Models and Neural Nets Lab (Econ 176 '25)
#
# This lab will guide you through a _modeling_ task, inspired by the I&RE module:
# + it's based on a widely-studied French third-party-liability dataset [here on Kaggle](https://www.kaggle.com/datasets/floser/french-motor-claims-datasets-fremtpl2freq)
# + this variation has seven features and is available from [OpenML](https://openml.org/). (It's also widely studied: Cited below.)
# + of the seven features, six are used as predictive features and one is the target (to be predicted from the other six)
# + the target (to be predicted) is the _number of claims filed_ &nbsp; ``claim_nb`` by an individual. We'll call these _claims_ or _incidents_.
# + the features are
#   + the ``year`` &nbsp;&nbsp; (there are only years 2018 and 2019)
#   + whether the driver lives in a ``town`` <font size="-1">``town == 1.0``</font> or in a more rural area <font size="-1">``town == 0.0``</font>
#   + the _driver's_ age (in years) &nbsp;&nbsp; ``driver_age``
#   + the car's _weight_ (in kg) &nbsp;&nbsp; ``car_weight``
#   + the car's engine _power_ (in hp) &nbsp;&nbsp; ``car_power``
#   + the _car's_ age (in years) &nbsp;&nbsp; ``car_age``
#
# <br>
#
# You'll model the
# The notebook will guide you through
# + loading the data and inspecting it, a bit
# + modeling the data with linear models (linear regression)

# %% [markdown]
# ## Loading and inspecting data
#
# &nbsp;&nbsp; <font color="Coral">there are two tasks here...</font>

# %%
# some of the libraries have warnings we want to ignore...
import warnings
warnings.filterwarnings("ignore")

# AI/ML libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml

# %matplotlib inline

# %% [markdown]
# These two cells grab and extract the data - one millon rows and seven features - from OpenML:

# %%
# Fetch the insurance-claim dataset from the OpenML repository  (an API call! :)
all = fetch_openml(data_id=45106, as_frame=True)

# %%
# Extract the pieces of the API result from the OpenML API call
df_all = all.data
df_all["claim_nb"] = all.target

print("Shape of full data:", df_all.shape)
df_all.head(30)    # print the first five rows of data
# Out:
# Shape of full data: (1000000, 7)
#       year  town  driver_age  car_weight  car_power  car_age  claim_nb
# 0   2018.0   1.0        51.0      1760.0      173.0      3.0       0.0
# 1   2019.0   1.0        41.0      1760.0      248.0      2.0       0.0
# 2   2018.0   1.0        25.0      1240.0      111.0      2.0       0.0
# 3   2019.0   0.0        40.0      1010.0       83.0      9.0       0.0
# 4   2018.0   0.0        43.0      2180.0      169.0      5.0       0.0
# 5   2018.0   1.0        45.0      1170.0      149.0      1.0       1.0
# 6   2019.0   0.0        72.0      1040.0       60.0      2.0       0.0
# 7   2018.0  -0.0        60.0      1060.0       66.0      2.0       0.0
# 8   2018.0   1.0        31.0      1400.0      118.0      0.0       0.0
# 9   2018.0   1.0        19.0      1310.0       78.0      0.0       0.0
# 10  2018.0   1.0        76.0      1140.0       89.0      4.0       0.0
# 11  2019.0   1.0        49.0      1060.0      106.0      7.0       0.0
# 12  2018.0   0.0        65.0      1670.0      173.0      1.0       0.0
# 13  2018.0   1.0        33.0      1010.0       97.0      6.0       0.0
# 14  2018.0   0.0        31.0      1490.0      146.0      1.0       0.0
# 15  2019.0   1.0        41.0      1240.0      152.0      1.0       0.0
# 16  2019.0   0.0        66.0      1230.0      205.0      8.0       0.0
# 17  2019.0  -0.0        70.0      1370.0      109.0      3.0       0.0
# 18  2018.0   1.0        59.0      1260.0       72.0      2.0       0.0
# 19  2018.0   1.0        26.0       960.0       69.0      0.0       1.0
# 20  2018.0   1.0        32.0      1120.0      127.0      0.0       0.0
# 21  2018.0   1.0        37.0       960.0       74.0      2.0       0.0
# 22  2018.0   0.0        25.0      1240.0      142.0      0.0       0.0
# 23  2019.0  -0.0        41.0       990.0       70.0      4.0       0.0
# 24  2019.0   0.0        24.0      1550.0      143.0      1.0       0.0
# 25  2018.0   0.0        70.0      1270.0       92.0      5.0       1.0
# 26  2018.0   1.0        34.0      1760.0      191.0      3.0       0.0
# 27  2019.0   0.0        56.0      1600.0      225.0      0.0       0.0
# 28  2018.0   1.0        66.0      1410.0       90.0      1.0       0.0
# 29  2018.0   1.0        36.0      1000.0      147.0      7.0       0.0

# %% [markdown]
# Here are the brief descriptions of each of the features:
# + the first six are the features we will use to _make_ predictions
#   + the ``year`` &nbsp;&nbsp; (there are only years 2018 and 2019)
#   + whether the driver lives in a ``town`` <font size="-1">``town == 1.0``</font> or in a more rural area <font size="-1">``town == 0.0``</font>
#   + the _driver's_ age (in years) &nbsp;&nbsp; ``driver_age``
#   + the car's _weight_ (in kg) &nbsp;&nbsp; ``car_weight``
#   + the car's engine _power_ (in hp) &nbsp;&nbsp; ``car_power``
#   + the _car's_ age (in years) &nbsp;&nbsp; ``car_age``
# + the seventh <b><tt>claim_nb</tt></b>, the number of claims files during that year, is the target to _be predicted_

# %%
df_all.describe()
# Out:
#                  year            town      driver_age      car_weight  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean      2018.550270        0.600130       45.998782     1308.266530
# std          0.497467        0.489872       13.997827      285.505998
# min       2018.000000        0.000000       18.000000      950.000000
# 25%       2018.000000        0.000000       35.000000     1090.000000
# 50%       2019.000000        1.000000       45.000000     1240.000000
# 75%       2019.000000        1.000000       56.000000     1460.000000
# max       2019.000000        1.000000       88.000000     3120.000000
#
#             car_power         car_age        claim_nb
# count  1000000.000000  1000000.000000  1000000.000000
# mean       124.981766        4.156266        0.089334
# std         49.133293        3.545284        0.300652
# min         50.000000        0.000000        0.000000
# 25%         86.000000        1.000000        0.000000
# 50%        116.000000        3.000000        0.000000
# 75%        156.000000        6.000000        0.000000
# max        341.000000       23.000000        4.000000

# %% [markdown]
# #### <font color="Coral"><b>Task 1</b></font>
#
# With full encouragement to use the built-in Colab AI -- or another of your choice, create five specific visualizations and an additional one:
# + create a histogram of all the drivers' ages, and
# + a histogram of all the the cars' ages, and
# + a histogram of the claim numbers, `claim_nb`
# + create a scatter plot of how the car's age varies with the driver's age
# + create a scatter plot of how the `claim_nb` varies with the driver's age
# + <font color="Coral"><b>also</b></font>, create one more - different - scatter plot of your choice, using this data
#
# <br>
#
# <font color="DodgerBlue">Below for task 2, write a short reflection</font> on the results of these data-visualizations. One sentence on what you see in each is perfect.  <br> <font size="-1">(There's another cell below reminding you of this!)</font>

# %%
import matplotlib.pyplot as plt
# Create a histogram of all the drivers' ages
plt.hist(df_all['driver_age'], bins=20)
plt.xlabel("Driver's Age")
plt.ylabel("Frequency")
plt.title("Histogram of Driver's Ages")
plt.show()

# %%
import matplotlib.pyplot as plt
# Create a histogram of all the cars' ages
plt.hist(df_all['car_age'], bins=20)
plt.xlabel("Car's Age")
plt.ylabel("Frequency")
plt.title("Histogram of Car's Ages")
plt.show()

# %%
import matplotlib.pyplot as plt
# Create a histogram of the claim numbers
plt.hist(df_all['claim_nb'], bins=20)
plt.xlabel("Claim Number")
plt.ylabel("Frequency")
plt.title("Histogram of Claim Numbers")
plt.show()

# %%
import matplotlib.pyplot as plt
# Create a scatter plot of how the car's age varies with the driver's age
df_sample = df_all.sample(n=100)  # Take a random sample of 100 data points
plt.scatter(df_sample['driver_age'], df_sample['car_age'])
plt.xlabel("Driver's Age")
plt.ylabel("Car's Age")
plt.title("Scatter Plot of Car's Age vs. Driver's Age")
plt.show()

# %%
# prompt: create a scatter plot of how the claim_nb varies with the driver's age of a random sample of 100

import matplotlib.pyplot as plt
# Create a scatter plot of how the claim_nb varies with the driver's age for a random sample of 100
sample_df = df_all.sample(n=200)
plt.scatter(sample_df['driver_age'], sample_df['claim_nb'])
plt.xlabel("Driver's Age")
plt.ylabel("Number of Claims (claim_nb)")
plt.title("Scatter Plot of Claim Number vs. Driver's Age (Random Sample)")
plt.show()

# %%
import matplotlib.pyplot as plt
# Create a scatter plot of how the claim_nb varies with the town
plt.scatter(df_all['town'], df_all['claim_nb'])
plt.xlabel("Town (1 = Town, 0 = Rural)")
plt.ylabel("Claim Number")
plt.title("Scatter Plot of Claim Number vs. Town")
plt.show()

# %% [markdown]
# #### <font color="Coral"><b>Task 2</b></font>
#
# <font color="DodgerBlue">Here, write a short reflection</font> -- a sentence or two for each of these is wonderful -- that describes the data-trends you see in the visualizations above.
#
# As a reminder, they were
# + histograms for the drivers' ages and the cars' ages and the claim numbers, `claim_nb`
# + a scatter plot of how the car's age varies with the driver's age
# + a scatter plot of how the `claim_nb` varies with the driver's age
# + <font color="Coral"><b>and</b></font>, one other - different - scatter plot that visualizes some of this data
#
# <br>
# <hr>
# <br>
#
# Feel free to use a new cell or the space below:
#
#
# *   Drivers' age histogram: The highest number of drivers fall under 40, and the large majority of drivers are between the ages 30-50.
# *   Cars' age histogram: The histogram is almost exponentially decaying, with the majority of cars being about a year old and decreasing exponentially.
# *   Claim numbers histogram: The majority of people have not made a claim, with significantly less people making a claim.
# *   Car age and driver age scatterplot: The correlation of car age and driver age is rather random, not showing any tendancy for an older car or newer car for older or younger drivers.
# *  Claim number and driver age scatter plot: This scatter plot is not a perfet representation of the data as it is a random sample, but it seems to show that the majority of claims are under the age of 50.
# *    Claim number and town: This scatter plot shows that overall, people in towns, not rural areas make more claims.
#
#
#
#
#
#
#
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# ## Modeling
#
# You will build two models for the <b><tt>claim_nb</tt></b> target:
# + a **linear-regression** model &nbsp;&nbsp; <font size="-2">since the target is a "number of occurrences" over a span of time, we use a _Poisson_ model</font>
# + a **neural-network** model &nbsp;&nbsp;  <font size="-2">of the same sort</font>
#
# You'll experiment with
# + interpreting the models
# + then, building some "deeper" neural networks
# + seeing how the two modeling approaches differ in the relationships they can express

# %% [markdown]
# ### Part 1: &nbsp;&nbsp; Data splitting
#
# The dataset has a million rows.
# + For speed of training, we will use only 100,000 of them.
# + At the end, you'll try changing at least three model parameters. This is one of those options! 😃

# %%
# Let's make sure everything runs first... using only 100,000 rows (instead of 1,000,000)

df_all = df_all.sample(frac=1.0, random_state=42)  # This shuffles the 1,000,000-row dataset

NUMROWS = 100000
df = df_all.iloc[0:NUMROWS,:].copy()    # This uses only the first 100,000 rows (or NUMROWS rows) for speed...

# %%
# We split into 90% training data and 10% testing data

from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.1, random_state=30)
print("Shape of training data:", train.shape)
print("Shape of test data:", test.shape)
# Out:
# Shape of training data: (90000, 7)
# Shape of test data: (10000, 7)

# %%
# Define target name (y) and feature names (x)
y, x = df.columns[-1], list(df.columns[:-1])

print("The response name:", y)
print("The feature names:", x)
# Out:
# The response name: claim_nb
# The feature names: ['year', 'town', 'driver_age', 'car_weight', 'car_power', 'car_age']

# %% [markdown]
# ### Part 2: &nbsp; A (Generalized) Linear Model (GLM)
#
# Here, we build a linear-regression model of the data.
#
# We'll use [Glum](https://glum.readthedocs.io/en/latest/), a high-performance implementation in Python. <br> <font size="-2"><tt>glum</tt> stands for _generalized linear modeling" ... not sure about the <tt>u</tt></font>

# %% [markdown]
# In Colab, you are likely to need to install `glum` once:

# %%
# !pip install glum
# Out:
# Collecting glum
#   Downloading glum-3.1.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from glum) (1.4.2)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.11/dist-packages (from glum) (2.10.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from glum) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from glum) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.23 in /usr/local/lib/python3.11/dist-packages (from glum) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from glum) (1.14.1)
# Collecting formulaic>=0.6 (from glum)
#   Downloading formulaic-1.1.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting tabmat>=4.0.0 (from glum)
#   Downloading tabmat-4.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=0.6->glum)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.6->glum) (4.13.1)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.6->glum) (1.17.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->glum) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->glum) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->glum) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.23->glum) (3.6.0)
# Requirement already satisfied: narwhals in /usr/local/lib/python3.11/dist-packages (from tabmat>=4.0.0->glum) (1.33.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->glum) (1.17.0)
# Downloading glum-3.1.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 84.6 MB/s eta 0:00:00
# Downloading formulaic-1.1.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.7/115.7 kB 7.1 MB/s eta 0:00:00
# Downloading tabmat-4.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 92.1 MB/s eta 0:00:00
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Installing collected packages: interface-meta, formulaic, tabmat, glum
# Successfully installed formulaic-1.1.1 glum-3.1.2 interface-meta-1.3.0 tabmat-4.1.1

# %% [markdown]
# We can use that library to build a linear model:

# %%
#
# there's not much code to build our model!
#
from glum import GeneralizedLinearRegressor

glm_model = GeneralizedLinearRegressor(family="poisson", alpha=1e-6)
glm_model.fit(X=train[x], y=train[y])

print("Coefficients")
pd.Series(np.append(glm_model.intercept_, glm_model.coef_), index=["Intercept"] + x)
# Out:
# Coefficients
# Intercept     5.524484
# year         -0.004149
# town          0.350489
# driver_age   -0.003272
# car_weight   -0.000068
# car_power     0.004117
# car_age      -0.022168
# dtype: float64

# %% [markdown]
# We did it!  &nbsp;&nbsp; But what _is_ it?!

# %% [markdown]
# #### As an absolute model, this is <u>not</u> very useful!
#
# **Everyone** has a very high likelihood of NOT having an auto incident/filing a claim. <i>This is good!</i>
#
# This means _everyone's_ expected number of incidents is 0 &nbsp; (Well, very close to it.)

# %% [markdown]
# #### In comparing the ***relative*** impact of a feature, the model <u>is</u> useful.
#
# Here is a full description of the ***relative*** relationships expressed by those coefficients [(cite)](https://ademos.people.uic.edu/Chapter19.html#:~:text=Rather%20than%20odds%20ratios%20(which,variable%5D%20is%20%5Bcoefficient%5D.):
#
#
# > <font color="DodgerBlue">The expected log count for each unit increase/decrease (depending on the sign of the coefficient) in [outcome variable] given [predictor variable] is [coefficient].</font>
#
#
# Wow!  &nbsp;&nbsp; This needs some unpacking...
#
# <hr>
# <br>

# %% [markdown]
# <font size="+1" color="Blue">Interpreting</font> <font size="+1" > coefficients, part one: &nbsp;&nbsp; <tt><b>town</b></tt> example</font>
#
#
# In practice, it's more straightforward than this suggests:
#
# Suppose your coefficient for `town` is 0.36. &nbsp; <font size="-2">That was one of my test-run values.</font>
#
# This means that "one unit" of `town` increases the <u>log of the claim count</u> by 0.36.  <br> <i><font color="Blue">But log-counts aren't very intuitive!</font></i> &nbsp; Let's _undo_ the log:
#
#
# `exp(0.36)` is about `1.43` &nbsp;&nbsp;&nbsp; Let's see that this is true:

# %%
from math import exp
exp(0.36)
# Out:
# 1.4333294145603401

# %% [markdown]
# This means that "one unit" of `town` ***multiplies*** &nbsp; the frequency of incidents by 1.43
#
# Since `town` only has values 0 and 1, this means that
#
# **when `town` is 1, the likelihood of an incident is 1.43 times higher then when it's 0**
#
# <br>
#
# <font color="Coral"><b>Aha!</b></font>
#
# <br>
#
# This ***incident-rate ratio*** is really useful!
# + for assessing the threat of an event that is relatively rare and/or
# + the _value_ of small changes to an individual's particular situation.
#
# In theory, the multiplier can be used many times:

# %%
exp(0.360105)    # for each unit of "townness,"  we multiply the expected claims by 1.433:
# Out:
# 1.433479922050374

# %%
exp(0.360105) ** 2   # so, we multiply twice for _two_ units of "townness":
# Out:
# 2.054864686921546

# %% [markdown]
# This means, if `town == 2`, the expected claims for those individuals would be 2.05x higher:
# + because, as above, `1.433 ** 2 == 1.433*1.433 == 2.05`
#
# There _isn't_ such a value in the dataset...
# + ... but models will allow this kind of extrapolation. Be careful!

# %% [markdown]
# <font size="+1" color="Blue">Interpreting</font> <font size="+1"> coefficients, part two: &nbsp;&nbsp; <tt><b>driver_age</b></tt> example</font>
#
# Let's try an example where there are multiple values, for example, for <b><tt>driver_age</tt></b> :
# + My coefficient for <tt><b>driver_age</b></tt> was <tt>-0.003272</tt>
# + And <tt>exp(-0.003272) == 0.9967</tt> &nbsp;&nbsp; <font size="-2">Let's confirm:</font>

# %%
exp(-0.003272)    # for each year of driver_age, you multiply the expected claims by 0.9967:
# Out:
# 0.9967333471584426

# %% [markdown]
# This means that, for this model, the number of claims is multiplied by <tt>0.9967</tt> ***for each additional year of age***
#
# <br>
#
# What if an individual is fifteen years older?

# %%
0.9967 ** 15
# Out:
# 0.9516272593744175

# %% [markdown]
# the model expects the number of claims to be 95% with that "additional experience"
#
# <br>
#
# What if we compare the oldest (88) and youngest (18) in the dataset:

# %%
exp(-0.003272)**(88-18)
# Out:
# 0.7952967210000054

# %% [markdown]
# Which states that our octogenerians will make 0.79 the claims as our 18-year-olds.
#
# Taking the reciprocal, the model is saying that moving across the dataset's full age-span, from old to young, multiplies the number of claims by 1.25:

# %%
1/0.7952
# Out:
# 1.2575452716297786

# %% [markdown]
# There is definitely room for skepticism here! 😀
#
# But we've successfully interpreted the model coefficients!
#
# Next, try two of your own:

# %% [markdown]
# #### <font color="Coral"><b>Task 3</b></font> &nbsp; Two more model-interpretations:
#
# Following the approach of the two examples above, choose **two more** features from the coefficients and:
# + compute the _per-unit_ incident-rate multiplier for that feature
# + decide on a "reasonable" number of units (years, kg, hp, ...)
# + compute the incident-rate multiplier for _that many units_
# + find the "full span" of units in the dataset (it's printed above ...)
# + compute the incident-rate multiplier for _that full span_
# + and reflect on what this is saying about the incidents in this data.
#
# Specifically, share how well does these _match your intution_ about these factors for auto incidents/insurance claims? Reasonable? Skeptical? Other?
#
# <br>
# <hr>
# <br>
#
# Feel free to use this cell or new ones just below:
#
# <br>
# <br>

# %%
exp(0.004117)
# Out:
# 1.004125486486792

# %%
exp(0.004117) ** 200
# Out:
# 2.278232675354985

# %%
1/(exp(0.004117)**(341-50))
# Out:
# 0.3017830189910322

# %% [markdown]
# For car power, measured in horse power, the per-unit multiplier is 1.004125486486792. For a car with 200 horsepower (what the internet considers normal...) the expected number of claims raises by 2.278232675354985. For the full span incident-rate multiplier, from high to low, multiplies the number of claims by 0.3017830189910322. This makes sense overall, the higher the horse power, we would expect an increase in claims, and as we move to the lower horsepower, there should be less claims.

# %%
exp(-0.000068)
# Out:
# 0.9999320023119476

# %%
exp(-0.000068) ** 1300
# Out:
# 0.9153946456237033

# %%
1/(exp(-0.000068)**(3120-950))
# Out:
# 1.1590028229130385

# %% [markdown]
# For car weight, measured in pounds, the per-unit multiplier is 0.9999320023119476. For a car that is 1300 pounds, the expected number of claims decreases by 0.9153946456237033. For the full span incident-rate multiplier, from high to low multiplies the number of claims by 1.1590028229130385. This makes sense overall, as the weight of the car decreases, it would make more sense if it might get a little more damaged making a claim necessary. However, it makes sense that this number is small as it really probaly shouldn't be a huge factor.

# %% [markdown]
# <br>
# <hr>
# <br>

# %% [markdown]
# ### Part 3. &nbsp; **Automatic** model-interpretation
#
# A technique called SHAP, short for SHapley Additive exPlanation, is able to estimate the feature-by-feature effects of _any_ model.
#
# It _should_ be here already:

# %%
import shap

# %% [markdown]
# SHAP works by sampling the model at several points and then surveying the space around those points to see how the model is changing. It integrates all of this information in order to be able to compare the influence of all of the variables with the same units, known as SHAP values. They are again relative values, and they indicate how the target varies with changes to each feature -- in light of _all_ the features in the model.
#
# Linear models like the one above are already interpretable. However, other models - like neural nets - are much less so.
#
# To get started, let's run SHAP for our linear model:

# %%
import shap

# First, extract background data. This is the same for all models to interpret:
X_bg = train[x].sample(200, random_state=8366)    # grab 200 samples from our training data - 200 is a lot...

# Exploring the space...   This will take a while...
glm_explainer = shap.KernelExplainer(lambda x: np.log(glm_model.predict(x)), data=X_bg)     # Don't worry about the warnings!

# Then, we can choose any data to explain. We'll choose 1,000 rows randomly called X_explain
X_explain = train[x].sample(n=1000, random_state=937)
shap_glm = glm_explainer.shap_values(X_explain, nsamples=30) # there are 30 non-trivial subsets of 6 features
# Out:
# WARNING:shap:Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# Let's see one of the explained individuals:

# %%
X_explain[0:1]
# Out:
#           year  town  driver_age  car_weight  car_power  car_age
# 396019  2018.0   0.0        50.0      1290.0      119.0      1.0

# %% [markdown]
# and, let's see their SHAP values:

# %%
shap_glm[0:1]
# Out:
# array([[ 0.00213664, -0.18400681, -0.01735597,  0.00128275, -0.02764656,
#          0.06816579]])

# %% [markdown]
# Ok!
#
# These numbers are (the sign and) relative weight of each of this individual's **per-feature contributions** to their risk (their expected number of claims).
#
# For example, in this model,
# + their age makes a claim less likely
# + their car's age make a claim more likely
#
# Plus, the <tt><b>SHAPvalue</b></tt> units are commensurate:
# + the impact of the driver's age carries almost three times the weight of their car's age
#
# <br>
#
# Better to plot all of them. &nbsp; Let's do that next:

# %%
#
# A function to create all of the dependence plots among our features
#
def all_dep_plots(x, shap_values, X):
    """ Dependence plots for all features x. """
    fig, _ = plt.subplots(nrows=2, ncols=3, figsize=(10, 6), sharey=True)

    for i, ax in enumerate(fig.axes):
        xvar = x[i]
        shap.dependence_plot(
            xvar,
            shap_values,
            features=X,
            x_jitter=0.2 * (xvar in ("town", "year")),
            ymin=-0.5,
            ymax=1,
            ax=ax,
            show=False,
        )
        ax.set_title(xvar, fontdict={"size": 16})
        ax.set_ylabel("SHAP values" if i % 3 == 0 else "")
        ax.grid()
    plt.tight_layout()

print("The all_dep_plots function has been defined.")
print("Run the next cell to plot the features and their impacts")
# Out:
# The all_dep_plots function has been defined.
# Run the next cell to plot the features and their impacts

# %%
all_dep_plots(x, shap_glm, X_explain)

# %% [markdown]
# #### <font color="Coral"><b>Task 4</b></font> &nbsp; How did SHAP do?
#
# In Task 3, you chose two features and examined their effects on the target value, the number of incidents.
#
# Here, revisit those two features, and in a couple of sentences, describe whether the effects you measured match the plots above.
#
# <br>
#
# **Note/Hints**  There are lots of dimensions here! And lots of information! The x-axis of each plot shows the feature values. The y-axis is the SHAP value (the relative impact on the number of claims).
#
# The red/blue coloring of datapoints shows how the _most influential **other** feature_ overlays onto the current plot. That **other** feature is the most influential for the one labeled on the x-axis, and so it will often be different for different plots.
#
# <br>
#
# As an example of this feature-comparison, remember that one <tt><b>town</b></tt> unit multiplied the claims by 1.4, and the full span of <tt><b>driver_age</b></tt> multiplied the claims by 1.25.
#
# This matches well!  In the above plot, the span for <tt><b>town</b></tt> is a little bit larger than the span for <tt><b>driver_age</b></tt>.
#
# The SHAP units are not the same, and SHAP takes into account more than linear dependencies, but it has captured the sign and the magnitude of the model it was interpreting.
#
#
# <br>
# <hr>
# <br>
#
# For your two reflections, feel free to use this cell or new ones just below this one:
#
# <br>
# <br>

# %% [markdown]
# Looking at car weight and car power, we can see that the span for car power is much larger than car weight. We knew this would be the case because we observed that units of horse power made a much more significant increase in change as opposed to how much units of pounds changed. This aligns with what the model was interpreting.

# %% [markdown]
# ### Part 4: &nbsp;&nbsp; A Neural Network model
#
# Here, we TensorFlow to fit a "shallow" neural net.
#
# Your task is to improve the results -- by adding more layers and retraining...
#
# Plus, the resulting layered network will be able to extract nonlinear relationships among the features <br> <font size="-1">(in exchange for much more training time...)</font>

# %% [markdown]
# Neurons work best when all their data is ***roughly the same magnitude***
#
# Our brains handle this at the sensor level -- our hearing and vision systems continually try to re-establish the ambient baseline to help convert their inputs into computable magnitudes:
# + light sensitivity increases in the dark and decreases in bright light
# + for sound, loud repetitive even soft sounds are heightened when in a quiet place.
#
# <br>
#
# For neural nets, we can scale each feature to be between -1 and 1:

# %%
# Scale features to [-1, 1]
from sklearn.preprocessing import MinMaxScaler

nn_preprocessor = MinMaxScaler(feature_range=(-1, 1))
X_train = nn_preprocessor.fit_transform(train[x])

print("Output after the data has been scaled:")
pd.DataFrame(X_train[0:5], columns=x)
# Out:
# Output after the data has been scaled:
#    year  town  driver_age  car_weight  car_power   car_age
# 0   1.0  -1.0    0.246377   -0.530612  -0.501754 -1.000000
# 1  -1.0   1.0   -0.072464   -0.530612  -0.256140 -0.818182
# 2   1.0   1.0   -0.072464   -0.969388  -0.817544 -0.636364
# 3   1.0   1.0   -0.333333   -0.867347  -0.887719 -0.181818
# 4   1.0   1.0   -0.594203   -0.489796  -0.445614 -0.727273

# %%
#
# Neural nets are worthy of their own course, for sure...
#
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
cb = [EarlyStopping(patience=20), ReduceLROnPlateau(patience=5)]  # "callbacks" for training (see below)

# Architecture
inputs = keras.Input(shape=(len(x),))
# additional layers can be added here!
outputs = layers.Dense(1, activation="exponential")(inputs)
nn_model_shallow = keras.Model(inputs=inputs, outputs=outputs)

nn_model_shallow.summary()

# Calculate gradients
nn_model_shallow.compile(optimizer=Adam(learning_rate=1e-4), loss="Poisson")
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 6)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │               7 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7 (28.00 B)
#  Trainable params: 7 (28.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Above, you see the artictecture of the network.
#
# This includes the total number of neuron-connections (parameters) to train.
#
# Let's train!

# %%
#
# train the network!
#

tf.random.set_seed(4349)

history_shallow = nn_model_shallow.fit(
    x=X_train,
    y=train[y],
    epochs=200,
    batch_size=10_000,
    validation_split=0.1,
    callbacks=cb,
    verbose=1,         # consider running both values 0 (no printing) and 1 (printing)
)
# Out:
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step - loss: 2.1282 - val_loss: 2.1296 - learning_rate: 1.0000e-04
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.1208 - val_loss: 2.1221 - learning_rate: 1.0000e-04
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.1133 - val_loss: 2.1147 - learning_rate: 1.0000e-04
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.1060 - val_loss: 2.1073 - learning_rate: 1.0000e-04
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.0986 - val_loss: 2.1000 - learning_rate: 1.0000e-04
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.0914 - val_loss: 2.0927 - learning_rate: 1.0000e-04
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 2.0841 - val_loss: 2.0854 - learning_rate: 1.0000e-04
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 2.0769 - val_loss: 2.0782 - learning_rate: 1.0000e-04
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.0698 - val_loss: 2.0711 - learning_rate: 1.0000e-04
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.0627 - val_loss: 2.0640 - learning_rate: 1.0000e-04
# Epoch 11/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 2.0556 - val_loss: 2.0569 - learning_rate: 1.0000e-04
# Epoch 12/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0486 - val_loss: 2.0499 - learning_rate: 1.0000e-04
# Epoch 13/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0416 - val_loss: 2.0429 - learning_rate: 1.0000e-04
# Epoch 14/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0347 - val_loss: 2.0360 - learning_rate: 1.0000e-04
# Epoch 15/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0278 - val_loss: 2.0291 - learning_rate: 1.0000e-04
# Epoch 16/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0210 - val_loss: 2.0222 - learning_rate: 1.0000e-04
# Epoch 17/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0142 - val_loss: 2.0154 - learning_rate: 1.0000e-04
# Epoch 18/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.0074 - val_loss: 2.0087 - learning_rate: 1.0000e-04
# Epoch 19/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.0007 - val_loss: 2.0019 - learning_rate: 1.0000e-04
# Epoch 20/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9940 - val_loss: 1.9953 - learning_rate: 1.0000e-04
# Epoch 21/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9874 - val_loss: 1.9886 - learning_rate: 1.0000e-04
# Epoch 22/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9808 - val_loss: 1.9820 - learning_rate: 1.0000e-04
# Epoch 23/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9742 - val_loss: 1.9754 - learning_rate: 1.0000e-04
# Epoch 24/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.9677 - val_loss: 1.9689 - learning_rate: 1.0000e-04
# Epoch 25/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.9612 - val_loss: 1.9624 - learning_rate: 1.0000e-04
# Epoch 26/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.9547 - val_loss: 1.9560 - learning_rate: 1.0000e-04
# Epoch 27/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.9483 - val_loss: 1.9495 - learning_rate: 1.0000e-04
# Epoch 28/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9420 - val_loss: 1.9432 - learning_rate: 1.0000e-04
# Epoch 29/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.9356 - val_loss: 1.9368 - learning_rate: 1.0000e-04
# Epoch 30/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.9293 - val_loss: 1.9305 - learning_rate: 1.0000e-04
# Epoch 31/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.9231 - val_loss: 1.9243 - learning_rate: 1.0000e-04
# Epoch 32/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.9168 - val_loss: 1.9180 - learning_rate: 1.0000e-04
# Epoch 33/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.9106 - val_loss: 1.9118 - learning_rate: 1.0000e-04
# Epoch 34/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.9045 - val_loss: 1.9057 - learning_rate: 1.0000e-04
# Epoch 35/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.8984 - val_loss: 1.8996 - learning_rate: 1.0000e-04
# Epoch 36/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8923 - val_loss: 1.8935 - learning_rate: 1.0000e-04
# Epoch 37/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8862 - val_loss: 1.8874 - learning_rate: 1.0000e-04
# Epoch 38/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8802 - val_loss: 1.8814 - learning_rate: 1.0000e-04
# Epoch 39/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8742 - val_loss: 1.8754 - learning_rate: 1.0000e-04
# Epoch 40/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8683 - val_loss: 1.8694 - learning_rate: 1.0000e-04
# Epoch 41/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.8624 - val_loss: 1.8635 - learning_rate: 1.0000e-04
# Epoch 42/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8565 - val_loss: 1.8576 - learning_rate: 1.0000e-04
# Epoch 43/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8506 - val_loss: 1.8518 - learning_rate: 1.0000e-04
# Epoch 44/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8448 - val_loss: 1.8460 - learning_rate: 1.0000e-04
# Epoch 45/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8390 - val_loss: 1.8402 - learning_rate: 1.0000e-04
# Epoch 46/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8333 - val_loss: 1.8344 - learning_rate: 1.0000e-04
# Epoch 47/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.8276 - val_loss: 1.8287 - learning_rate: 1.0000e-04
# Epoch 48/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8219 - val_loss: 1.8230 - learning_rate: 1.0000e-04
# Epoch 49/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8162 - val_loss: 1.8174 - learning_rate: 1.0000e-04
# Epoch 50/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8106 - val_loss: 1.8117 - learning_rate: 1.0000e-04
# Epoch 51/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.8050 - val_loss: 1.8061 - learning_rate: 1.0000e-04
# Epoch 52/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7994 - val_loss: 1.8006 - learning_rate: 1.0000e-04
# Epoch 53/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7939 - val_loss: 1.7950 - learning_rate: 1.0000e-04
# Epoch 54/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.7884 - val_loss: 1.7895 - learning_rate: 1.0000e-04
# Epoch 55/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7829 - val_loss: 1.7840 - learning_rate: 1.0000e-04
# Epoch 56/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7775 - val_loss: 1.7786 - learning_rate: 1.0000e-04
# Epoch 57/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7721 - val_loss: 1.7732 - learning_rate: 1.0000e-04
# Epoch 58/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7667 - val_loss: 1.7678 - learning_rate: 1.0000e-04
# Epoch 59/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7613 - val_loss: 1.7624 - learning_rate: 1.0000e-04
# Epoch 60/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7560 - val_loss: 1.7571 - learning_rate: 1.0000e-04
# Epoch 61/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7507 - val_loss: 1.7518 - learning_rate: 1.0000e-04
# Epoch 62/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7454 - val_loss: 1.7465 - learning_rate: 1.0000e-04
# Epoch 63/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7402 - val_loss: 1.7412 - learning_rate: 1.0000e-04
# Epoch 64/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.7350 - val_loss: 1.7360 - learning_rate: 1.0000e-04
# Epoch 65/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7298 - val_loss: 1.7308 - learning_rate: 1.0000e-04
# Epoch 66/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7246 - val_loss: 1.7257 - learning_rate: 1.0000e-04
# Epoch 67/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7195 - val_loss: 1.7205 - learning_rate: 1.0000e-04
# Epoch 68/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7144 - val_loss: 1.7154 - learning_rate: 1.0000e-04
# Epoch 69/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7093 - val_loss: 1.7103 - learning_rate: 1.0000e-04
# Epoch 70/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.7042 - val_loss: 1.7053 - learning_rate: 1.0000e-04
# Epoch 71/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.6992 - val_loss: 1.7002 - learning_rate: 1.0000e-04
# Epoch 72/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6942 - val_loss: 1.6952 - learning_rate: 1.0000e-04
# Epoch 73/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6892 - val_loss: 1.6903 - learning_rate: 1.0000e-04
# Epoch 74/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6843 - val_loss: 1.6853 - learning_rate: 1.0000e-04
# Epoch 75/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6793 - val_loss: 1.6804 - learning_rate: 1.0000e-04
# Epoch 76/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6744 - val_loss: 1.6755 - learning_rate: 1.0000e-04
# Epoch 77/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6696 - val_loss: 1.6706 - learning_rate: 1.0000e-04
# Epoch 78/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6647 - val_loss: 1.6657 - learning_rate: 1.0000e-04
# Epoch 79/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6599 - val_loss: 1.6609 - learning_rate: 1.0000e-04
# Epoch 80/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6551 - val_loss: 1.6561 - learning_rate: 1.0000e-04
# Epoch 81/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6503 - val_loss: 1.6513 - learning_rate: 1.0000e-04
# Epoch 82/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6455 - val_loss: 1.6466 - learning_rate: 1.0000e-04
# Epoch 83/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6408 - val_loss: 1.6418 - learning_rate: 1.0000e-04
# Epoch 84/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6361 - val_loss: 1.6371 - learning_rate: 1.0000e-04
# Epoch 85/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6314 - val_loss: 1.6324 - learning_rate: 1.0000e-04
# Epoch 86/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6268 - val_loss: 1.6278 - learning_rate: 1.0000e-04
# Epoch 87/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6221 - val_loss: 1.6231 - learning_rate: 1.0000e-04
# Epoch 88/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6175 - val_loss: 1.6185 - learning_rate: 1.0000e-04
# Epoch 89/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6129 - val_loss: 1.6139 - learning_rate: 1.0000e-04
# Epoch 90/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6083 - val_loss: 1.6093 - learning_rate: 1.0000e-04
# Epoch 91/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6038 - val_loss: 1.6048 - learning_rate: 1.0000e-04
# Epoch 92/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5993 - val_loss: 1.6003 - learning_rate: 1.0000e-04
# Epoch 93/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5948 - val_loss: 1.5958 - learning_rate: 1.0000e-04
# Epoch 94/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5903 - val_loss: 1.5913 - learning_rate: 1.0000e-04
# Epoch 95/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5858 - val_loss: 1.5868 - learning_rate: 1.0000e-04
# Epoch 96/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5814 - val_loss: 1.5824 - learning_rate: 1.0000e-04
# Epoch 97/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5770 - val_loss: 1.5780 - learning_rate: 1.0000e-04
# Epoch 98/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5726 - val_loss: 1.5736 - learning_rate: 1.0000e-04
# Epoch 99/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5682 - val_loss: 1.5692 - learning_rate: 1.0000e-04
# Epoch 100/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5639 - val_loss: 1.5648 - learning_rate: 1.0000e-04
# Epoch 101/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5595 - val_loss: 1.5605 - learning_rate: 1.0000e-04
# Epoch 102/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5552 - val_loss: 1.5562 - learning_rate: 1.0000e-04
# Epoch 103/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5509 - val_loss: 1.5519 - learning_rate: 1.0000e-04
# Epoch 104/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5467 - val_loss: 1.5476 - learning_rate: 1.0000e-04
# Epoch 105/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5424 - val_loss: 1.5434 - learning_rate: 1.0000e-04
# Epoch 106/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5382 - val_loss: 1.5391 - learning_rate: 1.0000e-04
# Epoch 107/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5340 - val_loss: 1.5349 - learning_rate: 1.0000e-04
# Epoch 108/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5298 - val_loss: 1.5307 - learning_rate: 1.0000e-04
# Epoch 109/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.5256 - val_loss: 1.5266 - learning_rate: 1.0000e-04
# Epoch 110/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5215 - val_loss: 1.5224 - learning_rate: 1.0000e-04
# Epoch 111/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5174 - val_loss: 1.5183 - learning_rate: 1.0000e-04
# Epoch 112/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5132 - val_loss: 1.5142 - learning_rate: 1.0000e-04
# Epoch 113/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.5092 - val_loss: 1.5101 - learning_rate: 1.0000e-04
# Epoch 114/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.5051 - val_loss: 1.5060 - learning_rate: 1.0000e-04
# Epoch 115/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.5010 - val_loss: 1.5020 - learning_rate: 1.0000e-04
# Epoch 116/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.4970 - val_loss: 1.4979 - learning_rate: 1.0000e-04
# Epoch 117/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.4930 - val_loss: 1.4939 - learning_rate: 1.0000e-04
# Epoch 118/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.4890 - val_loss: 1.4899 - learning_rate: 1.0000e-04
# Epoch 119/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.4850 - val_loss: 1.4859 - learning_rate: 1.0000e-04
# Epoch 120/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4810 - val_loss: 1.4820 - learning_rate: 1.0000e-04
# Epoch 121/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4771 - val_loss: 1.4780 - learning_rate: 1.0000e-04
# Epoch 122/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4732 - val_loss: 1.4741 - learning_rate: 1.0000e-04
# Epoch 123/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4693 - val_loss: 1.4702 - learning_rate: 1.0000e-04
# Epoch 124/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4654 - val_loss: 1.4663 - learning_rate: 1.0000e-04
# Epoch 125/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4615 - val_loss: 1.4624 - learning_rate: 1.0000e-04
# Epoch 126/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4577 - val_loss: 1.4586 - learning_rate: 1.0000e-04
# Epoch 127/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4538 - val_loss: 1.4547 - learning_rate: 1.0000e-04
# Epoch 128/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.4500 - val_loss: 1.4509 - learning_rate: 1.0000e-04
# Epoch 129/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4462 - val_loss: 1.4471 - learning_rate: 1.0000e-04
# Epoch 130/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4424 - val_loss: 1.4433 - learning_rate: 1.0000e-04
# Epoch 131/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4386 - val_loss: 1.4396 - learning_rate: 1.0000e-04
# Epoch 132/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4349 - val_loss: 1.4358 - learning_rate: 1.0000e-04
# Epoch 133/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4312 - val_loss: 1.4321 - learning_rate: 1.0000e-04
# Epoch 134/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4274 - val_loss: 1.4283 - learning_rate: 1.0000e-04
# Epoch 135/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4237 - val_loss: 1.4246 - learning_rate: 1.0000e-04
# Epoch 136/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4201 - val_loss: 1.4210 - learning_rate: 1.0000e-04
# Epoch 137/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4164 - val_loss: 1.4173 - learning_rate: 1.0000e-04
# Epoch 138/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4127 - val_loss: 1.4136 - learning_rate: 1.0000e-04
# Epoch 139/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4091 - val_loss: 1.4100 - learning_rate: 1.0000e-04
# Epoch 140/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4055 - val_loss: 1.4064 - learning_rate: 1.0000e-04
# Epoch 141/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4019 - val_loss: 1.4028 - learning_rate: 1.0000e-04
# Epoch 142/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3983 - val_loss: 1.3992 - learning_rate: 1.0000e-04
# Epoch 143/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3947 - val_loss: 1.3956 - learning_rate: 1.0000e-04
# Epoch 144/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3912 - val_loss: 1.3921 - learning_rate: 1.0000e-04
# Epoch 145/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3876 - val_loss: 1.3885 - learning_rate: 1.0000e-04
# Epoch 146/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3841 - val_loss: 1.3850 - learning_rate: 1.0000e-04
# Epoch 147/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3806 - val_loss: 1.3815 - learning_rate: 1.0000e-04
# Epoch 148/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3771 - val_loss: 1.3780 - learning_rate: 1.0000e-04
# Epoch 149/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3736 - val_loss: 1.3745 - learning_rate: 1.0000e-04
# Epoch 150/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3701 - val_loss: 1.3710 - learning_rate: 1.0000e-04
# Epoch 151/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3667 - val_loss: 1.3676 - learning_rate: 1.0000e-04
# Epoch 152/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3633 - val_loss: 1.3641 - learning_rate: 1.0000e-04
# Epoch 153/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3598 - val_loss: 1.3607 - learning_rate: 1.0000e-04
# Epoch 154/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3564 - val_loss: 1.3573 - learning_rate: 1.0000e-04
# Epoch 155/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3530 - val_loss: 1.3539 - learning_rate: 1.0000e-04
# Epoch 156/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3497 - val_loss: 1.3505 - learning_rate: 1.0000e-04
# Epoch 157/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3463 - val_loss: 1.3472 - learning_rate: 1.0000e-04
# Epoch 158/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3429 - val_loss: 1.3438 - learning_rate: 1.0000e-04
# Epoch 159/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3396 - val_loss: 1.3405 - learning_rate: 1.0000e-04
# Epoch 160/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3363 - val_loss: 1.3372 - learning_rate: 1.0000e-04
# Epoch 161/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3330 - val_loss: 1.3339 - learning_rate: 1.0000e-04
# Epoch 162/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3297 - val_loss: 1.3306 - learning_rate: 1.0000e-04
# Epoch 163/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3264 - val_loss: 1.3273 - learning_rate: 1.0000e-04
# Epoch 164/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3231 - val_loss: 1.3240 - learning_rate: 1.0000e-04
# Epoch 165/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3199 - val_loss: 1.3208 - learning_rate: 1.0000e-04
# Epoch 166/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3166 - val_loss: 1.3175 - learning_rate: 1.0000e-04
# Epoch 167/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3134 - val_loss: 1.3143 - learning_rate: 1.0000e-04
# Epoch 168/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3102 - val_loss: 1.3111 - learning_rate: 1.0000e-04
# Epoch 169/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3070 - val_loss: 1.3079 - learning_rate: 1.0000e-04
# Epoch 170/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3038 - val_loss: 1.3047 - learning_rate: 1.0000e-04
# Epoch 171/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3007 - val_loss: 1.3015 - learning_rate: 1.0000e-04
# Epoch 172/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2975 - val_loss: 1.2984 - learning_rate: 1.0000e-04
# Epoch 173/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2943 - val_loss: 1.2952 - learning_rate: 1.0000e-04
# Epoch 174/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2912 - val_loss: 1.2921 - learning_rate: 1.0000e-04
# Epoch 175/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2881 - val_loss: 1.2890 - learning_rate: 1.0000e-04
# Epoch 176/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2850 - val_loss: 1.2858 - learning_rate: 1.0000e-04
# Epoch 177/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2819 - val_loss: 1.2828 - learning_rate: 1.0000e-04
# Epoch 178/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2788 - val_loss: 1.2797 - learning_rate: 1.0000e-04
# Epoch 179/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2757 - val_loss: 1.2766 - learning_rate: 1.0000e-04
# Epoch 180/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2727 - val_loss: 1.2735 - learning_rate: 1.0000e-04
# Epoch 181/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2696 - val_loss: 1.2705 - learning_rate: 1.0000e-04
# Epoch 182/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2666 - val_loss: 1.2675 - learning_rate: 1.0000e-04
# Epoch 183/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2636 - val_loss: 1.2644 - learning_rate: 1.0000e-04
# Epoch 184/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2606 - val_loss: 1.2614 - learning_rate: 1.0000e-04
# Epoch 185/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2576 - val_loss: 1.2584 - learning_rate: 1.0000e-04
# Epoch 186/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2546 - val_loss: 1.2554 - learning_rate: 1.0000e-04
# Epoch 187/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2516 - val_loss: 1.2525 - learning_rate: 1.0000e-04
# Epoch 188/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2487 - val_loss: 1.2495 - learning_rate: 1.0000e-04
# Epoch 189/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2457 - val_loss: 1.2466 - learning_rate: 1.0000e-04
# Epoch 190/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2428 - val_loss: 1.2436 - learning_rate: 1.0000e-04
# Epoch 191/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2398 - val_loss: 1.2407 - learning_rate: 1.0000e-04
# Epoch 192/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2369 - val_loss: 1.2378 - learning_rate: 1.0000e-04
# Epoch 193/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2340 - val_loss: 1.2349 - learning_rate: 1.0000e-04
# Epoch 194/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2311 - val_loss: 1.2320 - learning_rate: 1.0000e-04
# Epoch 195/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2283 - val_loss: 1.2291 - learning_rate: 1.0000e-04
# Epoch 196/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.2254 - val_loss: 1.2262 - learning_rate: 1.0000e-04
# Epoch 197/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.2225 - val_loss: 1.2234 - learning_rate: 1.0000e-04
# Epoch 198/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2197 - val_loss: 1.2205 - learning_rate: 1.0000e-04
# Epoch 199/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.2168 - val_loss: 1.2177 - learning_rate: 1.0000e-04
# Epoch 200/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2140 - val_loss: 1.2149 - learning_rate: 1.0000e-04

# %%
# prompt: Could you show a heatmap of the values of the neuron's weights in the above model, named nn_model?

import seaborn as sns
import matplotlib.pyplot as plt

# Here, nn_model_shallow is the Keras (NNet) model
weights = nn_model_shallow.layers[1].get_weights()[0]  # Get weights from this layer (omitting the intercepts, which are in [1])
weights = np.transpose(weights)

# Create a heatmap of the weights
plt.figure(figsize=(10, 8))
sns.heatmap(weights, annot=False, cmap='viridis')
plt.title("Neuron Weights Heatmap of the Input Layer")
plt.xlabel("Input Features (6)")
plt.ylabel("Neurons from Inputs to Output")
plt.show()

# %% [markdown]
# And, let's see how the model does... using `shap`

# %%
def nn_predict_shallow(X):
    """Prediction function of the neural network (log scale)."""
    df = pd.DataFrame(X, columns=x)
    df_scaled = nn_preprocessor.transform(df)
    pred = nn_model_shallow.predict(df_scaled, verbose=0, batch_size=10_000).flatten()
    return np.log(pred)


nn_explainer = shap.KernelExplainer(nn_predict_shallow, data=X_bg)
shap_nn = nn_explainer.shap_values(X_explain, nsamples=30)

all_dep_plots(x, shap_nn, X_explain)
# Out:
# WARNING:shap:Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# #### Next, let's add a "hidden" layer to our network...
#
# Here, we add a middle, "hidden," layer to our network in line 14, below. Notice that
# + the value 7 is the number of neurons
# + the inputs from the initial layer are, in fact, the inputs to this middle layer
# + the variable z holds the outputs of this layer.
# + the output layer uses z as its input (and then estimates the goal, the number of claims from there)
#
# Additional layers are able to continue this pattern (one example is commented out on line 17):

# %%
#
# Let's add a second layer to our network:

import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
cb = [EarlyStopping(patience=20), ReduceLROnPlateau(patience=5)]  # "callbacks" for training (see below)

# Architecture: Adding Layers
inputs = keras.Input(shape=(len(x),))            # Here is the input layer

z = layers.Dense(7, activation="tanh")(inputs)   # Here is the new layer: 7 neurons, inputs are the input, and z is the output. Use "tanh"

# For more layers, you can continue using z.     # Here is a commented-out example:
# z = layers.Dense(3, activation="tanh"))(z)     # This is another layer: 3 neurons, z is the input, and z is the output

outputs = layers.Dense(1, activation="exponential")(z)   # Here, we convert the previous layer's results (z) into the overall output
nn_model_2layer = keras.Model(inputs=inputs, outputs=outputs)   # The final layer often uses a different activation function

nn_model_2layer.summary()

nn_model_2layer.compile(optimizer=Adam(learning_rate=1e-4), loss="Poisson")
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 6)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │              49 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               8 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 57 (228.00 B)
#  Trainable params: 57 (228.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.random.set_seed(4349)

history_2layer = nn_model_2layer.fit(
    x=X_train,
    y=train[y],
    epochs=200,
    batch_size=10_000,
    validation_split=0.1,
    callbacks=cb,
    verbose=1,         # consider running both values 0 (no printing) and 1 (printing)
)
# Out:
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 1.5806 - val_loss: 1.5695 - learning_rate: 1.0000e-04
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5656 - val_loss: 1.5547 - learning_rate: 1.0000e-04
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.5508 - val_loss: 1.5401 - learning_rate: 1.0000e-04
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5362 - val_loss: 1.5257 - learning_rate: 1.0000e-04
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5219 - val_loss: 1.5116 - learning_rate: 1.0000e-04
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.5078 - val_loss: 1.4977 - learning_rate: 1.0000e-04
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4939 - val_loss: 1.4840 - learning_rate: 1.0000e-04
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4803 - val_loss: 1.4706 - learning_rate: 1.0000e-04
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4669 - val_loss: 1.4574 - learning_rate: 1.0000e-04
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4537 - val_loss: 1.4444 - learning_rate: 1.0000e-04
# Epoch 11/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4408 - val_loss: 1.4317 - learning_rate: 1.0000e-04
# Epoch 12/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4280 - val_loss: 1.4191 - learning_rate: 1.0000e-04
# Epoch 13/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4155 - val_loss: 1.4068 - learning_rate: 1.0000e-04
# Epoch 14/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.4032 - val_loss: 1.3947 - learning_rate: 1.0000e-04
# Epoch 15/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3911 - val_loss: 1.3827 - learning_rate: 1.0000e-04
# Epoch 16/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3792 - val_loss: 1.3710 - learning_rate: 1.0000e-04
# Epoch 17/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3675 - val_loss: 1.3595 - learning_rate: 1.0000e-04
# Epoch 18/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.3559 - val_loss: 1.3481 - learning_rate: 1.0000e-04
# Epoch 19/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3446 - val_loss: 1.3369 - learning_rate: 1.0000e-04
# Epoch 20/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3334 - val_loss: 1.3259 - learning_rate: 1.0000e-04
# Epoch 21/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3225 - val_loss: 1.3151 - learning_rate: 1.0000e-04
# Epoch 22/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3117 - val_loss: 1.3044 - learning_rate: 1.0000e-04
# Epoch 23/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.3010 - val_loss: 1.2940 - learning_rate: 1.0000e-04
# Epoch 24/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.2905 - val_loss: 1.2836 - learning_rate: 1.0000e-04
# Epoch 25/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2802 - val_loss: 1.2735 - learning_rate: 1.0000e-04
# Epoch 26/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2701 - val_loss: 1.2635 - learning_rate: 1.0000e-04
# Epoch 27/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2601 - val_loss: 1.2536 - learning_rate: 1.0000e-04
# Epoch 28/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2502 - val_loss: 1.2439 - learning_rate: 1.0000e-04
# Epoch 29/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.2406 - val_loss: 1.2344 - learning_rate: 1.0000e-04
# Epoch 30/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2310 - val_loss: 1.2249 - learning_rate: 1.0000e-04
# Epoch 31/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2216 - val_loss: 1.2157 - learning_rate: 1.0000e-04
# Epoch 32/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.2124 - val_loss: 1.2065 - learning_rate: 1.0000e-04
# Epoch 33/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2032 - val_loss: 1.1975 - learning_rate: 1.0000e-04
# Epoch 34/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1942 - val_loss: 1.1887 - learning_rate: 1.0000e-04
# Epoch 35/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1854 - val_loss: 1.1799 - learning_rate: 1.0000e-04
# Epoch 36/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1767 - val_loss: 1.1713 - learning_rate: 1.0000e-04
# Epoch 37/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1681 - val_loss: 1.1629 - learning_rate: 1.0000e-04
# Epoch 38/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1596 - val_loss: 1.1545 - learning_rate: 1.0000e-04
# Epoch 39/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1513 - val_loss: 1.1463 - learning_rate: 1.0000e-04
# Epoch 40/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1430 - val_loss: 1.1381 - learning_rate: 1.0000e-04
# Epoch 41/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1349 - val_loss: 1.1301 - learning_rate: 1.0000e-04
# Epoch 42/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1269 - val_loss: 1.1222 - learning_rate: 1.0000e-04
# Epoch 43/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1190 - val_loss: 1.1145 - learning_rate: 1.0000e-04
# Epoch 44/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1113 - val_loss: 1.1068 - learning_rate: 1.0000e-04
# Epoch 45/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1036 - val_loss: 1.0992 - learning_rate: 1.0000e-04
# Epoch 46/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0961 - val_loss: 1.0918 - learning_rate: 1.0000e-04
# Epoch 47/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.0886 - val_loss: 1.0844 - learning_rate: 1.0000e-04
# Epoch 48/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0813 - val_loss: 1.0772 - learning_rate: 1.0000e-04
# Epoch 49/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0740 - val_loss: 1.0700 - learning_rate: 1.0000e-04
# Epoch 50/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0669 - val_loss: 1.0630 - learning_rate: 1.0000e-04
# Epoch 51/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0598 - val_loss: 1.0560 - learning_rate: 1.0000e-04
# Epoch 52/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0529 - val_loss: 1.0491 - learning_rate: 1.0000e-04
# Epoch 53/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0460 - val_loss: 1.0424 - learning_rate: 1.0000e-04
# Epoch 54/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0392 - val_loss: 1.0357 - learning_rate: 1.0000e-04
# Epoch 55/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0326 - val_loss: 1.0291 - learning_rate: 1.0000e-04
# Epoch 56/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0260 - val_loss: 1.0226 - learning_rate: 1.0000e-04
# Epoch 57/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0195 - val_loss: 1.0161 - learning_rate: 1.0000e-04
# Epoch 58/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0130 - val_loss: 1.0098 - learning_rate: 1.0000e-04
# Epoch 59/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0067 - val_loss: 1.0035 - learning_rate: 1.0000e-04
# Epoch 60/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0005 - val_loss: 0.9974 - learning_rate: 1.0000e-04
# Epoch 61/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9943 - val_loss: 0.9913 - learning_rate: 1.0000e-04
# Epoch 62/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9882 - val_loss: 0.9853 - learning_rate: 1.0000e-04
# Epoch 63/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9822 - val_loss: 0.9793 - learning_rate: 1.0000e-04
# Epoch 64/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.9762 - val_loss: 0.9735 - learning_rate: 1.0000e-04
# Epoch 65/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.9704 - val_loss: 0.9677 - learning_rate: 1.0000e-04
# Epoch 66/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.9646 - val_loss: 0.9619 - learning_rate: 1.0000e-04
# Epoch 67/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9589 - val_loss: 0.9563 - learning_rate: 1.0000e-04
# Epoch 68/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9532 - val_loss: 0.9507 - learning_rate: 1.0000e-04
# Epoch 69/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.9477 - val_loss: 0.9452 - learning_rate: 1.0000e-04
# Epoch 70/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.9422 - val_loss: 0.9398 - learning_rate: 1.0000e-04
# Epoch 71/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9367 - val_loss: 0.9344 - learning_rate: 1.0000e-04
# Epoch 72/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9314 - val_loss: 0.9291 - learning_rate: 1.0000e-04
# Epoch 73/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9261 - val_loss: 0.9239 - learning_rate: 1.0000e-04
# Epoch 74/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9208 - val_loss: 0.9187 - learning_rate: 1.0000e-04
# Epoch 75/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9156 - val_loss: 0.9136 - learning_rate: 1.0000e-04
# Epoch 76/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9105 - val_loss: 0.9085 - learning_rate: 1.0000e-04
# Epoch 77/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9055 - val_loss: 0.9035 - learning_rate: 1.0000e-04
# Epoch 78/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9005 - val_loss: 0.8986 - learning_rate: 1.0000e-04
# Epoch 79/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8955 - val_loss: 0.8937 - learning_rate: 1.0000e-04
# Epoch 80/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8907 - val_loss: 0.8889 - learning_rate: 1.0000e-04
# Epoch 81/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8859 - val_loss: 0.8841 - learning_rate: 1.0000e-04
# Epoch 82/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8811 - val_loss: 0.8794 - learning_rate: 1.0000e-04
# Epoch 83/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8764 - val_loss: 0.8748 - learning_rate: 1.0000e-04
# Epoch 84/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8717 - val_loss: 0.8702 - learning_rate: 1.0000e-04
# Epoch 85/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8671 - val_loss: 0.8656 - learning_rate: 1.0000e-04
# Epoch 86/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8626 - val_loss: 0.8611 - learning_rate: 1.0000e-04
# Epoch 87/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8581 - val_loss: 0.8567 - learning_rate: 1.0000e-04
# Epoch 88/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8537 - val_loss: 0.8523 - learning_rate: 1.0000e-04
# Epoch 89/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8493 - val_loss: 0.8479 - learning_rate: 1.0000e-04
# Epoch 90/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8449 - val_loss: 0.8436 - learning_rate: 1.0000e-04
# Epoch 91/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8406 - val_loss: 0.8394 - learning_rate: 1.0000e-04
# Epoch 92/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8364 - val_loss: 0.8352 - learning_rate: 1.0000e-04
# Epoch 93/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8322 - val_loss: 0.8310 - learning_rate: 1.0000e-04
# Epoch 94/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8280 - val_loss: 0.8269 - learning_rate: 1.0000e-04
# Epoch 95/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8239 - val_loss: 0.8229 - learning_rate: 1.0000e-04
# Epoch 96/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8199 - val_loss: 0.8189 - learning_rate: 1.0000e-04
# Epoch 97/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8158 - val_loss: 0.8149 - learning_rate: 1.0000e-04
# Epoch 98/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8119 - val_loss: 0.8110 - learning_rate: 1.0000e-04
# Epoch 99/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8079 - val_loss: 0.8071 - learning_rate: 1.0000e-04
# Epoch 100/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8041 - val_loss: 0.8032 - learning_rate: 1.0000e-04
# Epoch 101/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8002 - val_loss: 0.7994 - learning_rate: 1.0000e-04
# Epoch 102/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7964 - val_loss: 0.7956 - learning_rate: 1.0000e-04
# Epoch 103/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.7926 - val_loss: 0.7919 - learning_rate: 1.0000e-04
# Epoch 104/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7889 - val_loss: 0.7882 - learning_rate: 1.0000e-04
# Epoch 105/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7852 - val_loss: 0.7846 - learning_rate: 1.0000e-04
# Epoch 106/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7816 - val_loss: 0.7810 - learning_rate: 1.0000e-04
# Epoch 107/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.7780 - val_loss: 0.7774 - learning_rate: 1.0000e-04
# Epoch 108/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7744 - val_loss: 0.7739 - learning_rate: 1.0000e-04
# Epoch 109/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7709 - val_loss: 0.7704 - learning_rate: 1.0000e-04
# Epoch 110/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7674 - val_loss: 0.7669 - learning_rate: 1.0000e-04
# Epoch 111/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7639 - val_loss: 0.7635 - learning_rate: 1.0000e-04
# Epoch 112/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7605 - val_loss: 0.7601 - learning_rate: 1.0000e-04
# Epoch 113/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7571 - val_loss: 0.7567 - learning_rate: 1.0000e-04
# Epoch 114/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7537 - val_loss: 0.7534 - learning_rate: 1.0000e-04
# Epoch 115/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7504 - val_loss: 0.7501 - learning_rate: 1.0000e-04
# Epoch 116/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7471 - val_loss: 0.7468 - learning_rate: 1.0000e-04
# Epoch 117/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7438 - val_loss: 0.7436 - learning_rate: 1.0000e-04
# Epoch 118/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7406 - val_loss: 0.7404 - learning_rate: 1.0000e-04
# Epoch 119/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7374 - val_loss: 0.7373 - learning_rate: 1.0000e-04
# Epoch 120/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7342 - val_loss: 0.7341 - learning_rate: 1.0000e-04
# Epoch 121/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.7311 - val_loss: 0.7310 - learning_rate: 1.0000e-04
# Epoch 122/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7280 - val_loss: 0.7280 - learning_rate: 1.0000e-04
# Epoch 123/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7249 - val_loss: 0.7249 - learning_rate: 1.0000e-04
# Epoch 124/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7219 - val_loss: 0.7219 - learning_rate: 1.0000e-04
# Epoch 125/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7188 - val_loss: 0.7189 - learning_rate: 1.0000e-04
# Epoch 126/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7159 - val_loss: 0.7159 - learning_rate: 1.0000e-04
# Epoch 127/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.7129 - val_loss: 0.7130 - learning_rate: 1.0000e-04
# Epoch 128/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7100 - val_loss: 0.7101 - learning_rate: 1.0000e-04
# Epoch 129/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7071 - val_loss: 0.7072 - learning_rate: 1.0000e-04
# Epoch 130/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7042 - val_loss: 0.7044 - learning_rate: 1.0000e-04
# Epoch 131/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7013 - val_loss: 0.7016 - learning_rate: 1.0000e-04
# Epoch 132/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6985 - val_loss: 0.6988 - learning_rate: 1.0000e-04
# Epoch 133/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6957 - val_loss: 0.6960 - learning_rate: 1.0000e-04
# Epoch 134/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6929 - val_loss: 0.6933 - learning_rate: 1.0000e-04
# Epoch 135/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6902 - val_loss: 0.6905 - learning_rate: 1.0000e-04
# Epoch 136/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6875 - val_loss: 0.6878 - learning_rate: 1.0000e-04
# Epoch 137/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6848 - val_loss: 0.6852 - learning_rate: 1.0000e-04
# Epoch 138/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6821 - val_loss: 0.6825 - learning_rate: 1.0000e-04
# Epoch 139/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.6794 - val_loss: 0.6799 - learning_rate: 1.0000e-04
# Epoch 140/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6768 - val_loss: 0.6773 - learning_rate: 1.0000e-04
# Epoch 141/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.6742 - val_loss: 0.6747 - learning_rate: 1.0000e-04
# Epoch 142/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.6716 - val_loss: 0.6722 - learning_rate: 1.0000e-04
# Epoch 143/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6691 - val_loss: 0.6696 - learning_rate: 1.0000e-04
# Epoch 144/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6665 - val_loss: 0.6671 - learning_rate: 1.0000e-04
# Epoch 145/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6640 - val_loss: 0.6646 - learning_rate: 1.0000e-04
# Epoch 146/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6615 - val_loss: 0.6622 - learning_rate: 1.0000e-04
# Epoch 147/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6591 - val_loss: 0.6597 - learning_rate: 1.0000e-04
# Epoch 148/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6566 - val_loss: 0.6573 - learning_rate: 1.0000e-04
# Epoch 149/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6542 - val_loss: 0.6549 - learning_rate: 1.0000e-04
# Epoch 150/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6518 - val_loss: 0.6525 - learning_rate: 1.0000e-04
# Epoch 151/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6494 - val_loss: 0.6501 - learning_rate: 1.0000e-04
# Epoch 152/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6470 - val_loss: 0.6478 - learning_rate: 1.0000e-04
# Epoch 153/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6447 - val_loss: 0.6455 - learning_rate: 1.0000e-04
# Epoch 154/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6423 - val_loss: 0.6432 - learning_rate: 1.0000e-04
# Epoch 155/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6400 - val_loss: 0.6409 - learning_rate: 1.0000e-04
# Epoch 156/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6377 - val_loss: 0.6386 - learning_rate: 1.0000e-04
# Epoch 157/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6355 - val_loss: 0.6364 - learning_rate: 1.0000e-04
# Epoch 158/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6332 - val_loss: 0.6341 - learning_rate: 1.0000e-04
# Epoch 159/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6310 - val_loss: 0.6319 - learning_rate: 1.0000e-04
# Epoch 160/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6287 - val_loss: 0.6297 - learning_rate: 1.0000e-04
# Epoch 161/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6265 - val_loss: 0.6275 - learning_rate: 1.0000e-04
# Epoch 162/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6244 - val_loss: 0.6254 - learning_rate: 1.0000e-04
# Epoch 163/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6222 - val_loss: 0.6232 - learning_rate: 1.0000e-04
# Epoch 164/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6200 - val_loss: 0.6211 - learning_rate: 1.0000e-04
# Epoch 165/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6179 - val_loss: 0.6190 - learning_rate: 1.0000e-04
# Epoch 166/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6158 - val_loss: 0.6169 - learning_rate: 1.0000e-04
# Epoch 167/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6137 - val_loss: 0.6148 - learning_rate: 1.0000e-04
# Epoch 168/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6116 - val_loss: 0.6128 - learning_rate: 1.0000e-04
# Epoch 169/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6096 - val_loss: 0.6107 - learning_rate: 1.0000e-04
# Epoch 170/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6075 - val_loss: 0.6087 - learning_rate: 1.0000e-04
# Epoch 171/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6055 - val_loss: 0.6067 - learning_rate: 1.0000e-04
# Epoch 172/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6034 - val_loss: 0.6047 - learning_rate: 1.0000e-04
# Epoch 173/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6014 - val_loss: 0.6027 - learning_rate: 1.0000e-04
# Epoch 174/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5995 - val_loss: 0.6007 - learning_rate: 1.0000e-04
# Epoch 175/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5975 - val_loss: 0.5988 - learning_rate: 1.0000e-04
# Epoch 176/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5955 - val_loss: 0.5968 - learning_rate: 1.0000e-04
# Epoch 177/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5936 - val_loss: 0.5949 - learning_rate: 1.0000e-04
# Epoch 178/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5916 - val_loss: 0.5930 - learning_rate: 1.0000e-04
# Epoch 179/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5897 - val_loss: 0.5911 - learning_rate: 1.0000e-04
# Epoch 180/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5878 - val_loss: 0.5892 - learning_rate: 1.0000e-04
# Epoch 181/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5859 - val_loss: 0.5873 - learning_rate: 1.0000e-04
# Epoch 182/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5840 - val_loss: 0.5855 - learning_rate: 1.0000e-04
# Epoch 183/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5822 - val_loss: 0.5836 - learning_rate: 1.0000e-04
# Epoch 184/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5803 - val_loss: 0.5818 - learning_rate: 1.0000e-04
# Epoch 185/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5785 - val_loss: 0.5800 - learning_rate: 1.0000e-04
# Epoch 186/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5767 - val_loss: 0.5782 - learning_rate: 1.0000e-04
# Epoch 187/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5749 - val_loss: 0.5764 - learning_rate: 1.0000e-04
# Epoch 188/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5731 - val_loss: 0.5746 - learning_rate: 1.0000e-04
# Epoch 189/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5713 - val_loss: 0.5728 - learning_rate: 1.0000e-04
# Epoch 190/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5695 - val_loss: 0.5711 - learning_rate: 1.0000e-04
# Epoch 191/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5677 - val_loss: 0.5693 - learning_rate: 1.0000e-04
# Epoch 192/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5660 - val_loss: 0.5676 - learning_rate: 1.0000e-04
# Epoch 193/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5643 - val_loss: 0.5659 - learning_rate: 1.0000e-04
# Epoch 194/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5625 - val_loss: 0.5642 - learning_rate: 1.0000e-04
# Epoch 195/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5608 - val_loss: 0.5625 - learning_rate: 1.0000e-04
# Epoch 196/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5591 - val_loss: 0.5608 - learning_rate: 1.0000e-04
# Epoch 197/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5574 - val_loss: 0.5591 - learning_rate: 1.0000e-04
# Epoch 198/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5557 - val_loss: 0.5574 - learning_rate: 1.0000e-04
# Epoch 199/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5541 - val_loss: 0.5558 - learning_rate: 1.0000e-04
# Epoch 200/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5524 - val_loss: 0.5541 - learning_rate: 1.0000e-04

# %% [markdown]
# Let's see the neurons!
#
# At least as a heatmap of the weights:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

weights = nn_model_2layer.layers[1].get_weights()[0]  # Get weights from this layer (omit the intercept, which is [1])
weights = np.transpose(weights)

# Create a heatmap of the weights
plt.figure(figsize=(10, 8))
sns.heatmap(weights, annot=False, cmap='viridis')
plt.title("Neuron Weights Heatmap of the Input Layer")
plt.xlabel(f"Input Features (6)")
plt.ylabel("Neurons from Inputs to Layer1 (7)")
plt.show()

# %% [markdown]
# Next layer!

# %%
# Next layer
weights = nn_model_2layer.layers[2].get_weights()[0]  # Get weights from this layer (omit the intercept, which is [1])
weights = np.transpose(weights)

# Create a heatmap of the weights
plt.figure(figsize=(10, 8))
sns.heatmap(weights, annot=False, cmap='viridis')
plt.title("Neuron Weights Heatmap of Next Layer")
plt.xlabel("Neurons from Layer 1 (of 7)")
plt.ylabel("Neurons from Layer 1 to Layer 2 (of 1)")
plt.show()

# %% [markdown]
# Let's run `shap` to see if it does better...

# %%
def nn_predict_2layer(X):
    """Prediction function of the neural network (log scale)."""
    df = pd.DataFrame(X, columns=x)
    df_scaled = nn_preprocessor.transform(df)
    pred = nn_model_2layer.predict(df_scaled, verbose=0, batch_size=10_000).flatten()
    return np.log(pred)

nn_explainer = shap.KernelExplainer(nn_predict_2layer, data=X_bg)
shap_nn = nn_explainer.shap_values(X_explain, nsamples=30)

all_dep_plots(x, shap_nn, X_explain)   # create all feature-dependency plots
# Out:
# WARNING:shap:Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# Notice that these features do not _yet_ match the ones computed by the linear regression model we interpreted above.
#
# Thus far, the NNet is too primitive to be able to learn the real relationships among those dataset features.
#
# <font color="Coral">Your task</font> is to experiment below, in order to create a larger, more faithful NNet model.

# %% [markdown]
# ### The "Real" data model
#
# Usually datasets do not have a "real" model. At least not one that's known!
#
# This dataset, however, does have a _real_ underlying model! (It was inspired by the real data and then used to generate this dataset.)
#
# Here is the real model:

# %%
#
# The age is a much more complicated - non-linear - feature
def age_effect(age):
    x = (age - 66) / 60
    return 0.05 + x**8 + 0.4 * x**3 + 0.3 * x**2 + 0.06 * x

#
# here is the true model for this dataset:
def true_model(X):
    """Returns pd.Series of true expected frequencies."""
    df = pd.DataFrame(X, columns=x)  # Needed because SHAP turns df to np.array
    log_lambda = (
        0.15 * df.town
        + np.log(age_effect(df.driver_age))
        + (0.3 + 0.15 * df.town) * df.car_power / 100
        - 0.02 * df.car_age
    )
    return np.exp(log_lambda)

# %% [markdown]
# `shap` is not specific to NNets or linear regression models. It supports the interpretation of _any_ model, including the real one.
#
# Here is `shap`'s interpretation of this real model:

# %%
import shap

true_model_explainer = shap.KernelExplainer(lambda x: np.log(true_model(x)), data=X_bg)
shap_true = true_model_explainer.shap_values(X_explain, nsamples=30)

all_dep_plots(x, shap_true, X_explain)
# Out:
# WARNING:shap:Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# Things to notice:
# + the relationship between driver_age and the number of claims is "highly non-linear!"
# + there are also _two slopes_ for the linear car_power feature (so, officially, it's "not linear")
# + note, too, that car_weight has no impact on the output...
#   + Challenge question (not really a hw task): <br>  _**Why** do the modeling techniques above observe an impact of the car_weight feature?_

# %% [markdown]
# ## Final challenge: <font color="DodgerBlue">_Improve the NNet_</font>
#
# #### <font color="Coral"><b>Task Finale</b></font>
#
# From here, your task is to
# + create a more-capable neural network... with the goal of representing the actual data interactions ***better*** than the linear-regression model
# + consider using more layers (but not too many)
# + consider the "step-down" architecture, where
#   + the first post-input layer has the most neurons ("feature building")
#   + then, subsequent layers have fewer...
#   + tapering into the output layer
#
# You'll find that the NNet won't represent the "real" model perfectly, but it will
# + find its own features
# + represent the non-linear relationship (for driver_age)
# + and, for me, it could _start_ to represent the dependence of car_power on town
#
# <br>

# %% [markdown]
# ### Use the cells below to experiment with NNet building...
#
# Use the above `2layer` example as a template, and then - below -
# + experiment and create a new model -- and
# + show its `shap` interpretation... -- and
# + be sure to include a <font color="DodgerBlue">3-5 sentence <b>reflection</b> on</font> your experimentation (how long it took!) and how well the resulting NNet does at capturing the feature relationships of the actual, underlying "reality" ...
#
# <br>
#
# Worth remembering:  _We're **all** neural nets!_
# + It would seem we're always "keeping this in mind" 😀

# %%
#
# Neural nets are worthy of their own course, for sure...
#
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
cb = [EarlyStopping(patience=20), ReduceLROnPlateau(patience=5)]  # "callbacks" for training (see below)

# Architecture
inputs = keras.Input(shape=(len(x),))
# additional layers can be added here!
outputs = layers.Dense(1, activation="exponential")(inputs)
nn_model_shallow = keras.Model(inputs=inputs, outputs=outputs)

nn_model_shallow.summary()

# Calculate gradients
nn_model_shallow.compile(optimizer=Adam(learning_rate=1e-4), loss="Poisson")
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 6)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               7 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7 (28.00 B)
#  Trainable params: 7 (28.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
#
# Let's add a second layer to our network:

import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
cb = [EarlyStopping(patience=20), ReduceLROnPlateau(patience=5)]  # "callbacks" for training (see below)


# Architecture: Adding Layers
inputs = keras.Input(shape=(len(x),))  # Input layer

z = layers.Dense(10, activation="tanh")(inputs)
z = layers.Dense(8, activation="tanh")(z)
z = layers.Dense(6, activation="tanh")(z)
z = layers.Dense(4, activation="tanh")(z)


outputs = layers.Dense(1, activation="exponential")(z)  # Output layer with exponential activation
nn_model_4layer = keras.Model(inputs=inputs, outputs=outputs)

nn_model_4layer.summary()

nn_model_4layer.compile(optimizer=Adam(learning_rate=1e-4), loss="Poisson")
tf.random.set_seed(4349)

history_4layer = nn_model_4layer.fit(
    x=X_train,
    y=train[y],
    epochs=200,
    batch_size=10_000,
    validation_split=0.1,
    callbacks=cb,
    verbose=1,
)


def nn_predict_4layer(X):
    """Prediction function of the neural network (log scale)."""
    df = pd.DataFrame(X, columns=x)
    df_scaled = nn_preprocessor.transform(df)
    pred = nn_model_4layer.predict(df_scaled, verbose=0, batch_size=10_000).flatten()
    return np.log(pred)

nn_explainer = shap.KernelExplainer(nn_predict_4layer, data=X_bg)
shap_nn = nn_explainer.shap_values(X_explain, nsamples=30)

all_dep_plots(x, shap_nn, X_explain)
# Out:
# Model: "functional_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_9 (InputLayer)           │ (None, 6)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_32 (Dense)                     │ (None, 10)                  │              70 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_33 (Dense)                     │ (None, 8)                   │              88 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_34 (Dense)                     │ (None, 6)                   │              54 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_35 (Dense)                     │ (None, 4)                   │              28 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_36 (Dense)                     │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 245 (980.00 B)
#  Trainable params: 245 (980.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 73ms/step - loss: 0.9285 - val_loss: 0.9205 - learning_rate: 1.0000e-04
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.9191 - val_loss: 0.9112 - learning_rate: 1.0000e-04
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.9098 - val_loss: 0.9020 - learning_rate: 1.0000e-04
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.9006 - val_loss: 0.8928 - learning_rate: 1.0000e-04
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.8913 - val_loss: 0.8836 - learning_rate: 1.0000e-04
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.8821 - val_loss: 0.8744 - learning_rate: 1.0000e-04
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.8729 - val_loss: 0.8652 - learning_rate: 1.0000e-04
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.8637 - val_loss: 0.8560 - learning_rate: 1.0000e-04
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.8545 - val_loss: 0.8469 - learning_rate: 1.0000e-04
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8454 - val_loss: 0.8378 - learning_rate: 1.0000e-04
# Epoch 11/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8362 - val_loss: 0.8287 - learning_rate: 1.0000e-04
# Epoch 12/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8272 - val_loss: 0.8197 - learning_rate: 1.0000e-04
# Epoch 13/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8182 - val_loss: 0.8108 - learning_rate: 1.0000e-04
# Epoch 14/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8092 - val_loss: 0.8019 - learning_rate: 1.0000e-04
# Epoch 15/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8003 - val_loss: 0.7931 - learning_rate: 1.0000e-04
# Epoch 16/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.7915 - val_loss: 0.7844 - learning_rate: 1.0000e-04
# Epoch 17/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.7828 - val_loss: 0.7758 - learning_rate: 1.0000e-04
# Epoch 18/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.7742 - val_loss: 0.7673 - learning_rate: 1.0000e-04
# Epoch 19/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.7657 - val_loss: 0.7590 - learning_rate: 1.0000e-04
# Epoch 20/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.7573 - val_loss: 0.7507 - learning_rate: 1.0000e-04
# Epoch 21/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7491 - val_loss: 0.7426 - learning_rate: 1.0000e-04
# Epoch 22/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7409 - val_loss: 0.7345 - learning_rate: 1.0000e-04
# Epoch 23/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.7329 - val_loss: 0.7267 - learning_rate: 1.0000e-04
# Epoch 24/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.7250 - val_loss: 0.7189 - learning_rate: 1.0000e-04
# Epoch 25/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.7173 - val_loss: 0.7113 - learning_rate: 1.0000e-04
# Epoch 26/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.7097 - val_loss: 0.7039 - learning_rate: 1.0000e-04
# Epoch 27/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.7022 - val_loss: 0.6965 - learning_rate: 1.0000e-04
# Epoch 28/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.6949 - val_loss: 0.6894 - learning_rate: 1.0000e-04
# Epoch 29/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.6877 - val_loss: 0.6823 - learning_rate: 1.0000e-04
# Epoch 30/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6807 - val_loss: 0.6754 - learning_rate: 1.0000e-04
# Epoch 31/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.6738 - val_loss: 0.6687 - learning_rate: 1.0000e-04
# Epoch 32/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.6670 - val_loss: 0.6621 - learning_rate: 1.0000e-04
# Epoch 33/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.6604 - val_loss: 0.6556 - learning_rate: 1.0000e-04
# Epoch 34/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6539 - val_loss: 0.6493 - learning_rate: 1.0000e-04
# Epoch 35/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6476 - val_loss: 0.6431 - learning_rate: 1.0000e-04
# Epoch 36/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6414 - val_loss: 0.6371 - learning_rate: 1.0000e-04
# Epoch 37/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6354 - val_loss: 0.6312 - learning_rate: 1.0000e-04
# Epoch 38/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6295 - val_loss: 0.6254 - learning_rate: 1.0000e-04
# Epoch 39/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6237 - val_loss: 0.6198 - learning_rate: 1.0000e-04
# Epoch 40/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6180 - val_loss: 0.6143 - learning_rate: 1.0000e-04
# Epoch 41/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6125 - val_loss: 0.6089 - learning_rate: 1.0000e-04
# Epoch 42/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6071 - val_loss: 0.6036 - learning_rate: 1.0000e-04
# Epoch 43/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6018 - val_loss: 0.5985 - learning_rate: 1.0000e-04
# Epoch 44/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5967 - val_loss: 0.5935 - learning_rate: 1.0000e-04
# Epoch 45/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5916 - val_loss: 0.5886 - learning_rate: 1.0000e-04
# Epoch 46/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5867 - val_loss: 0.5838 - learning_rate: 1.0000e-04
# Epoch 47/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5819 - val_loss: 0.5791 - learning_rate: 1.0000e-04
# Epoch 48/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5772 - val_loss: 0.5745 - learning_rate: 1.0000e-04
# Epoch 49/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5726 - val_loss: 0.5700 - learning_rate: 1.0000e-04
# Epoch 50/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5681 - val_loss: 0.5657 - learning_rate: 1.0000e-04
# Epoch 51/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5637 - val_loss: 0.5614 - learning_rate: 1.0000e-04
# Epoch 52/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5594 - val_loss: 0.5572 - learning_rate: 1.0000e-04
# Epoch 53/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5552 - val_loss: 0.5531 - learning_rate: 1.0000e-04
# Epoch 54/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5511 - val_loss: 0.5491 - learning_rate: 1.0000e-04
# Epoch 55/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5471 - val_loss: 0.5452 - learning_rate: 1.0000e-04
# Epoch 56/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5431 - val_loss: 0.5414 - learning_rate: 1.0000e-04
# Epoch 57/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5393 - val_loss: 0.5377 - learning_rate: 1.0000e-04
# Epoch 58/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5355 - val_loss: 0.5340 - learning_rate: 1.0000e-04
# Epoch 59/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5319 - val_loss: 0.5304 - learning_rate: 1.0000e-04
# Epoch 60/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5283 - val_loss: 0.5269 - learning_rate: 1.0000e-04
# Epoch 61/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5247 - val_loss: 0.5235 - learning_rate: 1.0000e-04
# Epoch 62/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5213 - val_loss: 0.5202 - learning_rate: 1.0000e-04
# Epoch 63/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5179 - val_loss: 0.5169 - learning_rate: 1.0000e-04
# Epoch 64/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5146 - val_loss: 0.5137 - learning_rate: 1.0000e-04
# Epoch 65/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5114 - val_loss: 0.5105 - learning_rate: 1.0000e-04
# Epoch 66/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5082 - val_loss: 0.5074 - learning_rate: 1.0000e-04
# Epoch 67/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5051 - val_loss: 0.5044 - learning_rate: 1.0000e-04
# Epoch 68/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5020 - val_loss: 0.5015 - learning_rate: 1.0000e-04
# Epoch 69/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4991 - val_loss: 0.4986 - learning_rate: 1.0000e-04
# Epoch 70/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4961 - val_loss: 0.4957 - learning_rate: 1.0000e-04
# Epoch 71/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4933 - val_loss: 0.4929 - learning_rate: 1.0000e-04
# Epoch 72/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4904 - val_loss: 0.4902 - learning_rate: 1.0000e-04
# Epoch 73/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4877 - val_loss: 0.4875 - learning_rate: 1.0000e-04
# Epoch 74/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4850 - val_loss: 0.4849 - learning_rate: 1.0000e-04
# Epoch 75/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4823 - val_loss: 0.4823 - learning_rate: 1.0000e-04
# Epoch 76/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4797 - val_loss: 0.4798 - learning_rate: 1.0000e-04
# Epoch 77/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4772 - val_loss: 0.4773 - learning_rate: 1.0000e-04
# Epoch 78/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4746 - val_loss: 0.4749 - learning_rate: 1.0000e-04
# Epoch 79/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4722 - val_loss: 0.4725 - learning_rate: 1.0000e-04
# Epoch 80/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4698 - val_loss: 0.4701 - learning_rate: 1.0000e-04
# Epoch 81/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4674 - val_loss: 0.4678 - learning_rate: 1.0000e-04
# Epoch 82/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4650 - val_loss: 0.4655 - learning_rate: 1.0000e-04
# Epoch 83/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4627 - val_loss: 0.4633 - learning_rate: 1.0000e-04
# Epoch 84/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.4605 - val_loss: 0.4611 - learning_rate: 1.0000e-04
# Epoch 85/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4583 - val_loss: 0.4590 - learning_rate: 1.0000e-04
# Epoch 86/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.4561 - val_loss: 0.4568 - learning_rate: 1.0000e-04
# Epoch 87/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4539 - val_loss: 0.4548 - learning_rate: 1.0000e-04
# Epoch 88/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4518 - val_loss: 0.4527 - learning_rate: 1.0000e-04
# Epoch 89/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4498 - val_loss: 0.4507 - learning_rate: 1.0000e-04
# Epoch 90/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4477 - val_loss: 0.4487 - learning_rate: 1.0000e-04
# Epoch 91/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4457 - val_loss: 0.4468 - learning_rate: 1.0000e-04
# Epoch 92/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4437 - val_loss: 0.4448 - learning_rate: 1.0000e-04
# Epoch 93/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4418 - val_loss: 0.4429 - learning_rate: 1.0000e-04
# Epoch 94/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4398 - val_loss: 0.4411 - learning_rate: 1.0000e-04
# Epoch 95/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4380 - val_loss: 0.4393 - learning_rate: 1.0000e-04
# Epoch 96/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4361 - val_loss: 0.4375 - learning_rate: 1.0000e-04
# Epoch 97/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4343 - val_loss: 0.4357 - learning_rate: 1.0000e-04
# Epoch 98/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4325 - val_loss: 0.4339 - learning_rate: 1.0000e-04
# Epoch 99/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4307 - val_loss: 0.4322 - learning_rate: 1.0000e-04
# Epoch 100/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4289 - val_loss: 0.4305 - learning_rate: 1.0000e-04
# Epoch 101/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4272 - val_loss: 0.4288 - learning_rate: 1.0000e-04
# Epoch 102/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4255 - val_loss: 0.4272 - learning_rate: 1.0000e-04
# Epoch 103/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.4238 - val_loss: 0.4255 - learning_rate: 1.0000e-04
# Epoch 104/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4221 - val_loss: 0.4239 - learning_rate: 1.0000e-04
# Epoch 105/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4205 - val_loss: 0.4224 - learning_rate: 1.0000e-04
# Epoch 106/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4189 - val_loss: 0.4208 - learning_rate: 1.0000e-04
# Epoch 107/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4173 - val_loss: 0.4193 - learning_rate: 1.0000e-04
# Epoch 108/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4157 - val_loss: 0.4177 - learning_rate: 1.0000e-04
# Epoch 109/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4142 - val_loss: 0.4163 - learning_rate: 1.0000e-04
# Epoch 110/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4127 - val_loss: 0.4148 - learning_rate: 1.0000e-04
# Epoch 111/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4112 - val_loss: 0.4133 - learning_rate: 1.0000e-04
# Epoch 112/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4097 - val_loss: 0.4119 - learning_rate: 1.0000e-04
# Epoch 113/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4082 - val_loss: 0.4105 - learning_rate: 1.0000e-04
# Epoch 114/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.4068 - val_loss: 0.4091 - learning_rate: 1.0000e-04
# Epoch 115/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4054 - val_loss: 0.4077 - learning_rate: 1.0000e-04
# Epoch 116/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4040 - val_loss: 0.4064 - learning_rate: 1.0000e-04
# Epoch 117/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4026 - val_loss: 0.4050 - learning_rate: 1.0000e-04
# Epoch 118/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.4012 - val_loss: 0.4037 - learning_rate: 1.0000e-04
# Epoch 119/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3999 - val_loss: 0.4024 - learning_rate: 1.0000e-04
# Epoch 120/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3986 - val_loss: 0.4011 - learning_rate: 1.0000e-04
# Epoch 121/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3973 - val_loss: 0.3999 - learning_rate: 1.0000e-04
# Epoch 122/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3960 - val_loss: 0.3986 - learning_rate: 1.0000e-04
# Epoch 123/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3947 - val_loss: 0.3974 - learning_rate: 1.0000e-04
# Epoch 124/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3934 - val_loss: 0.3962 - learning_rate: 1.0000e-04
# Epoch 125/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3922 - val_loss: 0.3950 - learning_rate: 1.0000e-04
# Epoch 126/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3910 - val_loss: 0.3939 - learning_rate: 1.0000e-04
# Epoch 127/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3898 - val_loss: 0.3927 - learning_rate: 1.0000e-04
# Epoch 128/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3886 - val_loss: 0.3916 - learning_rate: 1.0000e-04
# Epoch 129/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3874 - val_loss: 0.3904 - learning_rate: 1.0000e-04
# Epoch 130/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3863 - val_loss: 0.3893 - learning_rate: 1.0000e-04
# Epoch 131/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3851 - val_loss: 0.3882 - learning_rate: 1.0000e-04
# Epoch 132/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3840 - val_loss: 0.3872 - learning_rate: 1.0000e-04
# Epoch 133/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.3829 - val_loss: 0.3861 - learning_rate: 1.0000e-04
# Epoch 134/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3818 - val_loss: 0.3851 - learning_rate: 1.0000e-04
# Epoch 135/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3808 - val_loss: 0.3840 - learning_rate: 1.0000e-04
# Epoch 136/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3797 - val_loss: 0.3830 - learning_rate: 1.0000e-04
# Epoch 137/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3787 - val_loss: 0.3820 - learning_rate: 1.0000e-04
# Epoch 138/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3776 - val_loss: 0.3810 - learning_rate: 1.0000e-04
# Epoch 139/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3766 - val_loss: 0.3801 - learning_rate: 1.0000e-04
# Epoch 140/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3756 - val_loss: 0.3791 - learning_rate: 1.0000e-04
# Epoch 141/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3747 - val_loss: 0.3782 - learning_rate: 1.0000e-04
# Epoch 142/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3737 - val_loss: 0.3772 - learning_rate: 1.0000e-04
# Epoch 143/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3727 - val_loss: 0.3763 - learning_rate: 1.0000e-04
# Epoch 144/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3718 - val_loss: 0.3754 - learning_rate: 1.0000e-04
# Epoch 145/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3709 - val_loss: 0.3745 - learning_rate: 1.0000e-04
# Epoch 146/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3700 - val_loss: 0.3737 - learning_rate: 1.0000e-04
# Epoch 147/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3691 - val_loss: 0.3728 - learning_rate: 1.0000e-04
# Epoch 148/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3682 - val_loss: 0.3720 - learning_rate: 1.0000e-04
# Epoch 149/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3673 - val_loss: 0.3711 - learning_rate: 1.0000e-04
# Epoch 150/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3664 - val_loss: 0.3703 - learning_rate: 1.0000e-04
# Epoch 151/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3656 - val_loss: 0.3695 - learning_rate: 1.0000e-04
# Epoch 152/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3648 - val_loss: 0.3687 - learning_rate: 1.0000e-04
# Epoch 153/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3639 - val_loss: 0.3679 - learning_rate: 1.0000e-04
# Epoch 154/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3631 - val_loss: 0.3671 - learning_rate: 1.0000e-04
# Epoch 155/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3623 - val_loss: 0.3664 - learning_rate: 1.0000e-04
# Epoch 156/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3615 - val_loss: 0.3656 - learning_rate: 1.0000e-04
# Epoch 157/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3608 - val_loss: 0.3649 - learning_rate: 1.0000e-04
# Epoch 158/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3600 - val_loss: 0.3642 - learning_rate: 1.0000e-04
# Epoch 159/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3593 - val_loss: 0.3634 - learning_rate: 1.0000e-04
# Epoch 160/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3585 - val_loss: 0.3627 - learning_rate: 1.0000e-04
# Epoch 161/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3578 - val_loss: 0.3620 - learning_rate: 1.0000e-04
# Epoch 162/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3571 - val_loss: 0.3614 - learning_rate: 1.0000e-04
# Epoch 163/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3564 - val_loss: 0.3607 - learning_rate: 1.0000e-04
# Epoch 164/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3557 - val_loss: 0.3600 - learning_rate: 1.0000e-04
# Epoch 165/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3550 - val_loss: 0.3594 - learning_rate: 1.0000e-04
# Epoch 166/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3543 - val_loss: 0.3587 - learning_rate: 1.0000e-04
# Epoch 167/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3536 - val_loss: 0.3581 - learning_rate: 1.0000e-04
# Epoch 168/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3530 - val_loss: 0.3575 - learning_rate: 1.0000e-04
# Epoch 169/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3523 - val_loss: 0.3568 - learning_rate: 1.0000e-04
# Epoch 170/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3517 - val_loss: 0.3562 - learning_rate: 1.0000e-04
# Epoch 171/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3511 - val_loss: 0.3556 - learning_rate: 1.0000e-04
# Epoch 172/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3504 - val_loss: 0.3551 - learning_rate: 1.0000e-04
# Epoch 173/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3498 - val_loss: 0.3545 - learning_rate: 1.0000e-04
# Epoch 174/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3492 - val_loss: 0.3539 - learning_rate: 1.0000e-04
# Epoch 175/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3486 - val_loss: 0.3533 - learning_rate: 1.0000e-04
# Epoch 176/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3481 - val_loss: 0.3528 - learning_rate: 1.0000e-04
# Epoch 177/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3475 - val_loss: 0.3522 - learning_rate: 1.0000e-04
# Epoch 178/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3469 - val_loss: 0.3517 - learning_rate: 1.0000e-04
# Epoch 179/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3464 - val_loss: 0.3512 - learning_rate: 1.0000e-04
# Epoch 180/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3458 - val_loss: 0.3506 - learning_rate: 1.0000e-04
# Epoch 181/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3453 - val_loss: 0.3501 - learning_rate: 1.0000e-04
# Epoch 182/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3447 - val_loss: 0.3496 - learning_rate: 1.0000e-04
# Epoch 183/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3442 - val_loss: 0.3491 - learning_rate: 1.0000e-04
# Epoch 184/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3437 - val_loss: 0.3486 - learning_rate: 1.0000e-04
# Epoch 185/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3432 - val_loss: 0.3481 - learning_rate: 1.0000e-04
# Epoch 186/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3427 - val_loss: 0.3477 - learning_rate: 1.0000e-04
# Epoch 187/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3422 - val_loss: 0.3472 - learning_rate: 1.0000e-04
# Epoch 188/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3417 - val_loss: 0.3467 - learning_rate: 1.0000e-04
# Epoch 189/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3412 - val_loss: 0.3463 - learning_rate: 1.0000e-04
# Epoch 190/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3407 - val_loss: 0.3458 - learning_rate: 1.0000e-04
# Epoch 191/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3402 - val_loss: 0.3454 - learning_rate: 1.0000e-04
# Epoch 192/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3398 - val_loss: 0.3449 - learning_rate: 1.0000e-04
# Epoch 193/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3393 - val_loss: 0.3445 - learning_rate: 1.0000e-04
# Epoch 194/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3389 - val_loss: 0.3441 - learning_rate: 1.0000e-04
# Epoch 195/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3384 - val_loss: 0.3437 - learning_rate: 1.0000e-04
# Epoch 196/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3380 - val_loss: 0.3432 - learning_rate: 1.0000e-04
# Epoch 197/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3376 - val_loss: 0.3428 - learning_rate: 1.0000e-04
# Epoch 198/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3371 - val_loss: 0.3424 - learning_rate: 1.0000e-04
# Epoch 199/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3367 - val_loss: 0.3420 - learning_rate: 1.0000e-04
# Epoch 200/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3363 - val_loss: 0.3416 - learning_rate: 1.0000e-04
# WARNING:shap:Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]
