# %% [markdown]
# # [REDACTED]near Models and Neural Nets Lab (Econ 176 '25)
#
# This lab will guide you through a _modeling_ task, inspired by the I&RE module:
# + it's based on a widely-studied French third-party-liability dataset [here on Kaggle](https://www.kaggle.com/datasets/floser/french-motor-claims-datasets-fremtpl2freq)
# + this variation has seven features and is available from [OpenML](https://openml.org/). (It's also widely studied: Cited below.)
# + of the seven features, six are used as predictive features and one is the target (to be predicted from the other six)
# + the target (to be predicted) is the _number of claims filed_ &nbsp; ``claim_nb`` by an individual. We'll call these _claims_ or _incidents_.
# + the features are
#   + the ``year`` &nbsp;&nbsp; (there are only years 2018 and 2019)
#   + whether the driver lives in a ``town`` <font size="-1">``town == 1.0``</font> or in a more rural area <font size="-1">``town == 0.0``</font>
#   + the _driver's_ age (in years) &nbsp;&nbsp; ``driver_age``
#   + the car's _weight_ (in kg) &nbsp;&nbsp; ``car_weight``
#   + the car's engine _power_ (in hp) &nbsp;&nbsp; ``car_power``
#   + the _car's_ age (in years) &nbsp;&nbsp; ``car_age``
#
# <br>
#
# You'll model the
# The notebook will guide you through
# + loading the data and inspecting it, a bit
# + modeling the data with linear models (linear regression)

# %% [markdown]
# ## Loading and inspecting data
#
# &nbsp;&nbsp; <font color="Coral">there are two tasks here...</font>

# %%
# some of the libraries have warnings we want to ignore...
import warnings
warnings.filterwarnings("ignore")

# AI/ML libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_openml

# %matplotlib inline

# %% [markdown]
# These two cells grab and extract the data - one millon rows and seven features - from OpenML:

# %%
# Fetch the insurance-claim dataset from the OpenML repository  (an API call! :)
all = fetch_openml(data_id=45106, as_frame=True)

# %%
# Extract the pieces of the API result from the OpenML API call
df_all = all.data
df_all["claim_nb"] = all.target

print("Shape of full data:", df_all.shape)
df_all.head(15)    # print the first five rows of data
# Out:
# Shape of full data: (1000000, 7)
#       year  town  driver_age  car_weight  car_power  car_age  claim_nb
# 0   2018.0   1.0        51.0      1760.0      173.0      3.0       0.0
# 1   2019.0   1.0        41.0      1760.0      248.0      2.0       0.0
# 2   2018.0   1.0        25.0      1240.0      111.0      2.0       0.0
# 3   2019.0   0.0        40.0      1010.0       83.0      9.0       0.0
# 4   2018.0   0.0        43.0      2180.0      169.0      5.0       0.0
# 5   2018.0   1.0        45.0      1170.0      149.0      1.0       1.0
# 6   2019.0   0.0        72.0      1040.0       60.0      2.0       0.0
# 7   2018.0  -0.0        60.0      1060.0       66.0      2.0       0.0
# 8   2018.0   1.0        31.0      1400.0      118.0      0.0       0.0
# 9   2018.0   1.0        19.0      1310.0       78.0      0.0       0.0
# 10  2018.0   1.0        76.0      1140.0       89.0      4.0       0.0
# 11  2019.0   1.0        49.0      1060.0      106.0      7.0       0.0
# 12  2018.0   0.0        65.0      1670.0      173.0      1.0       0.0
# 13  2018.0   1.0        33.0      1010.0       97.0      6.0       0.0
# 14  2018.0   0.0        31.0      1490.0      146.0      1.0       0.0

# %% [markdown]
# Here are the brief descriptions of each of the features:
# + the first six are the features we will use to _make_ predictions
#   + the ``year`` &nbsp;&nbsp; (there are only years 2018 and 2019)
#   + whether the driver lives in a ``town`` <font size="-1">``town == 1.0``</font> or in a more rural area <font size="-1">``town == 0.0``</font>
#   + the _driver's_ age (in years) &nbsp;&nbsp; ``driver_age``
#   + the car's _weight_ (in kg) &nbsp;&nbsp; ``car_weight``
#   + the car's engine _power_ (in hp) &nbsp;&nbsp; ``car_power``
#   + the _car's_ age (in years) &nbsp;&nbsp; ``car_age``
# + the seventh <b><tt>claim_nb</tt></b>, the number of claims files during that year, is the target to _be predicted_

# %%
df_all.describe()
# Out:
#                  year            town      driver_age      car_weight  \
# count  1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean      2018.550270        0.600130       45.998782     1308.266530
# std          0.497467        0.489872       13.997827      285.505998
# min       2018.000000        0.000000       18.000000      950.000000
# 25%       2018.000000        0.000000       35.000000     1090.000000
# 50%       2019.000000        1.000000       45.000000     1240.000000
# 75%       2019.000000        1.000000       56.000000     1460.000000
# max       2019.000000        1.000000       88.000000     3120.000000
#
#             car_power         car_age        claim_nb
# count  1000000.000000  1000000.000000  1000000.000000
# mean       124.981766        4.156266        0.089334
# std         49.133293        3.545284        0.300652
# min         50.000000        0.000000        0.000000
# 25%         86.000000        1.000000        0.000000
# 50%        116.000000        3.000000        0.000000
# 75%        156.000000        6.000000        0.000000
# max        341.000000       23.000000        4.000000

# %% [markdown]
# #### <font color="Coral"><b>Task 1</b></font>
#
# With full encouragement to use the built-in Colab AI -- or another of your choice, create five specific visu[REDACTED]zations and an additional one:
# + create a histogram of all the drivers' ages, and
# + a histogram of all the the cars' ages, and
# + a histogram of the claim numbers, `claim_nb`
# + create a scatter plot of how the car's age varies with the driver's age
# + create a scatter plot of how the `claim_nb` varies with the driver's age
# + <font color="Coral"><b>also</b></font>, create one more - different - scatter plot of your choice, using this data
#
# <br>
#
# <font color="DodgerBlue">Below for task 2, write a short reflection</font> on the results of these data-visu[REDACTED]zations. One sentence on what you see in each is perfect.  <br> <font size="-1">(There's another cell below reminding you of this!)</font>

# %%
#
# It's easiest to make additional code cells...
#

# %%
# Generating Histogram of Driver Age

plt.hist(df_all['driver_age'])
plt.xlabel('Driver Age')
plt.ylabel('Frequency')
plt.title('Histogram of Driver Ages')
plt.show()

# %%
# Histogram of Car Ages
plt.hist(df_all['car_age'])
plt.xlabel('Car Age')
plt.ylabel('Frequency')
plt.title('Histogram of Car Ages')
plt.show()

# %%
# a histogram of the claim numbers
plt.hist(df_all['claim_nb'])
plt.xlabel('Claim Number')
plt.ylabel('Frequency')
plt.title('Histogram of Claim Numbers')
plt.show()

# %%
# create a scatter plot of how the car's age varies with the driver's age
plt.scatter(df_all['driver_age'], df_all['car_age'])
plt.xlabel('Driver Age')
plt.ylabel('Car Age')
plt.title('Scatter Plot of Driver vs. Car Age')
plt.show()

# %%
# create a scatter plot of how the claim_nb varies with the driver's age
plt.scatter(df_all['driver_age'], df_all['claim_nb'])
plt.xlabel('Driver Age')
plt.ylabel('Claim Number')
plt.title('Scatter Plot of Driver vs. Claim Number')
plt.show()

# %%
# plot of my choice: scatter plot of car weight and car power
plt.scatter(df_all['car_weight'], df_all['car_power'])
plt.xlabel('Car Weight')
plt.ylabel('Car Power')
plt.title('Scatter Plot of Car Weight vs. Car Power')
plt.show()

# %% [markdown]
# #### <font color="Coral"><b>Task 2</b></font>
#
# <font color="DodgerBlue">Here, write a short reflection</font> -- a sentence or two for each of these is wonderful -- that describes the data-trends you see in the visu[REDACTED]zations above.
#
# As a reminder, they were
# + histograms for the drivers' ages and the cars' ages and the claim numbers, `claim_nb`
# + a scatter plot of how the car's age varies with the driver's age
# + a scatter plot of how the `claim_nb` varies with the driver's age
# + <font color="Coral"><b>and</b></font>, one other - different - scatter plot that visu[REDACTED]zes some of this data
#
# <br>
# <hr>
# <br>
#
# Feel free to use a new cell or the space below:
#
#
#
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# Short Reflection
#
# 1. The histogram of drivers ages appeared to right skewed, with the greatest number of drivers in the 40s age group. The overall range of ages is from 20 to almost 90 years old.
# 2. The histogram of car's ages is heavily right skewed. Most are only less than 5 years old.
# 3. The histogram of claims numbers reveals most people never file one (0), some only file 1, and barely anyone files for 2-2.5. No one files more claims than this.
# 4. There is no discernible pattern between car age and driver age
# 5. There is no discrernible pattern between driver age and claim_n
# 6. There seems to be a positive correlation between car weight and car power although there is a big spread

# %% [markdown]
# ## Modeling
#
# You will build two models for the <b><tt>claim_nb</tt></b> target:
# + a **linear-regression** model &nbsp;&nbsp; <font size="-2">since the target is a "number of occurrences" over a span of time, we use a _Poisson_ model</font>
# + a **neural-network** model &nbsp;&nbsp;  <font size="-2">of the same sort</font>
#
# You'll experiment with
# + interpreting the models
# + then, building some "deeper" neural networks
# + seeing how the two modeling approaches differ in the relationships they can express

# %% [markdown]
# ### Part 1: &nbsp;&nbsp; Data splitting
#
# The dataset has a million rows.
# + For speed of training, we will use only 100,000 of them.
# + At the end, you'll try changing at least three model parameters. This is one of those options! 😃

# %%
# Let's make sure everything runs first... using only 100,000 rows (instead of 1,000,000)

df_all = df_all.sample(frac=1.0, random_state=42)  # This shuffles the 1,000,000-row dataset

NUMROWS = 100000
df = df_all.iloc[0:NUMROWS,:].copy()    # This uses only the first 100,000 rows (or NUMROWS rows) for speed...

# %%
# We split into 90% training data and 10% testing data

from sklearn.model_selection import train_test_split

train, test = train_test_split(df, test_size=0.1, random_state=30)
print("Shape of training data:", train.shape)
print("Shape of test data:", test.shape)
# Out:
# Shape of training data: (90000, 7)
# Shape of test data: (10000, 7)

# %%
# Define target name (y) and feature names (x)
y, x = df.columns[-1], list(df.columns[:-1])

print("The response name:", y)
print("The feature names:", x)
# Out:
# The response name: claim_nb
# The feature names: ['year', 'town', 'driver_age', 'car_weight', 'car_power', 'car_age']

# %% [markdown]
# ### Part 2: &nbsp; A (Gener[REDACTED]zed) [REDACTED]near Model (GLM)
#
# Here, we build a linear-regression model of the data.
#
# We'll use [Glum](https://glum.readthedocs.io/en/latest/), a high-performance implementation in Python. <br> <font size="-2"><tt>glum</tt> stands for _gener[REDACTED]zed linear modeling" ... not sure about the <tt>u</tt></font>

# %% [markdown]
# In Colab, you are likely to need to install `glum` once:

# %%
# !pip install glum
# Out:
# Collecting glum
#   Downloading glum-3.1.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from glum) (1.4.2)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.11/dist-packages (from glum) (2.10.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from glum) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from glum) (2.2.2)
# Requirement already satisfied: scikit-learn>=0.23 in /usr/local/lib/python3.11/dist-packages (from glum) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from glum) (1.14.1)
# Collecting formulaic>=0.6 (from glum)
#   Downloading formulaic-1.1.1-py3-none-any.whl.metadata (6.9 kB)
# Collecting tabmat>=4.0.0 (from glum)
#   Downloading tabmat-4.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=0.6->glum)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.6->glum) (4.13.1)
# Requirement already satisfied: wrapt>=1.0 in /usr/local/lib/python3.11/dist-packages (from formulaic>=0.6->glum) (1.17.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->glum) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->glum) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->glum) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.23->glum) (3.6.0)
# Requirement already satisfied: narwhals in /usr/local/lib/python3.11/dist-packages (from tabmat>=4.0.0->glum) (1.33.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->glum) (1.17.0)
# Downloading glum-3.1.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 63.6 MB/s eta 0:00:00
# Downloading formulaic-1.1.1-py3-none-any.whl (115 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.7/115.7 kB 8.5 MB/s eta 0:00:00
# Downloading tabmat-4.1.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 63.5 MB/s eta 0:00:00
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Installing collected packages: interface-meta, formulaic, tabmat, glum
# Successfully installed formulaic-1.1.1 glum-3.1.2 interface-meta-1.3.0 tabmat-4.1.1

# %% [markdown]
# We can use that library to build a linear model:

# %%
#
# there's not much code to build our model!
#
from glum import Gener[REDACTED]zed[REDACTED]nearRegressor

glm_model = Gener[REDACTED]zed[REDACTED]nearRegressor(family="poisson", alpha=1e-6)
glm_model.fit(X=train[x], y=train[y])

print("Coefficients")
pd.Series(np.append(glm_model.intercept_, glm_model.coef_), index=["Intercept"] + x)
# Out:
# Coefficients
# Intercept     5.524484
# year         -0.004149
# town          0.350489
# driver_age   -0.003272
# car_weight   -0.000068
# car_power     0.004117
# car_age      -0.022168
# dtype: float64

# %% [markdown]
# We did it!  &nbsp;&nbsp; But what _is_ it?!

# %% [markdown]
# #### As an absolute model, this is <u>not</u> very useful!
#
# **Everyone** has a very high likelihood of NOT having an auto incident/filing a claim. <i>This is good!</i>
#
# This means _everyone's_ expected number of incidents is 0 &nbsp; (Well, very close to it.)

# %% [markdown]
# #### In comparing the ***relative*** impact of a feature, the model <u>is</u> useful.
#
# Here is a full description of the ***relative*** relationships expressed by those coefficients [(cite)](https://ademos.people.uic.edu/Chapter19.html#:~:text=Rather%20than%20odds%20ratios%20(which,variable%5D%20is%20%5Bcoefficient%5D.):
#
#
# > <font color="DodgerBlue">The expected log count for each unit increase/decrease (depending on the sign of the coefficient) in [outcome variable] given [predictor variable] is [coefficient].</font>
#
#
# Wow!  &nbsp;&nbsp; This needs some unpacking...
#
# <hr>
# <br>

# %% [markdown]
# <font size="+1" color="Blue">Interpreting</font> <font size="+1" > coefficients, part one: &nbsp;&nbsp; <tt><b>town</b></tt> example</font>
#
#
# In practice, it's more straightforward than this suggests:
#
# Suppose your coefficient for `town` is 0.36. &nbsp; <font size="-2">That was one of my test-run values.</font>
#
# This means that "one unit" of `town` increases the <u>log of the claim count</u> by 0.36.  <br> <i><font color="Blue">But log-counts aren't very intuitive!</font></i> &nbsp; Let's _undo_ the log:
#
#
# `exp(0.36)` is about `1.43` &nbsp;&nbsp;&nbsp; Let's see that this is true:

# %%
from math import exp
exp(0.36)
# Out:
# 1.4333294145603401

# %% [markdown]
# This means that "one unit" of `town` ***multiplies*** &nbsp; the frequency of incidents by 1.43
#
# Since `town` only has values 0 and 1, this means that
#
# **when `town` is 1, the likelihood of an incident is 1.43 times higher then when it's 0**
#
# <br>
#
# <font color="Coral"><b>Aha!</b></font>
#
# <br>
#
# This ***incident-rate ratio*** is really useful!
# + for assessing the threat of an event that is relatively rare and/or
# + the _value_ of small changes to an individual's particular situation.
#
# In theory, the multiplier can be used many times:

# %%
exp(0.360105)    # for each unit of "townness,"  we multiply the expected claims by 1.433:
# Out:
# 1.433479922050374

# %%
exp(0.360105) ** 2   # so, we multiply twice for _two_ units of "townness":
# Out:
# 2.054864686921546

# %% [markdown]
# This means, if `town == 2`, the expected claims for those individuals would be 2.05x higher:
# + because, as above, `1.433 ** 2 == 1.433*1.433 == 2.05`
#
# There _isn't_ such a value in the dataset...
# + ... but models will allow this kind of extrapolation. Be careful!

# %% [markdown]
# <font size="+1" color="Blue">Interpreting</font> <font size="+1"> coefficients, part two: &nbsp;&nbsp; <tt><b>driver_age</b></tt> example</font>
#
# Let's try an example where there are multiple values, for example, for <b><tt>driver_age</tt></b> :
# + My coefficient for <tt><b>driver_age</b></tt> was <tt>-0.003272</tt>
# + And <tt>exp(-0.003272) == 0.9967</tt> &nbsp;&nbsp; <font size="-2">Let's confirm:</font>

# %%
exp(-0.003272)    # for each year of driver_age, you multiply the expected claims by 0.9967:
# Out:
# 0.9967333471584426

# %% [markdown]
# This means that, for this model, the number of claims is multiplied by <tt>0.9967</tt> ***for each additional year of age***
#
# <br>
#
# What if an individual is fifteen years older?

# %%
0.9967 ** 15
# Out:
# 0.9516272593744175

# %% [markdown]
# the model expects the number of claims to be 95% with that "additional experience"
#
# <br>
#
# What if we compare the oldest (88) and youngest (18) in the dataset:

# %%
exp(-0.003272)**(88-18)
# Out:
# 0.7952967210000054

# %% [markdown]
# Which states that our octogenerians will make 0.79 the claims as our 18-year-olds.
#
# Taking the reciprocal, the model is saying that moving across the dataset's full age-span, from old to young, multiplies the number of claims by 1.25:

# %%
1/0.7952
# Out:
# 1.2575452716297786

# %% [markdown]
# There is definitely room for skepticism here! 😀
#
# But we've successfully interpreted the model coefficients!
#
# Next, try two of your own:

# %% [markdown]
# #### <font color="Coral"><b>Task 3</b></font> &nbsp; Two more model-interpretations:
#
# Following the approach of the two examples above, choose **two more** features from the coefficients and:
# + compute the _per-unit_ incident-rate multiplier for that feature
# + decide on a "reasonable" number of units (years, kg, hp, ...)
# + compute the incident-rate multiplier for _that many units_
# + find the "full span" of units in the dataset (it's printed above ...)
# + compute the incident-rate multiplier for _that full span_
# + and reflect on what this is saying about the incidents in this data.
#
# Specifically, share how well does these _match your intution_ about these factors for auto incidents/insurance claims? Reasonable? Skeptical? Other?
#
# <br>
# <hr>
# <br>
#
# Feel free to use this cell or new ones just below:
#
# <br>
# <br>

# %% [markdown]
# * Intercept	5.524484
# * year	-0.004149
# * town	0.350489
# * driver_age	-0.003272
# * car_weight	-0.000068
# * car_power	0.004117
# * car_age	-0.022168

# %% [markdown]
# <br>
# <hr>
# <br>

# %%
# Computing the per-unit incident rate multiplier for car_power

incident_rate_multiplier = exp(-0.004117)
print("Incident Rate Multiplier for car_power:", incident_rate_multiplier)

# On average, cars have 124.981766 Horse Power
incident_horsepower = incident_rate_multiplier ** 125
print("Incident_horsepower:", incident_horsepower)

# for full span of dataset
full_span = 341 - 50
full_span_rate = incident_rate_multiplier ** full_span
print("Incident Rate Multiplier for Full Span:", full_span_rate)

# Interpretation: Those with 341 horsepower cars will make 0.3 times the claims of those with 50 horsepower cars.
# This does not suport my intution. I expected those with higher horsepower cars to be riskier drivers and file more claims.
# Out:
# Incident Rate Multiplier for car_power: 0.9958914632261491
# Incident_horsepower: 0.5977246993582341
# Incident Rate Multiplier for Full Span: 0.301783018991029

# %%
# Computing the per-unit incident rate multiplier for car_age
incident_rate_multiplier = exp(-0.022168)
print("Incident Rate Multiplier for car_age:", incident_rate_multiplier)

# On average, cars have 4.15 age
incident_age = incident_rate_multiplier ** 4.15
print("Car age multiplier:", incident_age)

# for full span of dataset
full_span = 23 - 0
full_span_rate = incident_rate_multiplier ** full_span
print("Incident Rate Multiplier for Full Span:", full_span_rate)

# Interpretation: Those with car ages of 23 years filed 0.97 more claims than owners of cares with ages of 0. This goes against
# my intution, as I'd expect older cars to have more issues and require more insurance claims than relatively newer cars.
# Out:
# Incident Rate Multiplier for car_age: 0.9780759044958746
# Car age multiplier: 0.9121077034430844
# Incident Rate Multiplier for Full Span: 0.6005772517646187

# %% [markdown]
# ### Part 3. &nbsp; **Automatic** model-interpretation
#
# A technique called SHAP, short for SHapley Additive exPlanation, is able to estimate the feature-by-feature effects of _any_ model.
#
# It _should_ be here already:

# %%
import shap

# %% [markdown]
# SHAP works by sampling the model at several points and then surveying the space around those points to see how the model is changing. It integrates all of this information in order to be able to compare the influence of all of the variables with the same units, known as SHAP values. They are again relative values, and they indicate how the target varies with changes to each feature -- in light of _all_ the features in the model.
#
# [REDACTED]near models like the one above are already interpretable. However, other models - like neural nets - are much less so.
#
# To get started, let's run SHAP for our linear model:

# %%
import shap

# First, extract background data. This is the same for all models to interpret:
X_bg = train[x].sample(200, random_state=8366)    # grab 200 samples from our training data - 200 is a lot...

# Exploring the space...   This will take a while...
glm_explainer = shap.KernelExplainer(lambda x: np.log(glm_model.predict(x)), data=X_bg)     # Don't worry about the warnings!

# Then, we can choose any data to explain. We'll choose 1,000 rows randomly called X_explain
X_explain = train[x].sample(n=1000, random_state=937)
shap_glm = glm_explainer.shap_values(X_explain, nsamples=30) # there are 30 non-trivial subsets of 6 features
# Out:
# WARNING:shap:Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# Let's see one of the explained individuals:

# %%
X_explain[0:1]
# Out:
#           year  town  driver_age  car_weight  car_power  car_age
# 396019  2018.0   0.0        50.0      1290.0      119.0      1.0

# %% [markdown]
# and, let's see their SHAP values:

# %%
shap_glm[0:1]
# Out:
# array([[ 0.00213664, -0.18400681, -0.01735597,  0.00128275, -0.02764656,
#          0.06816579]])

# %% [markdown]
# Ok!
#
# These numbers are (the sign and) relative weight of each of this individual's **per-feature contributions** to their risk (their expected number of claims).
#
# For example, in this model,
# + their age makes a claim less likely
# + their car's age make a claim more likely
#
# Plus, the <tt><b>SHAPvalue</b></tt> units are commensurate:
# + the impact of the driver's age carries almost three times the weight of their car's age
#
# <br>
#
# Better to plot all of them. &nbsp; Let's do that next:

# %%
#
# A function to create all of the dependence plots among our features
#
def all_dep_plots(x, shap_values, X):
    """ Dependence plots for all features x. """
    fig, _ = plt.subplots(nrows=2, ncols=3, figsize=(10, 6), sharey=True)

    for i, ax in enumerate(fig.axes):
        xvar = x[i]
        shap.dependence_plot(
            xvar,
            shap_values,
            features=X,
            x_jitter=0.2 * (xvar in ("town", "year")),
            ymin=-0.5,
            ymax=1,
            ax=ax,
            show=False,
        )
        ax.set_title(xvar, fontdict={"size": 16})
        ax.set_ylabel("SHAP values" if i % 3 == 0 else "")
        ax.grid()
    plt.tight_layout()

print("The all_dep_plots function has been defined.")
print("Run the next cell to plot the features and their impacts")
# Out:
# The all_dep_plots function has been defined.
# Run the next cell to plot the features and their impacts

# %%
all_dep_plots(x, shap_glm, X_explain)

# %% [markdown]
# #### <font color="Coral"><b>Task 4</b></font> &nbsp; How did SHAP do?
#
# In Task 3, you chose two features and examined their effects on the target value, the number of incidents.
#
# Here, revisit those two features, and in a couple of sentences, describe whether the effects you measured match the plots above.
#
# <br>
#
# **Note/Hints**  There are lots of dimensions here! And lots of information! The x-axis of each plot shows the feature values. The y-axis is the SHAP value (the relative impact on the number of claims).
#
# The red/blue coloring of datapoints shows how the _most influential **other** feature_ overlays onto the current plot. That **other** feature is the most influential for the one labeled on the x-axis, and so it will often be different for different plots.
#
# <br>
#
# As an example of this feature-comparison, remember that one <tt><b>town</b></tt> unit multiplied the claims by 1.4, and the full span of <tt><b>driver_age</b></tt> multiplied the claims by 1.25.
#
# This matches well!  In the above plot, the span for <tt><b>town</b></tt> is a little bit larger than the span for <tt><b>driver_age</b></tt>.
#
# The SHAP units are not the same, and SHAP takes into account more than linear dependencies, but it has captured the sign and the magnitude of the model it was interpreting.
#
#
# <br>
# <hr>
# <br>
#
# For your two reflections, feel free to use this cell or new ones just below this one:
#
# <br>
# <br>

# %% [markdown]
# # Reflection
# It appears that the SHAP graph shows that as the car age increases, there is a weak negative effect on the number of claims. Meaning that as the car ages, it is less likely for a claim. This is supported by my findings above, although I find it hard to believe.
#
# For the second relationship, the graph shows that as car power increases, there is a strong positive effect on the number of claims. Meaning that as the HP of the car increases, it is more likely that the driver will file a claim. This contrasts my findings from above.

# %% [markdown]
# ### Part 4: &nbsp;&nbsp; A Neural Network model
#
# Here, we TensorFlow to fit a "shallow" neural net.
#
# Your task is to improve the results -- by adding more layers and retraining...
#
# Plus, the resulting layered network will be able to extract nonlinear relationships among the features <br> <font size="-1">(in exchange for much more training time...)</font>

# %% [markdown]
# Neurons work best when all their data is ***roughly the same magnitude***
#
# Our brains handle this at the sensor level -- our hearing and vision systems continually try to re-establish the ambient baseline to help convert their inputs into computable magnitudes:
# + light sensitivity increases in the dark and decreases in bright light
# + for sound, loud repetitive even soft sounds are heightened when in a quiet place.
#
# <br>
#
# For neural nets, we can scale each feature to be between -1 and 1:

# %%
# Scale features to [-1, 1]
from sklearn.preprocessing import MinMaxScaler

nn_preprocessor = MinMaxScaler(feature_range=(-1, 1))
X_train = nn_preprocessor.fit_transform(train[x])

print("Output after the data has been scaled:")
pd.DataFrame(X_train[0:5], columns=x)
# Out:
# Output after the data has been scaled:
#    year  town  driver_age  car_weight  car_power   car_age
# 0   1.0  -1.0    0.246377   -0.530612  -0.501754 -1.000000
# 1  -1.0   1.0   -0.072464   -0.530612  -0.256140 -0.818182
# 2   1.0   1.0   -0.072464   -0.969388  -0.817544 -0.636364
# 3   1.0   1.0   -0.333333   -0.867347  -0.887719 -0.181818
# 4   1.0   1.0   -0.594203   -0.489796  -0.445614 -0.727273

# %%
#
# Neural nets are worthy of their own course, for sure...
#
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
cb = [EarlyStopping(patience=20), ReduceLROnPlateau(patience=5)]  # "callbacks" for training (see below)

# Architecture
inputs = keras.Input(shape=(len(x),))
# additional layers can be added here!
outputs = layers.Dense(1, activation="exponential")(inputs)
nn_model_shallow = keras.Model(inputs=inputs, outputs=outputs)

nn_model_shallow.summary()

# Calculate gradients
nn_model_shallow.compile(optimizer=Adam(learning_rate=1e-4), loss="Poisson")
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 6)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │               7 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 7 (28.00 B)
#  Trainable params: 7 (28.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Above, you see the artictecture of the network.
#
# This includes the total number of neuron-connections (parameters) to train.
#
# Let's train!

# %%
#
# train the network!
#

tf.random.set_seed(4349)

history_shallow = nn_model_shallow.fit(
    x=X_train,
    y=train[y],
    epochs=200,
    batch_size=10_000,
    v[REDACTED]dation_split=0.1,
    callbacks=cb,
    verbose=1,         # consider running both values 0 (no printing) and 1 (printing)
)
# Out:
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.9543 - val_loss: 0.9422 - learning_rate: 1.0000e-04
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9518 - val_loss: 0.9397 - learning_rate: 1.0000e-04
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9493 - val_loss: 0.9373 - learning_rate: 1.0000e-04
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9468 - val_loss: 0.9349 - learning_rate: 1.0000e-04
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9444 - val_loss: 0.9325 - learning_rate: 1.0000e-04
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9419 - val_loss: 0.9301 - learning_rate: 1.0000e-04
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9395 - val_loss: 0.9277 - learning_rate: 1.0000e-04
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9371 - val_loss: 0.9253 - learning_rate: 1.0000e-04
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9347 - val_loss: 0.9230 - learning_rate: 1.0000e-04
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9323 - val_loss: 0.9206 - learning_rate: 1.0000e-04
# Epoch 11/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9300 - val_loss: 0.9183 - learning_rate: 1.0000e-04
# Epoch 12/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9276 - val_loss: 0.9160 - learning_rate: 1.0000e-04
# Epoch 13/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9253 - val_loss: 0.9137 - learning_rate: 1.0000e-04
# Epoch 14/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9229 - val_loss: 0.9114 - learning_rate: 1.0000e-04
# Epoch 15/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9206 - val_loss: 0.9091 - learning_rate: 1.0000e-04
# Epoch 16/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9183 - val_loss: 0.9069 - learning_rate: 1.0000e-04
# Epoch 17/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9160 - val_loss: 0.9046 - learning_rate: 1.0000e-04
# Epoch 18/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9138 - val_loss: 0.9024 - learning_rate: 1.0000e-04
# Epoch 19/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9115 - val_loss: 0.9001 - learning_rate: 1.0000e-04
# Epoch 20/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9092 - val_loss: 0.8979 - learning_rate: 1.0000e-04
# Epoch 21/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9070 - val_loss: 0.8957 - learning_rate: 1.0000e-04
# Epoch 22/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9048 - val_loss: 0.8935 - learning_rate: 1.0000e-04
# Epoch 23/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9026 - val_loss: 0.8914 - learning_rate: 1.0000e-04
# Epoch 24/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9003 - val_loss: 0.8892 - learning_rate: 1.0000e-04
# Epoch 25/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8982 - val_loss: 0.8870 - learning_rate: 1.0000e-04
# Epoch 26/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8960 - val_loss: 0.8849 - learning_rate: 1.0000e-04
# Epoch 27/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8938 - val_loss: 0.8828 - learning_rate: 1.0000e-04
# Epoch 28/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8917 - val_loss: 0.8806 - learning_rate: 1.0000e-04
# Epoch 29/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8895 - val_loss: 0.8785 - learning_rate: 1.0000e-04
# Epoch 30/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8874 - val_loss: 0.8764 - learning_rate: 1.0000e-04
# Epoch 31/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8852 - val_loss: 0.8743 - learning_rate: 1.0000e-04
# Epoch 32/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8831 - val_loss: 0.8723 - learning_rate: 1.0000e-04
# Epoch 33/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8810 - val_loss: 0.8702 - learning_rate: 1.0000e-04
# Epoch 34/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8789 - val_loss: 0.8681 - learning_rate: 1.0000e-04
# Epoch 35/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8769 - val_loss: 0.8661 - learning_rate: 1.0000e-04
# Epoch 36/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8748 - val_loss: 0.8641 - learning_rate: 1.0000e-04
# Epoch 37/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8727 - val_loss: 0.8621 - learning_rate: 1.0000e-04
# Epoch 38/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8707 - val_loss: 0.8600 - learning_rate: 1.0000e-04
# Epoch 39/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8687 - val_loss: 0.8580 - learning_rate: 1.0000e-04
# Epoch 40/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8666 - val_loss: 0.8561 - learning_rate: 1.0000e-04
# Epoch 41/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8646 - val_loss: 0.8541 - learning_rate: 1.0000e-04
# Epoch 42/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8626 - val_loss: 0.8521 - learning_rate: 1.0000e-04
# Epoch 43/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8606 - val_loss: 0.8501 - learning_rate: 1.0000e-04
# Epoch 44/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8586 - val_loss: 0.8482 - learning_rate: 1.0000e-04
# Epoch 45/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8567 - val_loss: 0.8463 - learning_rate: 1.0000e-04
# Epoch 46/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8547 - val_loss: 0.8443 - learning_rate: 1.0000e-04
# Epoch 47/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8528 - val_loss: 0.8424 - learning_rate: 1.0000e-04
# Epoch 48/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8508 - val_loss: 0.8405 - learning_rate: 1.0000e-04
# Epoch 49/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8489 - val_loss: 0.8386 - learning_rate: 1.0000e-04
# Epoch 50/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8470 - val_loss: 0.8367 - learning_rate: 1.0000e-04
# Epoch 51/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8450 - val_loss: 0.8348 - learning_rate: 1.0000e-04
# Epoch 52/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8431 - val_loss: 0.8330 - learning_rate: 1.0000e-04
# Epoch 53/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8412 - val_loss: 0.8311 - learning_rate: 1.0000e-04
# Epoch 54/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8394 - val_loss: 0.8292 - learning_rate: 1.0000e-04
# Epoch 55/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8375 - val_loss: 0.8274 - learning_rate: 1.0000e-04
# Epoch 56/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8356 - val_loss: 0.8256 - learning_rate: 1.0000e-04
# Epoch 57/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8338 - val_loss: 0.8237 - learning_rate: 1.0000e-04
# Epoch 58/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8319 - val_loss: 0.8219 - learning_rate: 1.0000e-04
# Epoch 59/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8301 - val_loss: 0.8201 - learning_rate: 1.0000e-04
# Epoch 60/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8282 - val_loss: 0.8183 - learning_rate: 1.0000e-04
# Epoch 61/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8264 - val_loss: 0.8165 - learning_rate: 1.0000e-04
# Epoch 62/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8246 - val_loss: 0.8147 - learning_rate: 1.0000e-04
# Epoch 63/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8228 - val_loss: 0.8130 - learning_rate: 1.0000e-04
# Epoch 64/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8210 - val_loss: 0.8112 - learning_rate: 1.0000e-04
# Epoch 65/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8192 - val_loss: 0.8095 - learning_rate: 1.0000e-04
# Epoch 66/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8174 - val_loss: 0.8077 - learning_rate: 1.0000e-04
# Epoch 67/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8157 - val_loss: 0.8060 - learning_rate: 1.0000e-04
# Epoch 68/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8139 - val_loss: 0.8042 - learning_rate: 1.0000e-04
# Epoch 69/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8122 - val_loss: 0.8025 - learning_rate: 1.0000e-04
# Epoch 70/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8104 - val_loss: 0.8008 - learning_rate: 1.0000e-04
# Epoch 71/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8087 - val_loss: 0.7991 - learning_rate: 1.0000e-04
# Epoch 72/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.8070 - val_loss: 0.7974 - learning_rate: 1.0000e-04
# Epoch 73/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8052 - val_loss: 0.7957 - learning_rate: 1.0000e-04
# Epoch 74/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.8035 - val_loss: 0.7940 - learning_rate: 1.0000e-04
# Epoch 75/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.8018 - val_loss: 0.7924 - learning_rate: 1.0000e-04
# Epoch 76/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8001 - val_loss: 0.7907 - learning_rate: 1.0000e-04
# Epoch 77/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7985 - val_loss: 0.7891 - learning_rate: 1.0000e-04
# Epoch 78/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7968 - val_loss: 0.7874 - learning_rate: 1.0000e-04
# Epoch 79/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7951 - val_loss: 0.7858 - learning_rate: 1.0000e-04
# Epoch 80/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.7934 - val_loss: 0.7841 - learning_rate: 1.0000e-04
# Epoch 81/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7918 - val_loss: 0.7825 - learning_rate: 1.0000e-04
# Epoch 82/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7901 - val_loss: 0.7809 - learning_rate: 1.0000e-04
# Epoch 83/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7885 - val_loss: 0.7793 - learning_rate: 1.0000e-04
# Epoch 84/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7869 - val_loss: 0.7777 - learning_rate: 1.0000e-04
# Epoch 85/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7852 - val_loss: 0.7761 - learning_rate: 1.0000e-04
# Epoch 86/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7836 - val_loss: 0.7745 - learning_rate: 1.0000e-04
# Epoch 87/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7820 - val_loss: 0.7729 - learning_rate: 1.0000e-04
# Epoch 88/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7804 - val_loss: 0.7713 - learning_rate: 1.0000e-04
# Epoch 89/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7788 - val_loss: 0.7698 - learning_rate: 1.0000e-04
# Epoch 90/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7772 - val_loss: 0.7682 - learning_rate: 1.0000e-04
# Epoch 91/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7757 - val_loss: 0.7667 - learning_rate: 1.0000e-04
# Epoch 92/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7741 - val_loss: 0.7651 - learning_rate: 1.0000e-04
# Epoch 93/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7725 - val_loss: 0.7636 - learning_rate: 1.0000e-04
# Epoch 94/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7710 - val_loss: 0.7621 - learning_rate: 1.0000e-04
# Epoch 95/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7694 - val_loss: 0.7605 - learning_rate: 1.0000e-04
# Epoch 96/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.7679 - val_loss: 0.7590 - learning_rate: 1.0000e-04
# Epoch 97/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7663 - val_loss: 0.7575 - learning_rate: 1.0000e-04
# Epoch 98/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7648 - val_loss: 0.7560 - learning_rate: 1.0000e-04
# Epoch 99/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7633 - val_loss: 0.7545 - learning_rate: 1.0000e-04
# Epoch 100/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7618 - val_loss: 0.7530 - learning_rate: 1.0000e-04
# Epoch 101/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7602 - val_loss: 0.7515 - learning_rate: 1.0000e-04
# Epoch 102/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7587 - val_loss: 0.7501 - learning_rate: 1.0000e-04
# Epoch 103/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7572 - val_loss: 0.7486 - learning_rate: 1.0000e-04
# Epoch 104/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7558 - val_loss: 0.7471 - learning_rate: 1.0000e-04
# Epoch 105/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7543 - val_loss: 0.7457 - learning_rate: 1.0000e-04
# Epoch 106/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7528 - val_loss: 0.7442 - learning_rate: 1.0000e-04
# Epoch 107/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7513 - val_loss: 0.7428 - learning_rate: 1.0000e-04
# Epoch 108/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7499 - val_loss: 0.7413 - learning_rate: 1.0000e-04
# Epoch 109/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7484 - val_loss: 0.7399 - learning_rate: 1.0000e-04
# Epoch 110/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7470 - val_loss: 0.7385 - learning_rate: 1.0000e-04
# Epoch 111/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7455 - val_loss: 0.7371 - learning_rate: 1.0000e-04
# Epoch 112/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7441 - val_loss: 0.7357 - learning_rate: 1.0000e-04
# Epoch 113/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7426 - val_loss: 0.7343 - learning_rate: 1.0000e-04
# Epoch 114/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7412 - val_loss: 0.7329 - learning_rate: 1.0000e-04
# Epoch 115/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7398 - val_loss: 0.7315 - learning_rate: 1.0000e-04
# Epoch 116/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7384 - val_loss: 0.7301 - learning_rate: 1.0000e-04
# Epoch 117/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7370 - val_loss: 0.7287 - learning_rate: 1.0000e-04
# Epoch 118/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7356 - val_loss: 0.7273 - learning_rate: 1.0000e-04
# Epoch 119/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7342 - val_loss: 0.7259 - learning_rate: 1.0000e-04
# Epoch 120/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7328 - val_loss: 0.7246 - learning_rate: 1.0000e-04
# Epoch 121/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7314 - val_loss: 0.7232 - learning_rate: 1.0000e-04
# Epoch 122/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7300 - val_loss: 0.7219 - learning_rate: 1.0000e-04
# Epoch 123/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7287 - val_loss: 0.7205 - learning_rate: 1.0000e-04
# Epoch 124/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7273 - val_loss: 0.7192 - learning_rate: 1.0000e-04
# Epoch 125/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7259 - val_loss: 0.7179 - learning_rate: 1.0000e-04
# Epoch 126/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7246 - val_loss: 0.7165 - learning_rate: 1.0000e-04
# Epoch 127/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7232 - val_loss: 0.7152 - learning_rate: 1.0000e-04
# Epoch 128/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7219 - val_loss: 0.7139 - learning_rate: 1.0000e-04
# Epoch 129/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7205 - val_loss: 0.7126 - learning_rate: 1.0000e-04
# Epoch 130/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7192 - val_loss: 0.7113 - learning_rate: 1.0000e-04
# Epoch 131/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7179 - val_loss: 0.7100 - learning_rate: 1.0000e-04
# Epoch 132/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7166 - val_loss: 0.7087 - learning_rate: 1.0000e-04
# Epoch 133/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7152 - val_loss: 0.7074 - learning_rate: 1.0000e-04
# Epoch 134/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7139 - val_loss: 0.7061 - learning_rate: 1.0000e-04
# Epoch 135/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7126 - val_loss: 0.7048 - learning_rate: 1.0000e-04
# Epoch 136/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7113 - val_loss: 0.7035 - learning_rate: 1.0000e-04
# Epoch 137/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7100 - val_loss: 0.7023 - learning_rate: 1.0000e-04
# Epoch 138/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7088 - val_loss: 0.7010 - learning_rate: 1.0000e-04
# Epoch 139/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7075 - val_loss: 0.6997 - learning_rate: 1.0000e-04
# Epoch 140/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7062 - val_loss: 0.6985 - learning_rate: 1.0000e-04
# Epoch 141/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7049 - val_loss: 0.6972 - learning_rate: 1.0000e-04
# Epoch 142/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7037 - val_loss: 0.6960 - learning_rate: 1.0000e-04
# Epoch 143/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7024 - val_loss: 0.6948 - learning_rate: 1.0000e-04
# Epoch 144/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.7011 - val_loss: 0.6935 - learning_rate: 1.0000e-04
# Epoch 145/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6999 - val_loss: 0.6923 - learning_rate: 1.0000e-04
# Epoch 146/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6986 - val_loss: 0.6911 - learning_rate: 1.0000e-04
# Epoch 147/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6974 - val_loss: 0.6899 - learning_rate: 1.0000e-04
# Epoch 148/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6962 - val_loss: 0.6887 - learning_rate: 1.0000e-04
# Epoch 149/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6949 - val_loss: 0.6874 - learning_rate: 1.0000e-04
# Epoch 150/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6937 - val_loss: 0.6862 - learning_rate: 1.0000e-04
# Epoch 151/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.6925 - val_loss: 0.6850 - learning_rate: 1.0000e-04
# Epoch 152/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6913 - val_loss: 0.6838 - learning_rate: 1.0000e-04
# Epoch 153/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6900 - val_loss: 0.6827 - learning_rate: 1.0000e-04
# Epoch 154/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6888 - val_loss: 0.6815 - learning_rate: 1.0000e-04
# Epoch 155/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6876 - val_loss: 0.6803 - learning_rate: 1.0000e-04
# Epoch 156/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.6864 - val_loss: 0.6791 - learning_rate: 1.0000e-04
# Epoch 157/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6852 - val_loss: 0.6780 - learning_rate: 1.0000e-04
# Epoch 158/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6841 - val_loss: 0.6768 - learning_rate: 1.0000e-04
# Epoch 159/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6829 - val_loss: 0.6756 - learning_rate: 1.0000e-04
# Epoch 160/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6817 - val_loss: 0.6745 - learning_rate: 1.0000e-04
# Epoch 161/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6805 - val_loss: 0.6733 - learning_rate: 1.0000e-04
# Epoch 162/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6793 - val_loss: 0.6722 - learning_rate: 1.0000e-04
# Epoch 163/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6782 - val_loss: 0.6710 - learning_rate: 1.0000e-04
# Epoch 164/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6770 - val_loss: 0.6699 - learning_rate: 1.0000e-04
# Epoch 165/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6759 - val_loss: 0.6688 - learning_rate: 1.0000e-04
# Epoch 166/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6747 - val_loss: 0.6676 - learning_rate: 1.0000e-04
# Epoch 167/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6736 - val_loss: 0.6665 - learning_rate: 1.0000e-04
# Epoch 168/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6724 - val_loss: 0.6654 - learning_rate: 1.0000e-04
# Epoch 169/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6713 - val_loss: 0.6643 - learning_rate: 1.0000e-04
# Epoch 170/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6701 - val_loss: 0.6632 - learning_rate: 1.0000e-04
# Epoch 171/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6690 - val_loss: 0.6621 - learning_rate: 1.0000e-04
# Epoch 172/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6679 - val_loss: 0.6610 - learning_rate: 1.0000e-04
# Epoch 173/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6668 - val_loss: 0.6599 - learning_rate: 1.0000e-04
# Epoch 174/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6657 - val_loss: 0.6588 - learning_rate: 1.0000e-04
# Epoch 175/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6645 - val_loss: 0.6577 - learning_rate: 1.0000e-04
# Epoch 176/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6634 - val_loss: 0.6566 - learning_rate: 1.0000e-04
# Epoch 177/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6623 - val_loss: 0.6555 - learning_rate: 1.0000e-04
# Epoch 178/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6612 - val_loss: 0.6544 - learning_rate: 1.0000e-04
# Epoch 179/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6601 - val_loss: 0.6534 - learning_rate: 1.0000e-04
# Epoch 180/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6590 - val_loss: 0.6523 - learning_rate: 1.0000e-04
# Epoch 181/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6580 - val_loss: 0.6512 - learning_rate: 1.0000e-04
# Epoch 182/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6569 - val_loss: 0.6502 - learning_rate: 1.0000e-04
# Epoch 183/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6558 - val_loss: 0.6491 - learning_rate: 1.0000e-04
# Epoch 184/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6547 - val_loss: 0.6480 - learning_rate: 1.0000e-04
# Epoch 185/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6537 - val_loss: 0.6470 - learning_rate: 1.0000e-04
# Epoch 186/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6526 - val_loss: 0.6460 - learning_rate: 1.0000e-04
# Epoch 187/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6515 - val_loss: 0.6449 - learning_rate: 1.0000e-04
# Epoch 188/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6505 - val_loss: 0.6439 - learning_rate: 1.0000e-04
# Epoch 189/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6494 - val_loss: 0.6428 - learning_rate: 1.0000e-04
# Epoch 190/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6484 - val_loss: 0.6418 - learning_rate: 1.0000e-04
# Epoch 191/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6473 - val_loss: 0.6408 - learning_rate: 1.0000e-04
# Epoch 192/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6463 - val_loss: 0.6398 - learning_rate: 1.0000e-04
# Epoch 193/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6452 - val_loss: 0.6388 - learning_rate: 1.0000e-04
# Epoch 194/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6442 - val_loss: 0.6377 - learning_rate: 1.0000e-04
# Epoch 195/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6432 - val_loss: 0.6367 - learning_rate: 1.0000e-04
# Epoch 196/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6421 - val_loss: 0.6357 - learning_rate: 1.0000e-04
# Epoch 197/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6411 - val_loss: 0.6347 - learning_rate: 1.0000e-04
# Epoch 198/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6401 - val_loss: 0.6337 - learning_rate: 1.0000e-04
# Epoch 199/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6391 - val_loss: 0.6327 - learning_rate: 1.0000e-04
# Epoch 200/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.6381 - val_loss: 0.6317 - learning_rate: 1.0000e-04

# %%
# prompt: Could you show a heatmap of the values of the neuron's weights in the above model, named nn_model?

import seaborn as sns
import matplotlib.pyplot as plt

# Here, nn_model_shallow is the Keras (NNet) model
weights = nn_model_shallow.layers[1].get_weights()[0]  # Get weights from this layer (omitting the intercepts, which are in [1])
weights = np.transpose(weights)

# Create a heatmap of the weights
plt.figure(figsize=(10, 8))
sns.heatmap(weights, annot=False, cmap='viridis')
plt.title("Neuron Weights Heatmap of the Input Layer")
plt.xlabel("Input Features (6)")
plt.ylabel("Neurons from Inputs to Output")
plt.show()

# %% [markdown]
# And, let's see how the model does... using `shap`

# %%
def nn_predict_shallow(X):
    """Prediction function of the neural network (log scale)."""
    df = pd.DataFrame(X, columns=x)
    df_scaled = nn_preprocessor.transform(df)
    pred = nn_model_shallow.predict(df_scaled, verbose=0, batch_size=10_000).flatten()
    return np.log(pred)


nn_explainer = shap.KernelExplainer(nn_predict_shallow, data=X_bg)
shap_nn = nn_explainer.shap_values(X_explain, nsamples=30)

all_dep_plots(x, shap_nn, X_explain)
# Out:
# WARNING:shap:Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# #### Next, let's add a "hidden" layer to our network...
#
# Here, we add a middle, "hidden," layer to our network in line 14, below. Notice that
# + the value 7 is the number of neurons
# + the inputs from the initial layer are, in fact, the inputs to this middle layer
# + the variable z holds the outputs of this layer.
# + the output layer uses z as its input (and then estimates the goal, the number of claims from there)
#
# Additional layers are able to continue this pattern (one example is commented out on line 17):

# %%
#
# Let's add a second layer to our network:

import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
cb = [EarlyStopping(patience=20), ReduceLROnPlateau(patience=5)]  # "callbacks" for training (see below)

# Architecture: Adding Layers
inputs = keras.Input(shape=(len(x),))            # Here is the input layer

z = layers.Dense(7, activation="tanh")(inputs)   # Here is the new layer: 7 neurons, inputs are the input, and z is the output. Use "tanh"

# For more layers, you can continue using z.     # Here is a commented-out example:
# z = layers.Dense(3, activation="tanh"))(z)     # This is another layer: 3 neurons, z is the input, and z is the output

outputs = layers.Dense(1, activation="exponential")(z)   # Here, we convert the previous layer's results (z) into the overall output
nn_model_2layer = keras.Model(inputs=inputs, outputs=outputs)   # The final layer often uses a different activation function

nn_model_2layer.summary()

nn_model_2layer.compile(optimizer=Adam(learning_rate=1e-4), loss="Poisson")
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 6)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 7)                   │              49 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               8 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 57 (228.00 B)
#  Trainable params: 57 (228.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.random.set_seed(4349)

history_2layer = nn_model_2layer.fit(
    x=X_train,
    y=train[y],
    epochs=200,
    batch_size=10_000,
    v[REDACTED]dation_split=0.1,
    callbacks=cb,
    verbose=1,         # consider running both values 0 (no printing) and 1 (printing)
)
# Out:
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.3019 - val_loss: 1.2982 - learning_rate: 1.0000e-04
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2918 - val_loss: 1.2882 - learning_rate: 1.0000e-04
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2819 - val_loss: 1.2782 - learning_rate: 1.0000e-04
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2720 - val_loss: 1.2685 - learning_rate: 1.0000e-04
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2623 - val_loss: 1.2588 - learning_rate: 1.0000e-04
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2528 - val_loss: 1.2493 - learning_rate: 1.0000e-04
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2434 - val_loss: 1.2400 - learning_rate: 1.0000e-04
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2341 - val_loss: 1.2307 - learning_rate: 1.0000e-04
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2249 - val_loss: 1.2216 - learning_rate: 1.0000e-04
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2159 - val_loss: 1.2127 - learning_rate: 1.0000e-04
# Epoch 11/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2070 - val_loss: 1.2038 - learning_rate: 1.0000e-04
# Epoch 12/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1982 - val_loss: 1.1951 - learning_rate: 1.0000e-04
# Epoch 13/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1896 - val_loss: 1.1865 - learning_rate: 1.0000e-04
# Epoch 14/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1810 - val_loss: 1.1780 - learning_rate: 1.0000e-04
# Epoch 15/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1726 - val_loss: 1.1696 - learning_rate: 1.0000e-04
# Epoch 16/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1643 - val_loss: 1.1613 - learning_rate: 1.0000e-04
# Epoch 17/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1561 - val_loss: 1.1532 - learning_rate: 1.0000e-04
# Epoch 18/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1480 - val_loss: 1.1451 - learning_rate: 1.0000e-04
# Epoch 19/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1399 - val_loss: 1.1372 - learning_rate: 1.0000e-04
# Epoch 20/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1320 - val_loss: 1.1293 - learning_rate: 1.0000e-04
# Epoch 21/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1242 - val_loss: 1.1215 - learning_rate: 1.0000e-04
# Epoch 22/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1165 - val_loss: 1.1138 - learning_rate: 1.0000e-04
# Epoch 23/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1089 - val_loss: 1.1063 - learning_rate: 1.0000e-04
# Epoch 24/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1013 - val_loss: 1.0988 - learning_rate: 1.0000e-04
# Epoch 25/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0939 - val_loss: 1.0914 - learning_rate: 1.0000e-04
# Epoch 26/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.0865 - val_loss: 1.0840 - learning_rate: 1.0000e-04
# Epoch 27/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0792 - val_loss: 1.0768 - learning_rate: 1.0000e-04
# Epoch 28/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0720 - val_loss: 1.0696 - learning_rate: 1.0000e-04
# Epoch 29/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.0649 - val_loss: 1.0625 - learning_rate: 1.0000e-04
# Epoch 30/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0578 - val_loss: 1.0555 - learning_rate: 1.0000e-04
# Epoch 31/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0509 - val_loss: 1.0486 - learning_rate: 1.0000e-04
# Epoch 32/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.0440 - val_loss: 1.0417 - learning_rate: 1.0000e-04
# Epoch 33/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.0371 - val_loss: 1.0349 - learning_rate: 1.0000e-04
# Epoch 34/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0304 - val_loss: 1.0282 - learning_rate: 1.0000e-04
# Epoch 35/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0237 - val_loss: 1.0215 - learning_rate: 1.0000e-04
# Epoch 36/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0171 - val_loss: 1.0150 - learning_rate: 1.0000e-04
# Epoch 37/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0105 - val_loss: 1.0085 - learning_rate: 1.0000e-04
# Epoch 38/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0040 - val_loss: 1.0020 - learning_rate: 1.0000e-04
# Epoch 39/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9976 - val_loss: 0.9956 - learning_rate: 1.0000e-04
# Epoch 40/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9912 - val_loss: 0.9893 - learning_rate: 1.0000e-04
# Epoch 41/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9850 - val_loss: 0.9831 - learning_rate: 1.0000e-04
# Epoch 42/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9787 - val_loss: 0.9769 - learning_rate: 1.0000e-04
# Epoch 43/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9726 - val_loss: 0.9707 - learning_rate: 1.0000e-04
# Epoch 44/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9665 - val_loss: 0.9647 - learning_rate: 1.0000e-04
# Epoch 45/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9604 - val_loss: 0.9587 - learning_rate: 1.0000e-04
# Epoch 46/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9544 - val_loss: 0.9527 - learning_rate: 1.0000e-04
# Epoch 47/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.9485 - val_loss: 0.9468 - learning_rate: 1.0000e-04
# Epoch 48/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.9426 - val_loss: 0.9410 - learning_rate: 1.0000e-04
# Epoch 49/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.9368 - val_loss: 0.9353 - learning_rate: 1.0000e-04
# Epoch 50/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.9311 - val_loss: 0.9295 - learning_rate: 1.0000e-04
# Epoch 51/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.9254 - val_loss: 0.9239 - learning_rate: 1.0000e-04
# Epoch 52/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.9198 - val_loss: 0.9183 - learning_rate: 1.0000e-04
# Epoch 53/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - loss: 0.9142 - val_loss: 0.9127 - learning_rate: 1.0000e-04
# Epoch 54/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.9087 - val_loss: 0.9073 - learning_rate: 1.0000e-04
# Epoch 55/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.9032 - val_loss: 0.9018 - learning_rate: 1.0000e-04
# Epoch 56/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 0.8978 - val_loss: 0.8964 - learning_rate: 1.0000e-04
# Epoch 57/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.8924 - val_loss: 0.8911 - learning_rate: 1.0000e-04
# Epoch 58/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8871 - val_loss: 0.8858 - learning_rate: 1.0000e-04
# Epoch 59/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.8818 - val_loss: 0.8806 - learning_rate: 1.0000e-04
# Epoch 60/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.8766 - val_loss: 0.8754 - learning_rate: 1.0000e-04
# Epoch 61/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8714 - val_loss: 0.8703 - learning_rate: 1.0000e-04
# Epoch 62/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8663 - val_loss: 0.8652 - learning_rate: 1.0000e-04
# Epoch 63/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8613 - val_loss: 0.8602 - learning_rate: 1.0000e-04
# Epoch 64/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8563 - val_loss: 0.8552 - learning_rate: 1.0000e-04
# Epoch 65/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8513 - val_loss: 0.8503 - learning_rate: 1.0000e-04
# Epoch 66/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8464 - val_loss: 0.8454 - learning_rate: 1.0000e-04
# Epoch 67/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8415 - val_loss: 0.8406 - learning_rate: 1.0000e-04
# Epoch 68/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8367 - val_loss: 0.8358 - learning_rate: 1.0000e-04
# Epoch 69/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8319 - val_loss: 0.8311 - learning_rate: 1.0000e-04
# Epoch 70/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8272 - val_loss: 0.8264 - learning_rate: 1.0000e-04
# Epoch 71/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8225 - val_loss: 0.8217 - learning_rate: 1.0000e-04
# Epoch 72/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.8179 - val_loss: 0.8171 - learning_rate: 1.0000e-04
# Epoch 73/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.8133 - val_loss: 0.8126 - learning_rate: 1.0000e-04
# Epoch 74/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8087 - val_loss: 0.8081 - learning_rate: 1.0000e-04
# Epoch 75/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.8042 - val_loss: 0.8036 - learning_rate: 1.0000e-04
# Epoch 76/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.7998 - val_loss: 0.7992 - learning_rate: 1.0000e-04
# Epoch 77/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.7953 - val_loss: 0.7948 - learning_rate: 1.0000e-04
# Epoch 78/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.7910 - val_loss: 0.7904 - learning_rate: 1.0000e-04
# Epoch 79/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7866 - val_loss: 0.7861 - learning_rate: 1.0000e-04
# Epoch 80/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7823 - val_loss: 0.7819 - learning_rate: 1.0000e-04
# Epoch 81/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7781 - val_loss: 0.7777 - learning_rate: 1.0000e-04
# Epoch 82/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.7739 - val_loss: 0.7735 - learning_rate: 1.0000e-04
# Epoch 83/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7697 - val_loss: 0.7693 - learning_rate: 1.0000e-04
# Epoch 84/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7656 - val_loss: 0.7652 - learning_rate: 1.0000e-04
# Epoch 85/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7615 - val_loss: 0.7612 - learning_rate: 1.0000e-04
# Epoch 86/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7574 - val_loss: 0.7572 - learning_rate: 1.0000e-04
# Epoch 87/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7534 - val_loss: 0.7532 - learning_rate: 1.0000e-04
# Epoch 88/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7494 - val_loss: 0.7492 - learning_rate: 1.0000e-04
# Epoch 89/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7455 - val_loss: 0.7453 - learning_rate: 1.0000e-04
# Epoch 90/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7416 - val_loss: 0.7414 - learning_rate: 1.0000e-04
# Epoch 91/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7377 - val_loss: 0.7376 - learning_rate: 1.0000e-04
# Epoch 92/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7339 - val_loss: 0.7338 - learning_rate: 1.0000e-04
# Epoch 93/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7301 - val_loss: 0.7301 - learning_rate: 1.0000e-04
# Epoch 94/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7263 - val_loss: 0.7263 - learning_rate: 1.0000e-04
# Epoch 95/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7226 - val_loss: 0.7226 - learning_rate: 1.0000e-04
# Epoch 96/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7189 - val_loss: 0.7190 - learning_rate: 1.0000e-04
# Epoch 97/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.7153 - val_loss: 0.7154 - learning_rate: 1.0000e-04
# Epoch 98/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.7116 - val_loss: 0.7118 - learning_rate: 1.0000e-04
# Epoch 99/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.7081 - val_loss: 0.7082 - learning_rate: 1.0000e-04
# Epoch 100/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.7045 - val_loss: 0.7047 - learning_rate: 1.0000e-04
# Epoch 101/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.7010 - val_loss: 0.7012 - learning_rate: 1.0000e-04
# Epoch 102/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.6975 - val_loss: 0.6978 - learning_rate: 1.0000e-04
# Epoch 103/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6941 - val_loss: 0.6943 - learning_rate: 1.0000e-04
# Epoch 104/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.6906 - val_loss: 0.6910 - learning_rate: 1.0000e-04
# Epoch 105/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6873 - val_loss: 0.6876 - learning_rate: 1.0000e-04
# Epoch 106/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.6839 - val_loss: 0.6843 - learning_rate: 1.0000e-04
# Epoch 107/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6806 - val_loss: 0.6810 - learning_rate: 1.0000e-04
# Epoch 108/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6773 - val_loss: 0.6777 - learning_rate: 1.0000e-04
# Epoch 109/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6740 - val_loss: 0.6745 - learning_rate: 1.0000e-04
# Epoch 110/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6708 - val_loss: 0.6713 - learning_rate: 1.0000e-04
# Epoch 111/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6676 - val_loss: 0.6681 - learning_rate: 1.0000e-04
# Epoch 112/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.6644 - val_loss: 0.6650 - learning_rate: 1.0000e-04
# Epoch 113/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6613 - val_loss: 0.6618 - learning_rate: 1.0000e-04
# Epoch 114/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6581 - val_loss: 0.6588 - learning_rate: 1.0000e-04
# Epoch 115/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6551 - val_loss: 0.6557 - learning_rate: 1.0000e-04
# Epoch 116/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6520 - val_loss: 0.6527 - learning_rate: 1.0000e-04
# Epoch 117/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6490 - val_loss: 0.6497 - learning_rate: 1.0000e-04
# Epoch 118/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6460 - val_loss: 0.6467 - learning_rate: 1.0000e-04
# Epoch 119/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6430 - val_loss: 0.6438 - learning_rate: 1.0000e-04
# Epoch 120/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6400 - val_loss: 0.6408 - learning_rate: 1.0000e-04
# Epoch 121/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6371 - val_loss: 0.6379 - learning_rate: 1.0000e-04
# Epoch 122/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6342 - val_loss: 0.6351 - learning_rate: 1.0000e-04
# Epoch 123/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6314 - val_loss: 0.6322 - learning_rate: 1.0000e-04
# Epoch 124/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6285 - val_loss: 0.6294 - learning_rate: 1.0000e-04
# Epoch 125/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6257 - val_loss: 0.6266 - learning_rate: 1.0000e-04
# Epoch 126/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6229 - val_loss: 0.6239 - learning_rate: 1.0000e-04
# Epoch 127/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6201 - val_loss: 0.6212 - learning_rate: 1.0000e-04
# Epoch 128/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.6174 - val_loss: 0.6184 - learning_rate: 1.0000e-04
# Epoch 129/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6147 - val_loss: 0.6158 - learning_rate: 1.0000e-04
# Epoch 130/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.6120 - val_loss: 0.6131 - learning_rate: 1.0000e-04
# Epoch 131/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6093 - val_loss: 0.6105 - learning_rate: 1.0000e-04
# Epoch 132/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6067 - val_loss: 0.6079 - learning_rate: 1.0000e-04
# Epoch 133/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6041 - val_loss: 0.6053 - learning_rate: 1.0000e-04
# Epoch 134/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.6015 - val_loss: 0.6027 - learning_rate: 1.0000e-04
# Epoch 135/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5989 - val_loss: 0.6002 - learning_rate: 1.0000e-04
# Epoch 136/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5964 - val_loss: 0.5976 - learning_rate: 1.0000e-04
# Epoch 137/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5939 - val_loss: 0.5952 - learning_rate: 1.0000e-04
# Epoch 138/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5914 - val_loss: 0.5927 - learning_rate: 1.0000e-04
# Epoch 139/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5889 - val_loss: 0.5902 - learning_rate: 1.0000e-04
# Epoch 140/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5864 - val_loss: 0.5878 - learning_rate: 1.0000e-04
# Epoch 141/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5840 - val_loss: 0.5854 - learning_rate: 1.0000e-04
# Epoch 142/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.5816 - val_loss: 0.5830 - learning_rate: 1.0000e-04
# Epoch 143/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.5792 - val_loss: 0.5807 - learning_rate: 1.0000e-04
# Epoch 144/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.5768 - val_loss: 0.5783 - learning_rate: 1.0000e-04
# Epoch 145/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.5745 - val_loss: 0.5760 - learning_rate: 1.0000e-04
# Epoch 146/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5722 - val_loss: 0.5737 - learning_rate: 1.0000e-04
# Epoch 147/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5699 - val_loss: 0.5714 - learning_rate: 1.0000e-04
# Epoch 148/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5676 - val_loss: 0.5692 - learning_rate: 1.0000e-04
# Epoch 149/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5653 - val_loss: 0.5669 - learning_rate: 1.0000e-04
# Epoch 150/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5631 - val_loss: 0.5647 - learning_rate: 1.0000e-04
# Epoch 151/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5609 - val_loss: 0.5625 - learning_rate: 1.0000e-04
# Epoch 152/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5587 - val_loss: 0.5604 - learning_rate: 1.0000e-04
# Epoch 153/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5565 - val_loss: 0.5582 - learning_rate: 1.0000e-04
# Epoch 154/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5543 - val_loss: 0.5561 - learning_rate: 1.0000e-04
# Epoch 155/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5522 - val_loss: 0.5540 - learning_rate: 1.0000e-04
# Epoch 156/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5501 - val_loss: 0.5519 - learning_rate: 1.0000e-04
# Epoch 157/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5480 - val_loss: 0.5498 - learning_rate: 1.0000e-04
# Epoch 158/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5459 - val_loss: 0.5477 - learning_rate: 1.0000e-04
# Epoch 159/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5438 - val_loss: 0.5457 - learning_rate: 1.0000e-04
# Epoch 160/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5418 - val_loss: 0.5437 - learning_rate: 1.0000e-04
# Epoch 161/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5397 - val_loss: 0.5417 - learning_rate: 1.0000e-04
# Epoch 162/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5377 - val_loss: 0.5397 - learning_rate: 1.0000e-04
# Epoch 163/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5357 - val_loss: 0.5377 - learning_rate: 1.0000e-04
# Epoch 164/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5337 - val_loss: 0.5358 - learning_rate: 1.0000e-04
# Epoch 165/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5318 - val_loss: 0.5338 - learning_rate: 1.0000e-04
# Epoch 166/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5299 - val_loss: 0.5319 - learning_rate: 1.0000e-04
# Epoch 167/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5279 - val_loss: 0.5300 - learning_rate: 1.0000e-04
# Epoch 168/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5260 - val_loss: 0.5281 - learning_rate: 1.0000e-04
# Epoch 169/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5241 - val_loss: 0.5263 - learning_rate: 1.0000e-04
# Epoch 170/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5223 - val_loss: 0.5244 - learning_rate: 1.0000e-04
# Epoch 171/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5204 - val_loss: 0.5226 - learning_rate: 1.0000e-04
# Epoch 172/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5186 - val_loss: 0.5208 - learning_rate: 1.0000e-04
# Epoch 173/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5167 - val_loss: 0.5190 - learning_rate: 1.0000e-04
# Epoch 174/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5149 - val_loss: 0.5172 - learning_rate: 1.0000e-04
# Epoch 175/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5132 - val_loss: 0.5154 - learning_rate: 1.0000e-04
# Epoch 176/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5114 - val_loss: 0.5137 - learning_rate: 1.0000e-04
# Epoch 177/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5096 - val_loss: 0.5120 - learning_rate: 1.0000e-04
# Epoch 178/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5079 - val_loss: 0.5102 - learning_rate: 1.0000e-04
# Epoch 179/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5062 - val_loss: 0.5085 - learning_rate: 1.0000e-04
# Epoch 180/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.5044 - val_loss: 0.5069 - learning_rate: 1.0000e-04
# Epoch 181/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.5027 - val_loss: 0.5052 - learning_rate: 1.0000e-04
# Epoch 182/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.5011 - val_loss: 0.5035 - learning_rate: 1.0000e-04
# Epoch 183/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4994 - val_loss: 0.5019 - learning_rate: 1.0000e-04
# Epoch 184/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4977 - val_loss: 0.5003 - learning_rate: 1.0000e-04
# Epoch 185/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4961 - val_loss: 0.4987 - learning_rate: 1.0000e-04
# Epoch 186/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4945 - val_loss: 0.4971 - learning_rate: 1.0000e-04
# Epoch 187/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4929 - val_loss: 0.4955 - learning_rate: 1.0000e-04
# Epoch 188/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4913 - val_loss: 0.4939 - learning_rate: 1.0000e-04
# Epoch 189/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4897 - val_loss: 0.4923 - learning_rate: 1.0000e-04
# Epoch 190/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4881 - val_loss: 0.4908 - learning_rate: 1.0000e-04
# Epoch 191/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4866 - val_loss: 0.4893 - learning_rate: 1.0000e-04
# Epoch 192/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4851 - val_loss: 0.4878 - learning_rate: 1.0000e-04
# Epoch 193/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4835 - val_loss: 0.4863 - learning_rate: 1.0000e-04
# Epoch 194/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4820 - val_loss: 0.4848 - learning_rate: 1.0000e-04
# Epoch 195/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4805 - val_loss: 0.4833 - learning_rate: 1.0000e-04
# Epoch 196/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4790 - val_loss: 0.4818 - learning_rate: 1.0000e-04
# Epoch 197/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4776 - val_loss: 0.4804 - learning_rate: 1.0000e-04
# Epoch 198/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4761 - val_loss: 0.4790 - learning_rate: 1.0000e-04
# Epoch 199/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.4747 - val_loss: 0.4775 - learning_rate: 1.0000e-04
# Epoch 200/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.4732 - val_loss: 0.4761 - learning_rate: 1.0000e-04

# %% [markdown]
# Let's see the neurons!
#
# At least as a heatmap of the weights:

# %%
import seaborn as sns
import matplotlib.pyplot as plt

weights = nn_model_2layer.layers[1].get_weights()[0]  # Get weights from this layer (omit the intercept, which is [1])
weights = np.transpose(weights)

# Create a heatmap of the weights
plt.figure(figsize=(10, 8))
sns.heatmap(weights, annot=False, cmap='viridis')
plt.title("Neuron Weights Heatmap of the Input Layer")
plt.xlabel(f"Input Features (6)")
plt.ylabel("Neurons from Inputs to Layer1 (7)")
plt.show()

# %% [markdown]
# Next layer!

# %%
# Next layer
weights = nn_model_2layer.layers[2].get_weights()[0]  # Get weights from this layer (omit the intercept, which is [1])
weights = np.transpose(weights)

# Create a heatmap of the weights
plt.figure(figsize=(10, 8))
sns.heatmap(weights, annot=False, cmap='viridis')
plt.title("Neuron Weights Heatmap of Next Layer")
plt.xlabel("Neurons from Layer 1 (of 7)")
plt.ylabel("Neurons from Layer 1 to Layer 2 (of 1)")
plt.show()

# %% [markdown]
# Let's run `shap` to see if it does better...

# %%
def nn_predict_2layer(X):
    """Prediction function of the neural network (log scale)."""
    df = pd.DataFrame(X, columns=x)
    df_scaled = nn_preprocessor.transform(df)
    pred = nn_model_2layer.predict(df_scaled, verbose=0, batch_size=10_000).flatten()
    return np.log(pred)

nn_explainer = shap.KernelExplainer(nn_predict_2layer, data=X_bg)
shap_nn = nn_explainer.shap_values(X_explain, nsamples=30)

all_dep_plots(x, shap_nn, X_explain)   # create all feature-dependency plots
# Out:
# WARNING:shap:Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# Notice that these features do not _yet_ match the ones computed by the linear regression model we interpreted above.
#
# Thus far, the NNet is too primitive to be able to learn the real relationships among those dataset features.
#
# <font color="Coral">Your task</font> is to experiment below, in order to create a larger, more faithful NNet model.

# %% [markdown]
# ### The "Real" data model
#
# Usually datasets do not have a "real" model. At least not one that's known!
#
# This dataset, however, does have a _real_ underlying model! (It was inspired by the real data and then used to generate this dataset.)
#
# Here is the real model:

# %%
#
# The age is a much more complicated - non-linear - feature
def age_effect(age):
    x = (age - 66) / 60
    return 0.05 + x**8 + 0.4 * x**3 + 0.3 * x**2 + 0.06 * x

#
# here is the true model for this dataset:
def true_model(X):
    """Returns pd.Series of true expected frequencies."""
    df = pd.DataFrame(X, columns=x)  # Needed because SHAP turns df to np.array
    log_lambda = (
        0.15 * df.town
        + np.log(age_effect(df.driver_age))
        + (0.3 + 0.15 * df.town) * df.car_power / 100
        - 0.02 * df.car_age
    )
    return np.exp(log_lambda)

# %% [markdown]
# `shap` is not specific to NNets or linear regression models. It supports the interpretation of _any_ model, including the real one.
#
# Here is `shap`'s interpretation of this real model:

# %%
import shap

true_model_explainer = shap.KernelExplainer(lambda x: np.log(true_model(x)), data=X_bg)
shap_true = true_model_explainer.shap_values(X_explain, nsamples=30)

all_dep_plots(x, shap_true, X_explain)
# Out:
# WARNING:shap:Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# Things to notice:
# + the relationship between driver_age and the number of claims is "highly non-linear!"
# + there are also _two slopes_ for the linear car_power feature (so, officially, it's "not linear")
# + note, too, that car_weight has no impact on the output...
#   + Challenge question (not really a hw task): <br>  _**Why** do the modeling techniques above observe an impact of the car_weight feature?_

# %% [markdown]
# ## Final challenge: <font color="DodgerBlue">_Improve the NNet_</font>
#
# #### <font color="Coral"><b>Task Finale</b></font>
#
# From here, your task is to
# + create a more-capable neural network... with the goal of representing the actual data interactions ***better*** than the linear-regression model
# + consider using more layers (but not too many)
# + consider the "step-down" architecture, where
#   + the first post-input layer has the most neurons ("feature building")
#   + then, subsequent layers have fewer...
#   + tapering into the output layer
#
# You'll find that the NNet won't represent the "real" model perfectly, but it will
# + find its own features
# + represent the non-linear relationship (for driver_age)
# + and, for me, it could _start_ to represent the dependence of car_power on town
#
# <br>

# %% [markdown]
# ### Use the cells below to experiment with NNet building...
#
# Use the above `2layer` example as a template, and then - below -
# + experiment and create a new model -- and
# + show its `shap` interpretation... -- and
# + be sure to include a <font color="DodgerBlue">3-5 sentence <b>reflection</b> on</font> your experimentation (how long it took!) and how well the resulting NNet does at capturing the feature relationships of the actual, underlying "re[REDACTED]ty" ...
#
# <br>
#
# Worth remembering:  _We're **all** neural nets!_
# + It would seem we're always "keeping this in mind" 😀

# %%
# Scale features to [-1, 1]
from sklearn.preprocessing import MinMaxScaler

nn_preprocessor = MinMaxScaler(feature_range=(-1, 1))
X_train = nn_preprocessor.fit_transform(train[x])

print("Output after the data has been scaled:")
pd.DataFrame(X_train[0:5], columns=x)
# Out:
# Output after the data has been scaled:
#    year  town  driver_age  car_weight  car_power   car_age
# 0   1.0  -1.0    0.246377   -0.530612  -0.501754 -1.000000
# 1  -1.0   1.0   -0.072464   -0.530612  -0.256140 -0.818182
# 2   1.0   1.0   -0.072464   -0.969388  -0.817544 -0.636364
# 3   1.0   1.0   -0.333333   -0.867347  -0.887719 -0.181818
# 4   1.0   1.0   -0.594203   -0.489796  -0.445614 -0.727273

# %%
#
# Neural nets are worthy of their own course, for sure...
#
import tensorflow as tf
from tensorflow import keras
from keras import layers
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam
cb = [EarlyStopping(patience=20), ReduceLROnPlateau(patience=5)]  # "callbacks" for training (see below)

# Architecture
inputs = keras.Input(shape=(len(x),))

# additional layers can be added here!

# Add hidden layers (step-down architecture)
h1 = layers.Dense(32, activation="relu")(inputs)  # First hidden layer with 32 neurons and ReLU activation
h2 = layers.Dense(16, activation="relu")(h1)  # Second hidden layer with 16 neurons and ReLU activation
h3 = layers.Dense(8, activation="relu")(h2)   # Third hidden layer with 8 neurons and ReLU activation

outputs = layers.Dense(1, activation="exponential")(h3)
nn_model_deep = keras.Model(inputs=inputs, outputs=outputs)

nn_model_deep.summary()

# Calculate gradients
nn_model_deep.compile(optimizer=Adam(learning_rate=1e-4), loss="Poisson")
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 6)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 32)                  │             224 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 897 (3.50 KB)
#  Trainable params: 897 (3.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.random.set_seed(4349)

history_2layer = nn_model_deep.fit(
    x=X_train,
    y=train[y],
    epochs=200,
    batch_size=10_000,
    v[REDACTED]dation_split=0.1,
    callbacks=cb,
    verbose=1,         # consider running both values 0 (no printing) and 1 (printing)
)
# Out:
# Epoch 1/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 0.8908 - val_loss: 0.8816 - learning_rate: 1.0000e-04
# Epoch 2/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8785 - val_loss: 0.8693 - learning_rate: 1.0000e-04
# Epoch 3/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.8661 - val_loss: 0.8568 - learning_rate: 1.0000e-04
# Epoch 4/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8535 - val_loss: 0.8441 - learning_rate: 1.0000e-04
# Epoch 5/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.8406 - val_loss: 0.8311 - learning_rate: 1.0000e-04
# Epoch 6/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.8277 - val_loss: 0.8180 - learning_rate: 1.0000e-04
# Epoch 7/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8145 - val_loss: 0.8049 - learning_rate: 1.0000e-04
# Epoch 8/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.8013 - val_loss: 0.7916 - learning_rate: 1.0000e-04
# Epoch 9/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7880 - val_loss: 0.7782 - learning_rate: 1.0000e-04
# Epoch 10/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7745 - val_loss: 0.7647 - learning_rate: 1.0000e-04
# Epoch 11/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.7609 - val_loss: 0.7512 - learning_rate: 1.0000e-04
# Epoch 12/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7473 - val_loss: 0.7376 - learning_rate: 1.0000e-04
# Epoch 13/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7336 - val_loss: 0.7241 - learning_rate: 1.0000e-04
# Epoch 14/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7200 - val_loss: 0.7106 - learning_rate: 1.0000e-04
# Epoch 15/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.7065 - val_loss: 0.6972 - learning_rate: 1.0000e-04
# Epoch 16/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.6931 - val_loss: 0.6839 - learning_rate: 1.0000e-04
# Epoch 17/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6797 - val_loss: 0.6706 - learning_rate: 1.0000e-04
# Epoch 18/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.6663 - val_loss: 0.6574 - learning_rate: 1.0000e-04
# Epoch 19/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.6530 - val_loss: 0.6443 - learning_rate: 1.0000e-04
# Epoch 20/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.6398 - val_loss: 0.6313 - learning_rate: 1.0000e-04
# Epoch 21/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.6268 - val_loss: 0.6184 - learning_rate: 1.0000e-04
# Epoch 22/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.6138 - val_loss: 0.6057 - learning_rate: 1.0000e-04
# Epoch 23/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.6011 - val_loss: 0.5933 - learning_rate: 1.0000e-04
# Epoch 24/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5886 - val_loss: 0.5811 - learning_rate: 1.0000e-04
# Epoch 25/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5764 - val_loss: 0.5692 - learning_rate: 1.0000e-04
# Epoch 26/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5644 - val_loss: 0.5576 - learning_rate: 1.0000e-04
# Epoch 27/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5528 - val_loss: 0.5463 - learning_rate: 1.0000e-04
# Epoch 28/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.5415 - val_loss: 0.5353 - learning_rate: 1.0000e-04
# Epoch 29/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5304 - val_loss: 0.5246 - learning_rate: 1.0000e-04
# Epoch 30/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.5197 - val_loss: 0.5142 - learning_rate: 1.0000e-04
# Epoch 31/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.5093 - val_loss: 0.5041 - learning_rate: 1.0000e-04
# Epoch 32/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4992 - val_loss: 0.4944 - learning_rate: 1.0000e-04
# Epoch 33/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.4893 - val_loss: 0.4849 - learning_rate: 1.0000e-04
# Epoch 34/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4798 - val_loss: 0.4757 - learning_rate: 1.0000e-04
# Epoch 35/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4706 - val_loss: 0.4668 - learning_rate: 1.0000e-04
# Epoch 36/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.4617 - val_loss: 0.4582 - learning_rate: 1.0000e-04
# Epoch 37/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4531 - val_loss: 0.4499 - learning_rate: 1.0000e-04
# Epoch 38/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.4448 - val_loss: 0.4420 - learning_rate: 1.0000e-04
# Epoch 39/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.4368 - val_loss: 0.4344 - learning_rate: 1.0000e-04
# Epoch 40/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.4291 - val_loss: 0.4270 - learning_rate: 1.0000e-04
# Epoch 41/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.4217 - val_loss: 0.4200 - learning_rate: 1.0000e-04
# Epoch 42/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.4147 - val_loss: 0.4133 - learning_rate: 1.0000e-04
# Epoch 43/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4080 - val_loss: 0.4069 - learning_rate: 1.0000e-04
# Epoch 44/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4015 - val_loss: 0.4008 - learning_rate: 1.0000e-04
# Epoch 45/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3954 - val_loss: 0.3950 - learning_rate: 1.0000e-04
# Epoch 46/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3895 - val_loss: 0.3895 - learning_rate: 1.0000e-04
# Epoch 47/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3840 - val_loss: 0.3843 - learning_rate: 1.0000e-04
# Epoch 48/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3787 - val_loss: 0.3794 - learning_rate: 1.0000e-04
# Epoch 49/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3737 - val_loss: 0.3747 - learning_rate: 1.0000e-04
# Epoch 50/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3690 - val_loss: 0.3703 - learning_rate: 1.0000e-04
# Epoch 51/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3646 - val_loss: 0.3662 - learning_rate: 1.0000e-04
# Epoch 52/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3604 - val_loss: 0.3623 - learning_rate: 1.0000e-04
# Epoch 53/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3565 - val_loss: 0.3587 - learning_rate: 1.0000e-04
# Epoch 54/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3528 - val_loss: 0.3553 - learning_rate: 1.0000e-04
# Epoch 55/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3494 - val_loss: 0.3522 - learning_rate: 1.0000e-04
# Epoch 56/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3462 - val_loss: 0.3493 - learning_rate: 1.0000e-04
# Epoch 57/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3432 - val_loss: 0.3466 - learning_rate: 1.0000e-04
# Epoch 58/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3405 - val_loss: 0.3441 - learning_rate: 1.0000e-04
# Epoch 59/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3379 - val_loss: 0.3418 - learning_rate: 1.0000e-04
# Epoch 60/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3355 - val_loss: 0.3396 - learning_rate: 1.0000e-04
# Epoch 61/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3333 - val_loss: 0.3376 - learning_rate: 1.0000e-04
# Epoch 62/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3312 - val_loss: 0.3358 - learning_rate: 1.0000e-04
# Epoch 63/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3293 - val_loss: 0.3341 - learning_rate: 1.0000e-04
# Epoch 64/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3276 - val_loss: 0.3326 - learning_rate: 1.0000e-04
# Epoch 65/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3260 - val_loss: 0.3312 - learning_rate: 1.0000e-04
# Epoch 66/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.3245 - val_loss: 0.3298 - learning_rate: 1.0000e-04
# Epoch 67/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.3231 - val_loss: 0.3286 - learning_rate: 1.0000e-04
# Epoch 68/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.3218 - val_loss: 0.3275 - learning_rate: 1.0000e-04
# Epoch 69/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.3206 - val_loss: 0.3265 - learning_rate: 1.0000e-04
# Epoch 70/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3196 - val_loss: 0.3256 - learning_rate: 1.0000e-04
# Epoch 71/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3186 - val_loss: 0.3248 - learning_rate: 1.0000e-04
# Epoch 72/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3176 - val_loss: 0.3240 - learning_rate: 1.0000e-04
# Epoch 73/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.3168 - val_loss: 0.3233 - learning_rate: 1.0000e-04
# Epoch 74/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.3160 - val_loss: 0.3226 - learning_rate: 1.0000e-04
# Epoch 75/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.3153 - val_loss: 0.3220 - learning_rate: 1.0000e-04
# Epoch 76/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.3146 - val_loss: 0.3215 - learning_rate: 1.0000e-04
# Epoch 77/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.3140 - val_loss: 0.3210 - learning_rate: 1.0000e-04
# Epoch 78/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.3134 - val_loss: 0.3206 - learning_rate: 1.0000e-04
# Epoch 79/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.3129 - val_loss: 0.3202 - learning_rate: 1.0000e-04
# Epoch 80/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3125 - val_loss: 0.3198 - learning_rate: 1.0000e-04
# Epoch 81/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3120 - val_loss: 0.3195 - learning_rate: 1.0000e-04
# Epoch 82/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3116 - val_loss: 0.3191 - learning_rate: 1.0000e-04
# Epoch 83/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.3112 - val_loss: 0.3189 - learning_rate: 1.0000e-04
# Epoch 84/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3109 - val_loss: 0.3186 - learning_rate: 1.0000e-04
# Epoch 85/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3106 - val_loss: 0.3184 - learning_rate: 1.0000e-04
# Epoch 86/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3103 - val_loss: 0.3182 - learning_rate: 1.0000e-04
# Epoch 87/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3100 - val_loss: 0.3180 - learning_rate: 1.0000e-04
# Epoch 88/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3097 - val_loss: 0.3178 - learning_rate: 1.0000e-04
# Epoch 89/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3095 - val_loss: 0.3177 - learning_rate: 1.0000e-04
# Epoch 90/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3093 - val_loss: 0.3175 - learning_rate: 1.0000e-04
# Epoch 91/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3091 - val_loss: 0.3174 - learning_rate: 1.0000e-04
# Epoch 92/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3089 - val_loss: 0.3173 - learning_rate: 1.0000e-04
# Epoch 93/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3087 - val_loss: 0.3172 - learning_rate: 1.0000e-04
# Epoch 94/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3085 - val_loss: 0.3171 - learning_rate: 1.0000e-04
# Epoch 95/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3084 - val_loss: 0.3170 - learning_rate: 1.0000e-04
# Epoch 96/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3082 - val_loss: 0.3169 - learning_rate: 1.0000e-04
# Epoch 97/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3081 - val_loss: 0.3168 - learning_rate: 1.0000e-04
# Epoch 98/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3080 - val_loss: 0.3167 - learning_rate: 1.0000e-04
# Epoch 99/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3079 - val_loss: 0.3167 - learning_rate: 1.0000e-04
# Epoch 100/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3077 - val_loss: 0.3166 - learning_rate: 1.0000e-04
# Epoch 101/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3076 - val_loss: 0.3165 - learning_rate: 1.0000e-04
# Epoch 102/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3075 - val_loss: 0.3165 - learning_rate: 1.0000e-04
# Epoch 103/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3074 - val_loss: 0.3165 - learning_rate: 1.0000e-04
# Epoch 104/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3073 - val_loss: 0.3164 - learning_rate: 1.0000e-04
# Epoch 105/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3072 - val_loss: 0.3164 - learning_rate: 1.0000e-04
# Epoch 106/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3072 - val_loss: 0.3163 - learning_rate: 1.0000e-04
# Epoch 107/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3071 - val_loss: 0.3163 - learning_rate: 1.0000e-04
# Epoch 108/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3070 - val_loss: 0.3163 - learning_rate: 1.0000e-04
# Epoch 109/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3069 - val_loss: 0.3162 - learning_rate: 1.0000e-04
# Epoch 110/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3069 - val_loss: 0.3162 - learning_rate: 1.0000e-04
# Epoch 111/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3068 - val_loss: 0.3162 - learning_rate: 1.0000e-04
# Epoch 112/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3067 - val_loss: 0.3161 - learning_rate: 1.0000e-04
# Epoch 113/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3067 - val_loss: 0.3161 - learning_rate: 1.0000e-04
# Epoch 114/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3066 - val_loss: 0.3161 - learning_rate: 1.0000e-04
# Epoch 115/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3065 - val_loss: 0.3161 - learning_rate: 1.0000e-04
# Epoch 116/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3065 - val_loss: 0.3160 - learning_rate: 1.0000e-04
# Epoch 117/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3064 - val_loss: 0.3160 - learning_rate: 1.0000e-04
# Epoch 118/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3064 - val_loss: 0.3160 - learning_rate: 1.0000e-04
# Epoch 119/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3063 - val_loss: 0.3160 - learning_rate: 1.0000e-04
# Epoch 120/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3063 - val_loss: 0.3160 - learning_rate: 1.0000e-04
# Epoch 121/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3062 - val_loss: 0.3159 - learning_rate: 1.0000e-04
# Epoch 122/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.3062 - val_loss: 0.3159 - learning_rate: 1.0000e-04
# Epoch 123/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.3061 - val_loss: 0.3159 - learning_rate: 1.0000e-04
# Epoch 124/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3061 - val_loss: 0.3159 - learning_rate: 1.0000e-04
# Epoch 125/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-04
# Epoch 126/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-05
# Epoch 127/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-05
# Epoch 128/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-05
# Epoch 129/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-05
# Epoch 130/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-05
# Epoch 131/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-06
# Epoch 132/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-06
# Epoch 133/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-06
# Epoch 134/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-06
# Epoch 135/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-06
# Epoch 136/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-07
# Epoch 137/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-07
# Epoch 138/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-07
# Epoch 139/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-07
# Epoch 140/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-07
# Epoch 141/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-08
# Epoch 142/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-08
# Epoch 143/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-08
# Epoch 144/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-08
# Epoch 145/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-08
# Epoch 146/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-09
# Epoch 147/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-09
# Epoch 148/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-09
# Epoch 149/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-09
# Epoch 150/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-09
# Epoch 151/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-10
# Epoch 152/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-10
# Epoch 153/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-10
# Epoch 154/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-10
# Epoch 155/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-10
# Epoch 156/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-11
# Epoch 157/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-11
# Epoch 158/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-11
# Epoch 159/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-11
# Epoch 160/200
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3060 - val_loss: 0.3159 - learning_rate: 1.0000e-11

# %%
# run SHAP
def nn_predict_2layer(X):
    """Prediction function of the neural network (log scale)."""
    df = pd.DataFrame(X, columns=x)
    df_scaled = nn_preprocessor.transform(df)
    pred = nn_model_deep.predict(df_scaled, verbose=0, batch_size=10_000).flatten()
    return np.log(pred)

nn_explainer = shap.KernelExplainer(nn_predict_2layer, data=X_bg)
shap_nn = nn_explainer.shap_values(X_explain, nsamples=30)

all_dep_plots(x, shap_nn, X_explain)   # create all feature-dependency plots
# Out:
# WARNING:shap:Using 200 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# I decided to add 3 extra layers of 32, 16, and 8 neurons. Following the stepwise decrease structure. My model did a good job approximating the year, town, and car_power impacts. Howevever, it did not capture the little impact of car_weight. It did not capture the the U-shaped non-linear impact of the driver age from the real model, rather it seemed to capture a smaller version of an upside-down version. Also, the car age relationship is positive while the actual is negative. 3/6 of the variables were modeled well. I spent around 10 minutes building this neural network, I wish I had more time to play around a tweak it for better results.
