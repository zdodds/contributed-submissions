# %% [markdown]
# <br>
#
# ##   hw6pr2digits_modeler
# + digits clasification via decision trees and random forests...
# + Remember: feel free to re-use the cleaned data from previous weeks (already here)

# %%
#
# SUGGESTION:  
# 
# +++ copy-paste-and-alter from the week6 iris- + births-modeling notebooks into here +++
#
# when the data is ready to view, you might want to grab
# the digits-visualization code    
#

# %% [markdown]
# ## Data set up...
# + Use the cleaned data from prior weeks (it should be here in this folder as digits_cleaned.csv)
# + (I don't think there's too much more to adjust, data-wise...)
# + Next, let's see how well the DT/RF techniques can predict the digit, based on its 64 pixels...

# %%
# libraries!
import numpy as np      # numpy is Python's "array" library
import pandas as pd     # Pandas is Python's "data" library ("dataframe" == spreadsheet)

# %%
filename = 'digits_cleaned.csv'
df_tidy = pd.read_csv(filename)      # encoding = "utf-8", "latin1"
print(f"{filename} : file read into a pandas dataframe.")
# Out:
# digits_cleaned.csv : file read into a pandas dataframe.

# %%
# different version vary on how to see all rows (adapt to suit your system!)
#
print(f"df_tidy.shape is {df_tidy.shape}\n")
# Out:
# df_tidy.shape is (1768, 65)

# %%
df_model1 = df_tidy
df_model1
# Out:
#       pix0  pix1  pix2  pix3  pix4  pix5  pix6  pix7  pix8  pix9  ...  pix55  \
# 0        0     0     9    14     8     1     0     0     0     0  ...      0
# 1        0     0    11    12     0     0     0     0     0     2  ...      0
# 2        0     0     1     9    15    11     0     0     0     0  ...      0
# 3        0     0     0     0    14    13     1     0     0     0  ...      0
# 4        0     0     5    12     1     0     0     0     0     0  ...      2
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...    ...
# 1763     0     0     4    10    13     6     0     0     0     1  ...      0
# 1764     0     0     6    16    13    11     1     0     0     0  ...      0
# 1765     0     0     1    11    15     1     0     0     0     0  ...      0
# 1766     0     0     2    10     7     0     0     0     0     0  ...      0
# 1767     0     0    10    14     8     1     0     0     0     2  ...      0
#
#       pix56  pix57  pix58  pix59  pix60  pix61  pix62  pix63  actual_digit
# 0         0      0     11     16     15     11      1      0             8
# 1         0      0      9     12     13      3      0      0             9
# 2         0      0      1     10     13      3      0      0             0
# 3         0      0      0      1     13     16      1      0             1
# 4         0      0      3     11      8     13     12      4             2
# ...     ...    ...    ...    ...    ...    ...    ...    ...           ...
# 1763      0      0      2     14     15      9      0      0             9
# 1764      0      0      6     16     14      6      0      0             0
# 1765      0      0      2      9     13      6      0      0             8
# 1766      0      0      5     12     16     12      0      0             9
# 1767      0      1      8     12     14     12      1      0             8
#
# [1768 rows x 65 columns]

# %%
#
# once we have all the columns we want, let's create an index of their names...

#
# Let's make sure we have all of our helpful variables in one place 
#       To be adapted if we drop/add more columns...
#

#
# let's keep our column names in variables, for reference
#
COLUMNS = df_model1.columns            # "list" of columns
print(f"COLUMNS is {COLUMNS}\n")  
  # It's a "pandas" list, called an Index
  # use it just as a Python list of strings:
print(f"COLUMNS[0] is {COLUMNS[0]}\n")

# let's create a dictionary to look up any column index by name
COL_INDEX = {}
for i, name in enumerate(COLUMNS):
    COL_INDEX[name] = i  # using the name (as key), look up the value (i)
print(f"COL_INDEX is {COL_INDEX}\n\n")

#
# Feature names!
#
FEATURES = COLUMNS[0:64]
TARGET = COLUMNS[64]

#
# and our "classification" names
#

# all of scikit-learn's ML routines need numbers, not strings
#   ... even for categories/classifications (like species!)

SPECIES = [str(x) for x in sorted(df_model1[TARGET].unique())]  
SPECIES_INDEX = {s: i for i, s in enumerate(SPECIES)}

# Let's try it out...
for label in SPECIES:
    print(f"{label} maps to {SPECIES_INDEX[label]}")
# Out:
# COLUMNS is Index(['pix0', 'pix1', 'pix2', 'pix3', 'pix4', 'pix5', 'pix6', 'pix7', 'pix8',
#        'pix9', 'pix10', 'pix11', 'pix12', 'pix13', 'pix14', 'pix15', 'pix16',
#        'pix17', 'pix18', 'pix19', 'pix20', 'pix21', 'pix22', 'pix23', 'pix24',
#        'pix25', 'pix26', 'pix27', 'pix28', 'pix29', 'pix30', 'pix31', 'pix32',
#        'pix33', 'pix34', 'pix35', 'pix36', 'pix37', 'pix38', 'pix39', 'pix40',
#        'pix41', 'pix42', 'pix43', 'pix44', 'pix45', 'pix46', 'pix47', 'pix48',
#        'pix49', 'pix50', 'pix51', 'pix52', 'pix53', 'pix54', 'pix55', 'pix56',
#        'pix57', 'pix58', 'pix59', 'pix60', 'pix61', 'pix62', 'pix63',
#        'actual_digit'],
#       dtype='object')
#
# COLUMNS[0] is pix0
#
# COL_INDEX is {'pix0': 0, 'pix1': 1, 'pix2': 2, 'pix3': 3, 'pix4': 4, 'pix5': 5, 'pix6': 6, 'pix7': 7, 'pix8': 8, 'pix9': 9, 'pix10': 10, 'pix11': 11, 'pix12': 12, 'pix13': 13, 'pix14': 14, 'pix15': 15, 'pix16': 16, 'pix17': 17, 'pix18': 18, 'pix19': 19, 'pix20': 20, 'pix21': 21, 'pix22': 22, 'pix23': 23, 'pix24': 24, 'pix25': 25, 'pix26': 26, 'pix27': 27, 'pix28': 28, 'pix29': 29, 'pix30': 30, 'pix31': 31, 'pix32': 32, 'pix33': 33, 'pix34': 34, 'pix35': 35, 'pix36': 36, 'pix37': 37, 'pix38': 38, 'pix39': 39, 'pix40': 40, 'pix41': 41, 'pix42': 42, 'pix43': 43, 'pix44': 44, 'pix45': 45, 'pix46': 46, 'pix47': 47, 'pix48': 48, 'pix49': 49, 'pix50': 50, 'pix51': 51, 'pix52': 52, 'pix53': 53, 'pix54': 54, 'pix55': 55, 'pix56': 56, 'pix57': 57, 'pix58': 58, 'pix59': 59, 'pix60': 60, 'pix61': 61, 'pix62': 62, 'pix63': 63, 'actual_digit': 64}
#
#
# 0 maps to 0
# 1 maps to 1
# 2 maps to 2
# 3 maps to 3
# 4 maps to 4
# 5 maps to 5
# 6 maps to 6
# 7 maps to 7
# 8 maps to 8
# 9 maps to 9

# %%
A = df_model1.to_numpy()   
print(A)
# Out:
# [[ 0  0  9 ...  1  0  8]
#  [ 0  0 11 ...  0  0  9]
#  [ 0  0  1 ...  0  0  0]
#  ...
#  [ 0  0  1 ...  0  0  8]
#  [ 0  0  2 ...  0  0  9]
#  [ 0  0 10 ...  1  0  8]]

# %%
A = A.astype('float64')  # so many:  www.tutorialspoint.com/numpy/numpy_data_types.htm
print(A)
# Out:
# [[ 0.  0.  9. ...  1.  0.  8.]
#  [ 0.  0. 11. ...  0.  0.  9.]
#  [ 0.  0.  1. ...  0.  0.  0.]
#  ...
#  [ 0.  0.  1. ...  0.  0.  8.]
#  [ 0.  0.  2. ...  0.  0.  9.]
#  [ 0.  0. 10. ...  1.  0.  8.]]

# %%
NUM_ROWS, NUM_COLS = A.shape
print(f"\nThe dataset has {NUM_ROWS} rows and {NUM_COLS} cols")
# Out:
# The dataset has 1768 rows and 65 cols

# %%
# let's use all our variables, to reinforce that we have
# (1) their names...
# (2) access and control over each...

# choose a row index, n:
n = 42
print(f"digit #{n} is {A[n]}")

for i in range(len(COLUMNS)):
    colname = COLUMNS[i]
    value = A[n][i]
    print(f"  Its {colname} is {value}")
# Out:
# digit #42 is [ 0.  0.  0. 10. 11.  0.  0.  0.  0.  0.  9. 16.  6.  0.  0.  0.  0.  0.
#  15. 13.  0.  0.  0.  0.  0.  0. 14. 10.  0.  0.  0.  0.  0.  1. 15. 12.
#   8.  2.  0.  0.  0.  0. 12. 16. 16. 16. 10.  1.  0.  0.  7. 16. 12. 12.
#  16.  4.  0.  0.  0.  9. 15. 12.  5.  0.  6.]
#   Its pix0 is 0.0
#   Its pix1 is 0.0
#   Its pix2 is 0.0
#   Its pix3 is 10.0
#   Its pix4 is 11.0
#   Its pix5 is 0.0
#   Its pix6 is 0.0
#   Its pix7 is 0.0
#   Its pix8 is 0.0
#   Its pix9 is 0.0
#   Its pix10 is 9.0
#   Its pix11 is 16.0
#   Its pix12 is 6.0
#   Its pix13 is 0.0
#   Its pix14 is 0.0
#   Its pix15 is 0.0
#   Its pix16 is 0.0
#   Its pix17 is 0.0
#   Its pix18 is 15.0
#   Its pix19 is 13.0
#   Its pix20 is 0.0
#   Its pix21 is 0.0
#   Its pix22 is 0.0
#   Its pix23 is 0.0
#   Its pix24 is 0.0
#   Its pix25 is 0.0
#   Its pix26 is 14.0
#   Its pix27 is 10.0
#   Its pix28 is 0.0
#   Its pix29 is 0.0
#   Its pix30 is 0.0
#   Its pix31 is 0.0
#   Its pix32 is 0.0
#   Its pix33 is 1.0
#   Its pix34 is 15.0
#   Its pix35 is 12.0
#   Its pix36 is 8.0
#   Its pix37 is 2.0
#   Its pix38 is 0.0
#   Its pix39 is 0.0
#   Its pix40 is 0.0
#   Its pix41 is 0.0
#   Its pix42 is 12.0
#   Its pix43 is 16.0
#   Its pix44 is 16.0
#   Its pix45 is 16.0
#   Its pix46 is 10.0
#   Its pix47 is 1.0
#   Its pix48 is 0.0
#   Its pix49 is 0.0
#   Its pix50 is 7.0
#   Its pix51 is 16.0
#   Its pix52 is 12.0
#   Its pix53 is 12.0
#   Its pix54 is 16.0
#   Its pix55 is 4.0
#   Its pix56 is 0.0
#   Its pix57 is 0.0
#   Its pix58 is 0.0
#   Its pix59 is 9.0
#   Its pix60 is 15.0
#   Its pix61 is 12.0
#   Its pix62 is 5.0
#   Its pix63 is 0.0
#   Its actual_digit is 6.0

# %%
#define the features (X_all) and the target to be predicted (y_all)
print("+++ Start of data definitions +++\n")

A = df_model1.values

X_all = A[:,0:64]      # features: 64 pixel
y_all = np.array([str(x) for x in A[:,64]]) #Be sure SPECIES are strings!  e.g.    SPECIES = [ str(x) for x in SPECIES ]

print(f"y_all (digit labels) are \n{y_all}")
print(f"X_all (features: month and day) are \n{X_all[0:5]}")
# Out:
# +++ Start of data definitions +++
#
# y_all (digit labels) are
# ['8' '9' '0' ... '8' '9' '8']
# X_all (features: month and day) are
# [[ 0  0  9 14  8  1  0  0  0  0 12 14 14 12  0  0  0  0  9 10  0 15  4  0
#    0  0  3 16 12 14  2  0  0  0  4 16 16  2  0  0  0  3 16  8 10 13  2  0
#    0  1 15  1  3 16  8  0  0  0 11 16 15 11  1  0]
#  [ 0  0 11 12  0  0  0  0  0  2 16 16 16 13  0  0  0  3 16 12 10 14  0  0
#    0  1 16  1 12 15  0  0  0  0 13 16  9 15  2  0  0  0  0  3  0  9 11  0
#    0  0  0  0  9 15  4  0  0  0  9 12 13  3  0  0]
#  [ 0  0  1  9 15 11  0  0  0  0 11 16  8 14  6  0  0  2 16 10  0  9  9  0
#    0  1 16  4  0  8  8  0  0  4 16  4  0  8  8  0  0  1 16  5  1 11  3  0
#    0  0 12 12 10 10  0  0  0  0  1 10 13  3  0  0]
#  [ 0  0  0  0 14 13  1  0  0  0  0  5 16 16  2  0  0  0  0 14 16 12  0  0
#    0  1 10 16 16 12  0  0  0  3 12 14 16  9  0  0  0  0  0  5 16 15  0  0
#    0  0  0  4 16 14  0  0  0  0  0  1 13 16  1  0]
#  [ 0  0  5 12  1  0  0  0  0  0 15 14  7  0  0  0  0  0 13  1 12  0  0  0
#    0  2 10  0 14  0  0  0  0  0  2  0 16  1  0  0  0  0  0  6 15  0  0  0
#    0  0  9 16 15  9  8  2  0  0  3 11  8 13 12  4]]

# %%
#permute
# we scramble the data, to remove (potential) dependence on its ordering: 
# 
indices = np.random.permutation(len(y_all))  # indices is a permutation-list

# we scramble both X and y, necessarily with the same permutation
X_permed = X_all[indices]              # we apply the _same_ permutation to each!
y_permed = y_all[indices]              # again...
print(f"The scrambled labels/species are \n {y_permed}")
print(f"The corresponding data rows are \n {X_permed[0:5]}")
# Out:
# The scrambled labels/species are
#  ['1' '3' '2' ... '4' '7' '9']
# The corresponding data rows are
#  [[ 0  0  0  0 12  8  0  0  0  0  0  3 16 16  0  0  0  0  1 13 16 11  0  0
#    0  3 15 16 16  8  0  0  0  0  3  7 16  8  0  0  0  0  0  4 16  8  0  0
#    0  0  0  4 16 14  0  0  0  0  0  0 14 15  5  0]
#  [ 0  2 13 16  4  0  0  0  0 12 12 12 15  0  0  0  0  5  2  7 14  0  0  0
#    0  0  3 15 15  7  0  0  0  0  4 12 12 16  3  0  0  0  0  0  0 15  7  0
#    0  3 16  8  9 16  6  0  0  1 11 12 14  9  0  0]
#  [ 0  0  9 16 16 13  1  0  0  0 12 13 14 16  7  0  0  0  0  0  6 16  4  0
#    0  0  0  0 13 14  1  0  0  0  1 10 16  6  0  0  0  0  7 16  8  0  0  0
#    0  2 15 16 12  7  0  0  0  0  9 14 16 16  2  0]
#  [ 0  4 14 16 16 12  1  0  0  2 12  7 14 16  6  0  0  0  0  5 16 10  0  0
#    0  0  0  4 16  7  0  0  0  0  0  4 16  6  0  0  0  0  0  1 15 11  0  0
#    0  1  8 10 16 10  0  0  0  5 16 16 15  1  0  0]
#  [ 0  0  5 15 16 14  1  0  0  0 11 13  9 16  5  0  0  0  0  0  5 16  2  0
#    0  0  0  0  9 11  0  0  0  0  7 13 15 12  1  0  0  0  7 14 14 12  4  0
#    0  0  0 14  3  0  0  0  0  0  7 10  0  0  0  0]]

# %%
#create 80/20 train/test split of data
#
# We next separate into test data and training data ... 
#    + We will train on the training data...
#    + We will _not_ look at the testing data to build the model
#
# Then, afterward, we will test on the testing data -- and see how well we do!
#

#
# a common convention:  train on 80%, test on 20%    Let's define the TEST_PERCENT
#

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_permed, y_permed, test_size=0.2, random_state=42)

print(f"training with {len(y_train)} rows;  testing with {len(y_test)} rows\n" )

print(f"Held-out data... (testing data: {len(y_test)})")
print(f"y_test: {y_test}\n")
print(f"X_test (few rows): {X_test[0:5,:]}")  # 5 rows
print()
print(f"Data used for modeling... (training data: {len(y_train)})")
print(f"y_train: {y_train}\n")
print(f"X_train (few rows): {X_train[0:5,:]}")  # 5 rows
# Out:
# training with 1414 rows;  testing with 354 rows
#
# Held-out data... (testing data: 354)
# y_test: ['4' '0' '2' '7' '2' '2' '6' '7' '4' '4' '8' '8' '8' '1' '2' '3' '8' '7'
#  '9' '0' '9' '3' '8' '8' '9' '2' '3' '6' '9' '0' '5' '3' '5' '7' '8' '3'
#  '6' '3' '3' '3' '7' '7' '6' '9' '9' '6' '6' '3' '5' '5' '9' '4' '6' '6'
#  '8' '8' '5' '5' '7' '3' '6' '9' '5' '0' '1' '4' '8' '3' '4' '5' '3' '7'
#  '0' '0' '5' '0' '6' '1' '0' '7' '9' '3' '9' '7' '4' '0' '1' '7' '9' '1'
#  '0' '7' '9' '3' '5' '0' '6' '2' '7' '1' '0' '8' '1' '6' '9' '8' '5' '4'
#  '0' '8' '1' '7' '2' '1' '1' '4' '4' '4' '7' '1' '5' '3' '0' '5' '8' '8'
#  '9' '5' '0' '6' '7' '2' '2' '5' '4' '3' '9' '8' '2' '1' '1' '7' '6' '3'
#  '2' '3' '2' '3' '9' '2' '5' '5' '2' '1' '6' '5' '0' '1' '6' '2' '3' '9'
#  '0' '1' '0' '1' '5' '1' '9' '2' '6' '0' '0' '5' '0' '1' '1' '9' '8' '1'
#  '0' '0' '2' '7' '2' '2' '8' '6' '3' '8' '6' '0' '4' '9' '9' '9' '7' '5'
#  '2' '6' '0' '4' '6' '6' '3' '7' '3' '9' '5' '6' '1' '7' '9' '9' '5' '0'
#  '0' '4' '1' '8' '1' '2' '8' '5' '5' '5' '8' '9' '6' '9' '8' '5' '2' '3'
#  '5' '5' '2' '0' '7' '1' '5' '1' '1' '0' '9' '2' '5' '8' '8' '4' '8' '0'
#  '7' '6' '2' '7' '2' '7' '5' '9' '9' '7' '3' '4' '7' '3' '9' '2' '3' '7'
#  '2' '6' '3' '4' '2' '8' '4' '5' '9' '3' '2' '9' '6' '2' '5' '9' '1' '9'
#  '6' '5' '0' '2' '8' '9' '6' '6' '0' '9' '4' '5' '9' '2' '5' '7' '4' '1'
#  '9' '7' '5' '2' '5' '7' '9' '8' '4' '8' '2' '9' '8' '8' '7' '5' '2' '5'
#  '7' '5' '3' '2' '4' '9' '5' '2' '0' '8' '7' '1' '1' '9' '8' '1' '8' '6'
#  '4' '0' '8' '4' '2' '3' '0' '6' '7' '7' '8' '7']
#
# X_test (few rows): [[ 0  0  0  8 13  0  0  0  0  0  1 16 16  0  0  0  0  0  7 16 16  0  0  0
#    0  1 15 16 16  0  0  0  0  6 16 15 16  9  2  0  0  6 15 16 16 16 11  0
#    0  0  0 11 16  0  0  0  0  0  0 10 14  0  0  0]
#  [ 0  0 10 12 14  1  0  0  0  0 16 16 16 12  0  0  0  5 16  8  3 16  0  0
#    0  8 13  0  0  8  7  0  0  8 12  0  0  6  8  0  0  8 13  0  4 12  8  0
#    0  7 16 16 16 13  0  0  0  0 11 14  8  1  0  0]
#  [ 0  2 13 16 10  0  0  0  0 12 15  9 16  2  0  0  0 10  8  1 16  6  0  0
#    0  1  1  2 16  6  0  0  0  0  0 10 15  2  0  0  0  0  2 15  9  0  0  0
#    0  2 15 16  9  8  6  0  0  1 13 16 16 16 16  3]
#  [ 0  0  3 10 16 16  4  0  0  0  0  0  1 14  7  0  0  0  0  0  2 15  4  0
#    0  0  4  4 12 15  5  0  0  1 15 16 16  9  4  0  0  0  2 11 13  0  0  0
#    0  0  1 16  5  0  0  0  0  0  3 12  0  0  0  0]
#  [ 0  5 16 15  5  0  0  0  0  2 12 15 16  0  0  0  0  0  0 14 14  2  0  0
#    0  0  2 16  9  0  0  0  0  0 11 16  2  0  0  0  0  4 16  8  0  0  0  0
#    0 13 16 11  8  8  3  0  0  6 16 16 16 16  7  0]]
#
# Data used for modeling... (training data: 1414)
# y_train: ['9' '6' '2' ... '7' '7' '8']
#
# X_train (few rows): [[ 0  0 10 13  9  1  0  0  0  2 16  7 10  8  0  0  0  0 12 12  7 11  0  0
#    0  3 16 16 16  7  0  0  0  0  5  8 12 10  1  0  0  0  0  0  0 11  7  0
#    0  0  0  0  0  3 15  0  0  0 11 16 16 16  8  0]
#  [ 0  0  2 15 15  3  0  0  0  0 13 15  8  3  0  0  0  5 16  6  0  0  0  0
#    0  8 15  5  4  2  0  0  0  8 16 16 16 14  2  0  0  4 16  7  1 13  8  0
#    0  0 11 12  1 11 13  0  0  0  1 12 16 16 10  0]
#  [ 0  0  9 16 16  8  0  0  0  5 16 15 14 16  0  0  0  4  9  3 13 12  0  0
#    0  0  0  8 15  1  0  0  0  0  2 16  7  0  0  0  0  0 11 14  1  4  3  0
#    0  0 16 14 15 16  4  0  0  0  9 16 15  5  0  0]
#  [ 0  0  0  2 14  0  0  0  0  0  0 12  9  0  0  0  0  0  8 12  0  0 13  5
#    0  0 13  8  0  9 14  0  0  4 16 16 12 16  4  0  0  4 12 12 15 12  0  0
#    0  0  0  1 15  4  0  0  0  0  0  4 10  0  0  0]
#  [ 0  0  1 13 12  5  0  0  0  0 11 16  4 13  2  0  0  2 16  4  0  8  5  0
#    0  7 12  0  0  8  8  0  0  6 12  0  0  5  8  0  0  3 16  0  0  8  7  0
#    0  1 15  8  6 15  3  0  0  0  2 13 15  6  0  0]]

# %% [markdown]
# ## First: &nbsp; _Decision Trees_

# %%
#
# +++ This is the "Model-building and Model-training Cell"
#       
# Create a DT model and train it! 
#
from sklearn import tree      # for decision trees

best_depth = 1   # we don't know what depth to use, so let's guess 1
dtree_model = tree.DecisionTreeClassifier(max_depth=best_depth)

# Let's train the model.   It's this one line:
dtree_model.fit(X_train, y_train)                              # yay!  trained!
print("Created and trained a DT classifier with max depth =", best_depth)
# Out:
# Created and trained a DT classifier with max depth = 1

# %%
#
# +++ This cell will "Model-testing Cell"
#
# Now, let's see how well our model does on our "held-out data" (the testing data)
#

# We run our test set:

# the function knn_model.predict is the instantiation of our model
# it's what runs the k-nearest-neighbors algorithm:
predicted_labels = dtree_model.predict(X_test)   
actual_labels = y_test

# Let's print them so we can compare...
print("Predicted labels:", predicted_labels)
print("Actual  labels  :", actual_labels)

# And, some overall results
num_correct = sum(predicted_labels == actual_labels)
total = len(actual_labels)
print(f"\nResults on test set:  {num_correct} correct out of {total} total.")
# Out:
# Predicted labels: ['3' '0' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3'
#  '3' '0' '3' '3' '3' '3' '3' '3' '3' '3' '0' '0' '3' '3' '3' '3' '3' '3'
#  '3' '3' '3' '3' '3' '3' '3' '3' '0' '3' '3' '3' '3' '0' '3' '3' '3' '3'
#  '3' '3' '3' '3' '3' '3' '3' '3' '3' '0' '3' '3' '3' '3' '3' '3' '3' '3'
#  '0' '0' '3' '0' '3' '3' '0' '3' '3' '3' '3' '3' '3' '0' '3' '3' '0' '3'
#  '0' '3' '3' '3' '3' '0' '3' '3' '3' '3' '0' '3' '3' '3' '3' '3' '3' '3'
#  '0' '3' '3' '3' '0' '3' '3' '3' '3' '3' '3' '3' '3' '3' '0' '3' '3' '3'
#  '3' '3' '0' '3' '3' '3' '3' '3' '3' '3' '3' '3' '0' '3' '3' '3' '3' '3'
#  '3' '3' '3' '3' '0' '3' '0' '3' '3' '3' '3' '3' '0' '3' '3' '3' '3' '3'
#  '0' '3' '0' '3' '3' '3' '3' '3' '3' '0' '0' '3' '0' '3' '3' '3' '3' '3'
#  '0' '0' '3' '3' '3' '3' '3' '3' '3' '3' '3' '0' '3' '3' '3' '3' '3' '3'
#  '3' '3' '0' '3' '3' '3' '3' '3' '3' '0' '3' '3' '3' '3' '0' '0' '3' '0'
#  '0' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3'
#  '3' '3' '3' '0' '3' '3' '3' '3' '3' '0' '3' '3' '0' '3' '3' '3' '3' '0'
#  '3' '3' '3' '3' '3' '3' '3' '0' '3' '3' '3' '3' '3' '3' '0' '3' '3' '3'
#  '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '0' '3' '3'
#  '3' '3' '0' '3' '3' '0' '3' '3' '0' '3' '3' '0' '3' '3' '3' '3' '3' '3'
#  '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3' '3'
#  '3' '0' '3' '3' '3' '0' '0' '3' '0' '3' '3' '3' '3' '3' '3' '3' '3' '3'
#  '3' '0' '3' '3' '3' '3' '0' '3' '3' '3' '3' '3']
# Actual  labels  : ['4' '0' '2' '7' '2' '2' '6' '7' '4' '4' '8' '8' '8' '1' '2' '3' '8' '7'
#  '9' '0' '9' '3' '8' '8' '9' '2' '3' '6' '9' '0' '5' '3' '5' '7' '8' '3'
#  '6' '3' '3' '3' '7' '7' '6' '9' '9' '6' '6' '3' '5' '5' '9' '4' '6' '6'
#  '8' '8' '5' '5' '7' '3' '6' '9' '5' '0' '1' '4' '8' '3' '4' '5' '3' '7'
#  '0' '0' '5' '0' '6' '1' '0' '7' '9' '3' '9' '7' '4' '0' '1' '7' '9' '1'
#  '0' '7' '9' '3' '5' '0' '6' '2' '7' '1' '0' '8' '1' '6' '9' '8' '5' '4'
#  '0' '8' '1' '7' '2' '1' '1' '4' '4' '4' '7' '1' '5' '3' '0' '5' '8' '8'
#  '9' '5' '0' '6' '7' '2' '2' '5' '4' '3' '9' '8' '2' '1' '1' '7' '6' '3'
#  '2' '3' '2' '3' '9' '2' '5' '5' '2' '1' '6' '5' '0' '1' '6' '2' '3' '9'
#  '0' '1' '0' '1' '5' '1' '9' '2' '6' '0' '0' '5' '0' '1' '1' '9' '8' '1'
#  '0' '0' '2' '7' '2' '2' '8' '6' '3' '8' '6' '0' '4' '9' '9' '9' '7' '5'
#  '2' '6' '0' '4' '6' '6' '3' '7' '3' '9' '5' '6' '1' '7' '9' '9' '5' '0'
#  '0' '4' '1' '8' '1' '2' '8' '5' '5' '5' '8' '9' '6' '9' '8' '5' '2' '3'
#  '5' '5' '2' '0' '7' '1' '5' '1' '1' '0' '9' '2' '5' '8' '8' '4' '8' '0'
#  '7' '6' '2' '7' '2' '7' '5' '9' '9' '7' '3' '4' '7' '3' '9' '2' '3' '7'
#  '2' '6' '3' '4' '2' '8' '4' '5' '9' '3' '2' '9' '6' '2' '5' '9' '1' '9'
#  '6' '5' '0' '2' '8' '9' '6' '6' '0' '9' '4' '5' '9' '2' '5' '7' '4' '1'
#  '9' '7' '5' '2' '5' '7' '9' '8' '4' '8' '2' '9' '8' '8' '7' '5' '2' '5'
#  '7' '5' '3' '2' '4' '9' '5' '2' '0' '8' '7' '1' '1' '9' '8' '1' '8' '6'
#  '4' '0' '8' '4' '2' '3' '0' '6' '7' '7' '8' '7']
#
# Results on test set:  66 correct out of 354 total.

# %%
#
# Let's print these more helpfully, in a vertical table
#

def compare_labels(predicted_labels, actual_labels):
    """ a more neatly formatted comparison """
    NUM_LABELS = len(predicted_labels)
    num_correct = 0
    
    for i in range(NUM_LABELS):
        p = int(predicted_labels[i])         # round protects from fp error 
        a = int(actual_labels[i])
        result = "incorrect"
        if p == a:  # if they match,
            result = ""       # no longer incorrect
            num_correct += 1  # and we count a match!

        print(f"row {i:>3d} : {SPECIES[p]:>12s} {SPECIES[a]:<12s}   {result}")   

    print()
    print("Correct:", num_correct, "out of", NUM_LABELS)
    return num_correct

# let's try it out!
compare_labels(predicted_labels,actual_labels)
# Out:
# row   0 :            3 4              incorrect
# row   1 :            0 0
# row   2 :            3 2              incorrect
# row   3 :            3 7              incorrect
# row   4 :            3 2              incorrect
# row   5 :            3 2              incorrect
# row   6 :            3 6              incorrect
# row   7 :            3 7              incorrect
# row   8 :            3 4              incorrect
# row   9 :            3 4              incorrect
# row  10 :            3 8              incorrect
# row  11 :            3 8              incorrect
# row  12 :            3 8              incorrect
# row  13 :            3 1              incorrect
# row  14 :            3 2              incorrect
# row  15 :            3 3
# row  16 :            3 8              incorrect
# row  17 :            3 7              incorrect
# row  18 :            3 9              incorrect
# row  19 :            0 0
# row  20 :            3 9              incorrect
# row  21 :            3 3
# row  22 :            3 8              incorrect
# row  23 :            3 8              incorrect
# row  24 :            3 9              incorrect
# row  25 :            3 2              incorrect
# row  26 :            3 3
# row  27 :            3 6              incorrect
# row  28 :            0 9              incorrect
# row  29 :            0 0
# row  30 :            3 5              incorrect
# row  31 :            3 3
# row  32 :            3 5              incorrect
# row  33 :            3 7              incorrect
# row  34 :            3 8              incorrect
# row  35 :            3 3
# row  36 :            3 6              incorrect
# row  37 :            3 3
# row  38 :            3 3
# row  39 :            3 3
# row  40 :            3 7              incorrect
# row  41 :            3 7              incorrect
# row  42 :            3 6              incorrect
# row  43 :            3 9              incorrect
# row  44 :            0 9              incorrect
# row  45 :            3 6              incorrect
# row  46 :            3 6              incorrect
# row  47 :            3 3
# row  48 :            3 5              incorrect
# row  49 :            0 5              incorrect
# row  50 :            3 9              incorrect
# row  51 :            3 4              incorrect
# row  52 :            3 6              incorrect
# row  53 :            3 6              incorrect
# row  54 :            3 8              incorrect
# row  55 :            3 8              incorrect
# row  56 :            3 5              incorrect
# row  57 :            3 5              incorrect
# row  58 :            3 7              incorrect
# row  59 :            3 3
# row  60 :            3 6              incorrect
# row  61 :            3 9              incorrect
# row  62 :            3 5              incorrect
# row  63 :            0 0
# row  64 :            3 1              incorrect
# row  65 :            3 4              incorrect
# row  66 :            3 8              incorrect
# row  67 :            3 3
# row  68 :            3 4              incorrect
# row  69 :            3 5              incorrect
# row  70 :            3 3
# row  71 :            3 7              incorrect
# row  72 :            0 0
# row  73 :            0 0
# row  74 :            3 5              incorrect
# row  75 :            0 0
# row  76 :            3 6              incorrect
# row  77 :            3 1              incorrect
# row  78 :            0 0
# row  79 :            3 7              incorrect
# row  80 :            3 9              incorrect
# row  81 :            3 3
# row  82 :            3 9              incorrect
# row  83 :            3 7              incorrect
# row  84 :            3 4              incorrect
# row  85 :            0 0
# row  86 :            3 1              incorrect
# row  87 :            3 7              incorrect
# row  88 :            0 9              incorrect
# row  89 :            3 1              incorrect
# row  90 :            0 0
# row  91 :            3 7              incorrect
# row  92 :            3 9              incorrect
# row  93 :            3 3
# row  94 :            3 5              incorrect
# row  95 :            0 0
# row  96 :            3 6              incorrect
# row  97 :            3 2              incorrect
# row  98 :            3 7              incorrect
# row  99 :            3 1              incorrect
# row 100 :            0 0
# row 101 :            3 8              incorrect
# row 102 :            3 1              incorrect
# row 103 :            3 6              incorrect
# row 104 :            3 9              incorrect
# row 105 :            3 8              incorrect
# row 106 :            3 5              incorrect
# row 107 :            3 4              incorrect
# row 108 :            0 0
# row 109 :            3 8              incorrect
# row 110 :            3 1              incorrect
# row 111 :            3 7              incorrect
# row 112 :            0 2              incorrect
# row 113 :            3 1              incorrect
# row 114 :            3 1              incorrect
# row 115 :            3 4              incorrect
# row 116 :            3 4              incorrect
# row 117 :            3 4              incorrect
# row 118 :            3 7              incorrect
# row 119 :            3 1              incorrect
# row 120 :            3 5              incorrect
# row 121 :            3 3
# row 122 :            0 0
# row 123 :            3 5              incorrect
# row 124 :            3 8              incorrect
# row 125 :            3 8              incorrect
# row 126 :            3 9              incorrect
# row 127 :            3 5              incorrect
# row 128 :            0 0
# row 129 :            3 6              incorrect
# row 130 :            3 7              incorrect
# row 131 :            3 2              incorrect
# row 132 :            3 2              incorrect
# row 133 :            3 5              incorrect
# row 134 :            3 4              incorrect
# row 135 :            3 3
# row 136 :            3 9              incorrect
# row 137 :            3 8              incorrect
# row 138 :            0 2              incorrect
# row 139 :            3 1              incorrect
# row 140 :            3 1              incorrect
# row 141 :            3 7              incorrect
# row 142 :            3 6              incorrect
# row 143 :            3 3
# row 144 :            3 2              incorrect
# row 145 :            3 3
# row 146 :            3 2              incorrect
# row 147 :            3 3
# row 148 :            0 9              incorrect
# row 149 :            3 2              incorrect
# row 150 :            0 5              incorrect
# row 151 :            3 5              incorrect
# row 152 :            3 2              incorrect
# row 153 :            3 1              incorrect
# row 154 :            3 6              incorrect
# row 155 :            3 5              incorrect
# row 156 :            0 0
# row 157 :            3 1              incorrect
# row 158 :            3 6              incorrect
# row 159 :            3 2              incorrect
# row 160 :            3 3
# row 161 :            3 9              incorrect
# row 162 :            0 0
# row 163 :            3 1              incorrect
# row 164 :            0 0
# row 165 :            3 1              incorrect
# row 166 :            3 5              incorrect
# row 167 :            3 1              incorrect
# row 168 :            3 9              incorrect
# row 169 :            3 2              incorrect
# row 170 :            3 6              incorrect
# row 171 :            0 0
# row 172 :            0 0
# row 173 :            3 5              incorrect
# row 174 :            0 0
# row 175 :            3 1              incorrect
# row 176 :            3 1              incorrect
# row 177 :            3 9              incorrect
# row 178 :            3 8              incorrect
# row 179 :            3 1              incorrect
# row 180 :            0 0
# row 181 :            0 0
# row 182 :            3 2              incorrect
# row 183 :            3 7              incorrect
# row 184 :            3 2              incorrect
# row 185 :            3 2              incorrect
# row 186 :            3 8              incorrect
# row 187 :            3 6              incorrect
# row 188 :            3 3
# row 189 :            3 8              incorrect
# row 190 :            3 6              incorrect
# row 191 :            0 0
# row 192 :            3 4              incorrect
# row 193 :            3 9              incorrect
# row 194 :            3 9              incorrect
# row 195 :            3 9              incorrect
# row 196 :            3 7              incorrect
# row 197 :            3 5              incorrect
# row 198 :            3 2              incorrect
# row 199 :            3 6              incorrect
# row 200 :            0 0
# row 201 :            3 4              incorrect
# row 202 :            3 6              incorrect
# row 203 :            3 6              incorrect
# row 204 :            3 3
# row 205 :            3 7              incorrect
# row 206 :            3 3
# row 207 :            0 9              incorrect
# row 208 :            3 5              incorrect
# row 209 :            3 6              incorrect
# row 210 :            3 1              incorrect
# row 211 :            3 7              incorrect
# row 212 :            0 9              incorrect
# row 213 :            0 9              incorrect
# row 214 :            3 5              incorrect
# row 215 :            0 0
# row 216 :            0 0
# row 217 :            3 4              incorrect
# row 218 :            3 1              incorrect
# row 219 :            3 8              incorrect
# row 220 :            3 1              incorrect
# row 221 :            3 2              incorrect
# row 222 :            3 8              incorrect
# row 223 :            3 5              incorrect
# row 224 :            3 5              incorrect
# row 225 :            3 5              incorrect
# row 226 :            3 8              incorrect
# row 227 :            3 9              incorrect
# row 228 :            3 6              incorrect
# row 229 :            3 9              incorrect
# row 230 :            3 8              incorrect
# row 231 :            3 5              incorrect
# row 232 :            3 2              incorrect
# row 233 :            3 3
# row 234 :            3 5              incorrect
# row 235 :            3 5              incorrect
# row 236 :            3 2              incorrect
# row 237 :            0 0
# row 238 :            3 7              incorrect
# row 239 :            3 1              incorrect
# row 240 :            3 5              incorrect
# row 241 :            3 1              incorrect
# row 242 :            3 1              incorrect
# row 243 :            0 0
# row 244 :            3 9              incorrect
# row 245 :            3 2              incorrect
# row 246 :            0 5              incorrect
# row 247 :            3 8              incorrect
# row 248 :            3 8              incorrect
# row 249 :            3 4              incorrect
# row 250 :            3 8              incorrect
# row 251 :            0 0
# row 252 :            3 7              incorrect
# row 253 :            3 6              incorrect
# row 254 :            3 2              incorrect
# row 255 :            3 7              incorrect
# row 256 :            3 2              incorrect
# row 257 :            3 7              incorrect
# row 258 :            3 5              incorrect
# row 259 :            0 9              incorrect
# row 260 :            3 9              incorrect
# row 261 :            3 7              incorrect
# row 262 :            3 3
# row 263 :            3 4              incorrect
# row 264 :            3 7              incorrect
# row 265 :            3 3
# row 266 :            0 9              incorrect
# row 267 :            3 2              incorrect
# row 268 :            3 3
# row 269 :            3 7              incorrect
# row 270 :            3 2              incorrect
# row 271 :            3 6              incorrect
# row 272 :            3 3
# row 273 :            3 4              incorrect
# row 274 :            3 2              incorrect
# row 275 :            3 8              incorrect
# row 276 :            3 4              incorrect
# row 277 :            3 5              incorrect
# row 278 :            3 9              incorrect
# row 279 :            3 3
# row 280 :            3 2              incorrect
# row 281 :            3 9              incorrect
# row 282 :            3 6              incorrect
# row 283 :            3 2              incorrect
# row 284 :            3 5              incorrect
# row 285 :            0 9              incorrect
# row 286 :            3 1              incorrect
# row 287 :            3 9              incorrect
# row 288 :            3 6              incorrect
# row 289 :            3 5              incorrect
# row 290 :            0 0
# row 291 :            3 2              incorrect
# row 292 :            3 8              incorrect
# row 293 :            0 9              incorrect
# row 294 :            3 6              incorrect
# row 295 :            3 6              incorrect
# row 296 :            0 0
# row 297 :            3 9              incorrect
# row 298 :            3 4              incorrect
# row 299 :            0 5              incorrect
# row 300 :            3 9              incorrect
# row 301 :            3 2              incorrect
# row 302 :            3 5              incorrect
# row 303 :            3 7              incorrect
# row 304 :            3 4              incorrect
# row 305 :            3 1              incorrect
# row 306 :            3 9              incorrect
# row 307 :            3 7              incorrect
# row 308 :            3 5              incorrect
# row 309 :            3 2              incorrect
# row 310 :            3 5              incorrect
# row 311 :            3 7              incorrect
# row 312 :            3 9              incorrect
# row 313 :            3 8              incorrect
# row 314 :            3 4              incorrect
# row 315 :            3 8              incorrect
# row 316 :            3 2              incorrect
# row 317 :            3 9              incorrect
# row 318 :            3 8              incorrect
# row 319 :            3 8              incorrect
# row 320 :            3 7              incorrect
# row 321 :            3 5              incorrect
# row 322 :            3 2              incorrect
# row 323 :            3 5              incorrect
# row 324 :            3 7              incorrect
# row 325 :            0 5              incorrect
# row 326 :            3 3
# row 327 :            3 2              incorrect
# row 328 :            3 4              incorrect
# row 329 :            0 9              incorrect
# row 330 :            0 5              incorrect
# row 331 :            3 2              incorrect
# row 332 :            0 0
# row 333 :            3 8              incorrect
# row 334 :            3 7              incorrect
# row 335 :            3 1              incorrect
# row 336 :            3 1              incorrect
# row 337 :            3 9              incorrect
# row 338 :            3 8              incorrect
# row 339 :            3 1              incorrect
# row 340 :            3 8              incorrect
# row 341 :            3 6              incorrect
# row 342 :            3 4              incorrect
# row 343 :            0 0
# row 344 :            3 8              incorrect
# row 345 :            3 4              incorrect
# row 346 :            3 2              incorrect
# row 347 :            3 3
# row 348 :            0 0
# row 349 :            3 6              incorrect
# row 350 :            3 7              incorrect
# row 351 :            3 7              incorrect
# row 352 :            3 8              incorrect
# row 353 :            3 7              incorrect
#
# Correct: 66 out of 354
# 66

# %%
#visualize each tree
# first, let's use text :)
#
text_representation = tree.export_text(dtree_model)
print(text_representation)
# Out:
# |--- feature_36 <= 0.50
# |   |--- class: 0
# |--- feature_36 >  0.50
# |   |--- class: 3

# %%
# Now, let's see the tree!
#

filename = 'tree_data.gv'    # sometimes .dot is used, instead of .gv

tree.export_graphviz(dtree_model, out_file=filename,  # the filename constructed above...!
                            feature_names=FEATURES,   # actual feature names, not species
                            filled=True,              # fun!
                            rotate=False,             # False for Up/Down; True for L/R
                            class_names=SPECIES,      # Yay! we created this  
                            leaves_parallel=True )    # lots of options!

print(f"# file {filename} written. Try pasting its contents to  http://viz-js.com/")
print()

with open(filename, "r") as f:
    all_file_text = f.read()
    print(all_file_text)
# Out:
# # file tree_data.gv written. Try pasting its contents to  http://viz-js.com/
#
# digraph Tree {
# node [shape=box, style="filled", color="black", fontname="helvetica"] ;
# graph [ranksep=equally, splines=polyline] ;
# edge [fontname="helvetica"] ;
# 0 [label="pix36 <= 0.5\ngini = 0.9\nsamples = 1414\nvalue = [138, 147, 136, 150, 153, 135, 147, 140, 135, 133]\nclass = 4", fillcolor="#ffffff"] ;
# 1 [label="gini = 0.546\nsamples = 211\nvalue = [134, 0, 2, 1, 5, 19, 5, 0, 2, 43]\nclass = 0", fillcolor="#f1bb94"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="gini = 0.888\nsamples = 1203\nvalue = [4, 147, 134, 149, 148, 116, 142, 140, 133, 90]\nclass = 3", fillcolor="#ffffff"] ;
# 0 -> 2 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# {rank=same ; 0} ;
# {rank=same ; 1; 2} ;
# }

# %%
import matplotlib.pyplot as plt 

fig = plt.figure(figsize=(5,4))              # Feel free to adjust this size...
tree_plot = tree.plot_tree(dtree_model, 
                   feature_names=FEATURES,   # Glad to have these FEATURES...
                   class_names=SPECIES,      # and these SPECIES...
                   filled=True)

# %%
#cross-validate to find the "best" tree depth
from sklearn.model_selection import cross_val_score

#
# cross-validation splits the training set into two pieces:
#   + model-building and model-validation. We'll use "build" and "validate"
#

best_d = 1
best_accuracy = 0.0

for d in range(1,10+1):
    cv_model = tree.DecisionTreeClassifier(max_depth=d)   # for each depth, d
    cv_scores = cross_val_score( cv_model, X_train, y_train, cv=5 ) # 5 means 80/20 split
    # print(cv_scores)  # we usually don't want to see the five individual scores 
    average_cv_accuracy = cv_scores.mean()  # more likely, only their average
    print(f"depth: {d:2d}  cv accuracy: {average_cv_accuracy:7.4f}")
    
    if average_cv_accuracy > best_accuracy:
        best_accuracy = average_cv_accuracy
        best_d = d

    
    
# assign best value of d to best_depth
best_depth = best_d   # may have to hand-tune this, depending on what happens...
print()
print(f"best_depth = {best_depth} with acc: {best_accuracy} is our balance.")
print()
print("Too deep and the tree will _overfit_ the training data.")
print("Too shallow and the tree will _underfit_ the training data.")
# Out:
# depth:  1  cv accuracy:  0.1980
# depth:  2  cv accuracy:  0.3175
# depth:  3  cv accuracy:  0.4696
# depth:  4  cv accuracy:  0.5792
# depth:  5  cv accuracy:  0.6796
# depth:  6  cv accuracy:  0.7567
# depth:  7  cv accuracy:  0.7928
# depth:  8  cv accuracy:  0.8260
# depth:  9  cv accuracy:  0.8409
# depth: 10  cv accuracy:  0.8331
#
# best_depth = 9 with acc: 0.8408515650452347 is our balance.
#
# Too deep and the tree will _overfit_ the training data.
# Too shallow and the tree will _underfit_ the training data.

# %%
#
# Now, we re-create and re-run the  "Model-building and -training Cell"
#
# this time, with the best depth, best_d, found by cross-validation model tuning:
#
from sklearn import tree      # for decision trees

# we should have best_depth from our cv exploration
dtree_model_tuned = tree.DecisionTreeClassifier(max_depth=best_depth)

# we train the model (it's one line!)
dtree_model_tuned.fit(X_train, y_train)                              # yay!  trained!
print("Created and trained a DT classifier with max depth =", best_depth)
# Out:
# Created and trained a DT classifier with max depth = 9

# %%
#see the deeper tree
filename = 'tree_data.gv'    # sometimes .dot is used, instead of .gv

tree.export_graphviz(dtree_model_tuned, out_file=filename,  # the filename constructed above...!
                            feature_names=FEATURES, # actual feature names, not species
                            filled=True,              # fun!
                            rotate=False,             # False for Up/Down; True for L/R
                            class_names=SPECIES,      # good to have   
                            leaves_parallel=True )    # lots of options!

# Use this line to print the tree to the console in the dot language:
# print(f"file {filename} written. Try pasting its contents to  http://viz-js.com/")

# with open(filename, "r") as f:    # here, it will print to a file:
#     all_file_text = f.read()
#     print(all_file_text)

#
# Treeing using matplotlib:
#
fig = plt.figure(figsize=(9,6))
tree_plot = tree.plot_tree(dtree_model_tuned, 
                   feature_names=FEATURES,   # Glad to have these!
                   class_names=SPECIES,      # and these!!
                   filled=True,
                   rounded=True,
                   fontsize=8)

# %%
# Re-create and re-run the  "Model-testing Cell"     How does it do with best_k?!
#
predicted_labels = dtree_model_tuned.predict(X_test)
actual_labels = y_test

# Let's print them so we can compare...
print("Predicted labels:", predicted_labels)
print("Actual labels:", actual_labels)
print()

# and, we'll print our nicer table...
compare_labels(predicted_labels,actual_labels)
# Out:
# Predicted labels: ['4' '0' '2' '7' '3' '2' '6' '3' '7' '4' '8' '8' '8' '1' '3' '3' '8' '7'
#  '9' '0' '9' '3' '8' '8' '9' '2' '3' '6' '9' '0' '5' '3' '5' '7' '8' '3'
#  '4' '3' '3' '3' '7' '7' '6' '9' '9' '6' '6' '3' '6' '5' '9' '7' '6' '6'
#  '8' '8' '5' '8' '7' '3' '6' '9' '5' '0' '1' '4' '8' '3' '4' '5' '3' '7'
#  '0' '0' '5' '0' '6' '1' '0' '7' '9' '3' '9' '7' '6' '5' '1' '7' '9' '1'
#  '0' '7' '9' '3' '5' '0' '6' '2' '7' '1' '0' '8' '1' '6' '9' '8' '5' '4'
#  '0' '1' '1' '7' '2' '1' '1' '4' '4' '4' '7' '2' '5' '3' '4' '3' '1' '2'
#  '9' '5' '0' '6' '7' '2' '2' '5' '4' '3' '9' '7' '5' '1' '1' '7' '6' '7'
#  '2' '3' '2' '3' '9' '2' '5' '5' '7' '1' '1' '5' '0' '1' '6' '2' '3' '9'
#  '0' '8' '0' '1' '5' '1' '9' '2' '6' '0' '0' '5' '0' '2' '1' '9' '8' '1'
#  '0' '0' '2' '7' '2' '2' '8' '6' '8' '8' '6' '0' '4' '9' '7' '9' '7' '5'
#  '2' '6' '0' '4' '6' '6' '3' '7' '3' '9' '5' '6' '1' '8' '9' '9' '4' '0'
#  '0' '4' '1' '8' '1' '2' '8' '5' '5' '5' '8' '3' '6' '9' '3' '5' '2' '7'
#  '5' '5' '2' '0' '7' '2' '5' '1' '1' '0' '9' '2' '5' '8' '8' '4' '8' '0'
#  '7' '6' '2' '7' '2' '7' '5' '5' '9' '7' '3' '4' '7' '3' '9' '2' '3' '9'
#  '2' '6' '3' '4' '2' '8' '9' '5' '9' '3' '8' '9' '4' '2' '5' '9' '1' '7'
#  '6' '5' '0' '2' '3' '5' '6' '6' '0' '7' '4' '5' '9' '2' '5' '7' '4' '1'
#  '9' '7' '5' '2' '5' '7' '8' '8' '4' '3' '2' '9' '1' '8' '7' '5' '9' '5'
#  '7' '5' '3' '2' '1' '9' '5' '2' '0' '8' '4' '1' '1' '9' '8' '1' '8' '6'
#  '4' '0' '8' '4' '2' '8' '0' '6' '7' '7' '2' '7']
# Actual labels: ['4' '0' '2' '7' '2' '2' '6' '7' '4' '4' '8' '8' '8' '1' '2' '3' '8' '7'
#  '9' '0' '9' '3' '8' '8' '9' '2' '3' '6' '9' '0' '5' '3' '5' '7' '8' '3'
#  '6' '3' '3' '3' '7' '7' '6' '9' '9' '6' '6' '3' '5' '5' '9' '4' '6' '6'
#  '8' '8' '5' '5' '7' '3' '6' '9' '5' '0' '1' '4' '8' '3' '4' '5' '3' '7'
#  '0' '0' '5' '0' '6' '1' '0' '7' '9' '3' '9' '7' '4' '0' '1' '7' '9' '1'
#  '0' '7' '9' '3' '5' '0' '6' '2' '7' '1' '0' '8' '1' '6' '9' '8' '5' '4'
#  '0' '8' '1' '7' '2' '1' '1' '4' '4' '4' '7' '1' '5' '3' '0' '5' '8' '8'
#  '9' '5' '0' '6' '7' '2' '2' '5' '4' '3' '9' '8' '2' '1' '1' '7' '6' '3'
#  '2' '3' '2' '3' '9' '2' '5' '5' '2' '1' '6' '5' '0' '1' '6' '2' '3' '9'
#  '0' '1' '0' '1' '5' '1' '9' '2' '6' '0' '0' '5' '0' '1' '1' '9' '8' '1'
#  '0' '0' '2' '7' '2' '2' '8' '6' '3' '8' '6' '0' '4' '9' '9' '9' '7' '5'
#  '2' '6' '0' '4' '6' '6' '3' '7' '3' '9' '5' '6' '1' '7' '9' '9' '5' '0'
#  '0' '4' '1' '8' '1' '2' '8' '5' '5' '5' '8' '9' '6' '9' '8' '5' '2' '3'
#  '5' '5' '2' '0' '7' '1' '5' '1' '1' '0' '9' '2' '5' '8' '8' '4' '8' '0'
#  '7' '6' '2' '7' '2' '7' '5' '9' '9' '7' '3' '4' '7' '3' '9' '2' '3' '7'
#  '2' '6' '3' '4' '2' '8' '4' '5' '9' '3' '2' '9' '6' '2' '5' '9' '1' '9'
#  '6' '5' '0' '2' '8' '9' '6' '6' '0' '9' '4' '5' '9' '2' '5' '7' '4' '1'
#  '9' '7' '5' '2' '5' '7' '9' '8' '4' '8' '2' '9' '8' '8' '7' '5' '2' '5'
#  '7' '5' '3' '2' '4' '9' '5' '2' '0' '8' '7' '1' '1' '9' '8' '1' '8' '6'
#  '4' '0' '8' '4' '2' '3' '0' '6' '7' '7' '8' '7']
#
# row   0 :            4 4
# row   1 :            0 0
# row   2 :            2 2
# row   3 :            7 7
# row   4 :            3 2              incorrect
# row   5 :            2 2
# row   6 :            6 6
# row   7 :            3 7              incorrect
# row   8 :            7 4              incorrect
# row   9 :            4 4
# row  10 :            8 8
# row  11 :            8 8
# row  12 :            8 8
# row  13 :            1 1
# row  14 :            3 2              incorrect
# row  15 :            3 3
# row  16 :            8 8
# row  17 :            7 7
# row  18 :            9 9
# row  19 :            0 0
# row  20 :            9 9
# row  21 :            3 3
# row  22 :            8 8
# row  23 :            8 8
# row  24 :            9 9
# row  25 :            2 2
# row  26 :            3 3
# row  27 :            6 6
# row  28 :            9 9
# row  29 :            0 0
# row  30 :            5 5
# row  31 :            3 3
# row  32 :            5 5
# row  33 :            7 7
# row  34 :            8 8
# row  35 :            3 3
# row  36 :            4 6              incorrect
# row  37 :            3 3
# row  38 :            3 3
# row  39 :            3 3
# row  40 :            7 7
# row  41 :            7 7
# row  42 :            6 6
# row  43 :            9 9
# row  44 :            9 9
# row  45 :            6 6
# row  46 :            6 6
# row  47 :            3 3
# row  48 :            6 5              incorrect
# row  49 :            5 5
# row  50 :            9 9
# row  51 :            7 4              incorrect
# row  52 :            6 6
# row  53 :            6 6
# row  54 :            8 8
# row  55 :            8 8
# row  56 :            5 5
# row  57 :            8 5              incorrect
# row  58 :            7 7
# row  59 :            3 3
# row  60 :            6 6
# row  61 :            9 9
# row  62 :            5 5
# row  63 :            0 0
# row  64 :            1 1
# row  65 :            4 4
# row  66 :            8 8
# row  67 :            3 3
# row  68 :            4 4
# row  69 :            5 5
# row  70 :            3 3
# row  71 :            7 7
# row  72 :            0 0
# row  73 :            0 0
# row  74 :            5 5
# row  75 :            0 0
# row  76 :            6 6
# row  77 :            1 1
# row  78 :            0 0
# row  79 :            7 7
# row  80 :            9 9
# row  81 :            3 3
# row  82 :            9 9
# row  83 :            7 7
# row  84 :            6 4              incorrect
# row  85 :            5 0              incorrect
# row  86 :            1 1
# row  87 :            7 7
# row  88 :            9 9
# row  89 :            1 1
# row  90 :            0 0
# row  91 :            7 7
# row  92 :            9 9
# row  93 :            3 3
# row  94 :            5 5
# row  95 :            0 0
# row  96 :            6 6
# row  97 :            2 2
# row  98 :            7 7
# row  99 :            1 1
# row 100 :            0 0
# row 101 :            8 8
# row 102 :            1 1
# row 103 :            6 6
# row 104 :            9 9
# row 105 :            8 8
# row 106 :            5 5
# row 107 :            4 4
# row 108 :            0 0
# row 109 :            1 8              incorrect
# row 110 :            1 1
# row 111 :            7 7
# row 112 :            2 2
# row 113 :            1 1
# row 114 :            1 1
# row 115 :            4 4
# row 116 :            4 4
# row 117 :            4 4
# row 118 :            7 7
# row 119 :            2 1              incorrect
# row 120 :            5 5
# row 121 :            3 3
# row 122 :            4 0              incorrect
# row 123 :            3 5              incorrect
# row 124 :            1 8              incorrect
# row 125 :            2 8              incorrect
# row 126 :            9 9
# row 127 :            5 5
# row 128 :            0 0
# row 129 :            6 6
# row 130 :            7 7
# row 131 :            2 2
# row 132 :            2 2
# row 133 :            5 5
# row 134 :            4 4
# row 135 :            3 3
# row 136 :            9 9
# row 137 :            7 8              incorrect
# row 138 :            5 2              incorrect
# row 139 :            1 1
# row 140 :            1 1
# row 141 :            7 7
# row 142 :            6 6
# row 143 :            7 3              incorrect
# row 144 :            2 2
# row 145 :            3 3
# row 146 :            2 2
# row 147 :            3 3
# row 148 :            9 9
# row 149 :            2 2
# row 150 :            5 5
# row 151 :            5 5
# row 152 :            7 2              incorrect
# row 153 :            1 1
# row 154 :            1 6              incorrect
# row 155 :            5 5
# row 156 :            0 0
# row 157 :            1 1
# row 158 :            6 6
# row 159 :            2 2
# row 160 :            3 3
# row 161 :            9 9
# row 162 :            0 0
# row 163 :            8 1              incorrect
# row 164 :            0 0
# row 165 :            1 1
# row 166 :            5 5
# row 167 :            1 1
# row 168 :            9 9
# row 169 :            2 2
# row 170 :            6 6
# row 171 :            0 0
# row 172 :            0 0
# row 173 :            5 5
# row 174 :            0 0
# row 175 :            2 1              incorrect
# row 176 :            1 1
# row 177 :            9 9
# row 178 :            8 8
# row 179 :            1 1
# row 180 :            0 0
# row 181 :            0 0
# row 182 :            2 2
# row 183 :            7 7
# row 184 :            2 2
# row 185 :            2 2
# row 186 :            8 8
# row 187 :            6 6
# row 188 :            8 3              incorrect
# row 189 :            8 8
# row 190 :            6 6
# row 191 :            0 0
# row 192 :            4 4
# row 193 :            9 9
# row 194 :            7 9              incorrect
# row 195 :            9 9
# row 196 :            7 7
# row 197 :            5 5
# row 198 :            2 2
# row 199 :            6 6
# row 200 :            0 0
# row 201 :            4 4
# row 202 :            6 6
# row 203 :            6 6
# row 204 :            3 3
# row 205 :            7 7
# row 206 :            3 3
# row 207 :            9 9
# row 208 :            5 5
# row 209 :            6 6
# row 210 :            1 1
# row 211 :            8 7              incorrect
# row 212 :            9 9
# row 213 :            9 9
# row 214 :            4 5              incorrect
# row 215 :            0 0
# row 216 :            0 0
# row 217 :            4 4
# row 218 :            1 1
# row 219 :            8 8
# row 220 :            1 1
# row 221 :            2 2
# row 222 :            8 8
# row 223 :            5 5
# row 224 :            5 5
# row 225 :            5 5
# row 226 :            8 8
# row 227 :            3 9              incorrect
# row 228 :            6 6
# row 229 :            9 9
# row 230 :            3 8              incorrect
# row 231 :            5 5
# row 232 :            2 2
# row 233 :            7 3              incorrect
# row 234 :            5 5
# row 235 :            5 5
# row 236 :            2 2
# row 237 :            0 0
# row 238 :            7 7
# row 239 :            2 1              incorrect
# row 240 :            5 5
# row 241 :            1 1
# row 242 :            1 1
# row 243 :            0 0
# row 244 :            9 9
# row 245 :            2 2
# row 246 :            5 5
# row 247 :            8 8
# row 248 :            8 8
# row 249 :            4 4
# row 250 :            8 8
# row 251 :            0 0
# row 252 :            7 7
# row 253 :            6 6
# row 254 :            2 2
# row 255 :            7 7
# row 256 :            2 2
# row 257 :            7 7
# row 258 :            5 5
# row 259 :            5 9              incorrect
# row 260 :            9 9
# row 261 :            7 7
# row 262 :            3 3
# row 263 :            4 4
# row 264 :            7 7
# row 265 :            3 3
# row 266 :            9 9
# row 267 :            2 2
# row 268 :            3 3
# row 269 :            9 7              incorrect
# row 270 :            2 2
# row 271 :            6 6
# row 272 :            3 3
# row 273 :            4 4
# row 274 :            2 2
# row 275 :            8 8
# row 276 :            9 4              incorrect
# row 277 :            5 5
# row 278 :            9 9
# row 279 :            3 3
# row 280 :            8 2              incorrect
# row 281 :            9 9
# row 282 :            4 6              incorrect
# row 283 :            2 2
# row 284 :            5 5
# row 285 :            9 9
# row 286 :            1 1
# row 287 :            7 9              incorrect
# row 288 :            6 6
# row 289 :            5 5
# row 290 :            0 0
# row 291 :            2 2
# row 292 :            3 8              incorrect
# row 293 :            5 9              incorrect
# row 294 :            6 6
# row 295 :            6 6
# row 296 :            0 0
# row 297 :            7 9              incorrect
# row 298 :            4 4
# row 299 :            5 5
# row 300 :            9 9
# row 301 :            2 2
# row 302 :            5 5
# row 303 :            7 7
# row 304 :            4 4
# row 305 :            1 1
# row 306 :            9 9
# row 307 :            7 7
# row 308 :            5 5
# row 309 :            2 2
# row 310 :            5 5
# row 311 :            7 7
# row 312 :            8 9              incorrect
# row 313 :            8 8
# row 314 :            4 4
# row 315 :            3 8              incorrect
# row 316 :            2 2
# row 317 :            9 9
# row 318 :            1 8              incorrect
# row 319 :            8 8
# row 320 :            7 7
# row 321 :            5 5
# row 322 :            9 2              incorrect
# row 323 :            5 5
# row 324 :            7 7
# row 325 :            5 5
# row 326 :            3 3
# row 327 :            2 2
# row 328 :            1 4              incorrect
# row 329 :            9 9
# row 330 :            5 5
# row 331 :            2 2
# row 332 :            0 0
# row 333 :            8 8
# row 334 :            4 7              incorrect
# row 335 :            1 1
# row 336 :            1 1
# row 337 :            9 9
# row 338 :            8 8
# row 339 :            1 1
# row 340 :            8 8
# row 341 :            6 6
# row 342 :            4 4
# row 343 :            0 0
# row 344 :            8 8
# row 345 :            4 4
# row 346 :            2 2
# row 347 :            8 3              incorrect
# row 348 :            0 0
# row 349 :            6 6
# row 350 :            7 7
# row 351 :            7 7
# row 352 :            2 8              incorrect
# row 353 :            7 7
#
# Correct: 306 out of 354
# 306

# %%
#feature importances
print(dtree_model_tuned.feature_importances_)
print()

# let's see them with each feature name:
IMPs = dtree_model_tuned.feature_importances_

# enumerate is great when you want indices _and_ elements!
for i, importance in enumerate(IMPs):
    perc = importance*100
    print(f"Feature {COLUMNS[i]:>12s} has {perc:>7.2f}% of the decision-making importance.")
# Out:
# [0.         0.00111541 0.01174366 0.00865502 0.00290703 0.0525022
#  0.         0.00143409 0.         0.00179262 0.02379778 0.00284428
#  0.00166081 0.01490204 0.         0.         0.         0.
#  0.01304558 0.00111541 0.03947243 0.08639211 0.00286819 0.
#  0.         0.00378984 0.06990644 0.08463093 0.00166072 0.01050377
#  0.         0.         0.         0.06325448 0.01812718 0.01069608
#  0.07475809 0.02207752 0.01443394 0.         0.         0.01067929
#  0.12738981 0.05161962 0.00983041 0.0037362  0.00754029 0.
#  0.         0.00378441 0.00592024 0.00250966 0.00393181 0.01292295
#  0.0016486  0.         0.         0.         0.0181879  0.0032527
#  0.06290916 0.02786918 0.00506472 0.00111541]
#
# Feature         pix0 has    0.00% of the decision-making importance.
# Feature         pix1 has    0.11% of the decision-making importance.
# Feature         pix2 has    1.17% of the decision-making importance.
# Feature         pix3 has    0.87% of the decision-making importance.
# Feature         pix4 has    0.29% of the decision-making importance.
# Feature         pix5 has    5.25% of the decision-making importance.
# Feature         pix6 has    0.00% of the decision-making importance.
# Feature         pix7 has    0.14% of the decision-making importance.
# Feature         pix8 has    0.00% of the decision-making importance.
# Feature         pix9 has    0.18% of the decision-making importance.
# Feature        pix10 has    2.38% of the decision-making importance.
# Feature        pix11 has    0.28% of the decision-making importance.
# Feature        pix12 has    0.17% of the decision-making importance.
# Feature        pix13 has    1.49% of the decision-making importance.
# Feature        pix14 has    0.00% of the decision-making importance.
# Feature        pix15 has    0.00% of the decision-making importance.
# Feature        pix16 has    0.00% of the decision-making importance.
# Feature        pix17 has    0.00% of the decision-making importance.
# Feature        pix18 has    1.30% of the decision-making importance.
# Feature        pix19 has    0.11% of the decision-making importance.
# Feature        pix20 has    3.95% of the decision-making importance.
# Feature        pix21 has    8.64% of the decision-making importance.
# Feature        pix22 has    0.29% of the decision-making importance.
# Feature        pix23 has    0.00% of the decision-making importance.
# Feature        pix24 has    0.00% of the decision-making importance.
# Feature        pix25 has    0.38% of the decision-making importance.
# Feature        pix26 has    6.99% of the decision-making importance.
# Feature        pix27 has    8.46% of the decision-making importance.
# Feature        pix28 has    0.17% of the decision-making importance.
# Feature        pix29 has    1.05% of the decision-making importance.
# Feature        pix30 has    0.00% of the decision-making importance.
# Feature        pix31 has    0.00% of the decision-making importance.
# Feature        pix32 has    0.00% of the decision-making importance.
# Feature        pix33 has    6.33% of the decision-making importance.
# Feature        pix34 has    1.81% of the decision-making importance.
# Feature        pix35 has    1.07% of the decision-making importance.
# Feature        pix36 has    7.48% of the decision-making importance.
# Feature        pix37 has    2.21% of the decision-making importance.
# Feature        pix38 has    1.44% of the decision-making importance.
# Feature        pix39 has    0.00% of the decision-making importance.
# Feature        pix40 has    0.00% of the decision-making importance.
# Feature        pix41 has    1.07% of the decision-making importance.
# Feature        pix42 has   12.74% of the decision-making importance.
# Feature        pix43 has    5.16% of the decision-making importance.
# Feature        pix44 has    0.98% of the decision-making importance.
# Feature        pix45 has    0.37% of the decision-making importance.
# Feature        pix46 has    0.75% of the decision-making importance.
# Feature        pix47 has    0.00% of the decision-making importance.
# Feature        pix48 has    0.00% of the decision-making importance.
# Feature        pix49 has    0.38% of the decision-making importance.
# Feature        pix50 has    0.59% of the decision-making importance.
# Feature        pix51 has    0.25% of the decision-making importance.
# Feature        pix52 has    0.39% of the decision-making importance.
# Feature        pix53 has    1.29% of the decision-making importance.
# Feature        pix54 has    0.16% of the decision-making importance.
# Feature        pix55 has    0.00% of the decision-making importance.
# Feature        pix56 has    0.00% of the decision-making importance.
# Feature        pix57 has    0.00% of the decision-making importance.
# Feature        pix58 has    1.82% of the decision-making importance.
# Feature        pix59 has    0.33% of the decision-making importance.
# Feature        pix60 has    6.29% of the decision-making importance.
# Feature        pix61 has    2.79% of the decision-making importance.
# Feature        pix62 has    0.51% of the decision-making importance.
# Feature        pix63 has    0.11% of the decision-making importance.

# %%
#
# Ok!  We have tuned our DT to use the "best" depth...
#
# Now, we use ALL available data to train our final predictive model:
#

from sklearn import tree      # for decision trees

# we should have best_depth from our cv exploration
dtree_model_final = tree.DecisionTreeClassifier(max_depth=best_depth)

# we train the model (it's one line!)
dtree_model_final.fit(X_all, y_all)                              # yay!  trained!
print("Created and trained a 'final' DT classifier with max depth =", best_depth)
# Out:
# Created and trained a 'final' DT classifier with max depth = 9

# %%
#
# final predictive model (decision trees), with tuned parameters + ALL data incorporated
#

def predictive_model( Features, Model ):
    """ input: a list of 64 pixel features 
                [ month, day ]
        output: the predicted class of digits, from
                  string (0) to (9)
    """
    our_features = np.asarray([Features])                 # extra brackets needed
    predicted_species = Model.predict(our_features)       # The model's prediction!
    predicted_species = int(predicted_species[0])  # unpack the extra brackets
    return predicted_species
   
#
# Try it!
# 

LoD = [[0,0,0,8,14,0,0,0,0,0,5,16,11,0,0,0,0,1,15,14,1,6,0,0,0,7,16,5,3,16,8,0,0,8,16,8,14,16,2,0,0,0,6,14,16,11,0,0,0,0,0,6,16,4,0,0,0,0,0,10,15,0,0,0],
[0,0,0,5,14,12,2,0,0,0,7,15,8,14,4,0,0,0,6,2,3,13,1,0,0,0,0,1,13,4,0,0,0,0,1,11,9,0,0,0,0,8,16,13,0,0,0,0,0,5,14,16,11,2,0,0,0,0,0,6,12,13,3,0],
[0,0,0,3,16,3,0,0,0,0,0,12,16,2,0,0,0,0,8,16,16,4,0,0,0,7,16,15,16,12,11,0,0,8,16,16,16,13,3,0,0,0,0,7,14,1,0,0,0,0,0,6,16,0,0,0,0,0,0,4,14,0,0,0],
[0,0,0,3,15,10,1,0,0,0,0,11,10,16,4,0,0,0,0,12,1,15,6,0,0,0,0,3,4,15,4,0,0,0,0,6,15,6,0,0,0,4,15,16,9,0,0,0,0,0,13,16,15,9,3,0,0,0,0,4,9,14,7,0],
[0,0,0,3,16,3,0,0,0,0,0,10,16,11,0,0,0,0,4,16,16,8,0,0,0,2,14,12,16,5,0,0,0,10,16,14,16,16,11,0,0,5,12,13,16,8,3,0,0,0,0,2,15,3,0,0,0,0,0,4,12,0,0,0],
[0,0,7,15,15,4,0,0,0,8,16,16,16,4,0,0,0,8,15,8,16,4,0,0,0,0,0,10,15,0,0,0,0,0,1,15,9,0,0,0,0,0,6,16,2,0,0,0,0,0,8,16,8,11,9,0,0,0,9,16,16,12,3,0]]

# run on each one:
for Features in LoD:
    predicted_species = predictive_model( Features, dtree_model_final )  # pass in the model, too!
    name = SPECIES[predicted_species]
    print(f"I predict {name} from the features {Features}")    # Answers in the assignment...
# Out:
# I predict 4 from the features [0, 0, 0, 8, 14, 0, 0, 0, 0, 0, 5, 16, 11, 0, 0, 0, 0, 1, 15, 14, 1, 6, 0, 0, 0, 7, 16, 5, 3, 16, 8, 0, 0, 8, 16, 8, 14, 16, 2, 0, 0, 0, 6, 14, 16, 11, 0, 0, 0, 0, 0, 6, 16, 4, 0, 0, 0, 0, 0, 10, 15, 0, 0, 0]
# I predict 2 from the features [0, 0, 0, 5, 14, 12, 2, 0, 0, 0, 7, 15, 8, 14, 4, 0, 0, 0, 6, 2, 3, 13, 1, 0, 0, 0, 0, 1, 13, 4, 0, 0, 0, 0, 1, 11, 9, 0, 0, 0, 0, 8, 16, 13, 0, 0, 0, 0, 0, 5, 14, 16, 11, 2, 0, 0, 0, 0, 0, 6, 12, 13, 3, 0]
# I predict 4 from the features [0, 0, 0, 3, 16, 3, 0, 0, 0, 0, 0, 12, 16, 2, 0, 0, 0, 0, 8, 16, 16, 4, 0, 0, 0, 7, 16, 15, 16, 12, 11, 0, 0, 8, 16, 16, 16, 13, 3, 0, 0, 0, 0, 7, 14, 1, 0, 0, 0, 0, 0, 6, 16, 0, 0, 0, 0, 0, 0, 4, 14, 0, 0, 0]
# I predict 2 from the features [0, 0, 0, 3, 15, 10, 1, 0, 0, 0, 0, 11, 10, 16, 4, 0, 0, 0, 0, 12, 1, 15, 6, 0, 0, 0, 0, 3, 4, 15, 4, 0, 0, 0, 0, 6, 15, 6, 0, 0, 0, 4, 15, 16, 9, 0, 0, 0, 0, 0, 13, 16, 15, 9, 3, 0, 0, 0, 0, 4, 9, 14, 7, 0]
# I predict 4 from the features [0, 0, 0, 3, 16, 3, 0, 0, 0, 0, 0, 10, 16, 11, 0, 0, 0, 0, 4, 16, 16, 8, 0, 0, 0, 2, 14, 12, 16, 5, 0, 0, 0, 10, 16, 14, 16, 16, 11, 0, 0, 5, 12, 13, 16, 8, 3, 0, 0, 0, 0, 2, 15, 3, 0, 0, 0, 0, 0, 4, 12, 0, 0, 0]
# I predict 2 from the features [0, 0, 7, 15, 15, 4, 0, 0, 0, 8, 16, 16, 16, 4, 0, 0, 0, 8, 15, 8, 16, 4, 0, 0, 0, 0, 0, 10, 15, 0, 0, 0, 0, 0, 1, 15, 9, 0, 0, 0, 0, 0, 6, 16, 2, 0, 0, 0, 0, 0, 8, 16, 8, 11, 9, 0, 0, 0, 9, 16, 16, 12, 3, 0]

# %%
#feature importances v2
# feature importances!
# 
#     feature importances are computed by tracking which feature is used at each decision-point
#     weighted by how often that decision-point is checked 
# 
# feature importances are often even more "important" than predictions, 
#         because they invite the question, "why" (Here, not a computational, but a biological/botanical q'n)
#

print(dtree_model_final.feature_importances_)
print()

# let's see them with each feature name:
IMPs = dtree_model_final.feature_importances_

# enumerate is great when you want indices _and_ elements!
for i, importance in enumerate(IMPs):
    perc = importance*100
    print(f"Feature {COLUMNS[i]:>12s} has {perc:>7.2f}% of the decision-making importance.")
# Out:
# [0.         0.         0.00575564 0.00910678 0.         0.06506638
#  0.01548142 0.         0.         0.00132054 0.01242993 0.
#  0.01458101 0.02143363 0.         0.         0.         0.00227328
#  0.01652145 0.01532459 0.0442396  0.08117541 0.         0.
#  0.00132997 0.         0.01939461 0.05816914 0.00563217 0.05009351
#  0.00066981 0.         0.         0.10494205 0.03027446 0.0110931
#  0.07641448 0.02150492 0.0041323  0.         0.         0.00185485
#  0.07747259 0.05629401 0.01973606 0.00608985 0.00400994 0.
#  0.         0.00178615 0.00696794 0.00383058 0.0026367  0.01436828
#  0.02404304 0.         0.         0.         0.02211278 0.00122798
#  0.06381907 0.00539004 0.         0.        ]
#
# Feature         pix0 has    0.00% of the decision-making importance.
# Feature         pix1 has    0.00% of the decision-making importance.
# Feature         pix2 has    0.58% of the decision-making importance.
# Feature         pix3 has    0.91% of the decision-making importance.
# Feature         pix4 has    0.00% of the decision-making importance.
# Feature         pix5 has    6.51% of the decision-making importance.
# Feature         pix6 has    1.55% of the decision-making importance.
# Feature         pix7 has    0.00% of the decision-making importance.
# Feature         pix8 has    0.00% of the decision-making importance.
# Feature         pix9 has    0.13% of the decision-making importance.
# Feature        pix10 has    1.24% of the decision-making importance.
# Feature        pix11 has    0.00% of the decision-making importance.
# Feature        pix12 has    1.46% of the decision-making importance.
# Feature        pix13 has    2.14% of the decision-making importance.
# Feature        pix14 has    0.00% of the decision-making importance.
# Feature        pix15 has    0.00% of the decision-making importance.
# Feature        pix16 has    0.00% of the decision-making importance.
# Feature        pix17 has    0.23% of the decision-making importance.
# Feature        pix18 has    1.65% of the decision-making importance.
# Feature        pix19 has    1.53% of the decision-making importance.
# Feature        pix20 has    4.42% of the decision-making importance.
# Feature        pix21 has    8.12% of the decision-making importance.
# Feature        pix22 has    0.00% of the decision-making importance.
# Feature        pix23 has    0.00% of the decision-making importance.
# Feature        pix24 has    0.13% of the decision-making importance.
# Feature        pix25 has    0.00% of the decision-making importance.
# Feature        pix26 has    1.94% of the decision-making importance.
# Feature        pix27 has    5.82% of the decision-making importance.
# Feature        pix28 has    0.56% of the decision-making importance.
# Feature        pix29 has    5.01% of the decision-making importance.
# Feature        pix30 has    0.07% of the decision-making importance.
# Feature        pix31 has    0.00% of the decision-making importance.
# Feature        pix32 has    0.00% of the decision-making importance.
# Feature        pix33 has   10.49% of the decision-making importance.
# Feature        pix34 has    3.03% of the decision-making importance.
# Feature        pix35 has    1.11% of the decision-making importance.
# Feature        pix36 has    7.64% of the decision-making importance.
# Feature        pix37 has    2.15% of the decision-making importance.
# Feature        pix38 has    0.41% of the decision-making importance.
# Feature        pix39 has    0.00% of the decision-making importance.
# Feature        pix40 has    0.00% of the decision-making importance.
# Feature        pix41 has    0.19% of the decision-making importance.
# Feature        pix42 has    7.75% of the decision-making importance.
# Feature        pix43 has    5.63% of the decision-making importance.
# Feature        pix44 has    1.97% of the decision-making importance.
# Feature        pix45 has    0.61% of the decision-making importance.
# Feature        pix46 has    0.40% of the decision-making importance.
# Feature        pix47 has    0.00% of the decision-making importance.
# Feature        pix48 has    0.00% of the decision-making importance.
# Feature        pix49 has    0.18% of the decision-making importance.
# Feature        pix50 has    0.70% of the decision-making importance.
# Feature        pix51 has    0.38% of the decision-making importance.
# Feature        pix52 has    0.26% of the decision-making importance.
# Feature        pix53 has    1.44% of the decision-making importance.
# Feature        pix54 has    2.40% of the decision-making importance.
# Feature        pix55 has    0.00% of the decision-making importance.
# Feature        pix56 has    0.00% of the decision-making importance.
# Feature        pix57 has    0.00% of the decision-making importance.
# Feature        pix58 has    2.21% of the decision-making importance.
# Feature        pix59 has    0.12% of the decision-making importance.
# Feature        pix60 has    6.38% of the decision-making importance.
# Feature        pix61 has    0.54% of the decision-making importance.
# Feature        pix62 has    0.00% of the decision-making importance.
# Feature        pix63 has    0.00% of the decision-making importance.

# %% [markdown]
# ## Then: &nbsp; _Random Forests_

# %%
#
# +++ We're back at the "Model-building and Model-training Cell"
#       
# Create a RF model and train it! 
#
from sklearn import tree      # for decision trees
from sklearn import ensemble  # for random forests, an ensemble classifier

best_d = 1            # we don't know what depth to use, so we guess...
best_num_trees = 42   # again, we guess
rforest_model = ensemble.RandomForestClassifier(max_depth=best_d, 
                                                n_estimators=best_num_trees,
                                                max_samples=0.5)  
# This max_samples=0.5 is the fraction of rows to use for each DT 
# For all of our forests, we will let max_samples be 0.5   

# We'll explore best_d and best_num_trees...

# we train the model (again, one line):
rforest_model.fit(X_train, y_train)                              # yay!  trained!
print(f"Built an RF with depth={best_d} and number of trees={best_num_trees}")
# Out:
# Built an RF with depth=1 and number of trees=42

# %%
#test
# +++ This is the "Model-testing Cell"
#
# Now, let's see how well we did on our "held-out data" (the testing data)
#

# We run our test set!
predicted_labels = rforest_model.predict(X_test)
actual_labels = y_test

# Let's print them so we can compare...
print("Predicted labels:", predicted_labels)
print("Actual  labels  :", actual_labels)

# And, some overall results
num_correct = sum(predicted_labels == actual_labels)
total = len(actual_labels)
print(f"\nResults on test set:  {num_correct} correct out of {total} total.")

# and, let's print our table, too...
compare_labels(predicted_labels,actual_labels)
# Out:
# Predicted labels: ['4' '0' '2' '7' '2' '2' '6' '7' '4' '4' '1' '2' '8' '1' '7' '3' '1' '7'
#  '3' '0' '3' '3' '8' '8' '3' '2' '3' '4' '9' '0' '5' '3' '4' '7' '3' '3'
#  '4' '3' '3' '3' '7' '7' '6' '7' '3' '6' '6' '3' '6' '0' '3' '7' '6' '6'
#  '8' '8' '5' '7' '7' '3' '4' '3' '4' '0' '2' '4' '3' '3' '4' '6' '3' '7'
#  '0' '0' '3' '0' '6' '3' '0' '7' '3' '3' '3' '7' '6' '0' '6' '7' '9' '3'
#  '4' '7' '3' '3' '5' '0' '6' '2' '7' '6' '0' '1' '1' '6' '3' '2' '4' '4'
#  '0' '2' '3' '7' '6' '7' '4' '4' '4' '4' '7' '8' '3' '3' '0' '3' '7' '3'
#  '3' '5' '0' '6' '7' '2' '2' '3' '4' '3' '3' '2' '3' '2' '2' '7' '6' '3'
#  '2' '3' '2' '3' '9' '2' '9' '5' '1' '2' '6' '4' '0' '4' '6' '2' '3' '3'
#  '0' '4' '0' '2' '5' '1' '3' '3' '6' '0' '0' '3' '0' '8' '3' '3' '3' '1'
#  '0' '0' '2' '7' '2' '2' '1' '6' '3' '3' '6' '0' '4' '3' '7' '3' '7' '3'
#  '2' '6' '0' '4' '6' '4' '3' '7' '3' '9' '5' '6' '3' '7' '3' '3' '4' '0'
#  '0' '4' '1' '4' '4' '1' '8' '4' '4' '3' '7' '3' '6' '3' '3' '5' '1' '3'
#  '5' '4' '2' '0' '7' '1' '5' '1' '4' '0' '3' '2' '9' '1' '3' '4' '2' '0'
#  '7' '6' '2' '7' '2' '0' '3' '3' '3' '7' '3' '4' '7' '3' '3' '2' '3' '4'
#  '2' '4' '3' '4' '2' '3' '7' '7' '3' '3' '2' '3' '6' '2' '3' '9' '1' '7'
#  '6' '5' '0' '3' '1' '3' '6' '6' '0' '3' '4' '0' '3' '2' '5' '7' '4' '3'
#  '3' '4' '3' '2' '4' '7' '3' '8' '6' '3' '2' '3' '4' '3' '7' '5' '3' '5'
#  '7' '9' '3' '2' '4' '9' '0' '2' '0' '2' '7' '4' '2' '3' '8' '2' '1' '6'
#  '4' '0' '8' '4' '2' '2' '0' '6' '7' '7' '1' '7']
# Actual  labels  : ['4' '0' '2' '7' '2' '2' '6' '7' '4' '4' '8' '8' '8' '1' '2' '3' '8' '7'
#  '9' '0' '9' '3' '8' '8' '9' '2' '3' '6' '9' '0' '5' '3' '5' '7' '8' '3'
#  '6' '3' '3' '3' '7' '7' '6' '9' '9' '6' '6' '3' '5' '5' '9' '4' '6' '6'
#  '8' '8' '5' '5' '7' '3' '6' '9' '5' '0' '1' '4' '8' '3' '4' '5' '3' '7'
#  '0' '0' '5' '0' '6' '1' '0' '7' '9' '3' '9' '7' '4' '0' '1' '7' '9' '1'
#  '0' '7' '9' '3' '5' '0' '6' '2' '7' '1' '0' '8' '1' '6' '9' '8' '5' '4'
#  '0' '8' '1' '7' '2' '1' '1' '4' '4' '4' '7' '1' '5' '3' '0' '5' '8' '8'
#  '9' '5' '0' '6' '7' '2' '2' '5' '4' '3' '9' '8' '2' '1' '1' '7' '6' '3'
#  '2' '3' '2' '3' '9' '2' '5' '5' '2' '1' '6' '5' '0' '1' '6' '2' '3' '9'
#  '0' '1' '0' '1' '5' '1' '9' '2' '6' '0' '0' '5' '0' '1' '1' '9' '8' '1'
#  '0' '0' '2' '7' '2' '2' '8' '6' '3' '8' '6' '0' '4' '9' '9' '9' '7' '5'
#  '2' '6' '0' '4' '6' '6' '3' '7' '3' '9' '5' '6' '1' '7' '9' '9' '5' '0'
#  '0' '4' '1' '8' '1' '2' '8' '5' '5' '5' '8' '9' '6' '9' '8' '5' '2' '3'
#  '5' '5' '2' '0' '7' '1' '5' '1' '1' '0' '9' '2' '5' '8' '8' '4' '8' '0'
#  '7' '6' '2' '7' '2' '7' '5' '9' '9' '7' '3' '4' '7' '3' '9' '2' '3' '7'
#  '2' '6' '3' '4' '2' '8' '4' '5' '9' '3' '2' '9' '6' '2' '5' '9' '1' '9'
#  '6' '5' '0' '2' '8' '9' '6' '6' '0' '9' '4' '5' '9' '2' '5' '7' '4' '1'
#  '9' '7' '5' '2' '5' '7' '9' '8' '4' '8' '2' '9' '8' '8' '7' '5' '2' '5'
#  '7' '5' '3' '2' '4' '9' '5' '2' '0' '8' '7' '1' '1' '9' '8' '1' '8' '6'
#  '4' '0' '8' '4' '2' '3' '0' '6' '7' '7' '8' '7']
#
# Results on test set:  213 correct out of 354 total.
# row   0 :            4 4
# row   1 :            0 0
# row   2 :            2 2
# row   3 :            7 7
# row   4 :            2 2
# row   5 :            2 2
# row   6 :            6 6
# row   7 :            7 7
# row   8 :            4 4
# row   9 :            4 4
# row  10 :            1 8              incorrect
# row  11 :            2 8              incorrect
# row  12 :            8 8
# row  13 :            1 1
# row  14 :            7 2              incorrect
# row  15 :            3 3
# row  16 :            1 8              incorrect
# row  17 :            7 7
# row  18 :            3 9              incorrect
# row  19 :            0 0
# row  20 :            3 9              incorrect
# row  21 :            3 3
# row  22 :            8 8
# row  23 :            8 8
# row  24 :            3 9              incorrect
# row  25 :            2 2
# row  26 :            3 3
# row  27 :            4 6              incorrect
# row  28 :            9 9
# row  29 :            0 0
# row  30 :            5 5
# row  31 :            3 3
# row  32 :            4 5              incorrect
# row  33 :            7 7
# row  34 :            3 8              incorrect
# row  35 :            3 3
# row  36 :            4 6              incorrect
# row  37 :            3 3
# row  38 :            3 3
# row  39 :            3 3
# row  40 :            7 7
# row  41 :            7 7
# row  42 :            6 6
# row  43 :            7 9              incorrect
# row  44 :            3 9              incorrect
# row  45 :            6 6
# row  46 :            6 6
# row  47 :            3 3
# row  48 :            6 5              incorrect
# row  49 :            0 5              incorrect
# row  50 :            3 9              incorrect
# row  51 :            7 4              incorrect
# row  52 :            6 6
# row  53 :            6 6
# row  54 :            8 8
# row  55 :            8 8
# row  56 :            5 5
# row  57 :            7 5              incorrect
# row  58 :            7 7
# row  59 :            3 3
# row  60 :            4 6              incorrect
# row  61 :            3 9              incorrect
# row  62 :            4 5              incorrect
# row  63 :            0 0
# row  64 :            2 1              incorrect
# row  65 :            4 4
# row  66 :            3 8              incorrect
# row  67 :            3 3
# row  68 :            4 4
# row  69 :            6 5              incorrect
# row  70 :            3 3
# row  71 :            7 7
# row  72 :            0 0
# row  73 :            0 0
# row  74 :            3 5              incorrect
# row  75 :            0 0
# row  76 :            6 6
# row  77 :            3 1              incorrect
# row  78 :            0 0
# row  79 :            7 7
# row  80 :            3 9              incorrect
# row  81 :            3 3
# row  82 :            3 9              incorrect
# row  83 :            7 7
# row  84 :            6 4              incorrect
# row  85 :            0 0
# row  86 :            6 1              incorrect
# row  87 :            7 7
# row  88 :            9 9
# row  89 :            3 1              incorrect
# row  90 :            4 0              incorrect
# row  91 :            7 7
# row  92 :            3 9              incorrect
# row  93 :            3 3
# row  94 :            5 5
# row  95 :            0 0
# row  96 :            6 6
# row  97 :            2 2
# row  98 :            7 7
# row  99 :            6 1              incorrect
# row 100 :            0 0
# row 101 :            1 8              incorrect
# row 102 :            1 1
# row 103 :            6 6
# row 104 :            3 9              incorrect
# row 105 :            2 8              incorrect
# row 106 :            4 5              incorrect
# row 107 :            4 4
# row 108 :            0 0
# row 109 :            2 8              incorrect
# row 110 :            3 1              incorrect
# row 111 :            7 7
# row 112 :            6 2              incorrect
# row 113 :            7 1              incorrect
# row 114 :            4 1              incorrect
# row 115 :            4 4
# row 116 :            4 4
# row 117 :            4 4
# row 118 :            7 7
# row 119 :            8 1              incorrect
# row 120 :            3 5              incorrect
# row 121 :            3 3
# row 122 :            0 0
# row 123 :            3 5              incorrect
# row 124 :            7 8              incorrect
# row 125 :            3 8              incorrect
# row 126 :            3 9              incorrect
# row 127 :            5 5
# row 128 :            0 0
# row 129 :            6 6
# row 130 :            7 7
# row 131 :            2 2
# row 132 :            2 2
# row 133 :            3 5              incorrect
# row 134 :            4 4
# row 135 :            3 3
# row 136 :            3 9              incorrect
# row 137 :            2 8              incorrect
# row 138 :            3 2              incorrect
# row 139 :            2 1              incorrect
# row 140 :            2 1              incorrect
# row 141 :            7 7
# row 142 :            6 6
# row 143 :            3 3
# row 144 :            2 2
# row 145 :            3 3
# row 146 :            2 2
# row 147 :            3 3
# row 148 :            9 9
# row 149 :            2 2
# row 150 :            9 5              incorrect
# row 151 :            5 5
# row 152 :            1 2              incorrect
# row 153 :            2 1              incorrect
# row 154 :            6 6
# row 155 :            4 5              incorrect
# row 156 :            0 0
# row 157 :            4 1              incorrect
# row 158 :            6 6
# row 159 :            2 2
# row 160 :            3 3
# row 161 :            3 9              incorrect
# row 162 :            0 0
# row 163 :            4 1              incorrect
# row 164 :            0 0
# row 165 :            2 1              incorrect
# row 166 :            5 5
# row 167 :            1 1
# row 168 :            3 9              incorrect
# row 169 :            3 2              incorrect
# row 170 :            6 6
# row 171 :            0 0
# row 172 :            0 0
# row 173 :            3 5              incorrect
# row 174 :            0 0
# row 175 :            8 1              incorrect
# row 176 :            3 1              incorrect
# row 177 :            3 9              incorrect
# row 178 :            3 8              incorrect
# row 179 :            1 1
# row 180 :            0 0
# row 181 :            0 0
# row 182 :            2 2
# row 183 :            7 7
# row 184 :            2 2
# row 185 :            2 2
# row 186 :            1 8              incorrect
# row 187 :            6 6
# row 188 :            3 3
# row 189 :            3 8              incorrect
# row 190 :            6 6
# row 191 :            0 0
# row 192 :            4 4
# row 193 :            3 9              incorrect
# row 194 :            7 9              incorrect
# row 195 :            3 9              incorrect
# row 196 :            7 7
# row 197 :            3 5              incorrect
# row 198 :            2 2
# row 199 :            6 6
# row 200 :            0 0
# row 201 :            4 4
# row 202 :            6 6
# row 203 :            4 6              incorrect
# row 204 :            3 3
# row 205 :            7 7
# row 206 :            3 3
# row 207 :            9 9
# row 208 :            5 5
# row 209 :            6 6
# row 210 :            3 1              incorrect
# row 211 :            7 7
# row 212 :            3 9              incorrect
# row 213 :            3 9              incorrect
# row 214 :            4 5              incorrect
# row 215 :            0 0
# row 216 :            0 0
# row 217 :            4 4
# row 218 :            1 1
# row 219 :            4 8              incorrect
# row 220 :            4 1              incorrect
# row 221 :            1 2              incorrect
# row 222 :            8 8
# row 223 :            4 5              incorrect
# row 224 :            4 5              incorrect
# row 225 :            3 5              incorrect
# row 226 :            7 8              incorrect
# row 227 :            3 9              incorrect
# row 228 :            6 6
# row 229 :            3 9              incorrect
# row 230 :            3 8              incorrect
# row 231 :            5 5
# row 232 :            1 2              incorrect
# row 233 :            3 3
# row 234 :            5 5
# row 235 :            4 5              incorrect
# row 236 :            2 2
# row 237 :            0 0
# row 238 :            7 7
# row 239 :            1 1
# row 240 :            5 5
# row 241 :            1 1
# row 242 :            4 1              incorrect
# row 243 :            0 0
# row 244 :            3 9              incorrect
# row 245 :            2 2
# row 246 :            9 5              incorrect
# row 247 :            1 8              incorrect
# row 248 :            3 8              incorrect
# row 249 :            4 4
# row 250 :            2 8              incorrect
# row 251 :            0 0
# row 252 :            7 7
# row 253 :            6 6
# row 254 :            2 2
# row 255 :            7 7
# row 256 :            2 2
# row 257 :            0 7              incorrect
# row 258 :            3 5              incorrect
# row 259 :            3 9              incorrect
# row 260 :            3 9              incorrect
# row 261 :            7 7
# row 262 :            3 3
# row 263 :            4 4
# row 264 :            7 7
# row 265 :            3 3
# row 266 :            3 9              incorrect
# row 267 :            2 2
# row 268 :            3 3
# row 269 :            4 7              incorrect
# row 270 :            2 2
# row 271 :            4 6              incorrect
# row 272 :            3 3
# row 273 :            4 4
# row 274 :            2 2
# row 275 :            3 8              incorrect
# row 276 :            7 4              incorrect
# row 277 :            7 5              incorrect
# row 278 :            3 9              incorrect
# row 279 :            3 3
# row 280 :            2 2
# row 281 :            3 9              incorrect
# row 282 :            6 6
# row 283 :            2 2
# row 284 :            3 5              incorrect
# row 285 :            9 9
# row 286 :            1 1
# row 287 :            7 9              incorrect
# row 288 :            6 6
# row 289 :            5 5
# row 290 :            0 0
# row 291 :            3 2              incorrect
# row 292 :            1 8              incorrect
# row 293 :            3 9              incorrect
# row 294 :            6 6
# row 295 :            6 6
# row 296 :            0 0
# row 297 :            3 9              incorrect
# row 298 :            4 4
# row 299 :            0 5              incorrect
# row 300 :            3 9              incorrect
# row 301 :            2 2
# row 302 :            5 5
# row 303 :            7 7
# row 304 :            4 4
# row 305 :            3 1              incorrect
# row 306 :            3 9              incorrect
# row 307 :            4 7              incorrect
# row 308 :            3 5              incorrect
# row 309 :            2 2
# row 310 :            4 5              incorrect
# row 311 :            7 7
# row 312 :            3 9              incorrect
# row 313 :            8 8
# row 314 :            6 4              incorrect
# row 315 :            3 8              incorrect
# row 316 :            2 2
# row 317 :            3 9              incorrect
# row 318 :            4 8              incorrect
# row 319 :            3 8              incorrect
# row 320 :            7 7
# row 321 :            5 5
# row 322 :            3 2              incorrect
# row 323 :            5 5
# row 324 :            7 7
# row 325 :            9 5              incorrect
# row 326 :            3 3
# row 327 :            2 2
# row 328 :            4 4
# row 329 :            9 9
# row 330 :            0 5              incorrect
# row 331 :            2 2
# row 332 :            0 0
# row 333 :            2 8              incorrect
# row 334 :            7 7
# row 335 :            4 1              incorrect
# row 336 :            2 1              incorrect
# row 337 :            3 9              incorrect
# row 338 :            8 8
# row 339 :            2 1              incorrect
# row 340 :            1 8              incorrect
# row 341 :            6 6
# row 342 :            4 4
# row 343 :            0 0
# row 344 :            8 8
# row 345 :            4 4
# row 346 :            2 2
# row 347 :            2 3              incorrect
# row 348 :            0 0
# row 349 :            6 6
# row 350 :            7 7
# row 351 :            7 7
# row 352 :            1 8              incorrect
# row 353 :            7 7
#
# Correct: 213 out of 354
# 213

# %%
#see one of the forest's trees
# we can get the individual trees, if we want...
#
tree_index = 28   # which tree
one_rf_tree = rforest_model.estimators_[tree_index]
print(f"One of the forest's trees is {one_rf_tree}")

# From there, it's possible to create a graphical version...
filename = f'rf_tree_{tree_index:03d}.gv'             # f strings! Could save all trees, but we won't do so here. 
tree.export_graphviz(one_rf_tree, out_file=filename,  # the filename constructed above...!
                            feature_names=FEATURES, # actual feature names, not species
                            filled=True,              # fun!
                            rotate=False,             # False for Up/Down; True for L/R
                            class_names=SPECIES,      # good to have   
                            leaves_parallel=True )    # lots of options!
                            
print(f"file {filename} written. Try copying the result to http://viz-js.com/ \n")

with open(filename, "r") as f:
    file_text = f.read()
    print(file_text)

#
# Treeing!
#
fig = plt.figure(figsize=(5,4))
tree_plot = tree.plot_tree(one_rf_tree, 
                   feature_names=FEATURES,   # Glad to have these!
                   class_names=SPECIES,      # and these!!
                   filled=True)
# Out:
# One of the forest's trees is DecisionTreeClassifier(max_depth=1, max_features='sqrt',
#                        random_state=2062163430)
# file rf_tree_028.gv written. Try copying the result to http://viz-js.com/
#
# digraph Tree {
# node [shape=box, style="filled", color="black", fontname="helvetica"] ;
# graph [ranksep=equally, splines=polyline] ;
# edge [fontname="helvetica"] ;
# 0 [label="pix36 <= 0.5\ngini = 0.9\nsamples = 558\nvalue = [78, 67, 65, 67, 73, 80, 72, 65, 72, 68]\nclass = 5", fillcolor="#feffff"] ;
# 1 [label="gini = 0.575\nsamples = 93\nvalue = [75, 0, 0, 1, 4, 16, 2, 0, 2, 23]\nclass = 0", fillcolor="#f1bd98"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="gini = 0.889\nsamples = 465\nvalue = [3, 67, 65, 66, 69, 64, 70, 65, 70, 45]\nclass = 6", fillcolor="#ffffff"] ;
# 0 -> 2 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# {rank=same ; 0} ;
# {rank=same ; 1; 2} ;
# }

# %%
#cross-validation over two parameters
#
# So, to compare different parameters, let's use cv
#

from sklearn.model_selection import cross_val_score

#
# cross-validation splits the training set into two pieces:
#   + model-building and model-validation. We'll use "build" and "validate"
#

#
# lab task:  wrap this loop in another one! (or create an inner one...)
#

best_d = 1         # range(1,6)
best_ntrees = 50   # [50,150,250]
best_accuracy = 0

for d in range(1,6):
    for ntrees in [50,150,250]:
        rforest_model = ensemble.RandomForestClassifier(max_depth=d, 
                                                        n_estimators=ntrees,
                                                        max_samples=0.5)
        cv_scores = cross_val_score( rforest_model, X_train, y_train, cv=5 ) # 5 means 80/20 split
        average_cv_accuracy = cv_scores.mean()  # more likely, only their average
        print(f"depth: {d:2d} ntrees: {ntrees:3d} cv accuracy: {average_cv_accuracy:7.4f}")
        if average_cv_accuracy > best_accuracy:
            best_accuracy = average_cv_accuracy
            best_d = d
            best_ntrees = ntrees

# 
# your task: assign best values by keeping a "running max"
#
best_depth = best_d   
best_num_trees = best_ntrees

# This will be incorrect when initially run (you'll fix it):
print()
print(f"best_depth: {best_depth} and best_num_trees: {best_num_trees} are our choices. Acc: {best_accuracy}")  

#
# remember that the RF lab task is to complete this nested cross-validation loop!
#
# Out:
# depth:  1 ntrees:  50 cv accuracy:  0.6563
# depth:  1 ntrees: 150 cv accuracy:  0.6598
# depth:  1 ntrees: 250 cv accuracy:  0.6690
# depth:  2 ntrees:  50 cv accuracy:  0.8055
# depth:  2 ntrees: 150 cv accuracy:  0.8197
# depth:  2 ntrees: 250 cv accuracy:  0.8281
# depth:  3 ntrees:  50 cv accuracy:  0.8606
# depth:  3 ntrees: 150 cv accuracy:  0.8819
# depth:  3 ntrees: 250 cv accuracy:  0.8819
# depth:  4 ntrees:  50 cv accuracy:  0.9024
# depth:  4 ntrees: 150 cv accuracy:  0.9151
# depth:  4 ntrees: 250 cv accuracy:  0.9158
# depth:  5 ntrees:  50 cv accuracy:  0.9356
# depth:  5 ntrees: 150 cv accuracy:  0.9413
# depth:  5 ntrees: 250 cv accuracy:  0.9399
#
# best_depth: 5 and best_num_trees: 150 are our choices. Acc: 0.9412926346389995

# %%
#build a tuned model with new parameter values
# Now, we re-create and re-run the  "Model-building and -training Cell"
#
from sklearn import tree      # for decision trees
from sklearn import ensemble  # for random forests
best_depth =  best_depth
best_num_trees = best_num_trees
# we should have best_depth and best_num_trees
rforest_model_tuned = ensemble.RandomForestClassifier(max_depth=best_depth, 
                                                      n_estimators=best_num_trees,
                                                      max_samples=0.5)

# we train the model (it's one line!)
rforest_model_tuned.fit(X_train, y_train)                              # yay!  trained!
print(f"Built an RF classifier with depth={best_depth} and ntrees={best_num_trees}")
# Out:
# Built an RF classifier with depth=5 and ntrees=150

# %%
#test
# +++ This is our "Model-testing Cell"
#
# Now, let's see how well we did on our "held-out data" (the testing data)
#

# We run our test set!
predicted_labels = rforest_model_tuned.predict(X_test)
actual_labels = y_test

# Let's print them so we can compare...
print("Predicted labels:", predicted_labels)
print("Actual  labels  :", actual_labels)

# And, some overall results
num_correct = sum(predicted_labels == actual_labels)
total = len(actual_labels)
print(f"\nResults on test set:  {num_correct} correct out of {total} total.")

# and, let's print our table, too...
compare_labels(predicted_labels,actual_labels)
# Out:
# Predicted labels: ['4' '0' '2' '7' '2' '2' '6' '7' '4' '4' '8' '8' '8' '1' '2' '3' '8' '7'
#  '9' '0' '9' '3' '8' '8' '9' '2' '3' '6' '9' '0' '5' '3' '5' '7' '8' '3'
#  '6' '3' '3' '3' '7' '7' '6' '9' '9' '6' '6' '3' '6' '5' '9' '7' '6' '6'
#  '8' '8' '5' '5' '7' '3' '6' '9' '5' '0' '1' '4' '8' '3' '4' '5' '3' '7'
#  '0' '0' '5' '0' '6' '1' '0' '7' '9' '3' '9' '7' '4' '0' '1' '7' '9' '1'
#  '0' '7' '9' '3' '5' '0' '6' '2' '7' '1' '0' '8' '1' '6' '9' '8' '5' '4'
#  '0' '1' '1' '7' '2' '8' '1' '4' '4' '4' '7' '1' '5' '3' '0' '5' '7' '8'
#  '9' '5' '0' '6' '7' '2' '2' '5' '4' '3' '9' '8' '2' '1' '1' '7' '6' '7'
#  '2' '3' '2' '3' '9' '2' '5' '5' '1' '1' '6' '5' '0' '1' '6' '2' '3' '9'
#  '0' '1' '0' '1' '5' '1' '9' '2' '6' '0' '0' '5' '0' '1' '1' '9' '8' '1'
#  '0' '0' '2' '7' '2' '2' '7' '6' '3' '8' '6' '0' '4' '9' '7' '9' '7' '5'
#  '2' '6' '0' '4' '6' '6' '3' '7' '3' '9' '5' '6' '1' '7' '9' '9' '5' '0'
#  '0' '4' '1' '8' '1' '2' '8' '5' '5' '5' '7' '9' '6' '9' '8' '5' '1' '3'
#  '5' '5' '2' '0' '7' '1' '5' '1' '1' '0' '9' '2' '5' '8' '8' '4' '8' '0'
#  '7' '6' '2' '7' '2' '7' '5' '9' '9' '7' '3' '4' '7' '3' '9' '2' '3' '7'
#  '2' '6' '3' '4' '2' '8' '7' '5' '9' '3' '2' '9' '6' '2' '5' '9' '1' '7'
#  '6' '5' '0' '2' '8' '9' '6' '6' '0' '9' '4' '5' '9' '2' '5' '7' '4' '1'
#  '9' '4' '5' '2' '5' '7' '9' '8' '4' '8' '2' '9' '8' '8' '7' '5' '2' '5'
#  '7' '5' '3' '2' '4' '9' '5' '2' '0' '8' '7' '1' '1' '9' '8' '1' '8' '6'
#  '4' '0' '8' '4' '2' '3' '0' '6' '7' '7' '8' '7']
# Actual  labels  : ['4' '0' '2' '7' '2' '2' '6' '7' '4' '4' '8' '8' '8' '1' '2' '3' '8' '7'
#  '9' '0' '9' '3' '8' '8' '9' '2' '3' '6' '9' '0' '5' '3' '5' '7' '8' '3'
#  '6' '3' '3' '3' '7' '7' '6' '9' '9' '6' '6' '3' '5' '5' '9' '4' '6' '6'
#  '8' '8' '5' '5' '7' '3' '6' '9' '5' '0' '1' '4' '8' '3' '4' '5' '3' '7'
#  '0' '0' '5' '0' '6' '1' '0' '7' '9' '3' '9' '7' '4' '0' '1' '7' '9' '1'
#  '0' '7' '9' '3' '5' '0' '6' '2' '7' '1' '0' '8' '1' '6' '9' '8' '5' '4'
#  '0' '8' '1' '7' '2' '1' '1' '4' '4' '4' '7' '1' '5' '3' '0' '5' '8' '8'
#  '9' '5' '0' '6' '7' '2' '2' '5' '4' '3' '9' '8' '2' '1' '1' '7' '6' '3'
#  '2' '3' '2' '3' '9' '2' '5' '5' '2' '1' '6' '5' '0' '1' '6' '2' '3' '9'
#  '0' '1' '0' '1' '5' '1' '9' '2' '6' '0' '0' '5' '0' '1' '1' '9' '8' '1'
#  '0' '0' '2' '7' '2' '2' '8' '6' '3' '8' '6' '0' '4' '9' '9' '9' '7' '5'
#  '2' '6' '0' '4' '6' '6' '3' '7' '3' '9' '5' '6' '1' '7' '9' '9' '5' '0'
#  '0' '4' '1' '8' '1' '2' '8' '5' '5' '5' '8' '9' '6' '9' '8' '5' '2' '3'
#  '5' '5' '2' '0' '7' '1' '5' '1' '1' '0' '9' '2' '5' '8' '8' '4' '8' '0'
#  '7' '6' '2' '7' '2' '7' '5' '9' '9' '7' '3' '4' '7' '3' '9' '2' '3' '7'
#  '2' '6' '3' '4' '2' '8' '4' '5' '9' '3' '2' '9' '6' '2' '5' '9' '1' '9'
#  '6' '5' '0' '2' '8' '9' '6' '6' '0' '9' '4' '5' '9' '2' '5' '7' '4' '1'
#  '9' '7' '5' '2' '5' '7' '9' '8' '4' '8' '2' '9' '8' '8' '7' '5' '2' '5'
#  '7' '5' '3' '2' '4' '9' '5' '2' '0' '8' '7' '1' '1' '9' '8' '1' '8' '6'
#  '4' '0' '8' '4' '2' '3' '0' '6' '7' '7' '8' '7']
#
# Results on test set:  340 correct out of 354 total.
# row   0 :            4 4
# row   1 :            0 0
# row   2 :            2 2
# row   3 :            7 7
# row   4 :            2 2
# row   5 :            2 2
# row   6 :            6 6
# row   7 :            7 7
# row   8 :            4 4
# row   9 :            4 4
# row  10 :            8 8
# row  11 :            8 8
# row  12 :            8 8
# row  13 :            1 1
# row  14 :            2 2
# row  15 :            3 3
# row  16 :            8 8
# row  17 :            7 7
# row  18 :            9 9
# row  19 :            0 0
# row  20 :            9 9
# row  21 :            3 3
# row  22 :            8 8
# row  23 :            8 8
# row  24 :            9 9
# row  25 :            2 2
# row  26 :            3 3
# row  27 :            6 6
# row  28 :            9 9
# row  29 :            0 0
# row  30 :            5 5
# row  31 :            3 3
# row  32 :            5 5
# row  33 :            7 7
# row  34 :            8 8
# row  35 :            3 3
# row  36 :            6 6
# row  37 :            3 3
# row  38 :            3 3
# row  39 :            3 3
# row  40 :            7 7
# row  41 :            7 7
# row  42 :            6 6
# row  43 :            9 9
# row  44 :            9 9
# row  45 :            6 6
# row  46 :            6 6
# row  47 :            3 3
# row  48 :            6 5              incorrect
# row  49 :            5 5
# row  50 :            9 9
# row  51 :            7 4              incorrect
# row  52 :            6 6
# row  53 :            6 6
# row  54 :            8 8
# row  55 :            8 8
# row  56 :            5 5
# row  57 :            5 5
# row  58 :            7 7
# row  59 :            3 3
# row  60 :            6 6
# row  61 :            9 9
# row  62 :            5 5
# row  63 :            0 0
# row  64 :            1 1
# row  65 :            4 4
# row  66 :            8 8
# row  67 :            3 3
# row  68 :            4 4
# row  69 :            5 5
# row  70 :            3 3
# row  71 :            7 7
# row  72 :            0 0
# row  73 :            0 0
# row  74 :            5 5
# row  75 :            0 0
# row  76 :            6 6
# row  77 :            1 1
# row  78 :            0 0
# row  79 :            7 7
# row  80 :            9 9
# row  81 :            3 3
# row  82 :            9 9
# row  83 :            7 7
# row  84 :            4 4
# row  85 :            0 0
# row  86 :            1 1
# row  87 :            7 7
# row  88 :            9 9
# row  89 :            1 1
# row  90 :            0 0
# row  91 :            7 7
# row  92 :            9 9
# row  93 :            3 3
# row  94 :            5 5
# row  95 :            0 0
# row  96 :            6 6
# row  97 :            2 2
# row  98 :            7 7
# row  99 :            1 1
# row 100 :            0 0
# row 101 :            8 8
# row 102 :            1 1
# row 103 :            6 6
# row 104 :            9 9
# row 105 :            8 8
# row 106 :            5 5
# row 107 :            4 4
# row 108 :            0 0
# row 109 :            1 8              incorrect
# row 110 :            1 1
# row 111 :            7 7
# row 112 :            2 2
# row 113 :            8 1              incorrect
# row 114 :            1 1
# row 115 :            4 4
# row 116 :            4 4
# row 117 :            4 4
# row 118 :            7 7
# row 119 :            1 1
# row 120 :            5 5
# row 121 :            3 3
# row 122 :            0 0
# row 123 :            5 5
# row 124 :            7 8              incorrect
# row 125 :            8 8
# row 126 :            9 9
# row 127 :            5 5
# row 128 :            0 0
# row 129 :            6 6
# row 130 :            7 7
# row 131 :            2 2
# row 132 :            2 2
# row 133 :            5 5
# row 134 :            4 4
# row 135 :            3 3
# row 136 :            9 9
# row 137 :            8 8
# row 138 :            2 2
# row 139 :            1 1
# row 140 :            1 1
# row 141 :            7 7
# row 142 :            6 6
# row 143 :            7 3              incorrect
# row 144 :            2 2
# row 145 :            3 3
# row 146 :            2 2
# row 147 :            3 3
# row 148 :            9 9
# row 149 :            2 2
# row 150 :            5 5
# row 151 :            5 5
# row 152 :            1 2              incorrect
# row 153 :            1 1
# row 154 :            6 6
# row 155 :            5 5
# row 156 :            0 0
# row 157 :            1 1
# row 158 :            6 6
# row 159 :            2 2
# row 160 :            3 3
# row 161 :            9 9
# row 162 :            0 0
# row 163 :            1 1
# row 164 :            0 0
# row 165 :            1 1
# row 166 :            5 5
# row 167 :            1 1
# row 168 :            9 9
# row 169 :            2 2
# row 170 :            6 6
# row 171 :            0 0
# row 172 :            0 0
# row 173 :            5 5
# row 174 :            0 0
# row 175 :            1 1
# row 176 :            1 1
# row 177 :            9 9
# row 178 :            8 8
# row 179 :            1 1
# row 180 :            0 0
# row 181 :            0 0
# row 182 :            2 2
# row 183 :            7 7
# row 184 :            2 2
# row 185 :            2 2
# row 186 :            7 8              incorrect
# row 187 :            6 6
# row 188 :            3 3
# row 189 :            8 8
# row 190 :            6 6
# row 191 :            0 0
# row 192 :            4 4
# row 193 :            9 9
# row 194 :            7 9              incorrect
# row 195 :            9 9
# row 196 :            7 7
# row 197 :            5 5
# row 198 :            2 2
# row 199 :            6 6
# row 200 :            0 0
# row 201 :            4 4
# row 202 :            6 6
# row 203 :            6 6
# row 204 :            3 3
# row 205 :            7 7
# row 206 :            3 3
# row 207 :            9 9
# row 208 :            5 5
# row 209 :            6 6
# row 210 :            1 1
# row 211 :            7 7
# row 212 :            9 9
# row 213 :            9 9
# row 214 :            5 5
# row 215 :            0 0
# row 216 :            0 0
# row 217 :            4 4
# row 218 :            1 1
# row 219 :            8 8
# row 220 :            1 1
# row 221 :            2 2
# row 222 :            8 8
# row 223 :            5 5
# row 224 :            5 5
# row 225 :            5 5
# row 226 :            7 8              incorrect
# row 227 :            9 9
# row 228 :            6 6
# row 229 :            9 9
# row 230 :            8 8
# row 231 :            5 5
# row 232 :            1 2              incorrect
# row 233 :            3 3
# row 234 :            5 5
# row 235 :            5 5
# row 236 :            2 2
# row 237 :            0 0
# row 238 :            7 7
# row 239 :            1 1
# row 240 :            5 5
# row 241 :            1 1
# row 242 :            1 1
# row 243 :            0 0
# row 244 :            9 9
# row 245 :            2 2
# row 246 :            5 5
# row 247 :            8 8
# row 248 :            8 8
# row 249 :            4 4
# row 250 :            8 8
# row 251 :            0 0
# row 252 :            7 7
# row 253 :            6 6
# row 254 :            2 2
# row 255 :            7 7
# row 256 :            2 2
# row 257 :            7 7
# row 258 :            5 5
# row 259 :            9 9
# row 260 :            9 9
# row 261 :            7 7
# row 262 :            3 3
# row 263 :            4 4
# row 264 :            7 7
# row 265 :            3 3
# row 266 :            9 9
# row 267 :            2 2
# row 268 :            3 3
# row 269 :            7 7
# row 270 :            2 2
# row 271 :            6 6
# row 272 :            3 3
# row 273 :            4 4
# row 274 :            2 2
# row 275 :            8 8
# row 276 :            7 4              incorrect
# row 277 :            5 5
# row 278 :            9 9
# row 279 :            3 3
# row 280 :            2 2
# row 281 :            9 9
# row 282 :            6 6
# row 283 :            2 2
# row 284 :            5 5
# row 285 :            9 9
# row 286 :            1 1
# row 287 :            7 9              incorrect
# row 288 :            6 6
# row 289 :            5 5
# row 290 :            0 0
# row 291 :            2 2
# row 292 :            8 8
# row 293 :            9 9
# row 294 :            6 6
# row 295 :            6 6
# row 296 :            0 0
# row 297 :            9 9
# row 298 :            4 4
# row 299 :            5 5
# row 300 :            9 9
# row 301 :            2 2
# row 302 :            5 5
# row 303 :            7 7
# row 304 :            4 4
# row 305 :            1 1
# row 306 :            9 9
# row 307 :            4 7              incorrect
# row 308 :            5 5
# row 309 :            2 2
# row 310 :            5 5
# row 311 :            7 7
# row 312 :            9 9
# row 313 :            8 8
# row 314 :            4 4
# row 315 :            8 8
# row 316 :            2 2
# row 317 :            9 9
# row 318 :            8 8
# row 319 :            8 8
# row 320 :            7 7
# row 321 :            5 5
# row 322 :            2 2
# row 323 :            5 5
# row 324 :            7 7
# row 325 :            5 5
# row 326 :            3 3
# row 327 :            2 2
# row 328 :            4 4
# row 329 :            9 9
# row 330 :            5 5
# row 331 :            2 2
# row 332 :            0 0
# row 333 :            8 8
# row 334 :            7 7
# row 335 :            1 1
# row 336 :            1 1
# row 337 :            9 9
# row 338 :            8 8
# row 339 :            1 1
# row 340 :            8 8
# row 341 :            6 6
# row 342 :            4 4
# row 343 :            0 0
# row 344 :            8 8
# row 345 :            4 4
# row 346 :            2 2
# row 347 :            3 3
# row 348 :            0 0
# row 349 :            6 6
# row 350 :            7 7
# row 351 :            7 7
# row 352 :            8 8
# row 353 :            7 7
#
# Correct: 340 out of 354
# 340

# %%
#build a final model
#
# Ok!  We have tuned our RF to use the "best" parameters
#
# Now, we use ALL available data to train our final predictive model:
#
from sklearn import tree      # for decision trees
from sklearn import ensemble  # for random forests

# we should have best_depth and best_num_trees
rforest_model_final = ensemble.RandomForestClassifier(max_depth=best_depth, 
                                                      n_estimators=best_num_trees,
                                                      max_samples=0.5)

# we train the model (it's one line!)
rforest_model_final.fit(X_all, y_all)              # yay!  trained!
print(f"Built an RF classifier with depth={best_depth} and ntrees={best_num_trees}")
# Out:
# Built an RF classifier with depth=5 and ntrees=150

# %%
#
# final predictive model (random forests), with tuned parameters + ALL data incorporated
#

def predictive_model( Features, Model ):
    """ input: a list of 64 pixel features 
                [ month, day ]
        output: the predicted class of digits, from
                  string (0) to (9)
    """
    our_features = np.asarray([Features])                 # extra brackets needed
    predicted_species = Model.predict(our_features)       # The model's prediction!
    predicted_species = int(predicted_species[0])  # unpack the extra brackets
    return predicted_species
   
#
# Try it!
# 

LoD = [[0,0,0,8,14,0,0,0,0,0,5,16,11,0,0,0,0,1,15,14,1,6,0,0,0,7,16,5,3,16,8,0,0,8,16,8,14,16,2,0,0,0,6,14,16,11,0,0,0,0,0,6,16,4,0,0,0,0,0,10,15,0,0,0],
[0,0,0,5,14,12,2,0,0,0,7,15,8,14,4,0,0,0,6,2,3,13,1,0,0,0,0,1,13,4,0,0,0,0,1,11,9,0,0,0,0,8,16,13,0,0,0,0,0,5,14,16,11,2,0,0,0,0,0,6,12,13,3,0],
[0,0,0,3,16,3,0,0,0,0,0,12,16,2,0,0,0,0,8,16,16,4,0,0,0,7,16,15,16,12,11,0,0,8,16,16,16,13,3,0,0,0,0,7,14,1,0,0,0,0,0,6,16,0,0,0,0,0,0,4,14,0,0,0],
[0,0,0,3,15,10,1,0,0,0,0,11,10,16,4,0,0,0,0,12,1,15,6,0,0,0,0,3,4,15,4,0,0,0,0,6,15,6,0,0,0,4,15,16,9,0,0,0,0,0,13,16,15,9,3,0,0,0,0,4,9,14,7,0],
[0,0,0,3,16,3,0,0,0,0,0,10,16,11,0,0,0,0,4,16,16,8,0,0,0,2,14,12,16,5,0,0,0,10,16,14,16,16,11,0,0,5,12,13,16,8,3,0,0,0,0,2,15,3,0,0,0,0,0,4,12,0,0,0],
[0,0,7,15,15,4,0,0,0,8,16,16,16,4,0,0,0,8,15,8,16,4,0,0,0,0,0,10,15,0,0,0,0,0,1,15,9,0,0,0,0,0,6,16,2,0,0,0,0,0,8,16,8,11,9,0,0,0,9,16,16,12,3,0]]

# run on each one:
for Features in LoD:
    predicted_species = predictive_model( Features, rforest_model_final )  # pass in the model, too!
    name = SPECIES[predicted_species]
    print(f"I predict {name} from the features {Features}")    # Answers in the assignment...
# Out:
# I predict 4 from the features [0, 0, 0, 8, 14, 0, 0, 0, 0, 0, 5, 16, 11, 0, 0, 0, 0, 1, 15, 14, 1, 6, 0, 0, 0, 7, 16, 5, 3, 16, 8, 0, 0, 8, 16, 8, 14, 16, 2, 0, 0, 0, 6, 14, 16, 11, 0, 0, 0, 0, 0, 6, 16, 4, 0, 0, 0, 0, 0, 10, 15, 0, 0, 0]
# I predict 2 from the features [0, 0, 0, 5, 14, 12, 2, 0, 0, 0, 7, 15, 8, 14, 4, 0, 0, 0, 6, 2, 3, 13, 1, 0, 0, 0, 0, 1, 13, 4, 0, 0, 0, 0, 1, 11, 9, 0, 0, 0, 0, 8, 16, 13, 0, 0, 0, 0, 0, 5, 14, 16, 11, 2, 0, 0, 0, 0, 0, 6, 12, 13, 3, 0]
# I predict 4 from the features [0, 0, 0, 3, 16, 3, 0, 0, 0, 0, 0, 12, 16, 2, 0, 0, 0, 0, 8, 16, 16, 4, 0, 0, 0, 7, 16, 15, 16, 12, 11, 0, 0, 8, 16, 16, 16, 13, 3, 0, 0, 0, 0, 7, 14, 1, 0, 0, 0, 0, 0, 6, 16, 0, 0, 0, 0, 0, 0, 4, 14, 0, 0, 0]
# I predict 2 from the features [0, 0, 0, 3, 15, 10, 1, 0, 0, 0, 0, 11, 10, 16, 4, 0, 0, 0, 0, 12, 1, 15, 6, 0, 0, 0, 0, 3, 4, 15, 4, 0, 0, 0, 0, 6, 15, 6, 0, 0, 0, 4, 15, 16, 9, 0, 0, 0, 0, 0, 13, 16, 15, 9, 3, 0, 0, 0, 0, 4, 9, 14, 7, 0]
# I predict 4 from the features [0, 0, 0, 3, 16, 3, 0, 0, 0, 0, 0, 10, 16, 11, 0, 0, 0, 0, 4, 16, 16, 8, 0, 0, 0, 2, 14, 12, 16, 5, 0, 0, 0, 10, 16, 14, 16, 16, 11, 0, 0, 5, 12, 13, 16, 8, 3, 0, 0, 0, 0, 2, 15, 3, 0, 0, 0, 0, 0, 4, 12, 0, 0, 0]
# I predict 2 from the features [0, 0, 7, 15, 15, 4, 0, 0, 0, 8, 16, 16, 16, 4, 0, 0, 0, 8, 15, 8, 16, 4, 0, 0, 0, 0, 0, 10, 15, 0, 0, 0, 0, 0, 1, 15, 9, 0, 0, 0, 0, 0, 6, 16, 2, 0, 0, 0, 0, 0, 8, 16, 8, 11, 9, 0, 0, 0, 9, 16, 16, 12, 3, 0]

# %%
#feature importance tend to be more meaningful when tapped from RD because wisdom of the crowd can emerge
# feature importances are often even more "important" than predictions...
#
#    Random forests can provide a much "smoother" measure of feature importance, since
#                   they integrate over so many individual models (each tree)
#
#    That is, it's much less likely that a feature will have 0% importance, unless it never varies
#

print(rforest_model_final.feature_importances_)
print()

# let's see them with each feature name:
IMPs = rforest_model_final.feature_importances_

# enumerate is great when you want indices _and_ elements!
for i, importance in enumerate(IMPs):
    perc = importance*100
    print(f"Feature {COLUMNS[i]:>12s} has {perc:>7.2f}% of the decision-making importance.")
# Out:
# [0.00000000e+00 1.05888757e-03 2.02728822e-02 5.02372376e-03
#  3.49699164e-03 1.82773393e-02 1.02500227e-02 3.00642242e-04
#  0.00000000e+00 1.20472418e-02 1.92157013e-02 2.55930779e-03
#  9.77464423e-03 2.71730702e-02 2.76611988e-03 9.76371724e-05
#  0.00000000e+00 3.84426147e-03 1.54114817e-02 1.83084746e-02
#  2.95406664e-02 6.71116059e-02 7.18053484e-03 1.02587683e-04
#  2.46897397e-05 1.25182882e-02 4.33447653e-02 2.00359600e-02
#  4.05651326e-02 2.29428419e-02 3.85486239e-02 2.50396400e-05
#  0.00000000e+00 4.45070254e-02 3.23586557e-02 1.35067342e-02
#  5.64485303e-02 1.50845092e-02 2.75111978e-02 0.00000000e+00
#  2.81053990e-05 1.32880163e-02 3.69181861e-02 5.06825068e-02
#  1.89063514e-02 1.15044505e-02 2.17117021e-02 0.00000000e+00
#  0.00000000e+00 1.08616591e-03 1.62284725e-02 1.19702489e-02
#  1.19042563e-02 2.12926541e-02 2.41461845e-02 8.13809671e-04
#  0.00000000e+00 9.68574983e-04 2.52310436e-02 6.23890152e-03
#  3.95146695e-02 2.92565048e-02 1.49546001e-02 2.11877694e-03]
#
# Feature         pix0 has    0.00% of the decision-making importance.
# Feature         pix1 has    0.11% of the decision-making importance.
# Feature         pix2 has    2.03% of the decision-making importance.
# Feature         pix3 has    0.50% of the decision-making importance.
# Feature         pix4 has    0.35% of the decision-making importance.
# Feature         pix5 has    1.83% of the decision-making importance.
# Feature         pix6 has    1.03% of the decision-making importance.
# Feature         pix7 has    0.03% of the decision-making importance.
# Feature         pix8 has    0.00% of the decision-making importance.
# Feature         pix9 has    1.20% of the decision-making importance.
# Feature        pix10 has    1.92% of the decision-making importance.
# Feature        pix11 has    0.26% of the decision-making importance.
# Feature        pix12 has    0.98% of the decision-making importance.
# Feature        pix13 has    2.72% of the decision-making importance.
# Feature        pix14 has    0.28% of the decision-making importance.
# Feature        pix15 has    0.01% of the decision-making importance.
# Feature        pix16 has    0.00% of the decision-making importance.
# Feature        pix17 has    0.38% of the decision-making importance.
# Feature        pix18 has    1.54% of the decision-making importance.
# Feature        pix19 has    1.83% of the decision-making importance.
# Feature        pix20 has    2.95% of the decision-making importance.
# Feature        pix21 has    6.71% of the decision-making importance.
# Feature        pix22 has    0.72% of the decision-making importance.
# Feature        pix23 has    0.01% of the decision-making importance.
# Feature        pix24 has    0.00% of the decision-making importance.
# Feature        pix25 has    1.25% of the decision-making importance.
# Feature        pix26 has    4.33% of the decision-making importance.
# Feature        pix27 has    2.00% of the decision-making importance.
# Feature        pix28 has    4.06% of the decision-making importance.
# Feature        pix29 has    2.29% of the decision-making importance.
# Feature        pix30 has    3.85% of the decision-making importance.
# Feature        pix31 has    0.00% of the decision-making importance.
# Feature        pix32 has    0.00% of the decision-making importance.
# Feature        pix33 has    4.45% of the decision-making importance.
# Feature        pix34 has    3.24% of the decision-making importance.
# Feature        pix35 has    1.35% of the decision-making importance.
# Feature        pix36 has    5.64% of the decision-making importance.
# Feature        pix37 has    1.51% of the decision-making importance.
# Feature        pix38 has    2.75% of the decision-making importance.
# Feature        pix39 has    0.00% of the decision-making importance.
# Feature        pix40 has    0.00% of the decision-making importance.
# Feature        pix41 has    1.33% of the decision-making importance.
# Feature        pix42 has    3.69% of the decision-making importance.
# Feature        pix43 has    5.07% of the decision-making importance.
# Feature        pix44 has    1.89% of the decision-making importance.
# Feature        pix45 has    1.15% of the decision-making importance.
# Feature        pix46 has    2.17% of the decision-making importance.
# Feature        pix47 has    0.00% of the decision-making importance.
# Feature        pix48 has    0.00% of the decision-making importance.
# Feature        pix49 has    0.11% of the decision-making importance.
# Feature        pix50 has    1.62% of the decision-making importance.
# Feature        pix51 has    1.20% of the decision-making importance.
# Feature        pix52 has    1.19% of the decision-making importance.
# Feature        pix53 has    2.13% of the decision-making importance.
# Feature        pix54 has    2.41% of the decision-making importance.
# Feature        pix55 has    0.08% of the decision-making importance.
# Feature        pix56 has    0.00% of the decision-making importance.
# Feature        pix57 has    0.10% of the decision-making importance.
# Feature        pix58 has    2.52% of the decision-making importance.
# Feature        pix59 has    0.62% of the decision-making importance.
# Feature        pix60 has    3.95% of the decision-making importance.
# Feature        pix61 has    2.93% of the decision-making importance.
# Feature        pix62 has    1.50% of the decision-making importance.
# Feature        pix63 has    0.21% of the decision-making importance.

# %%
# Record how well your best DT and RF did at the predictions for the digits and in their cross-validation (was it as good as kNN in hw4?) 

# DT best_depth = 9 with acc: 0.8408515650452347
# RF best_depth: 5 and best_num_trees: 150 with acc:0.9412926346389995

# vs best_k = 1   yields the highest average cv accuracy: 0.9872691276345137

# %% [markdown]
# <br>
# <hr>
# <br>
#
# ### Final task: &nbsp; _Visualizing_ pixel-importance:
# + using your best Random Forest model, find the 64 _relative feature importances_ for all 64 of the digits' pixels!
#   + Show these as a list of 64 values (they will be difficult to imagine, but you will see that they vary a great deal, pixel-to-pixel)
# + Then, grab-and-adapt the code for visualizing individual digits in order to visualize the "importance image" of pixels...
# + that is, you'll create a heat map visualization, which is really just another image, of how relatively-important each of the 64 pixels is in your final Random Forest
#
# This visualization will be a "low-res image" similar to the digits, ***but it won't itself be a digit***
# + Instead, it will show _how much_ each of the 64 spots, across all of the 8x8 grids in the dataset, contribute in classifying each digit...

# %%
# Include the values (at the bottom of your file) of the feature_importances_ from your RF.

# Feature         pix0 has    0.00% of the decision-making importance.
# Feature         pix1 has    0.11% of the decision-making importance.
# Feature         pix2 has    2.03% of the decision-making importance.
# Feature         pix3 has    0.50% of the decision-making importance.
# Feature         pix4 has    0.35% of the decision-making importance.
# Feature         pix5 has    1.83% of the decision-making importance.
# Feature         pix6 has    1.03% of the decision-making importance.
# Feature         pix7 has    0.03% of the decision-making importance.
# ...
# Feature        pix60 has    3.95% of the decision-making importance.
# Feature        pix61 has    2.93% of the decision-making importance.
# Feature        pix62 has    1.50% of the decision-making importance.
# Feature        pix63 has    0.21% of the decision-making importance.

# %%
# Here is an example of using Seaborn to plot one of the 8x8 images
#      In this case, it's a list of 64 ints from 0 (most background) to 16 (most digit)
#


#
# Remember that, for the challenge above, you will want to visualize the feature importances...
#      You'll have to transform them so that this code can be applied...


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


PIXEL_IMPORTANCES = rforest_model_final.feature_importances_

# to Pandas dataframe :)
pixels = pd.DataFrame([PIXEL_IMPORTANCES])


# pixels = digits.iloc[row_to_show,0:64]  # shows how to grab this from within a larger dataframe named "digits"


# to Numpy array :)
pixels = pixels.values              # converts to numpy array
#pixels = pixels.astype(int)         # convert to integers for plotting
pixels = np.reshape(pixels, (8,8))  # makes a series of 64 values into an 8x8 grid
print(f"Its pixels are\n{pixels}") 


# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
# plot! Change annot=True to False to skip the numbers... 


sns.heatmap(pixels, annot=True, fmt=".2f", linewidths=.5, ax=ax, cmap="Purples")
# all seaborn palettes: medium.com/@morganjonesartist/color-guide-to-seaborn-palettes-da849406d44f
# cmap=None for reddish palette, cmap="Accent", cmap="gray_r" (best?), cmap="Purples", cmap="spam" to see the list...

ax.set_title("Pixel Feature Importances", fontsize=16)
ax.set_xlabel("Pixel Column", fontsize=12)
ax.set_ylabel("Pixel Row", fontsize=12)
plt.tight_layout()
plt.show()
# Out:
# Its pixels are
# [[0.00000000e+00 1.05888757e-03 2.02728822e-02 5.02372376e-03
#   3.49699164e-03 1.82773393e-02 1.02500227e-02 3.00642242e-04]
#  [0.00000000e+00 1.20472418e-02 1.92157013e-02 2.55930779e-03
#   9.77464423e-03 2.71730702e-02 2.76611988e-03 9.76371724e-05]
#  [0.00000000e+00 3.84426147e-03 1.54114817e-02 1.83084746e-02
#   2.95406664e-02 6.71116059e-02 7.18053484e-03 1.02587683e-04]
#  [2.46897397e-05 1.25182882e-02 4.33447653e-02 2.00359600e-02
#   4.05651326e-02 2.29428419e-02 3.85486239e-02 2.50396400e-05]
#  [0.00000000e+00 4.45070254e-02 3.23586557e-02 1.35067342e-02
#   5.64485303e-02 1.50845092e-02 2.75111978e-02 0.00000000e+00]
#  [2.81053990e-05 1.32880163e-02 3.69181861e-02 5.06825068e-02
#   1.89063514e-02 1.15044505e-02 2.17117021e-02 0.00000000e+00]
#  [0.00000000e+00 1.08616591e-03 1.62284725e-02 1.19702489e-02
#   1.19042563e-02 2.12926541e-02 2.41461845e-02 8.13809671e-04]
#  [0.00000000e+00 9.68574983e-04 2.52310436e-02 6.23890152e-03
#   3.95146695e-02 2.92565048e-02 1.49546001e-02 2.11877694e-03]]

# %%
#
# That's it!  Welcome to the world of model-building workflows!!    
#
#             Our prediction?  We'll be back for more ML! 
#


# If you'd like, the EC is to run a DT/RF workflow on your own data...   (in hw6ec_modeler.ipynb)
