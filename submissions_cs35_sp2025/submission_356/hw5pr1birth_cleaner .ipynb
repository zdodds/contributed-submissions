# %% [markdown]
# ### hw5pr1 births cleaner
#
# Suggestion:
# + set up this file and the example iris-cleaner file side-by-side...
# + for each iris-cleaner cell, copy it over...
#    + edit it and make adjustments to suit the births problem (as needed)
#    + run it to make sure it works
#
# And, by the end, you'll have experienced the full data-cleaning workflow.
# + Running through this workflow by hand is a great way to digest the process...
# + hw5pr2 will ask you to do this again, with the digits
# + hw5ec is for another - optional - example, using your own dataset or, possibly, regression

# %%
#
# hw5pr1births_cleaner:  birth classification by month + day    (above/below median: 190942)
#

# %%
# libraries!
import numpy as np      # numpy is Python's "array" library
import pandas as pd     # Pandas is Python's "data" library ("dataframe" == spreadsheet)

# %%
# read in our spreadsheet (csv)
filename = 'births.csv'
df = pd.read_csv(filename)        # encoding="utf-8" et al.
print(f"{filename} : file read into a pandas dataframe.")
# Out:
# births.csv : file read into a pandas dataframe.

# %%
#
# a dataframe is a "spreadsheet in Python"   (note that extra column at the right!)
#
# let's view it:
df
# Out:
#      month  day  births above/below median  \
# 0        1    1  160369              below
# 1        1    2  169896              below
# 2        1    3  180036              below
# 3        1    4  182854              below
# 4        1    5  184145              below
# ..     ...  ...     ...                ...
# 367     12   27  194006              above
# 368     12   28  201768              above
# 369     12   29  204806              above
# 370     12   30  206894              above
# 371     12   31  194368              above
#
#      from http://chmullig.com/2012/06/births-by-day-of-year/
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 367                                                NaN
# 368                                                NaN
# 369                                                NaN
# 370                                                NaN
# 371                                                NaN
#
# [372 rows x 5 columns]

# %%
# let's look at the dataframe's "info":
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 5 columns):
#  #   Column                                                   Non-Null Count  Dtype
# ---  ------                                                   --------------  -----
#  0   month                                                    372 non-null    int64
#  1   day                                                      372 non-null    int64
#  2   births                                                   372 non-null    int64
#  3   above/below median                                       372 non-null    object
#  4   from http://chmullig.com/2012/06/births-by-day-of-year/  0 non-null      float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 14.7+ KB

# %%
# Let's look at the dataframe's columns:
df.columns
# Out:
# Index(['month', 'day', 'births', 'above/below median',
#        'from http://chmullig.com/2012/06/births-by-day-of-year/'],
#       dtype='object')

# %%
# we can drop a series of data (a row or a column)
# the dimensions each have a numeric value, row~0, col~1, but let's use readable names we define:
ROW = 0        
COLUMN = 1     

# We are dropping this final column - it was just a citation...
df_clean1 = df.drop('from http://chmullig.com/2012/06/births-by-day-of-year/', axis=COLUMN)
df_clean1

# df_clean1 is a new dataframe, without that unwanted column
# Out:
#      month  day  births above/below median
# 0        1    1  160369              below
# 1        1    2  169896              below
# 2        1    3  180036              below
# 3        1    4  182854              below
# 4        1    5  184145              below
# ..     ...  ...     ...                ...
# 367     12   27  194006              above
# 368     12   28  201768              above
# 369     12   29  204806              above
# 370     12   30  206894              above
# 371     12   31  194368              above
#
# [372 rows x 4 columns]

# %%
df_clean1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   month               372 non-null    int64
#  1   day                 372 non-null    int64
#  2   births              372 non-null    int64
#  3   above/below median  372 non-null    object
# dtypes: int64(3), object(1)
# memory usage: 11.8+ KB

# %%
#
# let's drop _all_ rows with data that is missing/NaN (not-a-number)
df_clean2 = df_clean1.dropna()  # drop na rows (NaN, not-a-number)
df_clean2.info()  # print the info, and
# let's see the whole table, as well:
df_clean2

# Tidy!  Our data is ready!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 372 entries, 0 to 371
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   month               372 non-null    int64
#  1   day                 372 non-null    int64
#  2   births              372 non-null    int64
#  3   above/below median  372 non-null    object
# dtypes: int64(3), object(1)
# memory usage: 11.8+ KB
#      month  day  births above/below median
# 0        1    1  160369              below
# 1        1    2  169896              below
# 2        1    3  180036              below
# 3        1    4  182854              below
# 4        1    5  184145              below
# ..     ...  ...     ...                ...
# 367     12   27  194006              above
# 368     12   28  201768              above
# 369     12   29  204806              above
# 370     12   30  206894              above
# 371     12   31  194368              above
#
# [372 rows x 4 columns]

# %%
#
# let's keep our column names in variables, for reference
#
COLUMNS = df_clean2.columns            # "list" of columns
print(f"COLUMNS is {COLUMNS}")  
  # It's a "pandas" list, called an Index
  # use it just as a Python list of strings:
print(f"COLUMNS[0] is {COLUMNS[0]}\n")

# let's create a dictionary to look up an index from its name:
COL_INDEX = {}
for i, name in enumerate(COLUMNS):
    COL_INDEX[name] = i  # using the name (as key), look up the value (i)
print(f"COL_INDEX is {COL_INDEX}")
print(f"COL_INDEX[ 'month' ] is {COL_INDEX[ 'month' ]}")
# Out:
# COLUMNS is Index(['month', 'day', 'births', 'above/below median'], dtype='object')
# COLUMNS[0] is month
#
# COL_INDEX is {'month': 0, 'day': 1, 'births': 2, 'above/below median': 3}
# COL_INDEX[ 'month' ] is 0

# %%
# all of scikit-learn's ML routines need numbers, not strings
#   ... even for categories/classifications (like species!)
#   so, we will convert the flower-species to numbers

#
# First, let's map our different species to numeric values:

levels = ['above','below']   # int to str
levels_index = {'above':0,'below':1}  # str to int

def convert_level(levelname):
    """ return the species index (a unique integer/category) """
    return levels_index[levelname]

# Let's try it out...
for level in levels:
    print(f"{level} maps to {convert_level(level)}")
# Out:
# above maps to 0
# below maps to 1

# %%
convert_level('above')
# Out:
# 0

# %%
#
# we can "apply" to a whole column and create a new column
#   it may give a warning, but this is ok...
#

df_clean3 = df_clean2.copy()  # copy everything AND...

# add a new column, 'irisnum'
df_clean3['levelnum'] = df_clean2['above/below median'].apply(convert_level)

# let's see...
df_clean3
# Out:
#      month  day  births above/below median  levelnum
# 0        1    1  160369              below         1
# 1        1    2  169896              below         1
# 2        1    3  180036              below         1
# 3        1    4  182854              below         1
# 4        1    5  184145              below         1
# ..     ...  ...     ...                ...       ...
# 367     12   27  194006              above         0
# 368     12   28  201768              above         0
# 369     12   29  204806              above         0
# 370     12   30  206894              above         0
# 371     12   31  194368              above         0
#
# [372 rows x 5 columns]

# %%
#
# it's no fun fiddling with the default table formatting.
#
# Remember: we have the data itself!  If we want to see it, we can print:

(NROWS, NCOLS) = df_clean3.shape
print(f"There are {NROWS = } and {NCOLS = }")
print()

for row in range(0,NROWS,5):
    print(df_clean3[row:row+5])    # Let's print 5 at a time...
# Out:
# There are NROWS = 372 and NCOLS = 5
#
#    month  day  births above/below median  levelnum
# 0      1    1  160369              below         1
# 1      1    2  169896              below         1
# 2      1    3  180036              below         1
# 3      1    4  182854              below         1
# 4      1    5  184145              below         1
#    month  day  births above/below median  levelnum
# 5      1    6  186726              below         1
# 6      1    7  188277              below         1
# 7      1    8  185186              below         1
# 8      1    9  181511              below         1
# 9      1   10  183668              below         1
#     month  day  births above/below median  levelnum
# 10      1   11  187006              below         1
# 11      1   12  188032              below         1
# 12      1   13  189202              below         1
# 13      1   14  192648              above         0
# 14      1   15  189346              below         1
#     month  day  births above/below median  levelnum
# 15      1   16  186601              below         1
# 16      1   17  186186              below         1
# 17      1   18  188293              below         1
# 18      1   19  189261              below         1
# 19      1   20  190701              below         1
#     month  day  births above/below median  levelnum
# 20      1   21  191610              above         0
# 21      1   22  189712              below         1
# 22      1   23  186670              below         1
# 23      1   24  186128              below         1
# 24      1   25  187920              below         1
#     month  day  births above/below median  levelnum
# 25      1   26  188636              below         1
# 26      1   27  189881              below         1
# 27      1   28  190872              below         1
# 28      1   29  188092              below         1
# 29      1   30  185769              below         1
#     month  day  births above/below median  levelnum
# 30      1   31  183931              below         1
# 31      2    1  186458              below         1
# 32      2    2  189721              below         1
# 33      2    3  190473              below         1
# 34      2    4  190433              below         1
#     month  day  births above/below median  levelnum
# 35      2    5  189132              below         1
# 36      2    6  187124              below         1
# 37      2    7  185986              below         1
# 38      2    8  186741              below         1
# 39      2    9  188543              below         1
#     month  day  births above/below median  levelnum
# 40      2   10  192034              above         0
# 41      2   11  192632              above         0
# 42      2   12  192948              above         0
# 43      2   13  185576              below         1
# 44      2   14  194510              above         0
#     month  day  births above/below median  levelnum
# 45      2   15  188253              below         1
# 46      2   16  189281              below         1
# 47      2   17  191707              above         0
# 48      2   18  192839              above         0
# 49      2   19  190064              below         1
#     month  day  births above/below median  levelnum
# 50      2   20  190051              below         1
# 51      2   21  186860              below         1
# 52      2   22  190061              below         1
# 53      2   23  190298              below         1
# 54      2   24  193160              above         0
#     month  day  births above/below median  levelnum
# 55      2   25  194281              above         0
# 56      2   26  191623              above         0
# 57      2   27  187750              below         1
# 58      2   28  187812              below         1
# 59      2   29   46420              below         1
#     month  day  births above/below median  levelnum
# 60      2   30      98              below         1
# 61      2   31      77              below         1
# 62      3    1  189687              below         1
# 63      3    2  190022              below         1
# 64      3    3  194871              above         0
#     month  day  births above/below median  levelnum
# 65      3    4  192862              above         0
# 66      3    5  191264              above         0
# 67      3    6  188875              below         1
# 68      3    7  188898              below         1
# 69      3    8  188729              below         1
#     month  day  births above/below median  levelnum
# 70      3    9  187683              below         1
# 71      3   10  191415              above         0
# 72      3   11  191429              above         0
# 73      3   12  190497              below         1
# 74      3   13  186098              below         1
#     month  day  births above/below median  levelnum
# 75      3   14  188761              below         1
# 76      3   15  186801              below         1
# 77      3   16  188147              below         1
# 78      3   17  193142              above         0
# 79      3   18  190940              below         1
#     month  day  births above/below median  levelnum
# 80      3   19  189925              below         1
# 81      3   20  188654              below         1
# 82      3   21  188915              below         1
# 83      3   22  186688              below         1
# 84      3   23  187888              below         1
#     month  day  births above/below median  levelnum
# 85      3   24  189002              below         1
# 86      3   25  190946              above         0
# 87      3   26  188913              below         1
# 88      3   27  187234              below         1
# 89      3   28  187786              below         1
#     month  day  births above/below median  levelnum
# 90      3   29  186601              below         1
# 91      3   30  186537              below         1
# 92      3   31  188930              below         1
# 93      4    1  184953              below         1
# 94      4    2  189753              below         1
#     month  day  births above/below median  levelnum
# 95      4    3  186117              below         1
# 96      4    4  187181              below         1
# 97      4    5  183473              below         1
# 98      4    6  185714              below         1
# 99      4    7  187594              below         1
#      month  day  births above/below median  levelnum
# 100      4    8  188481              below         1
# 101      4    9  185995              below         1
# 102      4   10  184427              below         1
# 103      4   11  184398              below         1
# 104      4   12  183632              below         1
#      month  day  births above/below median  levelnum
# 105      4   13  182379              below         1
# 106      4   14  187205              below         1
# 107      4   15  188116              below         1
# 108      4   16  186258              below         1
# 109      4   17  184176              below         1
#      month  day  births above/below median  levelnum
# 110      4   18  185340              below         1
# 111      4   19  183308              below         1
# 112      4   20  183651              below         1
# 113      4   21  186257              below         1
# 114      4   22  187468              below         1
#      month  day  births above/below median  levelnum
# 115      4   23  185749              below         1
# 116      4   24  183246              below         1
# 117      4   25  184090              below         1
# 118      4   26  183540              below         1
# 119      4   27  182878              below         1
#      month  day  births above/below median  levelnum
# 120      4   28  186262              below         1
# 121      4   29  184530              below         1
# 122      4   30  184604              below         1
# 123      4   31     128              below         1
# 124      5    1  186051              below         1
#      month  day  births above/below median  levelnum
# 125      5    2  184668              below         1
# 126      5    3  182809              below         1
# 127      5    4  183080              below         1
# 128      5    5  187492              below         1
# 129      5    6  187158              below         1
#      month  day  births above/below median  levelnum
# 130      5    7  186358              below         1
# 131      5    8  184950              below         1
# 132      5    9  184354              below         1
# 133      5   10  184927              below         1
# 134      5   11  186088              below         1
#      month  day  births above/below median  levelnum
# 135      5   12  187962              below         1
# 136      5   13  186466              below         1
# 137      5   14  186836              below         1
# 138      5   15  187141              below         1
# 139      5   16  186458              below         1
#      month  day  births above/below median  levelnum
# 140      5   17  185069              below         1
# 141      5   18  186955              below         1
# 142      5   19  188870              below         1
# 143      5   20  192277              above         0
# 144      5   21  189032              below         1
#      month  day  births above/below median  levelnum
# 145      5   22  188540              below         1
# 146      5   23  188844              below         1
# 147      5   24  187565              below         1
# 148      5   25  186477              below         1
# 149      5   26  186310              below         1
#      month  day  births above/below median  levelnum
# 150      5   27  189526              below         1
# 151      5   28  186866              below         1
# 152      5   29  188162              below         1
# 153      5   30  184047              below         1
# 154      5   31  183882              below         1
#      month  day  births above/below median  levelnum
# 155      6    1  190059              below         1
# 156      6    2  192186              above         0
# 157      6    3  191331              above         0
# 158      6    4  189779              below         1
# 159      6    5  188275              below         1
#      month  day  births above/below median  levelnum
# 160      6    6  190874              below         1
# 161      6    7  187242              below         1
# 162      6    8  187278              below         1
# 163      6    9  191371              above         0
# 164      6   10  193255              above         0
#      month  day  births above/below median  levelnum
# 165      6   11  190945              above         0
#      month  day  births above/below median  levelnum
# 330     11   21  192033              above         0
# 331     11   22  184076              below         1
# 332     11   23  186026              below         1
# 333     11   24  185885              below         1
# 334     11   25  185992              below         1
#      month  day  births above/below median  levelnum
# 335     11   26  183490              below         1
# 336     11   27  180462              below         1
# 337     11   28  183631              below         1
# 338     11   29  187069              below         1
# 339     11   30  190619              below         1
#      month  day  births above/below median  levelnum
# 340     11   31     215              below         1
# 341     12    1  193460              above         0
# 342     12    2  193212              above         0
# 343     12    3  190340              below         1
# 344     12    4  188749              below         1
#      month  day  births above/below median  levelnum
# 345     12    5  189387              below         1
# 346     12    6  187322              below         1
# 347     12    7  188173              below         1
# 348     12    8  192152              above         0
# 349     12    9  191753              above         0
#      month  day  births above/below median  levelnum
# 350     12   10  191413              above         0
# 351     12   11  189540              below         1
# 352     12   12  191652              above         0
# 353     12   13  187067              below         1
# 354     12   14  191684              above         0
#      month  day  births above/below median  levelnum
# 355     12   15  196832              above         0
# 356     12   16  198724              above         0
# 357     12   17  198064              above         0
# 358     12   18  197455              above         0
# 359     12   19  198517              above         0
#      month  day  births above/below median  levelnum
# 360     12   20  195081              above         0
# 361     12   21  192644              above         0
# 362     12   22  186477              below         1
# 363     12   23  178667              below         1
# 364     12   24  165050              below         1
#      month  day  births above/below median  levelnum
# 365     12   25  153778              below         1
# 366     12   26  175341              below         1
# 367     12   27  194006              above         0
# 368     12   28  201768              above         0
# 369     12   29  204806              above         0
#      month  day  births above/below median  levelnum
# 370     12   30  206894              above         0
# 371     12   31  194368              above         0

# %%
#
# let's call it df_tidy 
#
df_tidy =  df_clean3

# %%
#
# That's it!  Then, and write it out to iris_cleaned.csv

# We'll construct the new filename:
old_filename_without_extension = filename[:-4]                      # remove the ".csv"

cleaned_filename = old_filename_without_extension + "_cleaned.csv"  # name-creating
print(f"cleaned_filename is {cleaned_filename}")

# Now, save the dataframe names df_tidy
df_tidy.to_csv(cleaned_filename, index_label=False)  # no "index" column...
# Out:
# cleaned_filename is births_cleaned.csv

# %%
#
# Let's make sure this worked, by re-reading in the data...
#

# let's re-read that file and take a look...
df_tidy_reread = pd.read_csv(cleaned_filename)   # encoding="utf-8" et al.
print(f"{cleaned_filename} : file read into a pandas dataframe.")
df_tidy_reread
# Out:
# births_cleaned.csv : file read into a pandas dataframe.
#      month  day  births above/below median  levelnum
# 0        1    1  160369              below         1
# 1        1    2  169896              below         1
# 2        1    3  180036              below         1
# 3        1    4  182854              below         1
# 4        1    5  184145              below         1
# ..     ...  ...     ...                ...       ...
# 367     12   27  194006              above         0
# 368     12   28  201768              above         0
# 369     12   29  204806              above         0
# 370     12   30  206894              above         0
# 371     12   31  194368              above         0
#
# [372 rows x 5 columns]

# %%
#
# *** SUGGESTION ***  
# 
#       +++ copy-paste-and-alter from the iris-cleaning notebook to here +++
#
# This approach has the advantage of more deeply "digesting" the iris workflow...
#      ... altering the parts that don't transfer, and taking the parts that do!
#

# eventually you'll get rid of the _births_ column, that can be here or in the modeling notebook
