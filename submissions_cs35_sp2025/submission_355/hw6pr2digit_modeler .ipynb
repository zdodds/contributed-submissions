# %% [markdown]
# <br>
#
# ##   hw6pr2digits_modeler
# + digits clasification via decision trees and random forests...
# + Remember: feel free to re-use the cleaned data from previous weeks (already here)

# %%
#
# SUGGESTION:  
# 
# +++ copy-paste-and-alter from the week6 iris- + births-modeling notebooks into here +++
#
# when the data is ready to view, you might want to grab
# the digits-visualization code    
#

# %% [markdown]
# ## Data set up...
# + Use the cleaned data from prior weeks (it should be here in this folder as digits_cleaned.csv)
# + (I don't think there's too much more to adjust, data-wise...)
# + Next, let's see how well the DT/RF techniques can predict the digit, based on its 64 pixels...

# %%
# libraries!
import numpy as np      # numpy is Python's "array" library
import pandas as pd     # Pandas is Python's "data" library ("dataframe" == spreadsheet)

# let's read in our digits data...
# 
filename = 'digits_cleaned.csv'
df_tidy = pd.read_csv(filename)      # encoding = "utf-8", "latin1"
print(f"{filename} : file read into a pandas dataframe.")
# Out:
# digits_cleaned.csv : file read into a pandas dataframe.

# %%
print(f"df_tidy.shape is {df_tidy.shape}\n")
# Out:
# df_tidy.shape is (1768, 65)

# %%
df_tidy.info()  # prints column information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1768 entries, 0 to 1767
# Data columns (total 65 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   pix0          1768 non-null   int64
#  1   pix1          1768 non-null   int64
#  2   pix2          1768 non-null   int64
#  3   pix3          1768 non-null   int64
#  4   pix4          1768 non-null   int64
#  5   pix5          1768 non-null   int64
#  6   pix6          1768 non-null   int64
#  7   pix7          1768 non-null   int64
#  8   pix8          1768 non-null   int64
#  9   pix9          1768 non-null   int64
#  10  pix10         1768 non-null   int64
#  11  pix11         1768 non-null   int64
#  12  pix12         1768 non-null   int64
#  13  pix13         1768 non-null   int64
#  14  pix14         1768 non-null   int64
#  15  pix15         1768 non-null   int64
#  16  pix16         1768 non-null   int64
#  17  pix17         1768 non-null   int64
#  18  pix18         1768 non-null   int64
#  19  pix19         1768 non-null   int64
#  20  pix20         1768 non-null   int64
#  21  pix21         1768 non-null   int64
#  22  pix22         1768 non-null   int64
#  23  pix23         1768 non-null   int64
#  24  pix24         1768 non-null   int64
#  25  pix25         1768 non-null   int64
#  26  pix26         1768 non-null   int64
#  27  pix27         1768 non-null   int64
#  28  pix28         1768 non-null   int64
#  29  pix29         1768 non-null   int64
#  30  pix30         1768 non-null   int64
#  31  pix31         1768 non-null   int64
#  32  pix32         1768 non-null   int64
#  33  pix33         1768 non-null   int64
#  34  pix34         1768 non-null   int64
#  35  pix35         1768 non-null   int64
#  36  pix36         1768 non-null   int64
#  37  pix37         1768 non-null   int64
#  38  pix38         1768 non-null   int64
#  39  pix39         1768 non-null   int64
#  40  pix40         1768 non-null   int64
#  41  pix41         1768 non-null   int64
#  42  pix42         1768 non-null   int64
#  43  pix43         1768 non-null   int64
#  44  pix44         1768 non-null   int64
#  45  pix45         1768 non-null   int64
#  46  pix46         1768 non-null   int64
#  47  pix47         1768 non-null   int64
#  48  pix48         1768 non-null   int64
#  49  pix49         1768 non-null   int64
#  50  pix50         1768 non-null   int64
#  51  pix51         1768 non-null   int64
#  52  pix52         1768 non-null   int64
#  53  pix53         1768 non-null   int64
#  54  pix54         1768 non-null   int64
#  55  pix55         1768 non-null   int64
#  56  pix56         1768 non-null   int64
#  57  pix57         1768 non-null   int64
#  58  pix58         1768 non-null   int64
#  59  pix59         1768 non-null   int64
#  60  pix60         1768 non-null   int64
#  61  pix61         1768 non-null   int64
#  62  pix62         1768 non-null   int64
#  63  pix63         1768 non-null   int64
#  64  actual_digit  1768 non-null   int64
# dtypes: int64(65)
# memory usage: 897.9 KB

# %%
df_tidy
# Out:
#       pix0  pix1  pix2  pix3  pix4  pix5  pix6  pix7  pix8  pix9  ...  pix55  \
# 0        0     0     9    14     8     1     0     0     0     0  ...      0
# 1        0     0    11    12     0     0     0     0     0     2  ...      0
# 2        0     0     1     9    15    11     0     0     0     0  ...      0
# 3        0     0     0     0    14    13     1     0     0     0  ...      0
# 4        0     0     5    12     1     0     0     0     0     0  ...      2
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...    ...
# 1763     0     0     4    10    13     6     0     0     0     1  ...      0
# 1764     0     0     6    16    13    11     1     0     0     0  ...      0
# 1765     0     0     1    11    15     1     0     0     0     0  ...      0
# 1766     0     0     2    10     7     0     0     0     0     0  ...      0
# 1767     0     0    10    14     8     1     0     0     0     2  ...      0
#
#       pix56  pix57  pix58  pix59  pix60  pix61  pix62  pix63  actual_digit
# 0         0      0     11     16     15     11      1      0             8
# 1         0      0      9     12     13      3      0      0             9
# 2         0      0      1     10     13      3      0      0             0
# 3         0      0      0      1     13     16      1      0             1
# 4         0      0      3     11      8     13     12      4             2
# ...     ...    ...    ...    ...    ...    ...    ...    ...           ...
# 1763      0      0      2     14     15      9      0      0             9
# 1764      0      0      6     16     14      6      0      0             0
# 1765      0      0      2      9     13      6      0      0             8
# 1766      0      0      5     12     16     12      0      0             9
# 1767      0      1      8     12     14     12      1      0             8
#
# [1768 rows x 65 columns]

# %%
ROW = 0
COLUMN = 1
df_model1 = df_tidy # .drop('actual_digit', axis=COLUMN )
df_model1
# Out:
#       pix0  pix1  pix2  pix3  pix4  pix5  pix6  pix7  pix8  pix9  ...  pix55  \
# 0        0     0     9    14     8     1     0     0     0     0  ...      0
# 1        0     0    11    12     0     0     0     0     0     2  ...      0
# 2        0     0     1     9    15    11     0     0     0     0  ...      0
# 3        0     0     0     0    14    13     1     0     0     0  ...      0
# 4        0     0     5    12     1     0     0     0     0     0  ...      2
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...    ...
# 1763     0     0     4    10    13     6     0     0     0     1  ...      0
# 1764     0     0     6    16    13    11     1     0     0     0  ...      0
# 1765     0     0     1    11    15     1     0     0     0     0  ...      0
# 1766     0     0     2    10     7     0     0     0     0     0  ...      0
# 1767     0     0    10    14     8     1     0     0     0     2  ...      0
#
#       pix56  pix57  pix58  pix59  pix60  pix61  pix62  pix63  actual_digit
# 0         0      0     11     16     15     11      1      0             8
# 1         0      0      9     12     13      3      0      0             9
# 2         0      0      1     10     13      3      0      0             0
# 3         0      0      0      1     13     16      1      0             1
# 4         0      0      3     11      8     13     12      4             2
# ...     ...    ...    ...    ...    ...    ...    ...    ...           ...
# 1763      0      0      2     14     15      9      0      0             9
# 1764      0      0      6     16     14      6      0      0             0
# 1765      0      0      2      9     13      6      0      0             8
# 1766      0      0      5     12     16     12      0      0             9
# 1767      0      1      8     12     14     12      1      0             8
#
# [1768 rows x 65 columns]

# %%
#
# once we have all the columns we want, let's create an index of their names...

#
# Let's make sure we have all of our helpful variables in one place 
#       To be adapted if we drop/add more columns...
#

#
# let's keep our column names in variables, for reference
#
COLUMNS = df_model1.columns            # "list" of columns
print(f"COLUMNS is {COLUMNS}\n")  
  # It's a "pandas" list, called an Index
  # use it just as a Python list of strings:
print(f"COLUMNS[0] is {COLUMNS[0]}\n")

# let's create a dictionary to look up any column index by name
COL_INDEX = {}
for i, name in enumerate(COLUMNS):
    COL_INDEX[name] = i  # using the name (as key), look up the value (i)
print(f"COL_INDEX is {COL_INDEX}\n\n")


FEATURES = COLUMNS[0:64]

#
# and our "species" names
#

# all of scikit-learn's ML routines need numbers, not strings
#   ... even for categories/classifications (like species!)
#   so, we will convert the flower-species to numbers:

SPECIES = [f'pix{i}' for i in range(64)]   # int to str
SPECIES_INDEX = {pixel: int(pixel[3:]) for pixel in SPECIES}  # str to int

# Let's try it out...
for name in SPECIES:
    print(f"{name} maps to {SPECIES_INDEX[name]}")
# Out:
# COLUMNS is Index(['pix0', 'pix1', 'pix2', 'pix3', 'pix4', 'pix5', 'pix6', 'pix7', 'pix8',
#        'pix9', 'pix10', 'pix11', 'pix12', 'pix13', 'pix14', 'pix15', 'pix16',
#        'pix17', 'pix18', 'pix19', 'pix20', 'pix21', 'pix22', 'pix23', 'pix24',
#        'pix25', 'pix26', 'pix27', 'pix28', 'pix29', 'pix30', 'pix31', 'pix32',
#        'pix33', 'pix34', 'pix35', 'pix36', 'pix37', 'pix38', 'pix39', 'pix40',
#        'pix41', 'pix42', 'pix43', 'pix44', 'pix45', 'pix46', 'pix47', 'pix48',
#        'pix49', 'pix50', 'pix51', 'pix52', 'pix53', 'pix54', 'pix55', 'pix56',
#        'pix57', 'pix58', 'pix59', 'pix60', 'pix61', 'pix62', 'pix63',
#        'actual_digit'],
#       dtype='object')
#
# COLUMNS[0] is pix0
#
# COL_INDEX is {'pix0': 0, 'pix1': 1, 'pix2': 2, 'pix3': 3, 'pix4': 4, 'pix5': 5, 'pix6': 6, 'pix7': 7, 'pix8': 8, 'pix9': 9, 'pix10': 10, 'pix11': 11, 'pix12': 12, 'pix13': 13, 'pix14': 14, 'pix15': 15, 'pix16': 16, 'pix17': 17, 'pix18': 18, 'pix19': 19, 'pix20': 20, 'pix21': 21, 'pix22': 22, 'pix23': 23, 'pix24': 24, 'pix25': 25, 'pix26': 26, 'pix27': 27, 'pix28': 28, 'pix29': 29, 'pix30': 30, 'pix31': 31, 'pix32': 32, 'pix33': 33, 'pix34': 34, 'pix35': 35, 'pix36': 36, 'pix37': 37, 'pix38': 38, 'pix39': 39, 'pix40': 40, 'pix41': 41, 'pix42': 42, 'pix43': 43, 'pix44': 44, 'pix45': 45, 'pix46': 46, 'pix47': 47, 'pix48': 48, 'pix49': 49, 'pix50': 50, 'pix51': 51, 'pix52': 52, 'pix53': 53, 'pix54': 54, 'pix55': 55, 'pix56': 56, 'pix57': 57, 'pix58': 58, 'pix59': 59, 'pix60': 60, 'pix61': 61, 'pix62': 62, 'pix63': 63, 'actual_digit': 64}
#
#
# pix0 maps to 0
# pix1 maps to 1
# pix2 maps to 2
# pix3 maps to 3
# pix4 maps to 4
# pix5 maps to 5
# pix6 maps to 6
# pix7 maps to 7
# pix8 maps to 8
# pix9 maps to 9
# pix10 maps to 10
# pix11 maps to 11
# pix12 maps to 12
# pix13 maps to 13
# pix14 maps to 14
# pix15 maps to 15
# pix16 maps to 16
# pix17 maps to 17
# pix18 maps to 18
# pix19 maps to 19
# pix20 maps to 20
# pix21 maps to 21
# pix22 maps to 22
# pix23 maps to 23
# pix24 maps to 24
# pix25 maps to 25
# pix26 maps to 26
# pix27 maps to 27
# pix28 maps to 28
# pix29 maps to 29
# pix30 maps to 30
# pix31 maps to 31
# pix32 maps to 32
# pix33 maps to 33
# pix34 maps to 34
# pix35 maps to 35
# pix36 maps to 36
# pix37 maps to 37
# pix38 maps to 38
# pix39 maps to 39
# pix40 maps to 40
# pix41 maps to 41
# pix42 maps to 42
# pix43 maps to 43
# pix44 maps to 44
# pix45 maps to 45
# pix46 maps to 46
# pix47 maps to 47
# pix48 maps to 48
# pix49 maps to 49
# pix50 maps to 50
# pix51 maps to 51
# pix52 maps to 52
# pix53 maps to 53
# pix54 maps to 54
# pix55 maps to 55
# pix56 maps to 56
# pix57 maps to 57
# pix58 maps to 58
# pix59 maps to 59
# pix60 maps to 60
# pix61 maps to 61
# pix62 maps to 62
# pix63 maps to 63

# %%
A = df_model1.to_numpy()   
print(A)
# Out:
# [[ 0  0  9 ...  1  0  8]
#  [ 0  0 11 ...  0  0  9]
#  [ 0  0  1 ...  0  0  0]
#  ...
#  [ 0  0  1 ...  0  0  8]
#  [ 0  0  2 ...  0  0  9]
#  [ 0  0 10 ...  1  0  8]]

# %%
A = A.astype('float64')  # so many:  www.tutorialspoint.com/numpy/numpy_data_types.htm
print(A)
# Out:
# [[ 0.  0.  9. ...  1.  0.  8.]
#  [ 0.  0. 11. ...  0.  0.  9.]
#  [ 0.  0.  1. ...  0.  0.  0.]
#  ...
#  [ 0.  0.  1. ...  0.  0.  8.]
#  [ 0.  0.  2. ...  0.  0.  9.]
#  [ 0.  0. 10. ...  1.  0.  8.]]

# %%
#
# nice to have NUM_ROWS and NUM_COLS around
#
NUM_ROWS, NUM_COLS = A.shape
print(f"\nThe dataset has {NUM_ROWS} rows and {NUM_COLS} cols")
# Out:
# The dataset has 1768 rows and 65 cols

# %%
print("+++ Start of data definitions +++\n")

#
# we could do this at the data-frame level, too!
#

X_all = A[:,0:64]  # X (features) ... is all rows, columns 0, 1, 2, 3
y_all = A[:,64]    # y (labels) ... is all rows, column 4 only

print(f"y_all (just the labels/species)   are \n {y_all}")
print(f"X_all (just the features, first few rows) are \n {X_all[0:5]}")
# Out:
# +++ Start of data definitions +++
#
# y_all (just the labels/species)   are
#  [8. 9. 0. ... 8. 9. 8.]
# X_all (just the features, first few rows) are
#  [[ 0.  0.  9. 14.  8.  1.  0.  0.  0.  0. 12. 14. 14. 12.  0.  0.  0.  0.
#    9. 10.  0. 15.  4.  0.  0.  0.  3. 16. 12. 14.  2.  0.  0.  0.  4. 16.
#   16.  2.  0.  0.  0.  3. 16.  8. 10. 13.  2.  0.  0.  1. 15.  1.  3. 16.
#    8.  0.  0.  0. 11. 16. 15. 11.  1.  0.]
#  [ 0.  0. 11. 12.  0.  0.  0.  0.  0.  2. 16. 16. 16. 13.  0.  0.  0.  3.
#   16. 12. 10. 14.  0.  0.  0.  1. 16.  1. 12. 15.  0.  0.  0.  0. 13. 16.
#    9. 15.  2.  0.  0.  0.  0.  3.  0.  9. 11.  0.  0.  0.  0.  0.  9. 15.
#    4.  0.  0.  0.  9. 12. 13.  3.  0.  0.]
#  [ 0.  0.  1.  9. 15. 11.  0.  0.  0.  0. 11. 16.  8. 14.  6.  0.  0.  2.
#   16. 10.  0.  9.  9.  0.  0.  1. 16.  4.  0.  8.  8.  0.  0.  4. 16.  4.
#    0.  8.  8.  0.  0.  1. 16.  5.  1. 11.  3.  0.  0.  0. 12. 12. 10. 10.
#    0.  0.  0.  0.  1. 10. 13.  3.  0.  0.]
#  [ 0.  0.  0.  0. 14. 13.  1.  0.  0.  0.  0.  5. 16. 16.  2.  0.  0.  0.
#    0. 14. 16. 12.  0.  0.  0.  1. 10. 16. 16. 12.  0.  0.  0.  3. 12. 14.
#   16.  9.  0.  0.  0.  0.  0.  5. 16. 15.  0.  0.  0.  0.  0.  4. 16. 14.
#    0.  0.  0.  0.  0.  1. 13. 16.  1.  0.]
#  [ 0.  0.  5. 12.  1.  0.  0.  0.  0.  0. 15. 14.  7.  0.  0.  0.  0.  0.
#   13.  1. 12.  0.  0.  0.  0.  2. 10.  0. 14.  0.  0.  0.  0.  0.  2.  0.
#   16.  1.  0.  0.  0.  0.  0.  6. 15.  0.  0.  0.  0.  0.  9. 16. 15.  9.
#    8.  2.  0.  0.  3. 11.  8. 13. 12.  4.]]

# %%
#
# we scramble the data, to remove (potential) dependence on its ordering: 
# 
indices = np.random.permutation(len(y_all))  # indices is a permutation-list

# we scramble both X and y, necessarily with the same permutation
X_permed = X_all[indices]              # we apply the _same_ permutation to each!
y_permed = y_all[indices]              # again...
print(f"The scrambled labels/species are \n {y_permed}")
print(f"The corresponding data rows are \n {X_permed[0:5]}")
# Out:
# The scrambled labels/species are
#  [2. 0. 2. ... 0. 2. 7.]
# The corresponding data rows are
#  [[ 0.  4. 15. 15.  8.  0.  0.  0.  0.  8. 16. 16. 16.  3.  0.  0.  0.  1.
#    0.  1. 15.  5.  0.  0.  0.  0.  0.  0. 11.  6.  0.  0.  0.  0.  0.  3.
#   15.  2.  0.  0.  0.  0.  4. 15. 16. 14.  6.  0.  0.  6. 16. 16. 15. 11.
#    3.  0.  0.  7. 14. 11.  0.  0.  0.  0.]
#  [ 0.  0.  2. 15. 13.  3.  0.  0.  0.  0. 10. 15. 11. 15.  0.  0.  0.  3.
#   16.  6.  0. 10.  0.  0.  0.  4. 16.  8.  0.  3.  8.  0.  0.  8. 14.  3.
#    0.  4.  8.  0.  0.  3. 15.  1.  0.  3.  7.  0.  0.  0. 14. 11.  6. 14.
#    5.  0.  0.  0.  4. 12. 15.  6.  0.  0.]
#  [ 0.  0.  6. 16.  8.  0.  0.  0.  0.  0.  8. 13. 16.  3.  0.  0.  0.  0.
#    2. 12. 10.  8.  0.  0.  0.  0.  0.  0.  7. 11.  0.  0.  0.  0.  0.  0.
#    9. 10.  0.  0.  0.  0.  0.  0. 13.  7.  0.  0.  0.  0.  1. 10. 16. 10.
#    8.  3.  0.  0.  4. 16. 16. 15. 16. 16.]
#  [ 0.  0.  7. 11. 12. 14.  2.  0.  0.  8. 16.  9.  4.  3.  0.  0.  0. 10.
#   15.  5.  0.  0.  0.  0.  0.  3. 12. 16. 14.  4.  0.  0.  0.  0.  0.  2.
#   13. 16.  2.  0.  0.  0.  0.  0.  0. 15.  9.  0.  0.  0.  2.  4.  8. 15.
#    9.  0.  0.  0. 10. 16. 13.  8.  0.  0.]
#  [ 0.  0.  7. 16. 16. 16.  8.  0.  0.  0. 10. 12. 10. 16.  2.  0.  0.  0.
#   13.  6.  7. 13.  0.  0.  0.  0. 10.  1. 13.  5.  0.  0.  0.  0.  9. 10.
#   16.  8.  3.  0.  0.  1. 12. 15. 16. 16.  5.  0.  0.  0.  1. 16.  2.  3.
#    0.  0.  0.  0.  9. 14.  0.  0.  0.  0.]]

# %%
#
# We next separate into test data and training data ... 
#    + We will train on the training data...
#    + We will _not_ look at the testing data to build the model
#
# Then, afterward, we will test on the testing data -- and see how well we do!
#

#
# a common convention:  train on 80%, test on 20%    Let's define the TEST_PERCENT
#

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_permed, y_permed, test_size=0.2, random_state=42)

print(f"training with {len(y_train)} rows;  testing with {len(y_test)} rows\n" )

print(f"Held-out data... (testing data: {len(y_test)})")
print(f"y_test: {y_test}\n")
print(f"X_test (few rows): {X_test[0:5,:]}")  # 5 rows
print()
print(f"Data used for modeling... (training data: {len(y_train)})")
print(f"y_train: {y_train}\n")
print(f"X_train (few rows): {X_train[0:5,:]}")  # 5 rows
# Out:
# training with 1414 rows;  testing with 354 rows
#
# Held-out data... (testing data: 354)
# y_test: [1. 7. 8. 7. 3. 8. 2. 5. 2. 6. 8. 9. 7. 9. 7. 5. 6. 3. 9. 8. 5. 6. 0. 7.
#  7. 6. 6. 9. 6. 7. 9. 7. 4. 4. 3. 9. 6. 3. 1. 2. 3. 6. 9. 6. 4. 1. 8. 2.
#  3. 0. 2. 1. 4. 4. 4. 8. 7. 0. 3. 3. 3. 9. 9. 8. 1. 4. 7. 1. 1. 5. 0. 9.
#  0. 6. 0. 6. 9. 1. 9. 0. 1. 8. 6. 0. 6. 7. 8. 5. 0. 1. 1. 5. 1. 3. 1. 7.
#  9. 4. 7. 6. 7. 5. 5. 1. 4. 8. 2. 1. 7. 5. 8. 0. 9. 4. 2. 2. 9. 0. 0. 6.
#  5. 1. 6. 2. 6. 3. 9. 0. 5. 4. 4. 7. 7. 6. 9. 6. 9. 0. 9. 5. 3. 5. 3. 2.
#  6. 8. 8. 8. 4. 5. 2. 9. 3. 7. 1. 2. 5. 5. 0. 6. 3. 3. 5. 9. 4. 5. 3. 0.
#  1. 8. 7. 6. 1. 0. 8. 8. 6. 7. 7. 6. 0. 9. 1. 3. 5. 6. 4. 0. 9. 3. 0. 4.
#  5. 8. 1. 1. 3. 7. 9. 9. 7. 5. 8. 3. 3. 6. 7. 0. 1. 7. 1. 7. 6. 8. 7. 8.
#  8. 9. 6. 3. 8. 2. 9. 2. 4. 4. 2. 8. 1. 0. 3. 3. 0. 0. 3. 0. 7. 6. 2. 1.
#  7. 9. 8. 6. 6. 8. 8. 3. 8. 0. 7. 3. 1. 5. 1. 1. 5. 1. 0. 5. 1. 9. 9. 6.
#  7. 6. 6. 5. 1. 4. 5. 6. 1. 1. 9. 6. 6. 2. 2. 5. 5. 6. 0. 2. 1. 8. 0. 7.
#  7. 6. 9. 7. 2. 1. 0. 8. 6. 5. 4. 1. 7. 5. 6. 4. 1. 1. 0. 2. 2. 5. 0. 0.
#  7. 2. 6. 0. 7. 8. 0. 0. 2. 2. 6. 9. 3. 6. 8. 9. 7. 4. 3. 9. 7. 1. 6. 9.
#  4. 7. 6. 1. 3. 4. 8. 2. 9. 9. 1. 6. 5. 8. 9. 5. 1. 0.]
#
# X_test (few rows): [[ 0.  0.  3. 14. 15.  9.  0.  0.  0.  0. 10. 16. 16. 13.  0.  0.  0.  2.
#   13. 16. 16.  4.  0.  0.  0.  0. 12. 16. 16.  4.  0.  0.  0.  2. 13. 16.
#   16.  4.  0.  0.  0.  0. 12. 16. 16.  4.  0.  0.  0.  0.  6. 16. 16. 16.
#    6.  0.  0.  0.  2. 10. 16. 16.  2.  0.]
#  [ 0.  0.  3. 11. 16. 16.  4.  0.  0.  0.  9. 12. 12. 16.  9.  0.  0.  0.
#    0.  0.  1. 16.  8.  0.  0.  0.  0.  9. 14. 16.  9.  0.  0.  0.  1. 16.
#   16. 14.  5.  0.  0.  0.  0.  6. 16.  4.  0.  0.  0.  0.  0. 11. 14.  0.
#    0.  0.  0.  0.  1. 15.  7.  0.  0.  0.]
#  [ 0.  0.  5. 11.  8.  7.  0.  0.  0.  3. 16. 11.  9. 16.  4.  0.  0.  0.
#   14.  3.  7. 15.  0.  0.  0.  0.  5. 15. 15.  3.  0.  0.  0.  0. 10. 15.
#   14.  1.  0.  0.  0.  4. 13.  0.  9.  7.  0.  0.  0.  3. 11.  5. 13.  7.
#    0.  0.  0.  0.  6. 10.  6.  0.  0.  0.]
#  [ 0.  0.  9. 12. 15. 15.  2.  0.  0.  1. 15. 14. 11. 16.  7.  0.  0.  0.
#    2.  0.  2. 16.  4.  0.  0.  0.  2.  4. 10. 15.  2.  0.  0.  0. 13. 16.
#   16. 16.  9.  0.  0.  0. 13. 16. 10.  1.  0.  0.  0.  0.  6. 16.  1.  0.
#    0.  0.  0.  0. 11.  9.  0.  0.  0.  0.]
#  [ 0.  0.  3. 11. 15.  8.  0.  0.  0.  4. 14.  8. 13. 14.  0.  0.  0.  8.
#   11.  3. 15.  6.  0.  0.  0.  1.  1.  9. 14.  0.  0.  0.  0.  0.  0.  0.
#   13. 10.  0.  0.  0.  0.  0.  0.  1. 13.  7.  0.  0.  0.  9.  8.  2.  6.
#   11.  0.  0.  0.  4. 10. 14. 16. 10.  0.]]
#
# Data used for modeling... (training data: 1414)
# y_train: [9. 9. 0. ... 8. 7. 7.]
#
# X_train (few rows): [[ 0.  0.  9. 15. 13.  3.  0.  0.  0.  2. 14.  2.  6.  5.  0.  0.  0.  4.
#    9.  0.  0. 15.  4.  0.  0.  1. 13.  5.  7. 16.  6.  0.  0.  0.  2.  7.
#    7. 14.  3.  0.  0.  0.  0.  0.  1. 14.  1.  0.  0.  0.  3.  1. 10.  9.
#    0.  0.  0.  0. 11. 15.  9.  1.  0.  0.]
#  [ 0.  0.  0.  7. 12. 16. 16. 15.  0.  0.  9. 16. 10.  4. 16. 10.  0.  0.
#   14. 16. 13. 14. 12.  1.  0.  0.  4. 16. 16. 16. 12.  0.  0.  0.  0.  0.
#    0. 16. 10.  0.  0.  0.  0.  0.  7. 15.  0.  0.  0.  0.  0.  1. 15.  7.
#    0.  0.  0.  0.  0. 12.  6.  0.  0.  0.]
#  [ 0.  0.  3. 13.  9.  1.  0.  0.  0.  0. 13. 14. 15. 13.  0.  0.  0.  2.
#   14.  1.  2. 13.  4.  0.  0.  4.  8.  0.  0.  5.  8.  0.  0.  4.  8.  0.
#    0.  4.  8.  0.  0.  4. 10.  0.  0.  5.  8.  0.  0.  0. 14. 11. 10. 14.
#    5.  0.  0.  0.  4. 12. 13.  9.  0.  0.]
#  [ 0.  0.  0.  5. 15.  4.  0.  0.  0.  0.  1. 15. 11.  0.  0.  0.  0.  0.
#   12. 14.  2.  0.  0.  0.  0.  5. 16.  7.  7. 10.  0.  0.  0. 12. 16. 16.
#   16. 12.  0.  0.  0. 11. 12. 14. 16. 14.  1.  0.  0.  0.  0.  0. 16.  9.
#    0.  0.  0.  0.  0.  4. 16.  6.  0.  0.]
#  [ 0.  0.  5. 14. 11.  3.  0.  0.  0.  1. 15.  8. 13. 10.  0.  0.  0.  1.
#   15.  9.  9. 15.  2.  0.  0.  0. 10. 16. 16. 16.  3.  0.  0.  0.  0.  0.
#    1. 16.  4.  0.  0.  0.  0.  0.  0. 15.  4.  0.  0.  0.  7.  5.  9. 16.
#    0.  0.  0.  0.  6. 12. 13.  9.  0.  0.]]

# %% [markdown]
# ## First: &nbsp; _Decision Trees_

# %%
#
# +++ This is the "Model-building and Model-training Cell"
#       
# Create a DT model and train it! 
#
from sklearn import tree      # for decision trees

best_depth = 1   # we don't know what depth to use, so let's guess 1
dtree_model = tree.DecisionTreeClassifier(max_depth=best_depth)

# Let's train the model.   It's this one line:
dtree_model.fit(X_train, y_train)                              # yay!  trained!
print("Created and trained a DT classifier with max depth =", best_depth)
# Out:
# Created and trained a DT classifier with max depth = 1

# %%
#
# +++ This cell will "Model-testing Cell"
#
# Now, let's see how well our model does on our "held-out data" (the testing data)
#

# We run our test set:

# the function knn_model.predict is the instantiation of our model
# it's what runs the k-nearest-neighbors algorithm:
predicted_labels = dtree_model.predict(X_test)   
actual_labels = y_test

# Let's print them so we can compare...
print("Predicted labels:", predicted_labels)
print("Actual  labels  :", actual_labels)

# And, some overall results
num_correct = sum(predicted_labels == actual_labels)
total = len(actual_labels)
print(f"\nResults on test set:  {num_correct} correct out of {total} total.")
# Out:
# Predicted labels: [3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 4. 4. 3. 3. 3. 4. 4. 4. 3.
#  3. 4. 3. 3. 3. 3. 3. 3. 4. 4. 3. 3. 4. 3. 3. 3. 3. 4. 3. 3. 4. 3. 3. 3.
#  3. 4. 3. 4. 4. 4. 4. 3. 3. 4. 3. 3. 3. 3. 3. 4. 4. 4. 3. 3. 3. 3. 4. 3.
#  4. 3. 4. 3. 3. 3. 3. 3. 4. 3. 3. 4. 4. 3. 3. 3. 4. 3. 3. 3. 3. 3. 4. 3.
#  3. 4. 3. 4. 3. 4. 3. 3. 4. 3. 3. 3. 3. 3. 3. 4. 3. 4. 3. 3. 4. 4. 4. 4.
#  3. 3. 4. 3. 4. 3. 3. 4. 3. 4. 4. 3. 3. 3. 3. 4. 3. 4. 3. 3. 3. 3. 3. 3.
#  3. 3. 3. 3. 4. 3. 3. 3. 3. 4. 3. 3. 4. 4. 4. 3. 3. 3. 3. 3. 4. 3. 3. 4.
#  3. 3. 3. 3. 3. 3. 3. 3. 4. 3. 4. 4. 4. 3. 3. 3. 3. 4. 4. 4. 3. 3. 4. 4.
#  4. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 4. 4. 4. 3. 3. 3. 3. 4. 3. 4. 3.
#  3. 3. 4. 3. 3. 3. 3. 3. 4. 4. 3. 3. 3. 4. 3. 3. 4. 4. 3. 3. 3. 4. 3. 4.
#  4. 3. 3. 3. 3. 3. 3. 3. 3. 4. 3. 3. 3. 3. 4. 3. 4. 3. 4. 3. 3. 3. 3. 3.
#  3. 4. 4. 4. 3. 4. 3. 4. 4. 3. 3. 4. 4. 3. 3. 3. 3. 3. 4. 3. 4. 3. 4. 4.
#  3. 3. 3. 3. 3. 3. 4. 3. 4. 3. 4. 4. 3. 3. 4. 4. 3. 3. 4. 3. 3. 3. 4. 3.
#  3. 3. 4. 4. 3. 3. 4. 4. 3. 3. 4. 3. 3. 4. 4. 3. 3. 3. 3. 3. 3. 3. 4. 3.
#  4. 4. 3. 3. 3. 4. 3. 3. 3. 3. 3. 3. 3. 3. 3. 3. 4. 3.]
# Actual  labels  : [1. 7. 8. 7. 3. 8. 2. 5. 2. 6. 8. 9. 7. 9. 7. 5. 6. 3. 9. 8. 5. 6. 0. 7.
#  7. 6. 6. 9. 6. 7. 9. 7. 4. 4. 3. 9. 6. 3. 1. 2. 3. 6. 9. 6. 4. 1. 8. 2.
#  3. 0. 2. 1. 4. 4. 4. 8. 7. 0. 3. 3. 3. 9. 9. 8. 1. 4. 7. 1. 1. 5. 0. 9.
#  0. 6. 0. 6. 9. 1. 9. 0. 1. 8. 6. 0. 6. 7. 8. 5. 0. 1. 1. 5. 1. 3. 1. 7.
#  9. 4. 7. 6. 7. 5. 5. 1. 4. 8. 2. 1. 7. 5. 8. 0. 9. 4. 2. 2. 9. 0. 0. 6.
#  5. 1. 6. 2. 6. 3. 9. 0. 5. 4. 4. 7. 7. 6. 9. 6. 9. 0. 9. 5. 3. 5. 3. 2.
#  6. 8. 8. 8. 4. 5. 2. 9. 3. 7. 1. 2. 5. 5. 0. 6. 3. 3. 5. 9. 4. 5. 3. 0.
#  1. 8. 7. 6. 1. 0. 8. 8. 6. 7. 7. 6. 0. 9. 1. 3. 5. 6. 4. 0. 9. 3. 0. 4.
#  5. 8. 1. 1. 3. 7. 9. 9. 7. 5. 8. 3. 3. 6. 7. 0. 1. 7. 1. 7. 6. 8. 7. 8.
#  8. 9. 6. 3. 8. 2. 9. 2. 4. 4. 2. 8. 1. 0. 3. 3. 0. 0. 3. 0. 7. 6. 2. 1.
#  7. 9. 8. 6. 6. 8. 8. 3. 8. 0. 7. 3. 1. 5. 1. 1. 5. 1. 0. 5. 1. 9. 9. 6.
#  7. 6. 6. 5. 1. 4. 5. 6. 1. 1. 9. 6. 6. 2. 2. 5. 5. 6. 0. 2. 1. 8. 0. 7.
#  7. 6. 9. 7. 2. 1. 0. 8. 6. 5. 4. 1. 7. 5. 6. 4. 1. 1. 0. 2. 2. 5. 0. 0.
#  7. 2. 6. 0. 7. 8. 0. 0. 2. 2. 6. 9. 3. 6. 8. 9. 7. 4. 3. 9. 7. 1. 6. 9.
#  4. 7. 6. 1. 3. 4. 8. 2. 9. 9. 1. 6. 5. 8. 9. 5. 1. 0.]
#
# Results on test set:  54 correct out of 354 total.

# %%
#
# Let's print these more helpfully, in a vertical table
#

def compare_labels(predicted_labels, actual_labels):
    """ a more neatly formatted comparison """
    NUM_LABELS = len(predicted_labels)
    num_correct = 0
    
    for i in range(NUM_LABELS):
        p = int(round(predicted_labels[i]))         # round protects from fp error 
        a = int(round(actual_labels[i]))
        result = "incorrect"
        if p == a:  # if they match,
            result = ""       # no longer incorrect
            num_correct += 1  # and we count a match!

        print(f"row {i:>3d} : {SPECIES[p]:>12s} {SPECIES[a]:<12s}   {result}")   

    print()
    print("Correct:", num_correct, "out of", NUM_LABELS)
    return num_correct

# let's try it out!
compare_labels(predicted_labels,actual_labels)
# Out:
# row   0 :         pix3 pix1           incorrect
# row   1 :         pix3 pix7           incorrect
# row   2 :         pix3 pix8           incorrect
# row   3 :         pix3 pix7           incorrect
# row   4 :         pix3 pix3
# row   5 :         pix3 pix8           incorrect
# row   6 :         pix3 pix2           incorrect
# row   7 :         pix3 pix5           incorrect
# row   8 :         pix3 pix2           incorrect
# row   9 :         pix3 pix6           incorrect
# row  10 :         pix3 pix8           incorrect
# row  11 :         pix3 pix9           incorrect
# row  12 :         pix3 pix7           incorrect
# row  13 :         pix3 pix9           incorrect
# row  14 :         pix3 pix7           incorrect
# row  15 :         pix4 pix5           incorrect
# row  16 :         pix4 pix6           incorrect
# row  17 :         pix3 pix3
# row  18 :         pix3 pix9           incorrect
# row  19 :         pix3 pix8           incorrect
# row  20 :         pix4 pix5           incorrect
# row  21 :         pix4 pix6           incorrect
# row  22 :         pix4 pix0           incorrect
# row  23 :         pix3 pix7           incorrect
# row  24 :         pix3 pix7           incorrect
# row  25 :         pix4 pix6           incorrect
# row  26 :         pix3 pix6           incorrect
# row  27 :         pix3 pix9           incorrect
# row  28 :         pix3 pix6           incorrect
# row  29 :         pix3 pix7           incorrect
# row  30 :         pix3 pix9           incorrect
# row  31 :         pix3 pix7           incorrect
# row  32 :         pix4 pix4
# row  33 :         pix4 pix4
# row  34 :         pix3 pix3
# row  35 :         pix3 pix9           incorrect
# row  36 :         pix4 pix6           incorrect
# row  37 :         pix3 pix3
# row  38 :         pix3 pix1           incorrect
# row  39 :         pix3 pix2           incorrect
# row  40 :         pix3 pix3
# row  41 :         pix4 pix6           incorrect
# row  42 :         pix3 pix9           incorrect
# row  43 :         pix3 pix6           incorrect
# row  44 :         pix4 pix4
# row  45 :         pix3 pix1           incorrect
# row  46 :         pix3 pix8           incorrect
# row  47 :         pix3 pix2           incorrect
# row  48 :         pix3 pix3
# row  49 :         pix4 pix0           incorrect
# row  50 :         pix3 pix2           incorrect
# row  51 :         pix4 pix1           incorrect
# row  52 :         pix4 pix4
# row  53 :         pix4 pix4
# row  54 :         pix4 pix4
# row  55 :         pix3 pix8           incorrect
# row  56 :         pix3 pix7           incorrect
# row  57 :         pix4 pix0           incorrect
# row  58 :         pix3 pix3
# row  59 :         pix3 pix3
# row  60 :         pix3 pix3
# row  61 :         pix3 pix9           incorrect
# row  62 :         pix3 pix9           incorrect
# row  63 :         pix4 pix8           incorrect
# row  64 :         pix4 pix1           incorrect
# row  65 :         pix4 pix4
# row  66 :         pix3 pix7           incorrect
# row  67 :         pix3 pix1           incorrect
# row  68 :         pix3 pix1           incorrect
# row  69 :         pix3 pix5           incorrect
# row  70 :         pix4 pix0           incorrect
# row  71 :         pix3 pix9           incorrect
# row  72 :         pix4 pix0           incorrect
# row  73 :         pix3 pix6           incorrect
# row  74 :         pix4 pix0           incorrect
# row  75 :         pix3 pix6           incorrect
# row  76 :         pix3 pix9           incorrect
# row  77 :         pix3 pix1           incorrect
# row  78 :         pix3 pix9           incorrect
# row  79 :         pix3 pix0           incorrect
# row  80 :         pix4 pix1           incorrect
# row  81 :         pix3 pix8           incorrect
# row  82 :         pix3 pix6           incorrect
# row  83 :         pix4 pix0           incorrect
# row  84 :         pix4 pix6           incorrect
# row  85 :         pix3 pix7           incorrect
# row  86 :         pix3 pix8           incorrect
# row  87 :         pix3 pix5           incorrect
# row  88 :         pix4 pix0           incorrect
# row  89 :         pix3 pix1           incorrect
# row  90 :         pix3 pix1           incorrect
# row  91 :         pix3 pix5           incorrect
# row  92 :         pix3 pix1           incorrect
# row  93 :         pix3 pix3
# row  94 :         pix4 pix1           incorrect
# row  95 :         pix3 pix7           incorrect
# row  96 :         pix3 pix9           incorrect
# row  97 :         pix4 pix4
# row  98 :         pix3 pix7           incorrect
# row  99 :         pix4 pix6           incorrect
# row 100 :         pix3 pix7           incorrect
# row 101 :         pix4 pix5           incorrect
# row 102 :         pix3 pix5           incorrect
# row 103 :         pix3 pix1           incorrect
# row 104 :         pix4 pix4
# row 105 :         pix3 pix8           incorrect
# row 106 :         pix3 pix2           incorrect
# row 107 :         pix3 pix1           incorrect
# row 108 :         pix3 pix7           incorrect
# row 109 :         pix3 pix5           incorrect
# row 110 :         pix3 pix8           incorrect
# row 111 :         pix4 pix0           incorrect
# row 112 :         pix3 pix9           incorrect
# row 113 :         pix4 pix4
# row 114 :         pix3 pix2           incorrect
# row 115 :         pix3 pix2           incorrect
# row 116 :         pix4 pix9           incorrect
# row 117 :         pix4 pix0           incorrect
# row 118 :         pix4 pix0           incorrect
# row 119 :         pix4 pix6           incorrect
# row 120 :         pix3 pix5           incorrect
# row 121 :         pix3 pix1           incorrect
# row 122 :         pix4 pix6           incorrect
# row 123 :         pix3 pix2           incorrect
# row 124 :         pix4 pix6           incorrect
# row 125 :         pix3 pix3
# row 126 :         pix3 pix9           incorrect
# row 127 :         pix4 pix0           incorrect
# row 128 :         pix3 pix5           incorrect
# row 129 :         pix4 pix4
# row 130 :         pix4 pix4
# row 131 :         pix3 pix7           incorrect
# row 132 :         pix3 pix7           incorrect
# row 133 :         pix3 pix6           incorrect
# row 134 :         pix3 pix9           incorrect
# row 135 :         pix4 pix6           incorrect
# row 136 :         pix3 pix9           incorrect
# row 137 :         pix4 pix0           incorrect
# row 138 :         pix3 pix9           incorrect
# row 139 :         pix3 pix5           incorrect
# row 140 :         pix3 pix3
# row 141 :         pix3 pix5           incorrect
# row 142 :         pix3 pix3
# row 143 :         pix3 pix2           incorrect
# row 144 :         pix3 pix6           incorrect
# row 145 :         pix3 pix8           incorrect
# row 146 :         pix3 pix8           incorrect
# row 147 :         pix3 pix8           incorrect
# row 148 :         pix4 pix4
# row 149 :         pix3 pix5           incorrect
# row 150 :         pix3 pix2           incorrect
# row 151 :         pix3 pix9           incorrect
# row 152 :         pix3 pix3
# row 153 :         pix4 pix7           incorrect
# row 154 :         pix3 pix1           incorrect
# row 155 :         pix3 pix2           incorrect
# row 156 :         pix4 pix5           incorrect
# row 157 :         pix4 pix5           incorrect
# row 158 :         pix4 pix0           incorrect
# row 159 :         pix3 pix6           incorrect
# row 160 :         pix3 pix3
# row 161 :         pix3 pix3
# row 162 :         pix3 pix5           incorrect
# row 163 :         pix3 pix9           incorrect
# row 164 :         pix4 pix4
# row 165 :         pix3 pix5           incorrect
# row 166 :         pix3 pix3
# row 167 :         pix4 pix0           incorrect
# row 168 :         pix3 pix1           incorrect
# row 169 :         pix3 pix8           incorrect
# row 170 :         pix3 pix7           incorrect
# row 171 :         pix3 pix6           incorrect
# row 172 :         pix3 pix1           incorrect
# row 173 :         pix3 pix0           incorrect
# row 174 :         pix3 pix8           incorrect
# row 175 :         pix3 pix8           incorrect
# row 176 :         pix4 pix6           incorrect
# row 177 :         pix3 pix7           incorrect
# row 178 :         pix4 pix7           incorrect
# row 179 :         pix4 pix6           incorrect
# row 180 :         pix4 pix0           incorrect
# row 181 :         pix3 pix9           incorrect
# row 182 :         pix3 pix1           incorrect
# row 183 :         pix3 pix3
# row 184 :         pix3 pix5           incorrect
# row 185 :         pix4 pix6           incorrect
# row 186 :         pix4 pix4
# row 187 :         pix4 pix0           incorrect
# row 188 :         pix3 pix9           incorrect
# row 189 :         pix3 pix3
# row 190 :         pix4 pix0           incorrect
# row 191 :         pix4 pix4
# row 192 :         pix4 pix5           incorrect
# row 193 :         pix3 pix8           incorrect
# row 194 :         pix3 pix1           incorrect
# row 195 :         pix3 pix1           incorrect
# row 196 :         pix3 pix3
# row 197 :         pix3 pix7           incorrect
# row 198 :         pix3 pix9           incorrect
# row 199 :         pix3 pix9           incorrect
# row 200 :         pix3 pix7           incorrect
# row 201 :         pix3 pix5           incorrect
# row 202 :         pix3 pix8           incorrect
# row 203 :         pix3 pix3
# row 204 :         pix3 pix3
# row 205 :         pix4 pix6           incorrect
# row 206 :         pix4 pix7           incorrect
# row 207 :         pix4 pix0           incorrect
# row 208 :         pix3 pix1           incorrect
# row 209 :         pix3 pix7           incorrect
# row 210 :         pix3 pix1           incorrect
# row 211 :         pix3 pix7           incorrect
# row 212 :         pix4 pix6           incorrect
# row 213 :         pix3 pix8           incorrect
# row 214 :         pix4 pix7           incorrect
# row 215 :         pix3 pix8           incorrect
# row 216 :         pix3 pix8           incorrect
# row 217 :         pix3 pix9           incorrect
# row 218 :         pix4 pix6           incorrect
# row 219 :         pix3 pix3
# row 220 :         pix3 pix8           incorrect
# row 221 :         pix3 pix2           incorrect
# row 222 :         pix3 pix9           incorrect
# row 223 :         pix3 pix2           incorrect
# row 224 :         pix4 pix4
# row 225 :         pix4 pix4
# row 226 :         pix3 pix2           incorrect
# row 227 :         pix3 pix8           incorrect
# row 228 :         pix3 pix1           incorrect
# row 229 :         pix4 pix0           incorrect
# row 230 :         pix3 pix3
# row 231 :         pix3 pix3
# row 232 :         pix4 pix0           incorrect
# row 233 :         pix4 pix0           incorrect
# row 234 :         pix3 pix3
# row 235 :         pix3 pix0           incorrect
# row 236 :         pix3 pix7           incorrect
# row 237 :         pix4 pix6           incorrect
# row 238 :         pix3 pix2           incorrect
# row 239 :         pix4 pix1           incorrect
# row 240 :         pix4 pix7           incorrect
# row 241 :         pix3 pix9           incorrect
# row 242 :         pix3 pix8           incorrect
# row 243 :         pix3 pix6           incorrect
# row 244 :         pix3 pix6           incorrect
# row 245 :         pix3 pix8           incorrect
# row 246 :         pix3 pix8           incorrect
# row 247 :         pix3 pix3
# row 248 :         pix3 pix8           incorrect
# row 249 :         pix4 pix0           incorrect
# row 250 :         pix3 pix7           incorrect
# row 251 :         pix3 pix3
# row 252 :         pix3 pix1           incorrect
# row 253 :         pix3 pix5           incorrect
# row 254 :         pix4 pix1           incorrect
# row 255 :         pix3 pix1           incorrect
# row 256 :         pix4 pix5           incorrect
# row 257 :         pix3 pix1           incorrect
# row 258 :         pix4 pix0           incorrect
# row 259 :         pix3 pix5           incorrect
# row 260 :         pix3 pix1           incorrect
# row 261 :         pix3 pix9           incorrect
# row 262 :         pix3 pix9           incorrect
# row 263 :         pix3 pix6           incorrect
# row 264 :         pix3 pix7           incorrect
# row 265 :         pix4 pix6           incorrect
# row 266 :         pix4 pix6           incorrect
# row 267 :         pix4 pix5           incorrect
# row 268 :         pix3 pix1           incorrect
# row 269 :         pix4 pix4
# row 270 :         pix3 pix5           incorrect
# row 271 :         pix4 pix6           incorrect
# row 272 :         pix4 pix1           incorrect
# row 273 :         pix3 pix1           incorrect
# row 274 :         pix3 pix9           incorrect
# row 275 :         pix4 pix6           incorrect
# row 276 :         pix4 pix6           incorrect
# row 277 :         pix3 pix2           incorrect
# row 278 :         pix3 pix2           incorrect
# row 279 :         pix3 pix5           incorrect
# row 280 :         pix3 pix5           incorrect
# row 281 :         pix3 pix6           incorrect
# row 282 :         pix4 pix0           incorrect
# row 283 :         pix3 pix2           incorrect
# row 284 :         pix4 pix1           incorrect
# row 285 :         pix3 pix8           incorrect
# row 286 :         pix4 pix0           incorrect
# row 287 :         pix4 pix7           incorrect
# row 288 :         pix3 pix7           incorrect
# row 289 :         pix3 pix6           incorrect
# row 290 :         pix3 pix9           incorrect
# row 291 :         pix3 pix7           incorrect
# row 292 :         pix3 pix2           incorrect
# row 293 :         pix3 pix1           incorrect
# row 294 :         pix4 pix0           incorrect
# row 295 :         pix3 pix8           incorrect
# row 296 :         pix4 pix6           incorrect
# row 297 :         pix3 pix5           incorrect
# row 298 :         pix4 pix4
# row 299 :         pix4 pix1           incorrect
# row 300 :         pix3 pix7           incorrect
# row 301 :         pix3 pix5           incorrect
# row 302 :         pix4 pix6           incorrect
# row 303 :         pix4 pix4
# row 304 :         pix3 pix1           incorrect
# row 305 :         pix3 pix1           incorrect
# row 306 :         pix4 pix0           incorrect
# row 307 :         pix3 pix2           incorrect
# row 308 :         pix3 pix2           incorrect
# row 309 :         pix3 pix5           incorrect
# row 310 :         pix4 pix0           incorrect
# row 311 :         pix3 pix0           incorrect
# row 312 :         pix3 pix7           incorrect
# row 313 :         pix3 pix2           incorrect
# row 314 :         pix4 pix6           incorrect
# row 315 :         pix4 pix0           incorrect
# row 316 :         pix3 pix7           incorrect
# row 317 :         pix3 pix8           incorrect
# row 318 :         pix4 pix0           incorrect
# row 319 :         pix4 pix0           incorrect
# row 320 :         pix3 pix2           incorrect
# row 321 :         pix3 pix2           incorrect
# row 322 :         pix4 pix6           incorrect
# row 323 :         pix3 pix9           incorrect
# row 324 :         pix3 pix3
# row 325 :         pix4 pix6           incorrect
# row 326 :         pix4 pix8           incorrect
# row 327 :         pix3 pix9           incorrect
# row 328 :         pix3 pix7           incorrect
# row 329 :         pix3 pix4           incorrect
# row 330 :         pix3 pix3
# row 331 :         pix3 pix9           incorrect
# row 332 :         pix3 pix7           incorrect
# row 333 :         pix3 pix1           incorrect
# row 334 :         pix4 pix6           incorrect
# row 335 :         pix3 pix9           incorrect
# row 336 :         pix4 pix4
# row 337 :         pix4 pix7           incorrect
# row 338 :         pix3 pix6           incorrect
# row 339 :         pix3 pix1           incorrect
# row 340 :         pix3 pix3
# row 341 :         pix4 pix4
# row 342 :         pix3 pix8           incorrect
# row 343 :         pix3 pix2           incorrect
# row 344 :         pix3 pix9           incorrect
# row 345 :         pix3 pix9           incorrect
# row 346 :         pix3 pix1           incorrect
# row 347 :         pix3 pix6           incorrect
# row 348 :         pix3 pix5           incorrect
# row 349 :         pix3 pix8           incorrect
# row 350 :         pix3 pix9           incorrect
# row 351 :         pix3 pix5           incorrect
# row 352 :         pix4 pix1           incorrect
# row 353 :         pix3 pix0           incorrect
#
# Correct: 54 out of 354
# 54

# %%
#
# first, let's use text :)
#
text_representation = tree.export_text(dtree_model)
print(text_representation)
# Out:
# |--- feature_33 <= 3.50
# |   |--- class: 3.0
# |--- feature_33 >  3.50
# |   |--- class: 4.0

# %%
#
# Now, let's see the tree!
#

filename = 'tree_data.gv'    # sometimes .dot is used, instead of .gv

tree.export_graphviz(dtree_model, out_file=filename,  # the filename constructed above...!
                            feature_names=FEATURES,   # actual feature names, not species
                            filled=True,              # fun!
                            rotate=False,             # False for Up/Down; True for L/R
                            class_names=SPECIES,      # Yay! we created this  
                            leaves_parallel=True )    # lots of options!

print(f"# file {filename} written. Try pasting its contents to  http://viz-js.com/")
print()

with open(filename, "r") as f:
    all_file_text = f.read()
    print(all_file_text)
# Out:
# # file tree_data.gv written. Try pasting its contents to  http://viz-js.com/
#
# digraph Tree {
# node [shape=box, style="filled", color="black", fontname="helvetica"] ;
# graph [ranksep=equally, splines=polyline] ;
# edge [fontname="helvetica"] ;
# 0 [label="pix33 <= 3.5\ngini = 0.9\nsamples = 1414\nvalue = [136, 136, 149, 150, 154, 145, 132, 137, 138, 137]\nclass = pix4", fillcolor="#feffff"] ;
# 1 [label="gini = 0.876\nsamples = 1013\nvalue = [12, 120, 148, 149, 13, 115, 67, 116, 136, 137]\nclass = pix3", fillcolor="#ffffff"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="gini = 0.744\nsamples = 401\nvalue = [124, 16, 1, 1, 141, 30, 65, 21, 2, 0]\nclass = pix4", fillcolor="#f3fdfb"] ;
# 0 -> 2 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# {rank=same ; 0} ;
# {rank=same ; 1; 2} ;
# }

# %%
#
# Treeing!
#
import matplotlib.pyplot as plt 

fig = plt.figure(figsize=(5,4))              # Feel free to adjust this size...
tree_plot = tree.plot_tree(dtree_model, 
                   feature_names=FEATURES,   # Glad to have these FEATURES...
                   class_names=SPECIES,      # and these SPECIES...
                   filled=True)

# %%
#
# To compare different tree-depths, we use cross validation
#

from sklearn.model_selection import cross_val_score

#
# cross-validation splits the training set into two pieces:
#   + model-building and model-validation. We'll use "build" and "validate"
#

best_d = 1
best_accuracy = 0.0

for d in range(1,10+1):
    cv_model = tree.DecisionTreeClassifier(max_depth=d)   # for each depth, d
    cv_scores = cross_val_score( cv_model, X_train, y_train, cv=5 ) # 5 means 80/20 split
    # print(cv_scores)  # we usually don't want to see the five individual scores 
    average_cv_accuracy = cv_scores.mean()  # more likely, only their average
    print(f"depth: {d:2d}  cv accuracy: {average_cv_accuracy:7.4f}")
    
    if average_cv_accuracy > best_accuracy:
        best_accuracy = average_cv_accuracy
        best_d = d

    
    
# assign best value of d to best_depth
best_depth = best_d   # may have to hand-tune this, depending on what happens...
print()
print(f"best_depth = {best_depth} with acc: {best_accuracy} is our balance.")
print()
print("Too deep and the tree will _overfit_ the training data.")
print("Too shallow and the tree will _underfit_ the training data.")
# Out:
# depth:  1  cv accuracy:  0.2030
# depth:  2  cv accuracy:  0.3593
# depth:  3  cv accuracy:  0.5135
# depth:  4  cv accuracy:  0.6252
# depth:  5  cv accuracy:  0.7086
# depth:  6  cv accuracy:  0.7631
# depth:  7  cv accuracy:  0.7999
# depth:  8  cv accuracy:  0.8105
# depth:  9  cv accuracy:  0.8310
# depth: 10  cv accuracy:  0.8352
#
# best_depth = 10 with acc: 0.8352153973385461 is our balance.
#
# Too deep and the tree will _overfit_ the training data.
# Too shallow and the tree will _underfit_ the training data.

# %%
#
# Now, we re-create and re-run the  "Model-building and -training Cell"
#
# this time, with the best depth, best_d, found by cross-validation model tuning:
#
from sklearn import tree      # for decision trees

# we should have best_depth from our cv exploration
dtree_model_tuned = tree.DecisionTreeClassifier(max_depth=best_depth)

# we train the model (it's one line!)
dtree_model_tuned.fit(X_train, y_train)                              # yay!  trained!
print("Created and trained a DT classifier with max depth =", best_depth)
# Out:
# Created and trained a DT classifier with max depth = 10

# %%
#
# Now, let's see the tree!
#

filename = 'tree_data.gv'    # sometimes .dot is used, instead of .gv

tree.export_graphviz(dtree_model_tuned, out_file=filename,  # the filename constructed above...!
                            feature_names=FEATURES, # actual feature names, not species
                            filled=True,              # fun!
                            rotate=False,             # False for Up/Down; True for L/R
                            class_names=SPECIES,      # good to have   
                            leaves_parallel=True )    # lots of options!

# Use this line to print the tree to the console in the dot language:
# print(f"file {filename} written. Try pasting its contents to  http://viz-js.com/")

# with open(filename, "r") as f:    # here, it will print to a file:
#     all_file_text = f.read()
#     print(all_file_text)

#
# Treeing using matplotlib:
#
fig = plt.figure(figsize=(9,6))
tree_plot = tree.plot_tree(dtree_model_tuned, 
                   feature_names=FEATURES,   # Glad to have these!
                   class_names=SPECIES,      # and these!!
                   filled=True,
                   rounded=True,
                   fontsize=8)

# %%
#
# Re-create and re-run the  "Model-testing Cell"     How does it do with best_k?!
#
predicted_labels = dtree_model_tuned.predict(X_test)
actual_labels = y_test

# Let's print them so we can compare...
print("Predicted labels:", predicted_labels)
print("Actual labels:", actual_labels)
print()

# and, we'll print our nicer table...
compare_labels(predicted_labels,actual_labels)
# Out:
# Predicted labels: [1. 7. 8. 7. 3. 8. 2. 5. 2. 6. 8. 9. 7. 9. 2. 5. 6. 3. 1. 0. 6. 6. 0. 7.
#  7. 6. 6. 9. 6. 7. 1. 7. 4. 4. 3. 9. 6. 3. 1. 2. 3. 6. 9. 0. 1. 1. 8. 2.
#  3. 0. 2. 1. 4. 4. 4. 8. 7. 0. 3. 3. 3. 9. 9. 0. 1. 4. 7. 1. 1. 5. 0. 1.
#  0. 6. 0. 2. 9. 1. 9. 2. 1. 8. 6. 0. 6. 7. 8. 5. 0. 1. 1. 5. 1. 9. 1. 7.
#  9. 4. 7. 6. 7. 5. 1. 8. 4. 2. 2. 1. 7. 5. 8. 0. 9. 4. 2. 2. 4. 0. 0. 6.
#  3. 1. 6. 2. 4. 5. 9. 0. 5. 4. 4. 7. 7. 6. 9. 7. 9. 0. 9. 5. 3. 5. 3. 2.
#  6. 8. 2. 8. 4. 5. 1. 9. 3. 7. 2. 9. 5. 4. 0. 6. 3. 9. 5. 9. 4. 5. 8. 0.
#  1. 8. 7. 6. 1. 0. 4. 8. 6. 7. 4. 6. 0. 9. 1. 3. 5. 6. 4. 0. 9. 8. 0. 4.
#  5. 8. 1. 1. 8. 7. 9. 8. 7. 5. 8. 3. 3. 6. 7. 0. 1. 7. 1. 7. 6. 8. 7. 8.
#  8. 9. 6. 9. 8. 2. 1. 2. 4. 4. 2. 8. 8. 0. 3. 3. 0. 0. 3. 0. 7. 6. 2. 1.
#  7. 8. 8. 6. 6. 8. 0. 3. 1. 0. 7. 3. 1. 5. 2. 1. 5. 1. 0. 5. 1. 9. 1. 6.
#  7. 6. 6. 5. 2. 4. 5. 6. 1. 1. 9. 6. 6. 2. 8. 5. 1. 6. 0. 2. 6. 1. 0. 7.
#  7. 6. 9. 7. 6. 1. 0. 8. 6. 5. 4. 1. 7. 5. 6. 4. 1. 3. 0. 2. 2. 5. 0. 0.
#  7. 2. 6. 0. 7. 8. 0. 0. 2. 3. 6. 9. 2. 6. 1. 9. 4. 4. 3. 9. 7. 1. 6. 9.
#  4. 7. 6. 1. 3. 4. 8. 2. 1. 9. 1. 6. 5. 8. 9. 5. 1. 0.]
# Actual labels: [1. 7. 8. 7. 3. 8. 2. 5. 2. 6. 8. 9. 7. 9. 7. 5. 6. 3. 9. 8. 5. 6. 0. 7.
#  7. 6. 6. 9. 6. 7. 9. 7. 4. 4. 3. 9. 6. 3. 1. 2. 3. 6. 9. 6. 4. 1. 8. 2.
#  3. 0. 2. 1. 4. 4. 4. 8. 7. 0. 3. 3. 3. 9. 9. 8. 1. 4. 7. 1. 1. 5. 0. 9.
#  0. 6. 0. 6. 9. 1. 9. 0. 1. 8. 6. 0. 6. 7. 8. 5. 0. 1. 1. 5. 1. 3. 1. 7.
#  9. 4. 7. 6. 7. 5. 5. 1. 4. 8. 2. 1. 7. 5. 8. 0. 9. 4. 2. 2. 9. 0. 0. 6.
#  5. 1. 6. 2. 6. 3. 9. 0. 5. 4. 4. 7. 7. 6. 9. 6. 9. 0. 9. 5. 3. 5. 3. 2.
#  6. 8. 8. 8. 4. 5. 2. 9. 3. 7. 1. 2. 5. 5. 0. 6. 3. 3. 5. 9. 4. 5. 3. 0.
#  1. 8. 7. 6. 1. 0. 8. 8. 6. 7. 7. 6. 0. 9. 1. 3. 5. 6. 4. 0. 9. 3. 0. 4.
#  5. 8. 1. 1. 3. 7. 9. 9. 7. 5. 8. 3. 3. 6. 7. 0. 1. 7. 1. 7. 6. 8. 7. 8.
#  8. 9. 6. 3. 8. 2. 9. 2. 4. 4. 2. 8. 1. 0. 3. 3. 0. 0. 3. 0. 7. 6. 2. 1.
#  7. 9. 8. 6. 6. 8. 8. 3. 8. 0. 7. 3. 1. 5. 1. 1. 5. 1. 0. 5. 1. 9. 9. 6.
#  7. 6. 6. 5. 1. 4. 5. 6. 1. 1. 9. 6. 6. 2. 2. 5. 5. 6. 0. 2. 1. 8. 0. 7.
#  7. 6. 9. 7. 2. 1. 0. 8. 6. 5. 4. 1. 7. 5. 6. 4. 1. 1. 0. 2. 2. 5. 0. 0.
#  7. 2. 6. 0. 7. 8. 0. 0. 2. 2. 6. 9. 3. 6. 8. 9. 7. 4. 3. 9. 7. 1. 6. 9.
#  4. 7. 6. 1. 3. 4. 8. 2. 9. 9. 1. 6. 5. 8. 9. 5. 1. 0.]
#
# row   0 :         pix1 pix1
# row   1 :         pix7 pix7
# row   2 :         pix8 pix8
# row   3 :         pix7 pix7
# row   4 :         pix3 pix3
# row   5 :         pix8 pix8
# row   6 :         pix2 pix2
# row   7 :         pix5 pix5
# row   8 :         pix2 pix2
# row   9 :         pix6 pix6
# row  10 :         pix8 pix8
# row  11 :         pix9 pix9
# row  12 :         pix7 pix7
# row  13 :         pix9 pix9
# row  14 :         pix2 pix7           incorrect
# row  15 :         pix5 pix5
# row  16 :         pix6 pix6
# row  17 :         pix3 pix3
# row  18 :         pix1 pix9           incorrect
# row  19 :         pix0 pix8           incorrect
# row  20 :         pix6 pix5           incorrect
# row  21 :         pix6 pix6
# row  22 :         pix0 pix0
# row  23 :         pix7 pix7
# row  24 :         pix7 pix7
# row  25 :         pix6 pix6
# row  26 :         pix6 pix6
# row  27 :         pix9 pix9
# row  28 :         pix6 pix6
# row  29 :         pix7 pix7
# row  30 :         pix1 pix9           incorrect
# row  31 :         pix7 pix7
# row  32 :         pix4 pix4
# row  33 :         pix4 pix4
# row  34 :         pix3 pix3
# row  35 :         pix9 pix9
# row  36 :         pix6 pix6
# row  37 :         pix3 pix3
# row  38 :         pix1 pix1
# row  39 :         pix2 pix2
# row  40 :         pix3 pix3
# row  41 :         pix6 pix6
# row  42 :         pix9 pix9
# row  43 :         pix0 pix6           incorrect
# row  44 :         pix1 pix4           incorrect
# row  45 :         pix1 pix1
# row  46 :         pix8 pix8
# row  47 :         pix2 pix2
# row  48 :         pix3 pix3
# row  49 :         pix0 pix0
# row  50 :         pix2 pix2
# row  51 :         pix1 pix1
# row  52 :         pix4 pix4
# row  53 :         pix4 pix4
# row  54 :         pix4 pix4
# row  55 :         pix8 pix8
# row  56 :         pix7 pix7
# row  57 :         pix0 pix0
# row  58 :         pix3 pix3
# row  59 :         pix3 pix3
# row  60 :         pix3 pix3
# row  61 :         pix9 pix9
# row  62 :         pix9 pix9
# row  63 :         pix0 pix8           incorrect
# row  64 :         pix1 pix1
# row  65 :         pix4 pix4
# row  66 :         pix7 pix7
# row  67 :         pix1 pix1
# row  68 :         pix1 pix1
# row  69 :         pix5 pix5
# row  70 :         pix0 pix0
# row  71 :         pix1 pix9           incorrect
# row  72 :         pix0 pix0
# row  73 :         pix6 pix6
# row  74 :         pix0 pix0
# row  75 :         pix2 pix6           incorrect
# row  76 :         pix9 pix9
# row  77 :         pix1 pix1
# row  78 :         pix9 pix9
# row  79 :         pix2 pix0           incorrect
# row  80 :         pix1 pix1
# row  81 :         pix8 pix8
# row  82 :         pix6 pix6
# row  83 :         pix0 pix0
# row  84 :         pix6 pix6
# row  85 :         pix7 pix7
# row  86 :         pix8 pix8
# row  87 :         pix5 pix5
# row  88 :         pix0 pix0
# row  89 :         pix1 pix1
# row  90 :         pix1 pix1
# row  91 :         pix5 pix5
# row  92 :         pix1 pix1
# row  93 :         pix9 pix3           incorrect
# row  94 :         pix1 pix1
# row  95 :         pix7 pix7
# row  96 :         pix9 pix9
# row  97 :         pix4 pix4
# row  98 :         pix7 pix7
# row  99 :         pix6 pix6
# row 100 :         pix7 pix7
# row 101 :         pix5 pix5
# row 102 :         pix1 pix5           incorrect
# row 103 :         pix8 pix1           incorrect
# row 104 :         pix4 pix4
# row 105 :         pix2 pix8           incorrect
# row 106 :         pix2 pix2
# row 107 :         pix1 pix1
# row 108 :         pix7 pix7
# row 109 :         pix5 pix5
# row 110 :         pix8 pix8
# row 111 :         pix0 pix0
# row 112 :         pix9 pix9
# row 113 :         pix4 pix4
# row 114 :         pix2 pix2
# row 115 :         pix2 pix2
# row 116 :         pix4 pix9           incorrect
# row 117 :         pix0 pix0
# row 118 :         pix0 pix0
# row 119 :         pix6 pix6
# row 120 :         pix3 pix5           incorrect
# row 121 :         pix1 pix1
# row 122 :         pix6 pix6
# row 123 :         pix2 pix2
# row 124 :         pix4 pix6           incorrect
# row 125 :         pix5 pix3           incorrect
# row 126 :         pix9 pix9
# row 127 :         pix0 pix0
# row 128 :         pix5 pix5
# row 129 :         pix4 pix4
# row 130 :         pix4 pix4
# row 131 :         pix7 pix7
# row 132 :         pix7 pix7
# row 133 :         pix6 pix6
# row 134 :         pix9 pix9
# row 135 :         pix7 pix6           incorrect
# row 136 :         pix9 pix9
# row 137 :         pix0 pix0
# row 138 :         pix9 pix9
# row 139 :         pix5 pix5
# row 140 :         pix3 pix3
# row 141 :         pix5 pix5
# row 142 :         pix3 pix3
# row 143 :         pix2 pix2
# row 144 :         pix6 pix6
# row 145 :         pix8 pix8
# row 146 :         pix2 pix8           incorrect
# row 147 :         pix8 pix8
# row 148 :         pix4 pix4
# row 149 :         pix5 pix5
# row 150 :         pix1 pix2           incorrect
# row 151 :         pix9 pix9
# row 152 :         pix3 pix3
# row 153 :         pix7 pix7
# row 154 :         pix2 pix1           incorrect
# row 155 :         pix9 pix2           incorrect
# row 156 :         pix5 pix5
# row 157 :         pix4 pix5           incorrect
# row 158 :         pix0 pix0
# row 159 :         pix6 pix6
# row 160 :         pix3 pix3
# row 161 :         pix9 pix3           incorrect
# row 162 :         pix5 pix5
# row 163 :         pix9 pix9
# row 164 :         pix4 pix4
# row 165 :         pix5 pix5
# row 166 :         pix8 pix3           incorrect
# row 167 :         pix0 pix0
# row 168 :         pix1 pix1
# row 169 :         pix8 pix8
# row 170 :         pix7 pix7
# row 171 :         pix6 pix6
# row 172 :         pix1 pix1
# row 173 :         pix0 pix0
# row 174 :         pix4 pix8           incorrect
# row 175 :         pix8 pix8
# row 176 :         pix6 pix6
# row 177 :         pix7 pix7
# row 178 :         pix4 pix7           incorrect
# row 179 :         pix6 pix6
# row 180 :         pix0 pix0
# row 181 :         pix9 pix9
# row 182 :         pix1 pix1
# row 183 :         pix3 pix3
# row 184 :         pix5 pix5
# row 185 :         pix6 pix6
# row 186 :         pix4 pix4
# row 187 :         pix0 pix0
# row 188 :         pix9 pix9
# row 189 :         pix8 pix3           incorrect
# row 190 :         pix0 pix0
# row 191 :         pix4 pix4
# row 192 :         pix5 pix5
# row 193 :         pix8 pix8
# row 194 :         pix1 pix1
# row 195 :         pix1 pix1
# row 196 :         pix8 pix3           incorrect
# row 197 :         pix7 pix7
# row 198 :         pix9 pix9
# row 199 :         pix8 pix9           incorrect
# row 200 :         pix7 pix7
# row 201 :         pix5 pix5
# row 202 :         pix8 pix8
# row 203 :         pix3 pix3
# row 204 :         pix3 pix3
# row 205 :         pix6 pix6
# row 206 :         pix7 pix7
# row 207 :         pix0 pix0
# row 208 :         pix1 pix1
# row 209 :         pix7 pix7
# row 210 :         pix1 pix1
# row 211 :         pix7 pix7
# row 212 :         pix6 pix6
# row 213 :         pix8 pix8
# row 214 :         pix7 pix7
# row 215 :         pix8 pix8
# row 216 :         pix8 pix8
# row 217 :         pix9 pix9
# row 218 :         pix6 pix6
# row 219 :         pix9 pix3           incorrect
# row 220 :         pix8 pix8
# row 221 :         pix2 pix2
# row 222 :         pix1 pix9           incorrect
# row 223 :         pix2 pix2
# row 224 :         pix4 pix4
# row 225 :         pix4 pix4
# row 226 :         pix2 pix2
# row 227 :         pix8 pix8
# row 228 :         pix8 pix1           incorrect
# row 229 :         pix0 pix0
# row 230 :         pix3 pix3
# row 231 :         pix3 pix3
# row 232 :         pix0 pix0
# row 233 :         pix0 pix0
# row 234 :         pix3 pix3
# row 235 :         pix0 pix0
# row 236 :         pix7 pix7
# row 237 :         pix6 pix6
# row 238 :         pix2 pix2
# row 239 :         pix1 pix1
# row 240 :         pix7 pix7
# row 241 :         pix8 pix9           incorrect
# row 242 :         pix8 pix8
# row 243 :         pix6 pix6
# row 244 :         pix6 pix6
# row 245 :         pix8 pix8
# row 246 :         pix0 pix8           incorrect
# row 247 :         pix3 pix3
# row 248 :         pix1 pix8           incorrect
# row 249 :         pix0 pix0
# row 250 :         pix7 pix7
# row 251 :         pix3 pix3
# row 252 :         pix1 pix1
# row 253 :         pix5 pix5
# row 254 :         pix2 pix1           incorrect
# row 255 :         pix1 pix1
# row 256 :         pix5 pix5
# row 257 :         pix1 pix1
# row 258 :         pix0 pix0
# row 259 :         pix5 pix5
# row 260 :         pix1 pix1
# row 261 :         pix9 pix9
# row 262 :         pix1 pix9           incorrect
# row 263 :         pix6 pix6
# row 264 :         pix7 pix7
# row 265 :         pix6 pix6
# row 266 :         pix6 pix6
# row 267 :         pix5 pix5
# row 268 :         pix2 pix1           incorrect
# row 269 :         pix4 pix4
# row 270 :         pix5 pix5
# row 271 :         pix6 pix6
# row 272 :         pix1 pix1
# row 273 :         pix1 pix1
# row 274 :         pix9 pix9
# row 275 :         pix6 pix6
# row 276 :         pix6 pix6
# row 277 :         pix2 pix2
# row 278 :         pix8 pix2           incorrect
# row 279 :         pix5 pix5
# row 280 :         pix1 pix5           incorrect
# row 281 :         pix6 pix6
# row 282 :         pix0 pix0
# row 283 :         pix2 pix2
# row 284 :         pix6 pix1           incorrect
# row 285 :         pix1 pix8           incorrect
# row 286 :         pix0 pix0
# row 287 :         pix7 pix7
# row 288 :         pix7 pix7
# row 289 :         pix6 pix6
# row 290 :         pix9 pix9
# row 291 :         pix7 pix7
# row 292 :         pix6 pix2           incorrect
# row 293 :         pix1 pix1
# row 294 :         pix0 pix0
# row 295 :         pix8 pix8
# row 296 :         pix6 pix6
# row 297 :         pix5 pix5
# row 298 :         pix4 pix4
# row 299 :         pix1 pix1
# row 300 :         pix7 pix7
# row 301 :         pix5 pix5
# row 302 :         pix6 pix6
# row 303 :         pix4 pix4
# row 304 :         pix1 pix1
# row 305 :         pix3 pix1           incorrect
# row 306 :         pix0 pix0
# row 307 :         pix2 pix2
# row 308 :         pix2 pix2
# row 309 :         pix5 pix5
# row 310 :         pix0 pix0
# row 311 :         pix0 pix0
# row 312 :         pix7 pix7
# row 313 :         pix2 pix2
# row 314 :         pix6 pix6
# row 315 :         pix0 pix0
# row 316 :         pix7 pix7
# row 317 :         pix8 pix8
# row 318 :         pix0 pix0
# row 319 :         pix0 pix0
# row 320 :         pix2 pix2
# row 321 :         pix3 pix2           incorrect
# row 322 :         pix6 pix6
# row 323 :         pix9 pix9
# row 324 :         pix2 pix3           incorrect
# row 325 :         pix6 pix6
# row 326 :         pix1 pix8           incorrect
# row 327 :         pix9 pix9
# row 328 :         pix4 pix7           incorrect
# row 329 :         pix4 pix4
# row 330 :         pix3 pix3
# row 331 :         pix9 pix9
# row 332 :         pix7 pix7
# row 333 :         pix1 pix1
# row 334 :         pix6 pix6
# row 335 :         pix9 pix9
# row 336 :         pix4 pix4
# row 337 :         pix7 pix7
# row 338 :         pix6 pix6
# row 339 :         pix1 pix1
# row 340 :         pix3 pix3
# row 341 :         pix4 pix4
# row 342 :         pix8 pix8
# row 343 :         pix2 pix2
# row 344 :         pix1 pix9           incorrect
# row 345 :         pix9 pix9
# row 346 :         pix1 pix1
# row 347 :         pix6 pix6
# row 348 :         pix5 pix5
# row 349 :         pix8 pix8
# row 350 :         pix9 pix9
# row 351 :         pix5 pix5
# row 352 :         pix1 pix1
# row 353 :         pix0 pix0
#
# Correct: 302 out of 354
# 302

# %%
print(dtree_model_tuned.feature_importances_)
print()

# let's see them with each feature name:
IMPs = dtree_model_tuned.feature_importances_

# enumerate is great when you want indices _and_ elements!
for i, importance in enumerate(IMPs):
    perc = importance*100
    print(f"Feature {COLUMNS[i]:>12s} has {perc:>7.2f}% of the decision-making importance.")
# Out:
# [0.         0.00107138 0.02255984 0.01263657 0.00241061 0.01223451
#  0.01267392 0.         0.         0.         0.04661025 0.00220973
#  0.0208881  0.02824058 0.00158115 0.         0.         0.00080354
#  0.00233408 0.00986313 0.04950179 0.06592335 0.00314427 0.
#  0.         0.00080354 0.09005308 0.00796447 0.01220404 0.04072479
#  0.0055444  0.         0.         0.06936324 0.00281238 0.00120531
#  0.08381834 0.00659177 0.01825564 0.         0.         0.00157785
#  0.02121895 0.06867598 0.00318928 0.01886477 0.04602495 0.
#  0.         0.00107138 0.01084085 0.01624119 0.00332575 0.00423748
#  0.06089132 0.00507121 0.         0.         0.00128566 0.00389463
#  0.05374652 0.00395551 0.03418267 0.00767623]
#
# Feature         pix0 has    0.00% of the decision-making importance.
# Feature         pix1 has    0.11% of the decision-making importance.
# Feature         pix2 has    2.26% of the decision-making importance.
# Feature         pix3 has    1.26% of the decision-making importance.
# Feature         pix4 has    0.24% of the decision-making importance.
# Feature         pix5 has    1.22% of the decision-making importance.
# Feature         pix6 has    1.27% of the decision-making importance.
# Feature         pix7 has    0.00% of the decision-making importance.
# Feature         pix8 has    0.00% of the decision-making importance.
# Feature         pix9 has    0.00% of the decision-making importance.
# Feature        pix10 has    4.66% of the decision-making importance.
# Feature        pix11 has    0.22% of the decision-making importance.
# Feature        pix12 has    2.09% of the decision-making importance.
# Feature        pix13 has    2.82% of the decision-making importance.
# Feature        pix14 has    0.16% of the decision-making importance.
# Feature        pix15 has    0.00% of the decision-making importance.
# Feature        pix16 has    0.00% of the decision-making importance.
# Feature        pix17 has    0.08% of the decision-making importance.
# Feature        pix18 has    0.23% of the decision-making importance.
# Feature        pix19 has    0.99% of the decision-making importance.
# Feature        pix20 has    4.95% of the decision-making importance.
# Feature        pix21 has    6.59% of the decision-making importance.
# Feature        pix22 has    0.31% of the decision-making importance.
# Feature        pix23 has    0.00% of the decision-making importance.
# Feature        pix24 has    0.00% of the decision-making importance.
# Feature        pix25 has    0.08% of the decision-making importance.
# Feature        pix26 has    9.01% of the decision-making importance.
# Feature        pix27 has    0.80% of the decision-making importance.
# Feature        pix28 has    1.22% of the decision-making importance.
# Feature        pix29 has    4.07% of the decision-making importance.
# Feature        pix30 has    0.55% of the decision-making importance.
# Feature        pix31 has    0.00% of the decision-making importance.
# Feature        pix32 has    0.00% of the decision-making importance.
# Feature        pix33 has    6.94% of the decision-making importance.
# Feature        pix34 has    0.28% of the decision-making importance.
# Feature        pix35 has    0.12% of the decision-making importance.
# Feature        pix36 has    8.38% of the decision-making importance.
# Feature        pix37 has    0.66% of the decision-making importance.
# Feature        pix38 has    1.83% of the decision-making importance.
# Feature        pix39 has    0.00% of the decision-making importance.
# Feature        pix40 has    0.00% of the decision-making importance.
# Feature        pix41 has    0.16% of the decision-making importance.
# Feature        pix42 has    2.12% of the decision-making importance.
# Feature        pix43 has    6.87% of the decision-making importance.
# Feature        pix44 has    0.32% of the decision-making importance.
# Feature        pix45 has    1.89% of the decision-making importance.
# Feature        pix46 has    4.60% of the decision-making importance.
# Feature        pix47 has    0.00% of the decision-making importance.
# Feature        pix48 has    0.00% of the decision-making importance.
# Feature        pix49 has    0.11% of the decision-making importance.
# Feature        pix50 has    1.08% of the decision-making importance.
# Feature        pix51 has    1.62% of the decision-making importance.
# Feature        pix52 has    0.33% of the decision-making importance.
# Feature        pix53 has    0.42% of the decision-making importance.
# Feature        pix54 has    6.09% of the decision-making importance.
# Feature        pix55 has    0.51% of the decision-making importance.
# Feature        pix56 has    0.00% of the decision-making importance.
# Feature        pix57 has    0.00% of the decision-making importance.
# Feature        pix58 has    0.13% of the decision-making importance.
# Feature        pix59 has    0.39% of the decision-making importance.
# Feature        pix60 has    5.37% of the decision-making importance.
# Feature        pix61 has    0.40% of the decision-making importance.
# Feature        pix62 has    3.42% of the decision-making importance.
# Feature        pix63 has    0.77% of the decision-making importance.

# %%
#
# Ok!  We have tuned our DT to use the "best" depth...
#
# Now, we use ALL available data to train our final predictive model:
#

from sklearn import tree      # for decision trees

# we should have best_depth from our cv exploration
dtree_model_final = tree.DecisionTreeClassifier(max_depth=best_depth)

# we train the model (it's one line!)
dtree_model_final.fit(X_all, y_all)                              # yay!  trained!
print("Created and trained a 'final' DT classifier with max depth =", best_depth)
# Out:
# Created and trained a 'final' DT classifier with max depth = 10

# %%
#
# final predictive model (decision trees), with tuned parameters + ALL data incorporated
#

def predictive_model( Features, Model ):
    """ input: a list of four features 
                [ sepallen, sepalwid, petallen, petalwid ]
        output: the predicted species of iris, from
                  setosa (0), versicolor (1), virginica (2)
    """
    our_features = np.asarray([Features])                 # extra brackets needed
    predicted_species = Model.predict(our_features)       # The model's prediction!
    predicted_species = int(round(predicted_species[0]))  # unpack the extra brackets
    return predicted_species

#skipping feature tests

# %%
#
# feature importances!
# 
#     feature importances are computed by tracking which feature is used at each decision-point
#     weighted by how often that decision-point is checked 
# 
# feature importances are often even more "important" than predictions, 
#         because they invite the question, "why" (Here, not a computational, but a biological/botanical q'n)
#

print(dtree_model_final.feature_importances_)
print()

# let's see them with each feature name:
IMPs = dtree_model_final.feature_importances_

# enumerate is great when you want indices _and_ elements!
for i, importance in enumerate(IMPs):
    perc = importance*100
    print(f"Feature {COLUMNS[i]:>12s} has {perc:>7.2f}% of the decision-making importance.")
# Out:
# [0.         0.         0.01803968 0.01005142 0.00194607 0.06182895
#  0.01692742 0.         0.00127891 0.         0.01203807 0.00127885
#  0.01747289 0.02173095 0.00118926 0.         0.         0.00471774
#  0.01967165 0.02102181 0.04394847 0.08047077 0.         0.
#  0.00128805 0.00097303 0.01389227 0.04978449 0.00545461 0.04922784
#  0.         0.         0.         0.10163368 0.02875707 0.01047772
#  0.07443793 0.02082696 0.00636511 0.         0.         0.00374244
#  0.08109153 0.0545193  0.0162308  0.00573611 0.00793423 0.
#  0.         0.         0.00827732 0.00128805 0.00734052 0.01401416
#  0.02436622 0.         0.         0.         0.00870922 0.00097303
#  0.06180713 0.00414113 0.00309713 0.        ]
#
# Feature         pix0 has    0.00% of the decision-making importance.
# Feature         pix1 has    0.00% of the decision-making importance.
# Feature         pix2 has    1.80% of the decision-making importance.
# Feature         pix3 has    1.01% of the decision-making importance.
# Feature         pix4 has    0.19% of the decision-making importance.
# Feature         pix5 has    6.18% of the decision-making importance.
# Feature         pix6 has    1.69% of the decision-making importance.
# Feature         pix7 has    0.00% of the decision-making importance.
# Feature         pix8 has    0.13% of the decision-making importance.
# Feature         pix9 has    0.00% of the decision-making importance.
# Feature        pix10 has    1.20% of the decision-making importance.
# Feature        pix11 has    0.13% of the decision-making importance.
# Feature        pix12 has    1.75% of the decision-making importance.
# Feature        pix13 has    2.17% of the decision-making importance.
# Feature        pix14 has    0.12% of the decision-making importance.
# Feature        pix15 has    0.00% of the decision-making importance.
# Feature        pix16 has    0.00% of the decision-making importance.
# Feature        pix17 has    0.47% of the decision-making importance.
# Feature        pix18 has    1.97% of the decision-making importance.
# Feature        pix19 has    2.10% of the decision-making importance.
# Feature        pix20 has    4.39% of the decision-making importance.
# Feature        pix21 has    8.05% of the decision-making importance.
# Feature        pix22 has    0.00% of the decision-making importance.
# Feature        pix23 has    0.00% of the decision-making importance.
# Feature        pix24 has    0.13% of the decision-making importance.
# Feature        pix25 has    0.10% of the decision-making importance.
# Feature        pix26 has    1.39% of the decision-making importance.
# Feature        pix27 has    4.98% of the decision-making importance.
# Feature        pix28 has    0.55% of the decision-making importance.
# Feature        pix29 has    4.92% of the decision-making importance.
# Feature        pix30 has    0.00% of the decision-making importance.
# Feature        pix31 has    0.00% of the decision-making importance.
# Feature        pix32 has    0.00% of the decision-making importance.
# Feature        pix33 has   10.16% of the decision-making importance.
# Feature        pix34 has    2.88% of the decision-making importance.
# Feature        pix35 has    1.05% of the decision-making importance.
# Feature        pix36 has    7.44% of the decision-making importance.
# Feature        pix37 has    2.08% of the decision-making importance.
# Feature        pix38 has    0.64% of the decision-making importance.
# Feature        pix39 has    0.00% of the decision-making importance.
# Feature        pix40 has    0.00% of the decision-making importance.
# Feature        pix41 has    0.37% of the decision-making importance.
# Feature        pix42 has    8.11% of the decision-making importance.
# Feature        pix43 has    5.45% of the decision-making importance.
# Feature        pix44 has    1.62% of the decision-making importance.
# Feature        pix45 has    0.57% of the decision-making importance.
# Feature        pix46 has    0.79% of the decision-making importance.
# Feature        pix47 has    0.00% of the decision-making importance.
# Feature        pix48 has    0.00% of the decision-making importance.
# Feature        pix49 has    0.00% of the decision-making importance.
# Feature        pix50 has    0.83% of the decision-making importance.
# Feature        pix51 has    0.13% of the decision-making importance.
# Feature        pix52 has    0.73% of the decision-making importance.
# Feature        pix53 has    1.40% of the decision-making importance.
# Feature        pix54 has    2.44% of the decision-making importance.
# Feature        pix55 has    0.00% of the decision-making importance.
# Feature        pix56 has    0.00% of the decision-making importance.
# Feature        pix57 has    0.00% of the decision-making importance.
# Feature        pix58 has    0.87% of the decision-making importance.
# Feature        pix59 has    0.10% of the decision-making importance.
# Feature        pix60 has    6.18% of the decision-making importance.
# Feature        pix61 has    0.41% of the decision-making importance.
# Feature        pix62 has    0.31% of the decision-making importance.
# Feature        pix63 has    0.00% of the decision-making importance.

# %% [markdown]
# ## Then: &nbsp; _Random Forests_

# %%
#
# +++ We're back at the "Model-building and Model-training Cell"
#       
# Create a RF model and train it! 
#
from sklearn import tree      # for decision trees
from sklearn import ensemble  # for random forests, an ensemble classifier

best_d = 1            # we don't know what depth to use, so we guess...
best_num_trees = 42   # again, we guess
rforest_model = ensemble.RandomForestClassifier(max_depth=best_d, 
                                                n_estimators=best_num_trees,
                                                max_samples=0.5)  
# This max_samples=0.5 is the fraction of rows to use for each DT 
# For all of our forests, we will let max_samples be 0.5   

# We'll explore best_d and best_num_trees...

# we train the model (again, one line):
rforest_model.fit(X_train, y_train)                              # yay!  trained!
print(f"Built an RF with depth={best_d} and number of trees={best_num_trees}")
# Out:
# Built an RF with depth=1 and number of trees=42

# %%
#
# +++ This is the "Model-testing Cell"
#
# Now, let's see how well we did on our "held-out data" (the testing data)
#

# We run our test set!
predicted_labels = rforest_model.predict(X_test)
actual_labels = y_test

# Let's print them so we can compare...
print("Predicted labels:", predicted_labels)
print("Actual  labels  :", actual_labels)

# And, some overall results
num_correct = sum(predicted_labels == actual_labels)
total = len(actual_labels)
print(f"\nResults on test set:  {num_correct} correct out of {total} total.")

# and, let's print our table, too...
compare_labels(predicted_labels,actual_labels)
# Out:
# Predicted labels: [2. 7. 3. 7. 3. 2. 2. 3. 2. 6. 8. 9. 7. 9. 7. 4. 6. 3. 3. 3. 6. 6. 0. 7.
#  7. 6. 6. 9. 1. 7. 9. 7. 4. 4. 3. 3. 4. 3. 2. 2. 3. 6. 3. 4. 4. 2. 2. 2.
#  3. 0. 2. 4. 4. 4. 4. 2. 7. 0. 3. 3. 3. 9. 9. 0. 4. 4. 7. 9. 2. 5. 0. 9.
#  0. 6. 0. 6. 9. 2. 0. 0. 4. 2. 2. 0. 6. 7. 2. 5. 0. 1. 2. 5. 1. 3. 4. 7.
#  3. 4. 2. 6. 7. 4. 6. 7. 4. 2. 2. 2. 7. 5. 2. 0. 3. 4. 2. 2. 4. 0. 0. 6.
#  2. 1. 6. 2. 0. 3. 3. 0. 5. 4. 4. 7. 7. 6. 9. 4. 9. 0. 9. 5. 3. 5. 3. 2.
#  6. 3. 3. 2. 4. 5. 2. 9. 3. 4. 1. 2. 4. 4. 0. 6. 3. 3. 5. 0. 4. 5. 2. 0.
#  2. 2. 7. 6. 1. 0. 2. 2. 6. 7. 4. 4. 0. 9. 3. 3. 5. 6. 4. 0. 3. 3. 0. 4.
#  6. 2. 2. 2. 3. 7. 9. 9. 7. 2. 2. 3. 3. 6. 4. 0. 2. 7. 1. 7. 4. 2. 4. 2.
#  2. 3. 6. 3. 2. 2. 9. 2. 4. 4. 2. 3. 8. 0. 3. 3. 0. 0. 3. 0. 7. 6. 2. 4.
#  4. 3. 8. 6. 6. 2. 5. 3. 3. 0. 7. 2. 9. 3. 4. 4. 5. 4. 0. 5. 2. 9. 9. 6.
#  7. 6. 6. 0. 2. 4. 5. 4. 4. 5. 3. 6. 6. 2. 2. 5. 3. 6. 0. 2. 4. 2. 0. 4.
#  7. 6. 9. 7. 2. 1. 0. 2. 6. 5. 4. 4. 7. 3. 4. 4. 3. 2. 0. 2. 2. 5. 0. 0.
#  7. 2. 6. 0. 7. 3. 0. 0. 2. 2. 4. 9. 2. 4. 4. 9. 7. 7. 3. 9. 7. 2. 6. 9.
#  4. 4. 6. 1. 3. 4. 2. 2. 5. 9. 2. 6. 3. 8. 9. 5. 4. 0.]
# Actual  labels  : [1. 7. 8. 7. 3. 8. 2. 5. 2. 6. 8. 9. 7. 9. 7. 5. 6. 3. 9. 8. 5. 6. 0. 7.
#  7. 6. 6. 9. 6. 7. 9. 7. 4. 4. 3. 9. 6. 3. 1. 2. 3. 6. 9. 6. 4. 1. 8. 2.
#  3. 0. 2. 1. 4. 4. 4. 8. 7. 0. 3. 3. 3. 9. 9. 8. 1. 4. 7. 1. 1. 5. 0. 9.
#  0. 6. 0. 6. 9. 1. 9. 0. 1. 8. 6. 0. 6. 7. 8. 5. 0. 1. 1. 5. 1. 3. 1. 7.
#  9. 4. 7. 6. 7. 5. 5. 1. 4. 8. 2. 1. 7. 5. 8. 0. 9. 4. 2. 2. 9. 0. 0. 6.
#  5. 1. 6. 2. 6. 3. 9. 0. 5. 4. 4. 7. 7. 6. 9. 6. 9. 0. 9. 5. 3. 5. 3. 2.
#  6. 8. 8. 8. 4. 5. 2. 9. 3. 7. 1. 2. 5. 5. 0. 6. 3. 3. 5. 9. 4. 5. 3. 0.
#  1. 8. 7. 6. 1. 0. 8. 8. 6. 7. 7. 6. 0. 9. 1. 3. 5. 6. 4. 0. 9. 3. 0. 4.
#  5. 8. 1. 1. 3. 7. 9. 9. 7. 5. 8. 3. 3. 6. 7. 0. 1. 7. 1. 7. 6. 8. 7. 8.
#  8. 9. 6. 3. 8. 2. 9. 2. 4. 4. 2. 8. 1. 0. 3. 3. 0. 0. 3. 0. 7. 6. 2. 1.
#  7. 9. 8. 6. 6. 8. 8. 3. 8. 0. 7. 3. 1. 5. 1. 1. 5. 1. 0. 5. 1. 9. 9. 6.
#  7. 6. 6. 5. 1. 4. 5. 6. 1. 1. 9. 6. 6. 2. 2. 5. 5. 6. 0. 2. 1. 8. 0. 7.
#  7. 6. 9. 7. 2. 1. 0. 8. 6. 5. 4. 1. 7. 5. 6. 4. 1. 1. 0. 2. 2. 5. 0. 0.
#  7. 2. 6. 0. 7. 8. 0. 0. 2. 2. 6. 9. 3. 6. 8. 9. 7. 4. 3. 9. 7. 1. 6. 9.
#  4. 7. 6. 1. 3. 4. 8. 2. 9. 9. 1. 6. 5. 8. 9. 5. 1. 0.]
#
# Results on test set:  235 correct out of 354 total.
# row   0 :         pix2 pix1           incorrect
# row   1 :         pix7 pix7
# row   2 :         pix3 pix8           incorrect
# row   3 :         pix7 pix7
# row   4 :         pix3 pix3
# row   5 :         pix2 pix8           incorrect
# row   6 :         pix2 pix2
# row   7 :         pix3 pix5           incorrect
# row   8 :         pix2 pix2
# row   9 :         pix6 pix6
# row  10 :         pix8 pix8
# row  11 :         pix9 pix9
# row  12 :         pix7 pix7
# row  13 :         pix9 pix9
# row  14 :         pix7 pix7
# row  15 :         pix4 pix5           incorrect
# row  16 :         pix6 pix6
# row  17 :         pix3 pix3
# row  18 :         pix3 pix9           incorrect
# row  19 :         pix3 pix8           incorrect
# row  20 :         pix6 pix5           incorrect
# row  21 :         pix6 pix6
# row  22 :         pix0 pix0
# row  23 :         pix7 pix7
# row  24 :         pix7 pix7
# row  25 :         pix6 pix6
# row  26 :         pix6 pix6
# row  27 :         pix9 pix9
# row  28 :         pix1 pix6           incorrect
# row  29 :         pix7 pix7
# row  30 :         pix9 pix9
# row  31 :         pix7 pix7
# row  32 :         pix4 pix4
# row  33 :         pix4 pix4
# row  34 :         pix3 pix3
# row  35 :         pix3 pix9           incorrect
# row  36 :         pix4 pix6           incorrect
# row  37 :         pix3 pix3
# row  38 :         pix2 pix1           incorrect
# row  39 :         pix2 pix2
# row  40 :         pix3 pix3
# row  41 :         pix6 pix6
# row  42 :         pix3 pix9           incorrect
# row  43 :         pix4 pix6           incorrect
# row  44 :         pix4 pix4
# row  45 :         pix2 pix1           incorrect
# row  46 :         pix2 pix8           incorrect
# row  47 :         pix2 pix2
# row  48 :         pix3 pix3
# row  49 :         pix0 pix0
# row  50 :         pix2 pix2
# row  51 :         pix4 pix1           incorrect
# row  52 :         pix4 pix4
# row  53 :         pix4 pix4
# row  54 :         pix4 pix4
# row  55 :         pix2 pix8           incorrect
# row  56 :         pix7 pix7
# row  57 :         pix0 pix0
# row  58 :         pix3 pix3
# row  59 :         pix3 pix3
# row  60 :         pix3 pix3
# row  61 :         pix9 pix9
# row  62 :         pix9 pix9
# row  63 :         pix0 pix8           incorrect
# row  64 :         pix4 pix1           incorrect
# row  65 :         pix4 pix4
# row  66 :         pix7 pix7
# row  67 :         pix9 pix1           incorrect
# row  68 :         pix2 pix1           incorrect
# row  69 :         pix5 pix5
# row  70 :         pix0 pix0
# row  71 :         pix9 pix9
# row  72 :         pix0 pix0
# row  73 :         pix6 pix6
# row  74 :         pix0 pix0
# row  75 :         pix6 pix6
# row  76 :         pix9 pix9
# row  77 :         pix2 pix1           incorrect
# row  78 :         pix0 pix9           incorrect
# row  79 :         pix0 pix0
# row  80 :         pix4 pix1           incorrect
# row  81 :         pix2 pix8           incorrect
# row  82 :         pix2 pix6           incorrect
# row  83 :         pix0 pix0
# row  84 :         pix6 pix6
# row  85 :         pix7 pix7
# row  86 :         pix2 pix8           incorrect
# row  87 :         pix5 pix5
# row  88 :         pix0 pix0
# row  89 :         pix1 pix1
# row  90 :         pix2 pix1           incorrect
# row  91 :         pix5 pix5
# row  92 :         pix1 pix1
# row  93 :         pix3 pix3
# row  94 :         pix4 pix1           incorrect
# row  95 :         pix7 pix7
# row  96 :         pix3 pix9           incorrect
# row  97 :         pix4 pix4
# row  98 :         pix2 pix7           incorrect
# row  99 :         pix6 pix6
# row 100 :         pix7 pix7
# row 101 :         pix4 pix5           incorrect
# row 102 :         pix6 pix5           incorrect
# row 103 :         pix7 pix1           incorrect
# row 104 :         pix4 pix4
# row 105 :         pix2 pix8           incorrect
# row 106 :         pix2 pix2
# row 107 :         pix2 pix1           incorrect
# row 108 :         pix7 pix7
# row 109 :         pix5 pix5
# row 110 :         pix2 pix8           incorrect
# row 111 :         pix0 pix0
# row 112 :         pix3 pix9           incorrect
# row 113 :         pix4 pix4
# row 114 :         pix2 pix2
# row 115 :         pix2 pix2
# row 116 :         pix4 pix9           incorrect
# row 117 :         pix0 pix0
# row 118 :         pix0 pix0
# row 119 :         pix6 pix6
# row 120 :         pix2 pix5           incorrect
# row 121 :         pix1 pix1
# row 122 :         pix6 pix6
# row 123 :         pix2 pix2
# row 124 :         pix0 pix6           incorrect
# row 125 :         pix3 pix3
# row 126 :         pix3 pix9           incorrect
# row 127 :         pix0 pix0
# row 128 :         pix5 pix5
# row 129 :         pix4 pix4
# row 130 :         pix4 pix4
# row 131 :         pix7 pix7
# row 132 :         pix7 pix7
# row 133 :         pix6 pix6
# row 134 :         pix9 pix9
# row 135 :         pix4 pix6           incorrect
# row 136 :         pix9 pix9
# row 137 :         pix0 pix0
# row 138 :         pix9 pix9
# row 139 :         pix5 pix5
# row 140 :         pix3 pix3
# row 141 :         pix5 pix5
# row 142 :         pix3 pix3
# row 143 :         pix2 pix2
# row 144 :         pix6 pix6
# row 145 :         pix3 pix8           incorrect
# row 146 :         pix3 pix8           incorrect
# row 147 :         pix2 pix8           incorrect
# row 148 :         pix4 pix4
# row 149 :         pix5 pix5
# row 150 :         pix2 pix2
# row 151 :         pix9 pix9
# row 152 :         pix3 pix3
# row 153 :         pix4 pix7           incorrect
# row 154 :         pix1 pix1
# row 155 :         pix2 pix2
# row 156 :         pix4 pix5           incorrect
# row 157 :         pix4 pix5           incorrect
# row 158 :         pix0 pix0
# row 159 :         pix6 pix6
# row 160 :         pix3 pix3
# row 161 :         pix3 pix3
# row 162 :         pix5 pix5
# row 163 :         pix0 pix9           incorrect
# row 164 :         pix4 pix4
# row 165 :         pix5 pix5
# row 166 :         pix2 pix3           incorrect
# row 167 :         pix0 pix0
# row 168 :         pix2 pix1           incorrect
# row 169 :         pix2 pix8           incorrect
# row 170 :         pix7 pix7
# row 171 :         pix6 pix6
# row 172 :         pix1 pix1
# row 173 :         pix0 pix0
# row 174 :         pix2 pix8           incorrect
# row 175 :         pix2 pix8           incorrect
# row 176 :         pix6 pix6
# row 177 :         pix7 pix7
# row 178 :         pix4 pix7           incorrect
# row 179 :         pix4 pix6           incorrect
# row 180 :         pix0 pix0
# row 181 :         pix9 pix9
# row 182 :         pix3 pix1           incorrect
# row 183 :         pix3 pix3
# row 184 :         pix5 pix5
# row 185 :         pix6 pix6
# row 186 :         pix4 pix4
# row 187 :         pix0 pix0
# row 188 :         pix3 pix9           incorrect
# row 189 :         pix3 pix3
# row 190 :         pix0 pix0
# row 191 :         pix4 pix4
# row 192 :         pix6 pix5           incorrect
# row 193 :         pix2 pix8           incorrect
# row 194 :         pix2 pix1           incorrect
# row 195 :         pix2 pix1           incorrect
# row 196 :         pix3 pix3
# row 197 :         pix7 pix7
# row 198 :         pix9 pix9
# row 199 :         pix9 pix9
# row 200 :         pix7 pix7
# row 201 :         pix2 pix5           incorrect
# row 202 :         pix2 pix8           incorrect
# row 203 :         pix3 pix3
# row 204 :         pix3 pix3
# row 205 :         pix6 pix6
# row 206 :         pix4 pix7           incorrect
# row 207 :         pix0 pix0
# row 208 :         pix2 pix1           incorrect
# row 209 :         pix7 pix7
# row 210 :         pix1 pix1
# row 211 :         pix7 pix7
# row 212 :         pix4 pix6           incorrect
# row 213 :         pix2 pix8           incorrect
# row 214 :         pix4 pix7           incorrect
# row 215 :         pix2 pix8           incorrect
# row 216 :         pix2 pix8           incorrect
# row 217 :         pix3 pix9           incorrect
# row 218 :         pix6 pix6
# row 219 :         pix3 pix3
# row 220 :         pix2 pix8           incorrect
# row 221 :         pix2 pix2
# row 222 :         pix9 pix9
# row 223 :         pix2 pix2
# row 224 :         pix4 pix4
# row 225 :         pix4 pix4
# row 226 :         pix2 pix2
# row 227 :         pix3 pix8           incorrect
# row 228 :         pix8 pix1           incorrect
# row 229 :         pix0 pix0
# row 230 :         pix3 pix3
# row 231 :         pix3 pix3
# row 232 :         pix0 pix0
# row 233 :         pix0 pix0
# row 234 :         pix3 pix3
# row 235 :         pix0 pix0
# row 236 :         pix7 pix7
# row 237 :         pix6 pix6
# row 238 :         pix2 pix2
# row 239 :         pix4 pix1           incorrect
# row 240 :         pix4 pix7           incorrect
# row 241 :         pix3 pix9           incorrect
# row 242 :         pix8 pix8
# row 243 :         pix6 pix6
# row 244 :         pix6 pix6
# row 245 :         pix2 pix8           incorrect
# row 246 :         pix5 pix8           incorrect
# row 247 :         pix3 pix3
# row 248 :         pix3 pix8           incorrect
# row 249 :         pix0 pix0
# row 250 :         pix7 pix7
# row 251 :         pix2 pix3           incorrect
# row 252 :         pix9 pix1           incorrect
# row 253 :         pix3 pix5           incorrect
# row 254 :         pix4 pix1           incorrect
# row 255 :         pix4 pix1           incorrect
# row 256 :         pix5 pix5
# row 257 :         pix4 pix1           incorrect
# row 258 :         pix0 pix0
# row 259 :         pix5 pix5
# row 260 :         pix2 pix1           incorrect
# row 261 :         pix9 pix9
# row 262 :         pix9 pix9
# row 263 :         pix6 pix6
# row 264 :         pix7 pix7
# row 265 :         pix6 pix6
# row 266 :         pix6 pix6
# row 267 :         pix0 pix5           incorrect
# row 268 :         pix2 pix1           incorrect
# row 269 :         pix4 pix4
# row 270 :         pix5 pix5
# row 271 :         pix4 pix6           incorrect
# row 272 :         pix4 pix1           incorrect
# row 273 :         pix5 pix1           incorrect
# row 274 :         pix3 pix9           incorrect
# row 275 :         pix6 pix6
# row 276 :         pix6 pix6
# row 277 :         pix2 pix2
# row 278 :         pix2 pix2
# row 279 :         pix5 pix5
# row 280 :         pix3 pix5           incorrect
# row 281 :         pix6 pix6
# row 282 :         pix0 pix0
# row 283 :         pix2 pix2
# row 284 :         pix4 pix1           incorrect
# row 285 :         pix2 pix8           incorrect
# row 286 :         pix0 pix0
# row 287 :         pix4 pix7           incorrect
# row 288 :         pix7 pix7
# row 289 :         pix6 pix6
# row 290 :         pix9 pix9
# row 291 :         pix7 pix7
# row 292 :         pix2 pix2
# row 293 :         pix1 pix1
# row 294 :         pix0 pix0
# row 295 :         pix2 pix8           incorrect
# row 296 :         pix6 pix6
# row 297 :         pix5 pix5
# row 298 :         pix4 pix4
# row 299 :         pix4 pix1           incorrect
# row 300 :         pix7 pix7
# row 301 :         pix3 pix5           incorrect
# row 302 :         pix4 pix6           incorrect
# row 303 :         pix4 pix4
# row 304 :         pix3 pix1           incorrect
# row 305 :         pix2 pix1           incorrect
# row 306 :         pix0 pix0
# row 307 :         pix2 pix2
# row 308 :         pix2 pix2
# row 309 :         pix5 pix5
# row 310 :         pix0 pix0
# row 311 :         pix0 pix0
# row 312 :         pix7 pix7
# row 313 :         pix2 pix2
# row 314 :         pix6 pix6
# row 315 :         pix0 pix0
# row 316 :         pix7 pix7
# row 317 :         pix3 pix8           incorrect
# row 318 :         pix0 pix0
# row 319 :         pix0 pix0
# row 320 :         pix2 pix2
# row 321 :         pix2 pix2
# row 322 :         pix4 pix6           incorrect
# row 323 :         pix9 pix9
# row 324 :         pix2 pix3           incorrect
# row 325 :         pix4 pix6           incorrect
# row 326 :         pix4 pix8           incorrect
# row 327 :         pix9 pix9
# row 328 :         pix7 pix7
# row 329 :         pix7 pix4           incorrect
# row 330 :         pix3 pix3
# row 331 :         pix9 pix9
# row 332 :         pix7 pix7
# row 333 :         pix2 pix1           incorrect
# row 334 :         pix6 pix6
# row 335 :         pix9 pix9
# row 336 :         pix4 pix4
# row 337 :         pix4 pix7           incorrect
# row 338 :         pix6 pix6
# row 339 :         pix1 pix1
# row 340 :         pix3 pix3
# row 341 :         pix4 pix4
# row 342 :         pix2 pix8           incorrect
# row 343 :         pix2 pix2
# row 344 :         pix5 pix9           incorrect
# row 345 :         pix9 pix9
# row 346 :         pix2 pix1           incorrect
# row 347 :         pix6 pix6
# row 348 :         pix3 pix5           incorrect
# row 349 :         pix8 pix8
# row 350 :         pix9 pix9
# row 351 :         pix5 pix5
# row 352 :         pix4 pix1           incorrect
# row 353 :         pix0 pix0
#
# Correct: 235 out of 354
# 235

# %%
#
# we can get the individual trees, if we want...
#
tree_index = 28   # which tree
one_rf_tree = rforest_model.estimators_[tree_index]
print(f"One of the forest's trees is {one_rf_tree}")

# From there, it's possible to create a graphical version...
filename = f'rf_tree_{tree_index:03d}.gv'             # f strings! Could save all trees, but we won't do so here. 
tree.export_graphviz(one_rf_tree, out_file=filename,  # the filename constructed above...!
                            feature_names=FEATURES, # actual feature names, not species
                            filled=True,              # fun!
                            rotate=False,             # False for Up/Down; True for L/R
                            class_names=SPECIES,      # good to have   
                            leaves_parallel=True )    # lots of options!
                            
print(f"file {filename} written. Try copying the result to http://viz-js.com/ \n")

with open(filename, "r") as f:
    file_text = f.read()
    print(file_text)

#
# Treeing!
#
fig = plt.figure(figsize=(5,4))
tree_plot = tree.plot_tree(one_rf_tree, 
                   feature_names=FEATURES,   # Glad to have these!
                   class_names=SPECIES,      # and these!!
                   filled=True)
# Out:
# One of the forest's trees is DecisionTreeClassifier(max_depth=1, max_features='sqrt',
#                        random_state=1520690610)
# file rf_tree_028.gv written. Try copying the result to http://viz-js.com/
#
# digraph Tree {
# node [shape=box, style="filled", color="black", fontname="helvetica"] ;
# graph [ranksep=equally, splines=polyline] ;
# edge [fontname="helvetica"] ;
# 0 [label="pix44 <= 8.5\ngini = 0.899\nsamples = 565\nvalue = [62, 64, 76, 75, 91, 61, 65, 73, 71, 69]\nclass = pix4", fillcolor="#fafefe"] ;
# 1 [label="gini = 0.862\nsamples = 294\nvalue = [59.0, 4.0, 50.0, 63.0, 3.0, 43.0, 49.0, 11.0, 26.0\n63.0]\nclass = pix3", fillcolor="#ffffff"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label="gini = 0.835\nsamples = 271\nvalue = [3, 60, 26, 12, 88, 18, 16, 62, 45, 6]\nclass = pix4", fillcolor="#ecfdf9"] ;
# 0 -> 2 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# {rank=same ; 0} ;
# {rank=same ; 1; 2} ;
# }

# %%
#
# So, to compare different parameters, let's use cv
#

from sklearn.model_selection import cross_val_score

#
# cross-validation splits the training set into two pieces:
#   + model-building and model-validation. We'll use "build" and "validate"
#

#
# lab task:  wrap this loop in another one! (or create an inner one...)
#

best_d = 1         # range(1,6)
best_ntrees = 50   # [50,150,250]
best_accuracy = 0

for d in range(1,6):
    for ntrees in [50,150,250]:
        rforest_model = ensemble.RandomForestClassifier(max_depth=d, 
                                                        n_estimators=ntrees,
                                                        max_samples=0.5)
        cv_scores = cross_val_score( rforest_model, X_train, y_train, cv=5 ) # 5 means 80/20 split
        average_cv_accuracy = cv_scores.mean()  # more likely, only their average
        print(f"depth: {d:2d} ntrees: {ntrees:3d} cv accuracy: {average_cv_accuracy:7.4f}")
        if average_cv_accuracy > best_accuracy:
            best_accuracy = average_cv_accuracy
            best_d = d
            best_ntrees = ntrees

# 
# your task: assign best values by keeping a "running max"
#
best_depth = best_d   
best_num_trees = best_ntrees

# This will be incorrect when initially run (you'll fix it):
print()
print(f"best_depth: {best_depth} and best_num_trees: {best_num_trees} are our choices. Acc: {best_accuracy}")  

#
# remember that the RF lab task is to complete this nested cross-validation loop!
#
# Out:
# depth:  1 ntrees:  50 cv accuracy:  0.6570
# depth:  1 ntrees: 150 cv accuracy:  0.6916
# depth:  1 ntrees: 250 cv accuracy:  0.6973
# depth:  2 ntrees:  50 cv accuracy:  0.7907
# depth:  2 ntrees: 150 cv accuracy:  0.8182
# depth:  2 ntrees: 250 cv accuracy:  0.8175
# depth:  3 ntrees:  50 cv accuracy:  0.8522
# depth:  3 ntrees: 150 cv accuracy:  0.8671
# depth:  3 ntrees: 250 cv accuracy:  0.8642
# depth:  4 ntrees:  50 cv accuracy:  0.9095
# depth:  4 ntrees: 150 cv accuracy:  0.9095
# depth:  4 ntrees: 250 cv accuracy:  0.9194
# depth:  5 ntrees:  50 cv accuracy:  0.9314
# depth:  5 ntrees: 150 cv accuracy:  0.9363
# depth:  5 ntrees: 250 cv accuracy:  0.9406
#
# best_depth: 5 and best_num_trees: 250 are our choices. Acc: 0.9405909330125553

# %%
#
# Now, we re-create and re-run the  "Model-building and -training Cell"
#
from sklearn import tree      # for decision trees
from sklearn import ensemble  # for random forests
best_depth =  best_depth
best_num_trees = best_num_trees
# we should have best_depth and best_num_trees
rforest_model_tuned = ensemble.RandomForestClassifier(max_depth=best_depth, 
                                                      n_estimators=best_num_trees,
                                                      max_samples=0.5)

# we train the model (it's one line!)
rforest_model_tuned.fit(X_train, y_train)                              # yay!  trained!
print(f"Built an RF classifier with depth={best_depth} and ntrees={best_num_trees}")
# Out:
# Built an RF classifier with depth=5 and ntrees=250

# %%
#
# +++ This is our "Model-testing Cell"
#
# Now, let's see how well we did on our "held-out data" (the testing data)
#

# We run our test set!
predicted_labels = rforest_model_tuned.predict(X_test)
actual_labels = y_test

# Let's print them so we can compare...
print("Predicted labels:", predicted_labels)
print("Actual  labels  :", actual_labels)

# And, some overall results
num_correct = sum(predicted_labels == actual_labels)
total = len(actual_labels)
print(f"\nResults on test set:  {num_correct} correct out of {total} total.")

# and, let's print our table, too...
compare_labels(predicted_labels,actual_labels)
# Out:
# Predicted labels: [1. 7. 8. 7. 3. 8. 2. 5. 2. 6. 8. 9. 7. 9. 7. 5. 6. 3. 9. 8. 5. 6. 0. 7.
#  7. 6. 6. 9. 6. 7. 9. 7. 4. 4. 3. 3. 6. 3. 1. 2. 7. 6. 9. 6. 4. 1. 8. 2.
#  3. 0. 2. 1. 4. 4. 4. 8. 7. 0. 3. 3. 3. 9. 9. 5. 1. 4. 7. 9. 1. 5. 0. 9.
#  0. 6. 0. 6. 9. 1. 9. 0. 1. 8. 6. 0. 6. 7. 8. 5. 0. 1. 1. 5. 1. 3. 1. 7.
#  9. 4. 7. 6. 7. 5. 5. 1. 4. 8. 2. 1. 7. 5. 8. 0. 9. 4. 2. 2. 4. 0. 0. 6.
#  5. 1. 6. 2. 4. 3. 3. 0. 5. 4. 4. 7. 7. 6. 9. 4. 9. 0. 9. 5. 3. 5. 3. 2.
#  6. 8. 3. 8. 4. 5. 2. 9. 3. 7. 1. 2. 5. 5. 0. 6. 3. 3. 5. 9. 4. 5. 8. 0.
#  1. 8. 7. 6. 1. 0. 8. 8. 6. 7. 4. 6. 0. 9. 1. 3. 5. 6. 4. 0. 9. 3. 0. 4.
#  5. 8. 1. 1. 3. 7. 9. 9. 7. 5. 8. 3. 3. 6. 7. 0. 1. 7. 1. 7. 6. 8. 7. 8.
#  8. 9. 6. 3. 8. 2. 9. 2. 4. 4. 2. 9. 1. 0. 3. 3. 0. 0. 3. 0. 7. 6. 2. 1.
#  7. 3. 8. 6. 6. 8. 8. 3. 8. 0. 7. 8. 9. 5. 1. 1. 5. 1. 0. 5. 1. 9. 9. 6.
#  7. 6. 6. 5. 1. 4. 5. 6. 1. 1. 3. 6. 6. 2. 2. 5. 5. 6. 0. 2. 6. 8. 0. 7.
#  7. 6. 9. 7. 2. 1. 0. 8. 6. 5. 4. 1. 7. 5. 6. 4. 1. 1. 0. 2. 2. 5. 0. 0.
#  7. 2. 6. 0. 7. 8. 0. 0. 2. 2. 6. 9. 8. 6. 8. 9. 7. 7. 3. 9. 7. 1. 6. 9.
#  4. 7. 6. 1. 3. 4. 8. 2. 9. 9. 1. 6. 5. 8. 9. 5. 1. 0.]
# Actual  labels  : [1. 7. 8. 7. 3. 8. 2. 5. 2. 6. 8. 9. 7. 9. 7. 5. 6. 3. 9. 8. 5. 6. 0. 7.
#  7. 6. 6. 9. 6. 7. 9. 7. 4. 4. 3. 9. 6. 3. 1. 2. 3. 6. 9. 6. 4. 1. 8. 2.
#  3. 0. 2. 1. 4. 4. 4. 8. 7. 0. 3. 3. 3. 9. 9. 8. 1. 4. 7. 1. 1. 5. 0. 9.
#  0. 6. 0. 6. 9. 1. 9. 0. 1. 8. 6. 0. 6. 7. 8. 5. 0. 1. 1. 5. 1. 3. 1. 7.
#  9. 4. 7. 6. 7. 5. 5. 1. 4. 8. 2. 1. 7. 5. 8. 0. 9. 4. 2. 2. 9. 0. 0. 6.
#  5. 1. 6. 2. 6. 3. 9. 0. 5. 4. 4. 7. 7. 6. 9. 6. 9. 0. 9. 5. 3. 5. 3. 2.
#  6. 8. 8. 8. 4. 5. 2. 9. 3. 7. 1. 2. 5. 5. 0. 6. 3. 3. 5. 9. 4. 5. 3. 0.
#  1. 8. 7. 6. 1. 0. 8. 8. 6. 7. 7. 6. 0. 9. 1. 3. 5. 6. 4. 0. 9. 3. 0. 4.
#  5. 8. 1. 1. 3. 7. 9. 9. 7. 5. 8. 3. 3. 6. 7. 0. 1. 7. 1. 7. 6. 8. 7. 8.
#  8. 9. 6. 3. 8. 2. 9. 2. 4. 4. 2. 8. 1. 0. 3. 3. 0. 0. 3. 0. 7. 6. 2. 1.
#  7. 9. 8. 6. 6. 8. 8. 3. 8. 0. 7. 3. 1. 5. 1. 1. 5. 1. 0. 5. 1. 9. 9. 6.
#  7. 6. 6. 5. 1. 4. 5. 6. 1. 1. 9. 6. 6. 2. 2. 5. 5. 6. 0. 2. 1. 8. 0. 7.
#  7. 6. 9. 7. 2. 1. 0. 8. 6. 5. 4. 1. 7. 5. 6. 4. 1. 1. 0. 2. 2. 5. 0. 0.
#  7. 2. 6. 0. 7. 8. 0. 0. 2. 2. 6. 9. 3. 6. 8. 9. 7. 4. 3. 9. 7. 1. 6. 9.
#  4. 7. 6. 1. 3. 4. 8. 2. 9. 9. 1. 6. 5. 8. 9. 5. 1. 0.]
#
# Results on test set:  335 correct out of 354 total.
# row   0 :         pix1 pix1
# row   1 :         pix7 pix7
# row   2 :         pix8 pix8
# row   3 :         pix7 pix7
# row   4 :         pix3 pix3
# row   5 :         pix8 pix8
# row   6 :         pix2 pix2
# row   7 :         pix5 pix5
# row   8 :         pix2 pix2
# row   9 :         pix6 pix6
# row  10 :         pix8 pix8
# row  11 :         pix9 pix9
# row  12 :         pix7 pix7
# row  13 :         pix9 pix9
# row  14 :         pix7 pix7
# row  15 :         pix5 pix5
# row  16 :         pix6 pix6
# row  17 :         pix3 pix3
# row  18 :         pix9 pix9
# row  19 :         pix8 pix8
# row  20 :         pix5 pix5
# row  21 :         pix6 pix6
# row  22 :         pix0 pix0
# row  23 :         pix7 pix7
# row  24 :         pix7 pix7
# row  25 :         pix6 pix6
# row  26 :         pix6 pix6
# row  27 :         pix9 pix9
# row  28 :         pix6 pix6
# row  29 :         pix7 pix7
# row  30 :         pix9 pix9
# row  31 :         pix7 pix7
# row  32 :         pix4 pix4
# row  33 :         pix4 pix4
# row  34 :         pix3 pix3
# row  35 :         pix3 pix9           incorrect
# row  36 :         pix6 pix6
# row  37 :         pix3 pix3
# row  38 :         pix1 pix1
# row  39 :         pix2 pix2
# row  40 :         pix7 pix3           incorrect
# row  41 :         pix6 pix6
# row  42 :         pix9 pix9
# row  43 :         pix6 pix6
# row  44 :         pix4 pix4
# row  45 :         pix1 pix1
# row  46 :         pix8 pix8
# row  47 :         pix2 pix2
# row  48 :         pix3 pix3
# row  49 :         pix0 pix0
# row  50 :         pix2 pix2
# row  51 :         pix1 pix1
# row  52 :         pix4 pix4
# row  53 :         pix4 pix4
# row  54 :         pix4 pix4
# row  55 :         pix8 pix8
# row  56 :         pix7 pix7
# row  57 :         pix0 pix0
# row  58 :         pix3 pix3
# row  59 :         pix3 pix3
# row  60 :         pix3 pix3
# row  61 :         pix9 pix9
# row  62 :         pix9 pix9
# row  63 :         pix5 pix8           incorrect
# row  64 :         pix1 pix1
# row  65 :         pix4 pix4
# row  66 :         pix7 pix7
# row  67 :         pix9 pix1           incorrect
# row  68 :         pix1 pix1
# row  69 :         pix5 pix5
# row  70 :         pix0 pix0
# row  71 :         pix9 pix9
# row  72 :         pix0 pix0
# row  73 :         pix6 pix6
# row  74 :         pix0 pix0
# row  75 :         pix6 pix6
# row  76 :         pix9 pix9
# row  77 :         pix1 pix1
# row  78 :         pix9 pix9
# row  79 :         pix0 pix0
# row  80 :         pix1 pix1
# row  81 :         pix8 pix8
# row  82 :         pix6 pix6
# row  83 :         pix0 pix0
# row  84 :         pix6 pix6
# row  85 :         pix7 pix7
# row  86 :         pix8 pix8
# row  87 :         pix5 pix5
# row  88 :         pix0 pix0
# row  89 :         pix1 pix1
# row  90 :         pix1 pix1
# row  91 :         pix5 pix5
# row  92 :         pix1 pix1
# row  93 :         pix3 pix3
# row  94 :         pix1 pix1
# row  95 :         pix7 pix7
# row  96 :         pix9 pix9
# row  97 :         pix4 pix4
# row  98 :         pix7 pix7
# row  99 :         pix6 pix6
# row 100 :         pix7 pix7
# row 101 :         pix5 pix5
# row 102 :         pix5 pix5
# row 103 :         pix1 pix1
# row 104 :         pix4 pix4
# row 105 :         pix8 pix8
# row 106 :         pix2 pix2
# row 107 :         pix1 pix1
# row 108 :         pix7 pix7
# row 109 :         pix5 pix5
# row 110 :         pix8 pix8
# row 111 :         pix0 pix0
# row 112 :         pix9 pix9
# row 113 :         pix4 pix4
# row 114 :         pix2 pix2
# row 115 :         pix2 pix2
# row 116 :         pix4 pix9           incorrect
# row 117 :         pix0 pix0
# row 118 :         pix0 pix0
# row 119 :         pix6 pix6
# row 120 :         pix5 pix5
# row 121 :         pix1 pix1
# row 122 :         pix6 pix6
# row 123 :         pix2 pix2
# row 124 :         pix4 pix6           incorrect
# row 125 :         pix3 pix3
# row 126 :         pix3 pix9           incorrect
# row 127 :         pix0 pix0
# row 128 :         pix5 pix5
# row 129 :         pix4 pix4
# row 130 :         pix4 pix4
# row 131 :         pix7 pix7
# row 132 :         pix7 pix7
# row 133 :         pix6 pix6
# row 134 :         pix9 pix9
# row 135 :         pix4 pix6           incorrect
# row 136 :         pix9 pix9
# row 137 :         pix0 pix0
# row 138 :         pix9 pix9
# row 139 :         pix5 pix5
# row 140 :         pix3 pix3
# row 141 :         pix5 pix5
# row 142 :         pix3 pix3
# row 143 :         pix2 pix2
# row 144 :         pix6 pix6
# row 145 :         pix8 pix8
# row 146 :         pix3 pix8           incorrect
# row 147 :         pix8 pix8
# row 148 :         pix4 pix4
# row 149 :         pix5 pix5
# row 150 :         pix2 pix2
# row 151 :         pix9 pix9
# row 152 :         pix3 pix3
# row 153 :         pix7 pix7
# row 154 :         pix1 pix1
# row 155 :         pix2 pix2
# row 156 :         pix5 pix5
# row 157 :         pix5 pix5
# row 158 :         pix0 pix0
# row 159 :         pix6 pix6
# row 160 :         pix3 pix3
# row 161 :         pix3 pix3
# row 162 :         pix5 pix5
# row 163 :         pix9 pix9
# row 164 :         pix4 pix4
# row 165 :         pix5 pix5
# row 166 :         pix8 pix3           incorrect
# row 167 :         pix0 pix0
# row 168 :         pix1 pix1
# row 169 :         pix8 pix8
# row 170 :         pix7 pix7
# row 171 :         pix6 pix6
# row 172 :         pix1 pix1
# row 173 :         pix0 pix0
# row 174 :         pix8 pix8
# row 175 :         pix8 pix8
# row 176 :         pix6 pix6
# row 177 :         pix7 pix7
# row 178 :         pix4 pix7           incorrect
# row 179 :         pix6 pix6
# row 180 :         pix0 pix0
# row 181 :         pix9 pix9
# row 182 :         pix1 pix1
# row 183 :         pix3 pix3
# row 184 :         pix5 pix5
# row 185 :         pix6 pix6
# row 186 :         pix4 pix4
# row 187 :         pix0 pix0
# row 188 :         pix9 pix9
# row 189 :         pix3 pix3
# row 190 :         pix0 pix0
# row 191 :         pix4 pix4
# row 192 :         pix5 pix5
# row 193 :         pix8 pix8
# row 194 :         pix1 pix1
# row 195 :         pix1 pix1
# row 196 :         pix3 pix3
# row 197 :         pix7 pix7
# row 198 :         pix9 pix9
# row 199 :         pix9 pix9
# row 200 :         pix7 pix7
# row 201 :         pix5 pix5
# row 202 :         pix8 pix8
# row 203 :         pix3 pix3
# row 204 :         pix3 pix3
# row 205 :         pix6 pix6
# row 206 :         pix7 pix7
# row 207 :         pix0 pix0
# row 208 :         pix1 pix1
# row 209 :         pix7 pix7
# row 210 :         pix1 pix1
# row 211 :         pix7 pix7
# row 212 :         pix6 pix6
# row 213 :         pix8 pix8
# row 214 :         pix7 pix7
# row 215 :         pix8 pix8
# row 216 :         pix8 pix8
# row 217 :         pix9 pix9
# row 218 :         pix6 pix6
# row 219 :         pix3 pix3
# row 220 :         pix8 pix8
# row 221 :         pix2 pix2
# row 222 :         pix9 pix9
# row 223 :         pix2 pix2
# row 224 :         pix4 pix4
# row 225 :         pix4 pix4
# row 226 :         pix2 pix2
# row 227 :         pix9 pix8           incorrect
# row 228 :         pix1 pix1
# row 229 :         pix0 pix0
# row 230 :         pix3 pix3
# row 231 :         pix3 pix3
# row 232 :         pix0 pix0
# row 233 :         pix0 pix0
# row 234 :         pix3 pix3
# row 235 :         pix0 pix0
# row 236 :         pix7 pix7
# row 237 :         pix6 pix6
# row 238 :         pix2 pix2
# row 239 :         pix1 pix1
# row 240 :         pix7 pix7
# row 241 :         pix3 pix9           incorrect
# row 242 :         pix8 pix8
# row 243 :         pix6 pix6
# row 244 :         pix6 pix6
# row 245 :         pix8 pix8
# row 246 :         pix8 pix8
# row 247 :         pix3 pix3
# row 248 :         pix8 pix8
# row 249 :         pix0 pix0
# row 250 :         pix7 pix7
# row 251 :         pix8 pix3           incorrect
# row 252 :         pix9 pix1           incorrect
# row 253 :         pix5 pix5
# row 254 :         pix1 pix1
# row 255 :         pix1 pix1
# row 256 :         pix5 pix5
# row 257 :         pix1 pix1
# row 258 :         pix0 pix0
# row 259 :         pix5 pix5
# row 260 :         pix1 pix1
# row 261 :         pix9 pix9
# row 262 :         pix9 pix9
# row 263 :         pix6 pix6
# row 264 :         pix7 pix7
# row 265 :         pix6 pix6
# row 266 :         pix6 pix6
# row 267 :         pix5 pix5
# row 268 :         pix1 pix1
# row 269 :         pix4 pix4
# row 270 :         pix5 pix5
# row 271 :         pix6 pix6
# row 272 :         pix1 pix1
# row 273 :         pix1 pix1
# row 274 :         pix3 pix9           incorrect
# row 275 :         pix6 pix6
# row 276 :         pix6 pix6
# row 277 :         pix2 pix2
# row 278 :         pix2 pix2
# row 279 :         pix5 pix5
# row 280 :         pix5 pix5
# row 281 :         pix6 pix6
# row 282 :         pix0 pix0
# row 283 :         pix2 pix2
# row 284 :         pix6 pix1           incorrect
# row 285 :         pix8 pix8
# row 286 :         pix0 pix0
# row 287 :         pix7 pix7
# row 288 :         pix7 pix7
# row 289 :         pix6 pix6
# row 290 :         pix9 pix9
# row 291 :         pix7 pix7
# row 292 :         pix2 pix2
# row 293 :         pix1 pix1
# row 294 :         pix0 pix0
# row 295 :         pix8 pix8
# row 296 :         pix6 pix6
# row 297 :         pix5 pix5
# row 298 :         pix4 pix4
# row 299 :         pix1 pix1
# row 300 :         pix7 pix7
# row 301 :         pix5 pix5
# row 302 :         pix6 pix6
# row 303 :         pix4 pix4
# row 304 :         pix1 pix1
# row 305 :         pix1 pix1
# row 306 :         pix0 pix0
# row 307 :         pix2 pix2
# row 308 :         pix2 pix2
# row 309 :         pix5 pix5
# row 310 :         pix0 pix0
# row 311 :         pix0 pix0
# row 312 :         pix7 pix7
# row 313 :         pix2 pix2
# row 314 :         pix6 pix6
# row 315 :         pix0 pix0
# row 316 :         pix7 pix7
# row 317 :         pix8 pix8
# row 318 :         pix0 pix0
# row 319 :         pix0 pix0
# row 320 :         pix2 pix2
# row 321 :         pix2 pix2
# row 322 :         pix6 pix6
# row 323 :         pix9 pix9
# row 324 :         pix8 pix3           incorrect
# row 325 :         pix6 pix6
# row 326 :         pix8 pix8
# row 327 :         pix9 pix9
# row 328 :         pix7 pix7
# row 329 :         pix7 pix4           incorrect
# row 330 :         pix3 pix3
# row 331 :         pix9 pix9
# row 332 :         pix7 pix7
# row 333 :         pix1 pix1
# row 334 :         pix6 pix6
# row 335 :         pix9 pix9
# row 336 :         pix4 pix4
# row 337 :         pix7 pix7
# row 338 :         pix6 pix6
# row 339 :         pix1 pix1
# row 340 :         pix3 pix3
# row 341 :         pix4 pix4
# row 342 :         pix8 pix8
# row 343 :         pix2 pix2
# row 344 :         pix9 pix9
# row 345 :         pix9 pix9
# row 346 :         pix1 pix1
# row 347 :         pix6 pix6
# row 348 :         pix5 pix5
# row 349 :         pix8 pix8
# row 350 :         pix9 pix9
# row 351 :         pix5 pix5
# row 352 :         pix1 pix1
# row 353 :         pix0 pix0
#
# Correct: 335 out of 354
# 335

# %%
#
# Ok!  We have tuned our RF to use the "best" parameters
#
# Now, we use ALL available data to train our final predictive model:
#
from sklearn import tree      # for decision trees
from sklearn import ensemble  # for random forests

# we should have best_depth and best_num_trees
rforest_model_final = ensemble.RandomForestClassifier(max_depth=best_depth, 
                                                      n_estimators=best_num_trees,
                                                      max_samples=0.5)

# we train the model (it's one line!)
rforest_model_final.fit(X_all, y_all)              # yay!  trained!
print(f"Built an RF classifier with depth={best_depth} and ntrees={best_num_trees}")
# Out:
# Built an RF classifier with depth=5 and ntrees=250

# %%
#
# final predictive model (random forests), with tuned parameters + ALL data incorporated
#

def predictive_model( Features, Model ):
    """ input: a list of four features 
                [ sepallen, sepalwid, petallen, petalwid ]
        output: the predicted species of iris, from
                  setosa (0), versicolor (1), virginica (2)
    """
    our_features = np.asarray([Features])                 # extra brackets needed
    predicted_species = Model.predict(our_features)       # The model's prediction!
    predicted_species = int(round(predicted_species[0]))  # unpack the extra brackets
    return predicted_species

# %%
#
# feature importances are often even more "important" than predictions...
#
#    Random forests can provide a much "smoother" measure of feature importance, since
#                   they integrate over so many individual models (each tree)
#
#    That is, it's much less likely that a feature will have 0% importance, unless it never varies
#

print(rforest_model_final.feature_importances_)
print()

# let's see them with each feature name:
IMPs = rforest_model_final.feature_importances_

# enumerate is great when you want indices _and_ elements!
for i, importance in enumerate(IMPs):
    perc = importance*100
    print(f"Feature {COLUMNS[i]:>12s} has {perc:>7.2f}% of the decision-making importance.")
# Out:
# [0.         0.00160269 0.02085767 0.00546173 0.00535999 0.01719214
#  0.0062916  0.00014354 0.         0.01031639 0.02930203 0.00252314
#  0.00841809 0.03093536 0.00252817 0.00011585 0.         0.00397258
#  0.01448392 0.02197871 0.02718164 0.05790636 0.00553821 0.00022277
#  0.         0.01481632 0.03732569 0.02182716 0.03678616 0.02651413
#  0.04140447 0.         0.         0.04290886 0.02741082 0.01475176
#  0.05185988 0.01847336 0.02596641 0.         0.         0.01420842
#  0.04005057 0.04813509 0.02128546 0.01566173 0.02126166 0.
#  0.         0.00106876 0.01503343 0.01405265 0.01045061 0.02382067
#  0.03319747 0.00132024 0.         0.00154963 0.02052118 0.00541149
#  0.02813294 0.03024834 0.01968988 0.00252215]
#
# Feature         pix0 has    0.00% of the decision-making importance.
# Feature         pix1 has    0.16% of the decision-making importance.
# Feature         pix2 has    2.09% of the decision-making importance.
# Feature         pix3 has    0.55% of the decision-making importance.
# Feature         pix4 has    0.54% of the decision-making importance.
# Feature         pix5 has    1.72% of the decision-making importance.
# Feature         pix6 has    0.63% of the decision-making importance.
# Feature         pix7 has    0.01% of the decision-making importance.
# Feature         pix8 has    0.00% of the decision-making importance.
# Feature         pix9 has    1.03% of the decision-making importance.
# Feature        pix10 has    2.93% of the decision-making importance.
# Feature        pix11 has    0.25% of the decision-making importance.
# Feature        pix12 has    0.84% of the decision-making importance.
# Feature        pix13 has    3.09% of the decision-making importance.
# Feature        pix14 has    0.25% of the decision-making importance.
# Feature        pix15 has    0.01% of the decision-making importance.
# Feature        pix16 has    0.00% of the decision-making importance.
# Feature        pix17 has    0.40% of the decision-making importance.
# Feature        pix18 has    1.45% of the decision-making importance.
# Feature        pix19 has    2.20% of the decision-making importance.
# Feature        pix20 has    2.72% of the decision-making importance.
# Feature        pix21 has    5.79% of the decision-making importance.
# Feature        pix22 has    0.55% of the decision-making importance.
# Feature        pix23 has    0.02% of the decision-making importance.
# Feature        pix24 has    0.00% of the decision-making importance.
# Feature        pix25 has    1.48% of the decision-making importance.
# Feature        pix26 has    3.73% of the decision-making importance.
# Feature        pix27 has    2.18% of the decision-making importance.
# Feature        pix28 has    3.68% of the decision-making importance.
# Feature        pix29 has    2.65% of the decision-making importance.
# Feature        pix30 has    4.14% of the decision-making importance.
# Feature        pix31 has    0.00% of the decision-making importance.
# Feature        pix32 has    0.00% of the decision-making importance.
# Feature        pix33 has    4.29% of the decision-making importance.
# Feature        pix34 has    2.74% of the decision-making importance.
# Feature        pix35 has    1.48% of the decision-making importance.
# Feature        pix36 has    5.19% of the decision-making importance.
# Feature        pix37 has    1.85% of the decision-making importance.
# Feature        pix38 has    2.60% of the decision-making importance.
# Feature        pix39 has    0.00% of the decision-making importance.
# Feature        pix40 has    0.00% of the decision-making importance.
# Feature        pix41 has    1.42% of the decision-making importance.
# Feature        pix42 has    4.01% of the decision-making importance.
# Feature        pix43 has    4.81% of the decision-making importance.
# Feature        pix44 has    2.13% of the decision-making importance.
# Feature        pix45 has    1.57% of the decision-making importance.
# Feature        pix46 has    2.13% of the decision-making importance.
# Feature        pix47 has    0.00% of the decision-making importance.
# Feature        pix48 has    0.00% of the decision-making importance.
# Feature        pix49 has    0.11% of the decision-making importance.
# Feature        pix50 has    1.50% of the decision-making importance.
# Feature        pix51 has    1.41% of the decision-making importance.
# Feature        pix52 has    1.05% of the decision-making importance.
# Feature        pix53 has    2.38% of the decision-making importance.
# Feature        pix54 has    3.32% of the decision-making importance.
# Feature        pix55 has    0.13% of the decision-making importance.
# Feature        pix56 has    0.00% of the decision-making importance.
# Feature        pix57 has    0.15% of the decision-making importance.
# Feature        pix58 has    2.05% of the decision-making importance.
# Feature        pix59 has    0.54% of the decision-making importance.
# Feature        pix60 has    2.81% of the decision-making importance.
# Feature        pix61 has    3.02% of the decision-making importance.
# Feature        pix62 has    1.97% of the decision-making importance.
# Feature        pix63 has    0.25% of the decision-making importance.

# %% [markdown]
# <br>
# <hr>
# <br>
#
# ### Final task: &nbsp; _Visualizing_ pixel-importance:
# + using your best Random Forest model, find the 64 _relative feature importances_ for all 64 of the digits' pixels!
#   + Show these as a list of 64 values (they will be difficult to imagine, but you will see that they vary a great deal, pixel-to-pixel)
# + Then, grab-and-adapt the code for visualizing individual digits in order to visualize the "importance image" of pixels...
# + that is, you'll create a heat map visualization, which is really just another image, of how relatively-important each of the 64 pixels is in your final Random Forest
#
# This visualization will be a "low-res image" similar to the digits, ***but it won't itself be a digit***
# + Instead, it will show _how much_ each of the 64 spots, across all of the 8x8 grids in the dataset, contribute in classifying each digit...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
sns.set_theme()


pixels_as_row = IMPs
#print("importances:\n", pixels_as_row)

pixels_as_image = np.reshape(pixels_as_row, (8,8))   # reshape into a 2d 8x8 array (image)
#print("\npixels as 2d numpy array (image):\n", pixels_as_image)

# create the figure, f, and the axes, ax:
f, ax = plt.subplots(figsize=(9, 6))

# colormap choice! Fun!   www.practicalpythonfordatascience.com/ap_seaborn_palette or seaborn.pydata.org/tutorial/color_palettes.html
our_colormap = sns.color_palette("light:b", as_cmap=True) 

# Draw a heatmap with the numeric values in each cell (make annot=False to remove the values)
sns.heatmap(pixels_as_image, annot=True, linewidths=.5, ax=ax, cmap=our_colormap)
# Out:
# <Axes: >

# %%
#
# That's it!  Welcome to the world of model-building workflows!!    
#
#             Our prediction?  We'll be back for more ML! 
#


# If you'd like, the EC is to run a DT/RF workflow on your own data...   (in hw6ec_modeler.ipynb)
